# %%
import os
import datetime
import warnings
import polars as pl
import pandas as pd
import altair as alt

from src.najdi_rok import najdi_rok
from src.pocet_stran import pocet_stran
from src.bez_bordelu import bez_bordelu
from src.alt_friendly import alt_friendly
from src.hezke_jmeno import hezke_jmeno
from src.kristi_promin import kristi_promin
from src.zjisti_vazbu import zjisti_vazbu

pl.Config(tbl_rows=100)
alt.data_transformers.disable_max_rows()
alt.themes.register('irozhlas', kristi_promin)
alt.themes.enable('irozhlas')
warnings.filterwarnings('ignore')

# %%
df = pl.read_parquet(os.path.join("data/cnb_sloupce","100.parquet"))
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","leader.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","008.parquet")), left_on="001", right_on="001", how="left")
df = df.to_pandas()
df = df[df["leader"].str[6].isin(["a", "t"])]
df = df[~df["leader"].str[7].isin(["b", "i", "s", " "])]
df = df[(df["008"].str[15:17] == "xr") & (df["008"].str[35:38] == "cze")]
df = pl.from_pandas(df)
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","020.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","022.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","041.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","245.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","300.parquet")), left_on="001", right_on="001", how="left")
df = df.explode("022_a").filter(pl.col("022_a").is_null())
df = df.with_columns(pl.col('008').map_elements(najdi_rok, return_dtype=int).alias('rok'))
df = df.with_columns(pl.col('300_a').map_elements(pocet_stran, return_dtype=int).alias('stran'))
df = df.with_columns(pl.col('245_a').map_elements(bez_bordelu, return_dtype=str))
df = df.explode("020_q").with_columns(pl.col("020_q").map_elements(zjisti_vazbu, return_dtype=str).alias('vazba'))
df = df.explode('245_p').with_columns(pl.col('245_p').map_elements(bez_bordelu, return_dtype=str))
print(len(df))
df = df.sort(by="rok")
df = df.filter((~pl.col("245_h").str.contains("grafika")) | pl.col("245_h").is_null()).unique(subset=["100_a","245_a"], keep="first")
print(len(df))
# Out:
# 795736
# 566175

# %%
vedral = df.filter(pl.col("100_7") == "mzk2003169026")

# %%
vedral
# Out:
# shape: (655, 52)
# ┌──────────┬───────────────┬───────────────┬────────────────┬───┬───────┬──────┬───────┬───────────┐
# │ 100_ind1 ┆ 100_a         ┆ 100_7         ┆ 100_4          ┆ … ┆ 300_3 ┆ rok  ┆ stran ┆ vazba     │
# │ ---      ┆ ---           ┆ ---           ┆ ---            ┆   ┆ ---   ┆ ---  ┆ ---   ┆ ---       │
# │ str      ┆ str           ┆ str           ┆ list[str]      ┆   ┆ str   ┆ i64  ┆ i64   ┆ str       │
# ╞══════════╪═══════════════╪═══════════════╪════════════════╪═══╪═══════╪══════╪═══════╪═══════════╡
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2006 ┆ 12    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 44    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 136   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 24    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 188   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 164   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 28    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 272   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 28    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2010 ┆ 64    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2010 ┆ 455   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2010 ┆ 48    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2006 ┆ 2     ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2004 ┆ 120   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2003 ┆ 28    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 35    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 24    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 161   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 168   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 68    ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2009 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 184   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2009 ┆ 64    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 152   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2009 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 28    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 12    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 8     ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2006 ┆ 52    ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2008 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2005 ┆ 124   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 24    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 8     ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 32    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 164   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2008 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2003 ┆ 100   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 124   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 160   ┆ brožovaná │
# │ …        ┆ …             ┆ …             ┆ …              ┆ … ┆ …     ┆ …    ┆ …     ┆ …         │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 40    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 204   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 28    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2002 ┆ 32    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 140   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 8     ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 8     ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 44    ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2006 ┆ 108   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2003 ┆ 56    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2008 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2005 ┆ 88    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 150   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 48    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 62    ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2006 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2005 ┆ 152   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 148   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 24    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2008 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 188   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut", "pbl"] ┆ … ┆ null  ┆ 2013 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 320   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 148   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 108   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 20    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 88    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2013 ┆ 188   ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 24    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 28    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 24    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2014 ┆ 8     ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2011 ┆ 160   ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 16    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2012 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2008 ┆ 1     ┆ null      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2005 ┆ 64    ┆ brožovaná │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ null  ┆ 2015 ┆ 12    ┆ brožovaná │
# └──────────┴───────────────┴───────────────┴────────────────┴───┴───────┴──────┴───────┴───────────┘

# %%
def jazyk(retezec):
    for x in retezec.split(" "):
        if "-" in x:
            return x.lower()

# %%
def ceho(retezec):
    slova = retezec.split(" ")
    temata = []
    for s in slova:
        if "-" not in s:
            if s.lower() != "slovník":
                temata.append(s)
    return ' '.join(temata)

# %%
vedral = vedral.with_columns(
    pl.col("245_a").map_elements(jazyk).alias('jazyk')
).with_columns(pl.col('245_a').map_elements(ceho).alias('ceho'))

# %%
vedral
# Out:
# shape: (655, 54)
# ┌──────────┬───────────────┬───────────────┬────────────────┬───┬───────┬───────────┬─────────────────┬────────────────┐
# │ 100_ind1 ┆ 100_a         ┆ 100_7         ┆ 100_4          ┆ … ┆ stran ┆ vazba     ┆ jazyk           ┆ ceho           │
# │ ---      ┆ ---           ┆ ---           ┆ ---            ┆   ┆ ---   ┆ ---       ┆ ---             ┆ ---            │
# │ str      ┆ str           ┆ str           ┆ list[str]      ┆   ┆ i64   ┆ str       ┆ str             ┆ str            │
# ╞══════════╪═══════════════╪═══════════════╪════════════════╪═══╪═══════╪═══════════╪═════════════════╪════════════════╡
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 12    ┆ brožovaná ┆ česko-německý   ┆ jmen hub       │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 44    ┆ brožovaná ┆ anglicko-český  ┆ hudební        │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 20    ┆ brožovaná ┆ francouzsko-čes ┆ nádorů         │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆ ký              ┆                │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 136   ┆ brožovaná ┆ česko-thajský   ┆ lékařský       │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 24    ┆ brožovaná ┆ řecko-český     ┆ třídění odpadů │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 188   ┆ null      ┆ estonsko-český  ┆ lékařský       │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 20    ┆ brožovaná ┆ portugalsko-čes ┆ ekonomických   │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆ ký              ┆ činností       │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆                 ┆ (NACE)         │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 164   ┆ null      ┆ lotyšsko-český  ┆ PRODCOM        │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 16    ┆ brožovaná ┆ španělsko-český ┆ jmen mořských  │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆                 ┆ živočichů      │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 28    ┆ brožovaná ┆ německo-český   ┆ rybářský       │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 20    ┆ brožovaná ┆ null            ┆ Medicína pro   │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆                 ┆ překladatele   │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 272   ┆ null      ┆ turecko-český   ┆ PRODCOM na CD  │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 28    ┆ brožovaná ┆ nizozemsko-česk ┆ ICF10          │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆ ý               ┆                │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 1     ┆ null      ┆ rusko-český     ┆ celní sazebník │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆                 ┆ na CD          │
# │ 1        ┆ Vedral, Jiří, ┆ mzk2003169026 ┆ ["aut"]        ┆ … ┆ 64    ┆ brožovaná ┆ anglicko-český  ┆ zpracování     │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆                 ┆

# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆                 ┆ zaměstnání     │
# │          ┆               ┆               ┆                ┆   ┆       ┆           ┆                 ┆ (standa…       │
# └──────────┴───────────────┴───────────────┴────────────────┴───┴───────┴───────────┴─────────────────┴────────────────┘

# %%
df = vedral.filter(pl.col('ceho').is_not_null() & pl.col('jazyk').is_not_null()).select(pl.col(['ceho','jazyk']))

# %%
df
# Out:
# shape: (632, 2)
# ┌─────────────────────────────────┬──────────────────────┐
# │ ceho                            ┆ jazyk                │
# │ ---                             ┆ ---                  │
# │ str                             ┆ str                  │
# ╞═════════════════════════════════╪══════════════════════╡
# │ jmen hub                        ┆ česko-německý        │
# │ hudební                         ┆ anglicko-český       │
# │ nádorů                          ┆ francouzsko-český    │
# │ lékařský                        ┆ česko-thajský        │
# │ třídění odpadů                  ┆ řecko-český          │
# │ lékařský                        ┆ estonsko-český       │
# │ ekonomických činností (NACE)    ┆ portugalsko-český    │
# │ PRODCOM                         ┆ lotyšsko-český       │
# │ jmen mořských živočichů         ┆ španělsko-český      │
# │ rybářský                        ┆ německo-český        │
# │ PRODCOM na CD                   ┆ turecko-český        │
# │ ICF10                           ┆ nizozemsko-český     │
# │ celní sazebník na CD            ┆ rusko-český          │
# │ zpracování informací            ┆ anglicko-český       │
# │ přírodovědný                    ┆ seversko-český       │
# │ nádorů                          ┆ španělsko-český      │
# │ filmový a televizní             ┆ česko-anglický       │
# │ biologický                      ┆ česko-dánský         │
# │ biologický                      ┆ finsko-český         │
# │ jmen rostlin                    ┆ skotsko-český        │
# │ pivovarský                      ┆ německo-český        │
# │ divadelní                       ┆ anglicko-český       │
# │ jmen jehličnanů                 ┆ anglicko-český       │
# │ veřejných zakázek CPV           ┆ maltsko-český        │
# │ vnější příčiny nemocnosti a úm… ┆ ázerbajdžánsko-český │
# │ jmen ptáků                      ┆ portugalsko-český    │
# │ jmen ryb                        ┆ švédsko-český        │
# │ biologický na CD                ┆ rusko-český          │
# │ zemědělské ekonomiky            ┆ anglicko-český       │
# │ PRODCOM                         ┆ chorvatsko-český     │
# │ veřejných zakázek CPV           ┆ maďarsko-český       │
# │ přírodovědný bez latiny na CD   ┆ rusko-český          │
# │ chráněných zvířat a rostlin     ┆ bulharsko-český      │
# │ z oboru masného průmyslu        ┆ anglicko-český       │
# │ části strojů                    ┆ anglicko-český       │
# │ subjaderná fyzika               ┆ německo-český        │
# │ všeobecný neslovník na CD       ┆ latinsko-český       │
# │ nádorů                          ┆ maďarsko-český       │
# │ třídění odpadů                  ┆ lotyšsko-český       │
# │ ICF                             ┆ polsko-český         │
# │ počítačový                      ┆ německo-český        │
# │ zaměstnání ISCO 08 KZAM         ┆ slovensko-český      │
# │ chemický na CD                  ┆ anglicko-český       │
# │ škůdců                          ┆ latinsko-český       │
# │ lékařský                        ┆ švédsko-český        │
# │ lékařský                        ┆ bulharsko-český      │
# │ zemědělský                      ┆ arabsko-český        │
# │ PRODCOM                         ┆ bosensko-český       │
# │ třídění odpadů                  ┆ polsko-český         │
# │ mikrobiologický slovníček       ┆ anglicko-český       │
# │ …                               ┆ …                    │
# │ veřejných zakázek CPV           ┆ slovinsko-český      │
# │ slang roku 1942                 ┆ anglicko-český       │
# │ zaměstnání FEOR08               ┆ maďarsko-český       │
# │ celní sazebník                  ┆ slovensko-český      │
# │ jmen rostlin                    ┆ česko-korejský       │
# │ lékařský ICD 10                 ┆ arménsko-český       │
# │ lékařský                        ┆ čínsko-český         │
# │ povolání ISCO 08                ┆ lotyšsko-český       │
# │ jaderné techniky a technologie  ┆ anglicko-český       │
# │ International Standard Classif… ┆ thajsko-český        │
# │ jmen ptáků                      ┆ rusko-český          │
# │ ICF                             ┆ portugalsko-český    │
# │ ICF                             ┆ turecko-český        │
# │ lékařský                        ┆ lotyšsko-český       │
# │ třídění odpadů                  ┆ slovensko-český      │
# │ jmen ptáků                      ┆ česko-německý        │
# │ biologický taxonomický          ┆ německo-český        │
# │ na CD                           ┆ anglicko-český       │
# │ lékařské přístroje              ┆ anglicko-český       │
# │ veřejných zakázek CPV           ┆ litevsko-český       │
# │ mořských živočichů FAO          ┆ francouzsko-český    │
# │ celní sazebník na CD            ┆ čínsko-český         │
# │ jmen ptáků                      ┆ česko-estonský       │
# │ zemědělská ekonomika            ┆ česko-anglický       │
# │ zdravotnický na CD              ┆ německo-český        │
# │ zemědělský                      ┆ korejsko-český       │
# │ zemědělský na CD                ┆ portugalsko-český    │
# │ jmen zvířat                     ┆ japonsko-český       │
# │ přírodovědný na CD              ┆ francouzsko-český    │
# │ lékařský                        ┆ makedonsko-český     │
# │ zemědělský na CD                ┆ arabsko-český        │
# │ zdravotnický na CD              ┆ francouzsko-český    │
# │ lékařský                        ┆ islandsko-český      │
# │ veřejných zakázek CPV           ┆ německo-český        │
# │ jmen ptáků                      ┆ česko-švédský        │
# │ ekonomických činností (NACE)    ┆ maďarsko-český       │
# │ celní sazebník                  ┆ španělsko-český      │
# │ nádorů                          ┆ slovinsko-český      │
# │ chirurgických výkonů            ┆ německo-český        │
# │ lékařský                        ┆ thajsko-český        │
# │ klasifikace zaměstnání          ┆ portugalsko-český    │
# │ slovních i.e. chlazení a ohřev… ┆ italsko-český        │
# │ katalog odpadů                  ┆ slovinsko-český      │
# │ ekologický                      ┆ italsko-český        │
# │ ICF                             ┆ bosensko-český       │
# │ veřejných zakázek CPV           ┆ nizozemsko-český     │
# │ zaměstnání ISCO 08              ┆ bulharsko-český      │
# │ zdravotnický na CD              ┆ nizozemsko-český     │
# │ biologický na CD                ┆ polsko-český         │
# │ klasifikace zaměstnání (standa… ┆ bosensko-česká       │
# └─────────────────────────────────┴──────────────────────┘

# %%
temata = df.group_by('ceho').len().sort(by='len',descending=True).head(20)
temata
# Out:
# shape: (20, 2)
# ┌─────────────────────────────────┬─────┐
# │ ceho                            ┆ len │
# │ ---                             ┆ --- │
# │ str                             ┆ u32 │
# ╞═════════════════════════════════╪═════╡
# │ jmen ptáků                      ┆ 36  │
# │ katalog odpadů                  ┆ 26  │
# │ biologický                      ┆ 26  │
# │ ekonomických činností (NACE)    ┆ 25  │
# │ lékařský                        ┆ 24  │
# │ PRODCOM                         ┆ 19  │
# │ celní sazebník                  ┆ 19  │
# │ veřejných zakázek CPV           ┆ 18  │
# │ třídění odpadů                  ┆ 18  │
# │ zemědělský                      ┆ 16  │
# │ zaměstnání ISCO 08              ┆ 13  │
# │ nádorů                          ┆ 12  │
# │ zemědělský na CD                ┆ 10  │
# │ ICF                             ┆ 8   │
# │ ICF 10                          ┆ 7   │
# │ veřejných zakázek (CPV)         ┆ 7   │
# │ PRODCOM na CD                   ┆ 7   │
# │ jmen rostlin                    ┆ 7   │
# │ jmen hub                        ┆ 6   │
# │ vnější příčiny nemocnosti a úm… ┆ 6   │
# └─────────────────────────────────┴─────┘

# %%
reci = df.filter(pl.col('jazyk').str.contains('český')).group_by('jazyk').len().sort(by='len',descending=True).head(20)
reci
# Out:
# shape: (20, 2)
# ┌───────────────────┬─────┐
# │ jazyk             ┆ len │
# │ ---               ┆ --- │
# │ str               ┆ u32 │
# ╞═══════════════════╪═════╡
# │ anglicko-český    ┆ 129 │
# │ německo-český     ┆ 48  │
# │ francouzsko-český ┆ 21  │
# │ španělsko-český   ┆ 19  │
# │ italsko-český     ┆ 19  │
# │ portugalsko-český ┆ 18  │
# │ polsko-český      ┆ 15  │
# │ maďarsko-český    ┆ 14  │
# │ nizozemsko-český  ┆ 13  │
# │ rusko-český       ┆ 13  │
# │ finsko-český      ┆ 13  │
# │ slovinsko-český   ┆ 13  │
# │ turecko-český     ┆ 12  │
# │ slovensko-český   ┆ 11  │
# │ japonsko-český    ┆ 11  │
# │ latinsko-český    ┆ 11  │
# │ švédsko-český     ┆ 10  │
# │ bulharsko-český   ┆ 10  │
# │ dánsko-český      ┆ 10  │
# │ estonsko-český    ┆ 10  │
# └───────────────────┴─────┘

# %%
dilo = []
for t in temata.select(pl.col('ceho')).to_series().to_list():
    slovnik = {}
    for r in reci:

# %%
pl.DataFrame([
    {"finsko-český":
     {"jmen hub": 0, "jmen rostlin": 1},
    },
    {"rusko-český":
     {"jmen hub": 1, "jmen rostlin": 0},
    }
])
# Out:
# shape: (2, 2)
# ┌──────────────┬─────────────┐
# │ finsko-český ┆ rusko-český │
# │ ---          ┆ ---         │
# │ struct[2]    ┆ struct[2]   │
# ╞══════════════╪═════════════╡
# │ {0,1}        ┆ null        │
# │ null         ┆ {1,0}       │
# └──────────────┴─────────────┘

# %%
[
    {"finsko-český":
     {"jmen hub": 0, "jmen rostlin": 1},
    },
    {"rusko-český":
     {"jmen hub": 1, "jmen rostlin": 0},
    }
]
# Out:
# [{'finsko-český': {'jmen hub': 0, 'jmen rostlin': 1}},
#  {'rusko-český': {'jmen hub': 1, 'jmen rostlin': 0}}]

# %%
{"rusko-český":
     {"jmen hub": 1, "jmen rostlin": 0},
    }
# Out:
# {'rusko-český': {'jmen hub': 1, 'jmen rostlin': 0}}
