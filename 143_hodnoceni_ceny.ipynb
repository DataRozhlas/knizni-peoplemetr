# %%
import os
import pandas as pd

# %% [markdown]
# Co sledovat:
# - [Kniha roku Deníku N](https://denikn.cz/1575113/knihy-roku-deniku-n-2024-hlasujte-o-nejdulezitejsich-literarnich-pocinech/?ref=list)

# %%
gr = pd.read_csv(os.path.join('data','goodreads-hodnoceni.csv'))

# %%
gr[gr['GR_title'].str.contains('Flora')]
# Out:
# Empty DataFrame
# Columns: [GR_isbn, GR_date, GR_title, GR_rating, GR_ratings_count, GR_reviews, GR_published, GR_1_stars, GR_2_stars, GR_3_stars, GR_4_stars, GR_5_stars]
# Index: []

# %%
dk = pd.read_csv(os.path.join('data','databazeknih-hodnoceni.csv'))

# %%
dk[dk['DK_titul'].str.contains('Flora')]
# Out:
#             DK_isbn              DK_date DK_titul  DK_rating  \
# 52374  9.788076e+12  2024-11-11 03:58:56    Flora      100.0
# 53878  9.788076e+12  2024-11-12 02:07:26    Flora      100.0
#
#        DK_ratings_count                         DK_tags  DK_Právě_čtených  \
# 52374               4.0  ['Novely', 'Literatura česká']               2.0
# 53878               4.0  ['Novely', 'Literatura česká']               2.0
#
#        DK_Přečtených  DK_Čtenářské_výzvě  DK_Knihotéce  DK_Chystám_se_číst  \
# 52374            4.0                 NaN           2.0                13.0
# 53878            4.0                 NaN           3.0                16.0
#
#        DK_Chci_si_koupit  DK_dalších_seznamech  DK_Doporučených  \
# 52374                6.0                   NaN              NaN
# 53878                6.0                   NaN              NaN
#
#            DK_autorstvo
# 52374  ['Jonáš Zbořil']
# 53878  ['Jonáš Zbořil']

# %%
dk[dk['DK_titul'].str.contains('Tahle kniha ti změní život')]
# Out:
#             DK_isbn              DK_date                    DK_titul  \
# 40093  9.788028e+12  2024-09-30 04:02:12  Tahle kniha ti změní život
# 40806  9.788028e+12  2024-10-07 03:31:12  Tahle kniha ti změní život
# 42566  9.788028e+12  2024-10-14 03:26:57  Tahle kniha ti změní život
# 46462  9.788028e+12  2024-10-21 04:13:59  Tahle kniha ti změní život
# 47918  9.788028e+12  2024-10-28 03:16:39  Tahle kniha ti změní život
# 49279  9.788028e+12  2024-11-04 03:41:51  Tahle kniha ti změní život
# 52919  9.788028e+12  2024-11-11 04:04:43  Tahle kniha ti změní život
# 53754  9.788028e+12  2024-11-12 02:06:16  Tahle kniha ti změní život
#
#        DK_rating  DK_ratings_count                          DK_tags  \
# 40093       80.0               2.0  ['Literatura česká', 'Příběhy']
# 40806       84.0               5.0  ['Literatura česká', 'Příběhy']
# 42566       73.0              12.0  ['Literatura česká', 'Příběhy']
# 46462       75.0              23.0  ['Literatura česká', 'Příběhy']
# ...
