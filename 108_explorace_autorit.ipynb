# %%
import os
import pandas as pd

# %%
df = pd.read_parquet(os.path.join("data","aut_vyber.parquet"))

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
df['100_a']
# Out:
# 001
# jk01010001           [Abraham, Jiří,]
# jk01010002          [Abraham, Josef,]
# jk01010003          [Abraham, Pavel,]
# jk01010004          [Absolon, Josef,]
# jk01010005          [Absolon, Karel,]
#                          ...
# jo20241238555      [Svoboda, Michal,]
# mzk20241238556                   None
# mzk20241238557     [Dwyer, Charlotte]
# mzk20241238558     [Langdana, Hannah]
# jo20241238559     [Jindrová, Milena,]
# Name: 100_a, Length: 1209486, dtype: object

# %%
obsazenost = {}
for c in df.columns.to_list():
    obsazenost[c] = len(df[df[c].notnull()]) / len(df)
obsazenost = pd.Series(obsazenost)
obsazenost.sort_values()
# Out:
# 370_t       0.003790
# 370_s       0.005469
# 500_i       0.010861
# 400_q       0.013812
# 500_a       0.014530
# 500_ind1    0.014530
# 370_b       0.022358
# 400_i       0.025754
# 373_a       0.034625
# 370_f       0.036187
# 370_a       0.055769
# 024_2       0.071972
# 024_a       0.071972
# 856_u       0.130307
# 046_g       0.205324
# 400_d       0.209071
# 400_ind1    0.253673
# 400_a       0.253674
# 374_a       0.298812
# 375_a       0.312793
# 377_a       0.342697
# 372_a       0.351468
# 046_f       0.503109
# 100_d       0.541426
# 370_c       0.548608
# 100_7       0.777062
# 100_a       0.777062
# 678_a       0.787416
# leader      1.000000
# dtype: float64

# %%
df[['400_d','400_i']].dropna().sample(40)
# Out:
#                                                                400_d  \
# 001
# jo2018983210       [1590-1660, 1590-1660, 1590-1660, 1590-1660, 1...
# mzk20181007365                                 [1977-, 1977-, 1977-]
# xx0106028                                                    [1969-]
# xx0173180                          [1761-1840, 1761-1840, 1761-1840]
# utb20191050879                                               [1976-]
# jk01110018                                               [1839-1895]
# xx0080918                                             [1972-, 1972-]
# jn20000602451                                                [1961-]
# xx0146750                                     [1907-1969, 1907-1969]
# jcu2016910380                                                [1976-]
# xx0243425                                                    [1973-]
# ola2010573836                                                [1968-]
# ...

# %%
df[df['100_a'].astype(str).str.contains('Macl, Ondřej', na=False)]
# Out:
#                  046_f             500_a             100_7  \
# 001
# pna2017973707   [1989]  [Rejdiš, Baban,]   [pna2017973707]
# aun20231198978    None              None  [aun20231198978]
#
#                                                             372_a 500_ind1  \
# 001
# pna2017973707   [poezie, slam poetry, performance (umění), lit...      [1]
# aun20231198978                                               None     None
#
#                370_b            400_a                    leader  \
# 001
# pna2017973707   None             None       cz  a22     n  4500
# aun20231198978  None  [Macl, Ondřej,]       nz  a22     n  4500
#
#                                         024_a  \
# 001
# pna2017973707   [0000000499377720, Q55102163]
# aun20231198978                           None
#
#                                                             374_a    100_d  \
# 001
# pna2017973707   [básníci, literární kritici, publicisté, básní...  [1989-]
# ...

# %%
df[df['100_a'].astype(str).str.contains('Diviš, Ivan', na=False)]
# Out:
#                 046_f 500_a            100_7 372_a 500_ind1 370_b 400_a  \
# 001
# jk01022321     [1924]  None     [jk01022321]  None     None  None  None
# jn19981000665    None  None  [jn19981000665]  None     None  None  None
# aun2008462799    None  None  [aun2008462799]  None     None  None  None
# aun2018996756    None  None  [aun2018996756]  None     None  None  None
#
#                                  leader                        024_a 374_a  \
# 001
# jk01022321          cz  a22     n  4500  [0000000110597830, Q709766]  None
# jn19981000665       nz  a22     n  4500                         None  None
# aun2008462799       nz  a22     n  4500                         None  None
# aun2018996756       nz  a22     n  4500                         None  None
#
#                       100_d  \
# 001
# jk01022321      [1924-1999]
# jn19981000665          None
# aun2008462799  [1924-1999.]
# aun2018996756  [1924-1999.]
#
# ...

# %%
df[df['100_a'].astype(str).str.contains('Biler, Stanislav', na=False)]
# Out:
#                 046_f 500_a            100_7         372_a 500_ind1 370_b  \
# 001
# mzk2015855552  [1982]  None  [mzk2015855552]  [sociologie]     None  None
#
#               400_a                    leader 024_a  \
# 001
# mzk2015855552  None       cz  a22     n  4500  None
#
#                                                 374_a    100_d  \
# 001
# mzk2015855552  [sociologové, publicisté, spisovatelé]  [1982-]
#
#                                                            678_a 400_q 370_f  \
# 001
# mzk2015855552  [Narozen 22. 1. 1982. Sociolog, spisovatel a p...  None  None
#
#                375_a                                            856_u 500_i  \
# 001
# mzk2015855552  [muž]  [https://cs.wikipedia.org/wiki/Stanislav_Biler]  None
#
#               046_g 400_d 370_a  377_a 370_s 400_i    370_c 400_ind1 024_2  \
# 001
# mzk2015855552  None  None  None  [cze]  None  None  [Česko]     None  None
#
#                              100_a 370_t 373_a
# 001
# ...

# %%
df[df['100_a'].astype(str).str.contains('Kašpárek, Michal', na=False)]
# Out:
#                 046_f 500_a            100_7 372_a 500_ind1 370_b 400_a  \
# 001
# jx20100301005  [1984]  None  [jx20100301005]  None     None  None  None
#
#                                  leader 024_a 374_a    100_d  \
# 001
# jx20100301005       cz  a22     n  4500  None  None  [1984-]
#
#                                                            678_a 400_q 370_f  \
# 001
# jx20100301005  [Narozen 1984 v Brně. Publicista a textař. Aut...  None  None
#
#               375_a 856_u 500_i 046_g 400_d 370_a 377_a 370_s 400_i    370_c  \
# 001
# jx20100301005  None  None  None  None  None  None  None  None  None  [Česko]
#
#               400_ind1 024_2                100_a 370_t 373_a
# 001
# jx20100301005     None  None  [Kašpárek, Michal,]  None  None

# %%
df
# Out:
#                  046_f 500_a             100_7  \
# 001
# jk01010001      [1931]  None      [jk01010001]
# jk01010002      [1890]  None      [jk01010002]
# jk01010003      [1957]  None      [jk01010003]
# jk01010004      [1889]  None      [jk01010004]
# jk01010005      [1877]  None      [jk01010005]
# ...                ...   ...               ...
# jo20241238555   [1977]  None   [jo20241238555]
# mzk20241238556    None  None              None
# mzk20241238557    None  None  [mzk20241238557]
# mzk20241238558    None  None  [mzk20241238558]
# jo20241238559   [1944]  None   [jo20241238559]
#
#                                                             372_a 500_ind1  \
# 001
# jk01010001                                                   None     None
# jk01010002                                                   None     None
# jk01010003                                                   None     None
# jk01010004                                                   None     None
# ...
