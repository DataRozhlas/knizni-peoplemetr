# %%
import os
import re
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_parquet(os.path.join("data","cnb_ceska_proza.parquet"))
len(df)
# Out:
# 47419

# %%
df = df[df['rok'] >= 1900]

# %%
df = df.sort_values(by='rok')
df = df.drop_duplicates(subset=['autorstvo','titul'], keep='first')
len(df)
# Out:
# 43752

# %%
df = df.merge(pd.read_parquet(os.path.join("data/cnb_sloupce","246.parquet")), left_index=True, right_index=True, how="left")
len(df)
# Out:
# 43752

# %%
df[df['246_a'].notnull()]
# Out:
#                    rok                                              titul  \
# 001
# bknzdr05028     1900.0         Karla Havlíčka Borovského Politické spisy.
# nkc20142637949  1900.0                            Zločin tajného oddělení
# bkn20011003393  1900.0  Zajímavé vzpomínky na činnost soudruhův a orga...
# bkn20011003391  1900.0  Zajímavé vzpomínky na činnost soudruhův a orga...
# cpk19970277121  1900.0                                       Pestré květy
# ...                ...                                                ...
# nkc20243632045  2024.0                                       Ve výslužbě.
# nkc20243613143  2024.0                         Řecké báje a Pověsti české
# nkc20243630865  2024.0                                          Tři pruty
# nkc20243631028  2024.0  Dosvětáci, aneb, Moře, to nejni Tálinskej rybn...
# nkc20243626136  2024.0                                        Ahaerův meč
#
#                                   autorstvo  autorstvo_kod 902_a 902_q 902_z  \
# 001
# bknzdr05028         Havlíček Borovský Karel     jk01040361   NaN   NaN   NaN
# nkc20142637949                 Projsa Pavel     jk01101264   NaN   NaN   NaN
# bkn20011003393                  Hybeš Josef     jk01043378   NaN   NaN   NaN
# bkn20011003391                  Hybeš Josef     jk01043378   NaN   NaN   NaN
# cpk19970277121  Vykoukal František Vladimír     jk01151175   NaN   NaN   NaN
# ...                                     ...            ...   ...   ...   ...
# nkc20243632045                 Goffa Martin      xx0165664   NaN   NaN   NaN
# nkc20243613143              Bárta František           None   NaN   NaN   NaN
# nkc20243630865                Černík Martin      xx0322605   NaN   NaN   NaN
# nkc20243631028                   Vlk Václav  ola2004220062   NaN   NaN   NaN
# nkc20243626136              Draug Martin T.      xx0322648   NaN   NaN   NaN
#
#                246_ind1 246_ind2  \
# 001
# bknzdr05028      [3, 3]   [0, 0]
# nkc20142637949      [3]      [0]
# bkn20011003393   [3, 3]   [0, 4]
# bkn20011003391      [3]      [4]
# cpk19970277121      [1]      [4]
# ...                 ...      ...
# nkc20243632045   [3, 3]   [0, 0]
# nkc20243613143      [3]      [0]
# nkc20243630865   [3, 3]      [0]
# nkc20243631028      [3]      [0]
# nkc20243626136      [3]      [0]
#
#                                                             246_a 246_i  \
# 001
# bknzdr05028         [Politické spisy, Pražské noviny (1846-1848)]  None
# nkc20142637949                 [Román vyděděnky z rodinného krbu]  None
# bkn20011003393  [Z prvních dob hnutí soudruhů českých, Tajné s...  None
# bkn20011003391  [Zajímavé vzpomínky na činnost soudruhův a org...  None
# cpk19970277121                         [Povídky ze zahrady mládí]  None
# ...                                                           ...   ...
# nkc20243632045  [Zmizelá, aneb První poslední případ, První po...  None
# nkc20243613143                                    [Pověsti české]  None
# nkc20243630865                                    [3 pruty, IIIP]  None
# nkc20243631028               [Moře, to nejni Tálinskej rybník...]  None
# nkc20243626136                            [Příběhy jedné družiny]  None
#
#                                                             246_b 246_n 246_p  \
# 001
# bknzdr05028                                                  None  None  None
# nkc20142637949                                               None  None  None
# bkn20011003393  [None, úryvky z bojů české sociální demokracie...  None  None
# bkn20011003391                                               None  None  None
# cpk19970277121                                               None  None  None
# ...                                                           ...   ...   ...
# nkc20243632045                                               None  None  None
# nkc20243613143                                               None  None  None
# nkc20243630865                                               None  None  None
# nkc20243631028                                               None  None  None
# nkc20243626136                                               None  None  None
#
#                246_g 246_f 246_h 246_y 246_k
# 001
# bknzdr05028     None  None  None  None  None
# nkc20142637949  None  None  None  None  None
# bkn20011003393  None  None  None  None  None
# bkn20011003391  None  None  None  None  None
# cpk19970277121  None  None  None  None  None
# ...              ...   ...   ...   ...   ...
# nkc20243632045  None  None  None  None  None
# nkc20243613143  None  None  None  None  None
# nkc20243630865  None  None  None  None  None
# nkc20243631028  None  None  None  None  None
# nkc20243626136  None  None  None  None  None
#
# [6074 rows x 19 columns]
