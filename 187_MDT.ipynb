# %%
import polars as pl

# %%
df = pl.read_parquet("data/cnb_vyber.parquet")

# %%
df.sample(10)
# Out:
# shape: (10, 62)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ 008          ┆ 020_a        ┆ 020_c        ┆ 020_q       ┆ … ┆ 928_a       ┆ 964_a       ┆ leader      ┆ 001         │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ ---         │
# │ str          ┆ list[str]    ┆ list[str]    ┆ list[str]   ┆   ┆ list[str]   ┆ list[str]   ┆ str         ┆ str         │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 990614s1936  ┆ null         ┆ null         ┆ null        ┆ … ┆ null        ┆ null        ┆ nam a22     ┆ bk193606049 │
# │ xr           ┆              ┆              ┆             ┆   ┆             ┆             ┆ 1  4500     ┆             │
# ...

# %%
len(df.select(pl.col(["072_a","072_x"])).explode(["072_a","072_x"]).drop_nulls().unique())
# Out:
# 638

# %%
df.select(pl.col(["072_a","072_x"])).explode(["072_a","072_x"]).drop_nulls().unique().sample(10)
# Out:
# shape: (10, 2)
# ┌─────────────────┬─────────────────────────────────┐
# │ 072_a           ┆ 072_x                           │
# │ ---             ┆ ---                             │
# │ str             ┆ str                             │
# ╞═════════════════╪═════════════════════════════════╡
# │ 780.92          ┆ Persons associated with music   │
# │ 811.34          ┆ Vymřelé jazyky neznámé klasifi… │
# │ 94(46)          ┆ Dějiny států a území na Pyrene… │
# │ 683             ┆ Železářství. Zámečnictví. Topn… │
# │ 780.901-780.905 ┆ Periods of stylistic developme… │
# │ 154             ┆ Subconscious and altered state… │
# │ 791             ┆ Film. Cirkus. Lidová zábava     │
# │ 316.36          ┆ Manželství a rodina. Sexuální … │
# │ 21              ┆ Prehistorická a primitivní náb… │
# │ 316.77          ┆ Informační věda                 │
# └─────────────────┴─────────────────────────────────┘

# %%
df.select(pl.col(["072_a","072_x"])).explode(["072_a","072_x"]).drop_nulls().unique().write_csv('data/temata_czen.csv')

# %%
nulaosmdesat = pl.read_parquet("data/cnb_sloupce/080.parquet")

# %%
nulaosmdesat
# Out:
# shape: (1_032_857, 5)
# ┌─────────────────────────────────┬───────────────────────────────┬───────┬───────────┬────────────────┐
# │ 080_a                           ┆ 080_2                         ┆ 080_x ┆ 080_ind1  ┆ 001            │
# │ ---                             ┆ ---                           ┆ ---   ┆ ---       ┆ ---            │
# │ list[str]                       ┆ list[str]                     ┆ str   ┆ list[str] ┆ str            │
# ╞═════════════════════════════════╪═══════════════════════════════╪═══════╪═══════════╪════════════════╡
# │ ["352/353", "338.46"]           ┆ ["undef", "undef"]            ┆ null  ┆ null      ┆ ck8300078      │
# │ ["339.923", "338.45"]           ┆ ["undef", "undef"]            ┆ null  ┆ null      ┆ ck8300080      │
# │ ["339.923"]                     ┆ ["undef"]                     ┆ null  ┆ null      ┆ ck8300081      │
# │ ["343.3/.7", "343", … "(082)"]  ┆ ["MRF", "MRF", … "MRF"]       ┆ null  ┆ null      ┆ ck8300082      │
# ...

# %%
nulaosmdesat.filter(~pl.col('080_x').is_null())
# Out:
# shape: (5, 5)
# ┌────────────────┬───────────┬───────────┬───────────┬────────────────┐
# │ 080_a          ┆ 080_2     ┆ 080_x     ┆ 080_ind1  ┆ 001            │
# │ ---            ┆ ---       ┆ ---       ┆ ---       ┆ ---            │
# │ list[str]      ┆ list[str] ┆ str       ┆ list[str] ┆ str            │
# ╞════════════════╪═══════════╪═══════════╪═══════════╪════════════════╡
# │ ["913"]        ┆ ["MRF"]   ┆ (437.6)   ┆ null      ┆ nos190135946   │
# │ ["502:912.43"] ┆ ["MRF"]   ┆ (437.316) ┆ null      ┆ cpc20142633715 │
# │ ["502:912.43"] ┆ ["MRF"]   ┆ (437.315) ┆ null      ┆ cpc20142633876 │
# │ ["502:912.43"] ┆ ["MRF"]   ┆ (437.315) ┆ null      ┆ cpc20142633880 │
# │ ["550:912.43"] ┆ ["MRF"]   ┆ (437.315) ┆ null      ┆ cpc20142633922 │
# └────────────────┴───────────┴───────────┴───────────┴────────────────┘

# %%
sestsetpadesat = pl.read_parquet("data/cnb_sloupce/650.parquet")

# %%
sestsetpadesat.drop_nulls().sample(10)
# Out:
# shape: (10, 9)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ 650_ind1     ┆ 650_ind2     ┆ 650_a        ┆ 650_7       ┆ … ┆ 650_x       ┆ 650_z       ┆ 650_y       ┆ 001         │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ ---         │
# │ list[str]    ┆ list[str]    ┆ list[str]    ┆ list[str]   ┆   ┆ list[str]   ┆ list[str]   ┆ list[str]   ┆ str         │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ ["0", "0", … ┆ ["7", "7", … ┆ ["režisérky" ┆ ["ph871606" ┆ … ┆ [null,      ┆ ["Česko",   ┆ ["20.-21.   ┆ nkc20172958 │
# │ "0"]         ┆ "9"]         ┆ ,            ┆ ,           ┆   ┆ null, …     ┆ "Česko", …  ┆ století",   ┆ 439         │
# ...

# %%
sestsetpadesat.drop_nulls().select(pl.col(["650_a","650_7","650_2"])).explode(["650_a","650_7","650_2"]).filter(pl.col("650_2") == "czenas").unique().select(pl.col(["650_a","650_7"]))
# Out:
# shape: (5_493, 2)
# ┌────────────────────────┬──────────┐
# │ 650_a                  ┆ 650_7    │
# │ ---                    ┆ ---      │
# │ str                    ┆ str      │
# ╞════════════════════════╪══════════╡
# │ prezidentské volby     ┆ ph115883 │
# │ měšťanská rodina       ┆ ph123116 │
# │ scénografie            ┆ ph116114 │
# │ rozvoj venkova         ┆ ph136666 │
# │ cisterciácké kláštery  ┆ ph119244 │
# │ …                      ┆ …        │
# │ vysokoškolské studium  ┆ ph127279 │
# │ kati                   ┆ ph121522 │
# │ soukromí zemědělci     ┆ ph125876 │
# │ architektonický design ┆ ph114079 │
# │ hra na klavír          ┆ ph135165 │
# └────────────────────────┴──────────┘

# %%
sestsetpadesat.drop_nulls().select(pl.col(["650_a","650_7","650_2"])).explode(["650_a","650_7","650_2"]).filter(pl.col("650_2") == "czenas").unique().select(pl.col(["650_a","650_7"])).write_csv('data/temata_czenas.csv')
