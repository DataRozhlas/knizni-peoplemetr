# %%
import os
import json
import pandas as pd

# %%
df = pd.read_csv(os.path.join('data_raw','martinus_raw.csv'))

# %%
df.columns
# Out:
# Index(['M_titul', 'M_autorstvo', 'M_anotace', 'M_počet_stran', 'M_vazba',
#        'M_rozměr', 'M_hmotnost', 'M_isbn', 'M_rok_vydání',
#        'M_naše_katalogové_číslo', 'M_jazyk', 'M_původ', 'M_nakladatel',
#        'M_kategorizace', 'M_cena', 'M_datum', 'soubor', 'M_série', 'M_díl',
#        'M_edice', 'M_pro_koho', 'M_e-kniha', 'M_přečtená',
#        'M_věkové_doporučení', 'M_styl', 'M_ilustrace', 'M_účel_knihy',
#        'M_audiokniha', 'M_vydání', 'M_originální_název', 'M_překlad',
#        'M_ostatní', 'M_předběžné_datum_vydání', 'M_filmové_zpracování',
#        'M_příloha', 'M_jazyková_úroveň', 'M_knižní_předloha'],
#       dtype='object')

# %%
df = df.drop(columns=['M_naše_katalogové_číslo','soubor','M_filmové_zpracování'])

# %%
df[df['M_kategorizace'].notnull()]['M_kategorizace']
# Out:
# 0        ['Knihy', 'Odborné a naučné', 'Umění, design a...
# 1        ['Knihy', 'Odborné a naučné', 'Motivace a sebe...
# 2        ['Knihy', 'Odborné a naučné', 'Byznys a manage...
# 3        ['Knihy', 'Odborné a naučné', 'Byznys a manage...
# 4        ['Knihy', 'Náboženství a ezoterika', 'Nábožens...
#                                ...
# 11709    ['Knihy', 'Beletrie', 'Mýty, pověsti a legendy...
# 11710                      ['Knihy', 'Beletrie', 'Poezie']
# 11711        ['Knihy', 'Beletrie', 'Společenská beletrie']
# 11712        ['Knihy', 'Beletrie', 'Společenská beletrie']
# 11713                      ['Knihy', 'Beletrie', 'Poezie']
# Name: M_kategorizace, Length: 11709, dtype: object

# %%
kategorizace = df.explode('M_kategorizace')
kategorizace.groupby('M_kategorizace').size().nlargest(20)
# Out:
# M_kategorizace
# ['Knihy', 'Beletrie']                                                                                                           1256
# ['Knihy', 'Beletrie', 'Poezie']                                                                                                 1172
# ['Knihy', 'Beletrie', 'Společenská beletrie', 'Knihy', 'Beletrie']                                                               661
# ['Knihy', 'Beletrie', 'Společenská beletrie']                                                                                    631
# ['Knihy', 'Odborné a naučné', 'Humanitní a společenské vědy', 'Historie']                                                        368
# ['Knihy', 'Odborné a naučné', 'Humanitní a společenské vědy', 'Právo']                                                           201
# ['Knihy', 'Beletrie', 'Knihy', 'Beletrie', 'Společenská beletrie']                                                               149
# ['Knihy', 'Beletrie', 'Detektivky, thrillery a horory', 'Detektivky', 'Knihy', 'Beletrie', 'Detektivky, thrillery a horory']     146
# ['Knihy', 'Beletrie', 'Sci-fi a fantasy']                                                                                        124
# ['Knihy', 'Beletrie', 'Detektivky, thrillery a horory', 'Knihy', 'Beletrie', 'Detektivky, thrillery a horory', 'Detektivky']      93
# ['Knihy', 'Beletrie', 'Detektivky, thrillery a horory']                                                                           88
# ['Knihy', 'Odborné a naučné', 'Byznys a management', 'Účetnictví a daně', 'Daně']                                                 82
# ['Knihy', 'Beletrie', 'Sci-fi a fantasy', 'Fantasy']                                                                              78
# ['Knihy', 'Odborné a naučné', 'Humanitní a společenské vědy', 'Literární věda']                                                   77
# ['Knihy', 'Beletrie', 'Detektivky, thrillery a horory', 'Detektivky']                                                             72
# ['Knihy', 'Odborné a naučné', 'Umění, design a architektura', 'Malířství a sochařství', 'Malířství']                              71
# ['Knihy', 'Odborné a naučné', 'Humanitní a společenské vědy', 'Filozofie']                                                        66
# ['Knihy', 'Odborné a naučné', 'Umění, design a architektura', 'Hudba', 'Noty']                                                    64
# ['Knihy', 'Odborné a naučné', 'Humanitní a společenské vědy', 'Historie', '20. století']                                          61
# ['Knihy', 'Odborné a naučné', 'Humanitní a společenské vědy', 'Politologie a politika']                                           54
# dtype: int64

# %%
df['M_ostatní'].drop_duplicates()
# Out:
# 0                                  NaN
# 108                     s podporou FPU
# 340                  podle skutečnosti
# 2388     ['s hračkou', 'interaktivní']
# 3732                 Krajina čitateľov
# 4726                       logopedické
# 5340                           dárkový
# 5918                           vánoční
# 6183            ['vánoční', 'dárkový']
# 6935               prostorové (pop-up)
# 10726                   knihy s puzzle
# Name: M_ostatní, dtype: object

# %%
df
# Out:
#                                                  M_titul  \
# 0      Jindřich Chalupecký. Texty a kontexty kritika ...
# 1                                        Hra s formami 2
# 2      Práce, odvody a mzdy bez chyb, pokut a penále ...
# 3                                       Daně v podnikání
# 4                                  Budoucnost začíná teď
# ...                                                  ...
# 11709               V severnom vetre čítaš správy ďaleké
# 11710                              Louka a spousta tance
# 11711                                      Z čeho je den
# 11712                 Krvavý Žižkov\n            Novinka
# 11713                      Tam kde smrt chodí na čekanou
#
#                         M_autorstvo  \
# 0                   Tomáš Pospiszyl
# 1                     Eduardo Duran
# 2                               NaN
# 3      Alena Vančurová Hana Zídková
# 4                       Lukáš Bujna
# ...                             ...
# 11709                  Martin Odler
# 11710                  Jakub Klikar
# 11711             Dominika Prejdová
# 11712                 Martin Reiner
# 11713              Vladimír Paleček
#
#                                                M_anotace  M_počet_stran  \
# 0      Kritik a teoretik umění Jindřich Chalupecký (1...          396.0
# 1      Vedomie je individuálne vnímanie, ktoré má kaž...          404.0
# 2      Firemní školky jako benefit - Někteří zaměstna...            NaN
# 3      Publikace vychází již podruhé, v aktualizované...          368.0
# 4      Během pandemie covidu si husitský farář a básn...          248.0
# ...                                                  ...            ...
# 11709  Kniha V severnom vetre čítaš správy ďaleké je ...          208.0
# 11710  Tato básnická sbírka obsahující třicet básní, ...           40.0
# 11711  Román Dominiky Prejdové popisuje dynamiku a mi...          264.0
# 11712  Krvavý Žižkov je antologie, která má svého pře...          256.0
# 11713  Vladimír Paleček (* 1975) se věnoval poezii od...           83.0
#
#                M_vazba    M_rozměr M_hmotnost         M_isbn  M_rok_vydání  \
# 0      brožovaná vazba  150×220 mm      513 g  9788088366478        2023.0
# 1      brožovaná vazba  135×205 mm      510 g  9798373986052        2023.0
# 2      brožovaná vazba         NaN        NaN  9771801993457        2024.0
# 3      brožovaná vazba  155×235 mm      544 g  9788076763593        2022.0
# 4      brožovaná vazba  150×210 mm        NaN  9788090788145        2023.0
# ...                ...         ...        ...            ...           ...
# 11709      pevná vazba  154×226 mm      490 g  9788082450296        2023.0
# 11710  brožovaná vazba  140×210 mm       76 g  9788075682079        2020.0
# 11711      pevná vazba  135×208 mm       40 g  9788024275772        2021.0
# 11712      pevná vazba  150×210 mm        NaN  9788072279012        2024.0
# 11713  brožovaná vazba  148×210 mm      140 g  9788074924217        2020.0
#
#            M_jazyk  ... M_účel_knihy M_audiokniha M_vydání M_originální_název  \
# 0          čeština  ...          NaN          NaN      NaN                NaN
# 1      slovenština  ...          NaN          NaN      NaN                NaN
# 2          čeština  ...          NaN          NaN      NaN                NaN
# 3          čeština  ...          NaN          NaN      NaN                NaN
# 4          čeština  ...          NaN          NaN      NaN                NaN
# ...            ...  ...          ...          ...      ...                ...
# 11709  slovenština  ...          NaN          NaN      NaN                NaN
# 11710      čeština  ...          NaN          NaN      NaN                NaN
# 11711      čeština  ...          NaN          NaN      NaN                NaN
# 11712      čeština  ...          NaN          NaN      NaN                NaN
# 11713      čeština  ...          NaN          NaN      NaN                NaN
#
#       M_překlad M_ostatní  M_předběžné_datum_vydání M_příloha  \
# 0           NaN       NaN                       NaN       NaN
# 1           NaN       NaN                       NaN       NaN
# 2           NaN       NaN                       NaN       NaN
# 3           NaN       NaN                       NaN       NaN
# 4           NaN       NaN                       NaN       NaN
# ...         ...       ...                       ...       ...
# 11709       NaN       NaN                       NaN       NaN
# 11710       NaN       NaN                       NaN       NaN
# 11711       NaN       NaN                       NaN       NaN
# 11712       NaN       NaN                       NaN       NaN
# 11713       NaN       NaN                       NaN       NaN
#
#       M_jazyková_úroveň M_knižní_předloha
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 11709               NaN               NaN
# 11710               NaN               NaN
# 11711               NaN               NaN
# 11712               NaN               NaN
# 11713               NaN               NaN
#
# [11714 rows x 34 columns]

# %%
df['M_isbn'] = df['M_isbn'].apply(lambda x: str(x).split(".")[0]).astype(str)

# %%
df['M_věkové_doporučení'] = df['M_věkové_doporučení'].apply(lambda x: str(x).replace("+","") if x else None)

# %%
df
# Out:
#                                                  M_titul  \
# 0      Jindřich Chalupecký. Texty a kontexty kritika ...
# 1                                        Hra s formami 2
# 2      Práce, odvody a mzdy bez chyb, pokut a penále ...
# 3                                       Daně v podnikání
# 4                                  Budoucnost začíná teď
# ...                                                  ...
# 11709               V severnom vetre čítaš správy ďaleké
# 11710                              Louka a spousta tance
# 11711                                      Z čeho je den
# 11712                 Krvavý Žižkov\n            Novinka
# 11713                      Tam kde smrt chodí na čekanou
#
#                         M_autorstvo  \
# 0                   Tomáš Pospiszyl
# 1                     Eduardo Duran
# 2                               NaN
# 3      Alena Vančurová Hana Zídková
# 4                       Lukáš Bujna
# ...                             ...
# 11709                  Martin Odler
# 11710                  Jakub Klikar
# 11711             Dominika Prejdová
# 11712                 Martin Reiner
# 11713              Vladimír Paleček
#
#                                                M_anotace  M_počet_stran  \
# 0      Kritik a teoretik umění Jindřich Chalupecký (1...          396.0
# 1      Vedomie je individuálne vnímanie, ktoré má kaž...          404.0
# 2      Firemní školky jako benefit - Někteří zaměstna...            NaN
# 3      Publikace vychází již podruhé, v aktualizované...          368.0
# 4      Během pandemie covidu si husitský farář a básn...          248.0
# ...                                                  ...            ...
# 11709  Kniha V severnom vetre čítaš správy ďaleké je ...          208.0
# 11710  Tato básnická sbírka obsahující třicet básní, ...           40.0
# 11711  Román Dominiky Prejdové popisuje dynamiku a mi...          264.0
# 11712  Krvavý Žižkov je antologie, která má svého pře...          256.0
# 11713  Vladimír Paleček (* 1975) se věnoval poezii od...           83.0
#
#                M_vazba    M_rozměr M_hmotnost         M_isbn  M_rok_vydání  \
# 0      brožovaná vazba  150×220 mm      513 g  9788088366478        2023.0
# 1      brožovaná vazba  135×205 mm      510 g  9798373986052        2023.0
# 2      brožovaná vazba         NaN        NaN  9771801993457        2024.0
# 3      brožovaná vazba  155×235 mm      544 g  9788076763593        2022.0
# 4      brožovaná vazba  150×210 mm        NaN  9788090788145        2023.0
# ...                ...         ...        ...            ...           ...
# 11709      pevná vazba  154×226 mm      490 g  9788082450296        2023.0
# 11710  brožovaná vazba  140×210 mm       76 g  9788075682079        2020.0
# 11711      pevná vazba  135×208 mm       40 g  9788024275772        2021.0
# 11712      pevná vazba  150×210 mm        NaN  9788072279012        2024.0
# 11713  brožovaná vazba  148×210 mm      140 g  9788074924217        2020.0
#
#            M_jazyk  ... M_účel_knihy M_audiokniha M_vydání M_originální_název  \
# 0          čeština  ...          NaN          NaN      NaN                NaN
# 1      slovenština  ...          NaN          NaN      NaN                NaN
# 2          čeština  ...          NaN          NaN      NaN                NaN
# 3          čeština  ...          NaN          NaN      NaN                NaN
# 4          čeština  ...          NaN          NaN      NaN                NaN
# ...            ...  ...          ...          ...      ...                ...
# 11709  slovenština  ...          NaN          NaN      NaN                NaN
# 11710      čeština  ...          NaN          NaN      NaN                NaN
# 11711      čeština  ...          NaN          NaN      NaN                NaN
# 11712      čeština  ...          NaN          NaN      NaN                NaN
# 11713      čeština  ...          NaN          NaN      NaN                NaN
#
#       M_překlad M_ostatní  M_předběžné_datum_vydání M_příloha  \
# 0           NaN       NaN                       NaN       NaN
# 1           NaN       NaN                       NaN       NaN
# 2           NaN       NaN                       NaN       NaN
# 3           NaN       NaN                       NaN       NaN
# 4           NaN       NaN                       NaN       NaN
# ...         ...       ...                       ...       ...
# 11709       NaN       NaN                       NaN       NaN
# 11710       NaN       NaN                       NaN       NaN
# 11711       NaN       NaN                       NaN       NaN
# 11712       NaN       NaN                       NaN       NaN
# 11713       NaN       NaN                       NaN       NaN
#
#       M_jazyková_úroveň M_knižní_předloha
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 11709               NaN               NaN
# 11710               NaN               NaN
# 11711               NaN               NaN
# 11712               NaN               NaN
# 11713               NaN               NaN
#
# [11714 rows x 34 columns]

# %%
na_int = ['M_počet_stran','M_rok_vydání','M_díl','M_věkové_doporučení']
for i in na_int:
    df[i] = pd.to_numeric(df[i], errors='coerce', downcast='integer')

# %%
df
# Out:
#                                                  M_titul  \
# 0      Jindřich Chalupecký. Texty a kontexty kritika ...
# 1                                        Hra s formami 2
# 2      Práce, odvody a mzdy bez chyb, pokut a penále ...
# 3                                       Daně v podnikání
# 4                                  Budoucnost začíná teď
# ...                                                  ...
# 11709               V severnom vetre čítaš správy ďaleké
# 11710                              Louka a spousta tance
# 11711                                      Z čeho je den
# 11712                 Krvavý Žižkov\n            Novinka
# 11713                      Tam kde smrt chodí na čekanou
#
#                         M_autorstvo  \
# 0                   Tomáš Pospiszyl
# 1                     Eduardo Duran
# 2                               NaN
# 3      Alena Vančurová Hana Zídková
# 4                       Lukáš Bujna
# ...                             ...
# 11709                  Martin Odler
# 11710                  Jakub Klikar
# 11711             Dominika Prejdová
# 11712                 Martin Reiner
# 11713              Vladimír Paleček
#
#                                                M_anotace  M_počet_stran  \
# 0      Kritik a teoretik umění Jindřich Chalupecký (1...          396.0
# 1      Vedomie je individuálne vnímanie, ktoré má kaž...          404.0
# 2      Firemní školky jako benefit - Někteří zaměstna...            NaN
# 3      Publikace vychází již podruhé, v aktualizované...          368.0
# 4      Během pandemie covidu si husitský farář a básn...          248.0
# ...                                                  ...            ...
# 11709  Kniha V severnom vetre čítaš správy ďaleké je ...          208.0
# 11710  Tato básnická sbírka obsahující třicet básní, ...           40.0
# 11711  Román Dominiky Prejdové popisuje dynamiku a mi...          264.0
# 11712  Krvavý Žižkov je antologie, která má svého pře...          256.0
# 11713  Vladimír Paleček (* 1975) se věnoval poezii od...           83.0
#
#                M_vazba    M_rozměr M_hmotnost         M_isbn  M_rok_vydání  \
# 0      brožovaná vazba  150×220 mm      513 g  9788088366478        2023.0
# 1      brožovaná vazba  135×205 mm      510 g  9798373986052        2023.0
# 2      brožovaná vazba         NaN        NaN  9771801993457        2024.0
# 3      brožovaná vazba  155×235 mm      544 g  9788076763593        2022.0
# 4      brožovaná vazba  150×210 mm        NaN  9788090788145        2023.0
# ...                ...         ...        ...            ...           ...
# 11709      pevná vazba  154×226 mm      490 g  9788082450296        2023.0
# 11710  brožovaná vazba  140×210 mm       76 g  9788075682079        2020.0
# 11711      pevná vazba  135×208 mm       40 g  9788024275772        2021.0
# 11712      pevná vazba  150×210 mm        NaN  9788072279012        2024.0
# 11713  brožovaná vazba  148×210 mm      140 g  9788074924217        2020.0
#
#            M_jazyk  ... M_účel_knihy M_audiokniha M_vydání M_originální_název  \
# 0          čeština  ...          NaN          NaN      NaN                NaN
# 1      slovenština  ...          NaN          NaN      NaN                NaN
# 2          čeština  ...          NaN          NaN      NaN                NaN
# 3          čeština  ...          NaN          NaN      NaN                NaN
# 4          čeština  ...          NaN          NaN      NaN                NaN
# ...            ...  ...          ...          ...      ...                ...
# 11709  slovenština  ...          NaN          NaN      NaN                NaN
# 11710      čeština  ...          NaN          NaN      NaN                NaN
# 11711      čeština  ...          NaN          NaN      NaN                NaN
# 11712      čeština  ...          NaN          NaN      NaN                NaN
# 11713      čeština  ...          NaN          NaN      NaN                NaN
#
#       M_překlad M_ostatní  M_předběžné_datum_vydání M_příloha  \
# 0           NaN       NaN                       NaN       NaN
# 1           NaN       NaN                       NaN       NaN
# 2           NaN       NaN                       NaN       NaN
# 3           NaN       NaN                       NaN       NaN
# 4           NaN       NaN                       NaN       NaN
# ...         ...       ...                       ...       ...
# 11709       NaN       NaN                       NaN       NaN
# 11710       NaN       NaN                       NaN       NaN
# 11711       NaN       NaN                       NaN       NaN
# 11712       NaN       NaN                       NaN       NaN
# 11713       NaN       NaN                       NaN       NaN
#
#       M_jazyková_úroveň M_knižní_předloha
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 11709               NaN               NaN
# 11710               NaN               NaN
# 11711               NaN               NaN
# 11712               NaN               NaN
# 11713               NaN               NaN
#
# [11714 rows x 34 columns]

# %%
if not os.path.exists('data'):
    os.makedirs('data')

# %%
df[df['M_předběžné_datum_vydání'].notnull()].to_json(os.path.join('data','martinus_vyjde.json'))
df[df['M_rok_vydání'].notnull()].to_json(os.path.join('data','martinus_vyslo.json'))

# %%
puvod = df.explode("M_původ")
puvod.size
# Out:
# 398276

# %%
puvod[puvod['M_původ'] == "Česko"].drop_duplicates(subset=['M_isbn']).size
# Out:
# 371926

# %%
puvod[puvod['M_původ'] == "Česko"]
# Out:
#                                                  M_titul  \
# 0      Jindřich Chalupecký. Texty a kontexty kritika ...
# 1                                        Hra s formami 2
# 2      Práce, odvody a mzdy bez chyb, pokut a penále ...
# 3                                       Daně v podnikání
# 4                                  Budoucnost začíná teď
# ...                                                  ...
# 11709               V severnom vetre čítaš správy ďaleké
# 11710                              Louka a spousta tance
# 11711                                      Z čeho je den
# 11712                 Krvavý Žižkov\n            Novinka
# 11713                      Tam kde smrt chodí na čekanou
#
#                         M_autorstvo  \
# 0                   Tomáš Pospiszyl
# 1                     Eduardo Duran
# 2                               NaN
# 3      Alena Vančurová Hana Zídková
# 4                       Lukáš Bujna
# ...                             ...
# 11709                  Martin Odler
# 11710                  Jakub Klikar
# 11711             Dominika Prejdová
# 11712                 Martin Reiner
# 11713              Vladimír Paleček
#
#                                                M_anotace  M_počet_stran  \
# 0      Kritik a teoretik umění Jindřich Chalupecký (1...          396.0
# 1      Vedomie je individuálne vnímanie, ktoré má kaž...          404.0
# 2      Firemní školky jako benefit - Někteří zaměstna...            NaN
# 3      Publikace vychází již podruhé, v aktualizované...          368.0
# 4      Během pandemie covidu si husitský farář a básn...          248.0
# ...                                                  ...            ...
# 11709  Kniha V severnom vetre čítaš správy ďaleké je ...          208.0
# 11710  Tato básnická sbírka obsahující třicet básní, ...           40.0
# 11711  Román Dominiky Prejdové popisuje dynamiku a mi...          264.0
# 11712  Krvavý Žižkov je antologie, která má svého pře...          256.0
# 11713  Vladimír Paleček (* 1975) se věnoval poezii od...           83.0
#
#                M_vazba    M_rozměr M_hmotnost         M_isbn  M_rok_vydání  \
# 0      brožovaná vazba  150×220 mm      513 g  9788088366478        2023.0
# 1      brožovaná vazba  135×205 mm      510 g  9798373986052        2023.0
# 2      brožovaná vazba         NaN        NaN  9771801993457        2024.0
# 3      brožovaná vazba  155×235 mm      544 g  9788076763593        2022.0
# 4      brožovaná vazba  150×210 mm        NaN  9788090788145        2023.0
# ...                ...         ...        ...            ...           ...
# 11709      pevná vazba  154×226 mm      490 g  9788082450296        2023.0
# 11710  brožovaná vazba  140×210 mm       76 g  9788075682079        2020.0
# 11711      pevná vazba  135×208 mm       40 g  9788024275772        2021.0
# 11712      pevná vazba  150×210 mm        NaN  9788072279012        2024.0
# 11713  brožovaná vazba  148×210 mm      140 g  9788074924217        2020.0
#
#            M_jazyk  ... M_účel_knihy M_audiokniha M_vydání M_originální_název  \
# 0          čeština  ...          NaN          NaN      NaN                NaN
# 1      slovenština  ...          NaN          NaN      NaN                NaN
# 2          čeština  ...          NaN          NaN      NaN                NaN
# 3          čeština  ...          NaN          NaN      NaN                NaN
# 4          čeština  ...          NaN          NaN      NaN                NaN
# ...            ...  ...          ...          ...      ...                ...
# 11709  slovenština  ...          NaN          NaN      NaN                NaN
# 11710      čeština  ...          NaN          NaN      NaN                NaN
# 11711      čeština  ...          NaN          NaN      NaN                NaN
# 11712      čeština  ...          NaN          NaN      NaN                NaN
# 11713      čeština  ...          NaN          NaN      NaN                NaN
#
#       M_překlad M_ostatní  M_předběžné_datum_vydání M_příloha  \
# 0           NaN       NaN                       NaN       NaN
# 1           NaN       NaN                       NaN       NaN
# 2           NaN       NaN                       NaN       NaN
# 3           NaN       NaN                       NaN       NaN
# 4           NaN       NaN                       NaN       NaN
# ...         ...       ...                       ...       ...
# 11709       NaN       NaN                       NaN       NaN
# 11710       NaN       NaN                       NaN       NaN
# 11711       NaN       NaN                       NaN       NaN
# 11712       NaN       NaN                       NaN       NaN
# 11713       NaN       NaN                       NaN       NaN
#
#       M_jazyková_úroveň M_knižní_předloha
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 11709               NaN               NaN
# 11710               NaN               NaN
# 11711               NaN               NaN
# 11712               NaN               NaN
# 11713               NaN               NaN
#
# [11545 rows x 34 columns]

# %%
with open(os.path.join("data","nesledovat.json")) as nesledovat:
    nesledovat = json.load(nesledovat)

# %%
puvod[(~puvod['M_isbn'].isin(nesledovat)) & (puvod['M_rok_vydání'].isin([2023,2024])) & (puvod['M_vydání'].isnull()) & (puvod['M_originální_název'].isnull()) & (puvod['M_překlad'].isnull())][['M_titul','M_isbn']].reset_index().to_json(os.path.join('data','sledovat.json'))
