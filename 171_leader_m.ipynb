# %%
import os
import polars as pl

# %%
df = pl.read_parquet(os.path.join("data","cnb_vyber.parquet"))

# %%
df = df.with_columns(pl.col("leader").str.slice(7,1).alias("slice"))

# %%
df.select(pl.col("slice")).sample(20)
# Out:
# shape: (20, 1)
# ┌───────┐
# │ slice │
# │ ---   │
# │ str   │
# ╞═══════╡
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# │ m     │
# └───────┘

# %%
df.filter(pl.col("slice") == 'm')
# Out:
# shape: (859_939, 63)
# ┌───────────────────────────────┬───────────────────────┬────────────────┬──────────────────────────┬───┬──────────────────────────────┬──────────────────────────┬────────────────┬───────┐
# │ 008                           ┆ 020_a                 ┆ 020_c          ┆ 020_q                    ┆ … ┆ 964_a                        ┆ leader                   ┆ 001            ┆ slice │
# │ ---                           ┆ ---                   ┆ ---            ┆ ---                      ┆   ┆ ---                          ┆ ---                      ┆ ---            ┆ ---   │
# │ str                           ┆ list[str]             ┆ list[str]      ┆ list[str]                ┆   ┆ list[str]                    ┆ str                      ┆ str            ┆ str   │
# ╞═══════════════════════════════╪═══════════════════════╪════════════════╪══════════════════════════╪═══╪══════════════════════════════╪══════════════════════════╪════════════════╪═══════╡
# ...
