# %%
import os

import pandas as pd

# %%
df = pd.read_parquet(os.path.join("data", "cnb_vyber.parquet"))

# %%
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 500)

# %%
df[df["245_a"].astype(str).str.contains("Nápady čtenáře detektivek", na=False)]
# Out:
# KeyboardInterrupt

# %%
df[df["830_a"].astype(str).str.contains("Otázky a názory", na=False)]

# %%
df[df["245_a"].astype(str).str.contains("Jak s tím pohnu", na=False)]

# %%
df[
    df["830_a"].astype(str).str.contains("Krystal", na=False)
    & df["830_a"].astype(str).str.contains("dětské knihy", na=False)
]

# %%
df[df["490_a"].astype(str).str.contains("Krystal", na=False)]

# %%
df[df["100_a"].astype(str).str.contains("Houška, Vítězslav", na=False)]

# %%
df[df["245_a"].astype(str).str.contains("Naši savci", na=False)]

# %%
df[
    df["830_a"].astype(str).str.contains("Oko", na=False)
    & df["830_a"].astype(str).str.contains("Albatros", na=False)
]

# %%
df[df["245_a"].astype(str).str.contains("Každému chléb", na=False)]

# %%
df[df["830_a"].astype(str).str.contains("Dobrý vítr", na=False)]

# %%
df[df["100_a"].astype(str).str.contains("Richta, Radov", na=False)]
# Out:
#                                                  008 020_a        020_c  \
# 001
# bk196401074   970920s1963    xr     e      00| 0 cze  None         None
# bk196401170   970923s1963    xr     g      000 0 cze  None         None
# bk196505047a  971213s1966    xr a   e      000 0 cze  None         None
# bk196700715   970714s1967    xr a   e      000 0 cze  None         None
# bk196902469   971111s1969    xr     e      000 0 cze  None  [Kčs 33,00]
#
#                    020_q 041_a 041_h 041_ind1 044_a    072_a  \
# 001
# bk196401074    [(Brož.)]  None  None     None  None  [316.3]
# bk196401170    [(Brož.)]  None  None     None  None     [62]
# bk196505047a   [(Brož.)]  None  None     None  None  [316.4]
# bk196700715         None  None  None     None  None  [316.4]
# bk196902469   [(Váz.) :]  None  None     None  None  [316.4]
#
#                                                           072_x  \
# 001
# bk196401074   [Globální společnosti. Sociální struktura. Soc...
# ...

# %%
df[df["964_a"].astype(str).str.contains("Revoluce vědeckotechnická", na=False)]
# Out:
#                                                    008 020_a        020_c  \
# 001
# bk196401170     970923s1963    xr     g      000 0 cze  None         None
# bk196503139     971016s1965    xr            000 | cze  None         None
# bk196505047a    971213s1966    xr a   e      000 0 cze  None         None
# bk196601008     970922s1966    xr                  cze  None         None
# bk196700715     970714s1967    xr a   e      000 0 cze  None         None
# bk196701467     970724s1967    xr            000 | cze  None         None
# bk196704651     971120s1967    xr                  cze  None         None
# bk196802063     970620s1968    xr                  cze  None         None
# bk196803043     970716s1968    xr                  cze  None         None
# bk196803055     970716s1968    xr                  cze  None         None
# bk196803716     970825s1968    xr                  cze  None         None
# bk196803717     970825s1968    xr                  cze  None         None
# ...
