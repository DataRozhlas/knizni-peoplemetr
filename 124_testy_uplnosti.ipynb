# %%
import os
import re
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_parquet(os.path.join("data","cnb_vyber.parquet"))
len(df)
# Out:
# 855454

# %% [markdown]
# ## Jsou tam sborníky, do kterých přispíval Michal Kašpárek?

# %%
df[df['100_a'].astype(str).str.contains('Kašpárek, Micha',na=False)]
# Out:
#                                                    008                020_a  \
# 001
# nkc20182997195  180516s2018    xr     g      000 j cze  [978-80-7549-850-2]
# nkc20233549616  230925s2023    xr     g      000 f cze  [978-80-7637-400-3]
#
#                020_c          020_q 041_a 041_h 041_ind1 044_a          072_a  \
# 001
# nkc20182997195  None     [(vázáno)]  None  None     None  None  [821.162.3-3]
# nkc20233549616  None  [(brožováno)]  None  None     None  None  [821.162.3-3]
#
#                         072_x                         080_a  100_4  \
# 001
# nkc20182997195  [Česká próza]  [821.162.3-32, (0:82-323.1)]  [aut]
# nkc20233549616  [Česká próza]     [821.162.3-31, (0:82-31)]  [aut]
#
#                           100_7                100_a    100_d 240_l  \
# 001
# nkc20182997195  [jx20100301005]  [Kašpárek, Michal,]  [1984-]  None
# nkc20233549616  [jx20100301005]  [Kašpárek, Michal,]  [1984-]  None
#
# ...

# %%
df[df['700_7'].astype(str).str.contains('jx20100301005',na=False)]
# Out:
#                                                    008                020_a  \
# 001
# nkc20122386191  120716s2012    xr a   e f    001 0 cze  [978-80-265-0030-8]
# nkc20132497877  130911s2013    xr ac  e f    001 0 cze  [978-80-265-0129-9]
# nkc20233534156  230721s2023    xr a   e f    001 0 cze  [978-80-265-1142-7]
#
#                       020_c            020_q  041_a  041_h 041_ind1 044_a  \
# 001
# nkc20122386191         None        [(brož.)]  [cze]  [eng]      [1]  None
# nkc20132497877         None        [(brož.)]  [cze]  [eng]      [1]  None
# nkc20233534156  [Kč 399,00]  [(brožováno) :]  [cze]  [eng]      [1]  None
#
#                    072_a                    072_x  \
# 001
# nkc20122386191  [159.95]  [Vyšší duševní procesy]
# nkc20132497877     [005]     [Management. Řízení]
# nkc20233534156  [159.95]  [Vyšší duševní procesy]
#
#                                                             080_a  100_4  \
# 001
# ...

# %%
df[df['245_a'].astype(str).str.contains('Neviditelné řemeslo',na=False)]
# Out:
#                                                    008                020_a  \
# 001
# nkc20233566871  231113s2023    xr a   e      001 e cze  [978-80-7637-401-0]
#
#                020_c       020_q 041_a 041_h 041_ind1 044_a  072_a  \
# 001
# nkc20233566871  None  [(vázáno)]  None  None     None  None  [655]
#
#                                                       072_x  \
# 001
# nkc20233566871  [Polygrafie. Vydavatelství a knižní obchod]
#
#                                                          080_a 100_4 100_7  \
# 001
# nkc20233566871  [655.5, 655.4/.5+070, 655.41, (0:82-4), (082)]  None  None
#
#                100_a 100_d 240_l                    245_a  \
# 001
# nkc20233566871  None  None  None  [Neviditelné řemeslo /]
#
#                                                             245_c 245_n 245_p  \
# 001
# nkc20233566871  [uspořádal Jakub Sedláček ; ilustroval Lukáš F...  None  None
#
#                246_a           250_a 250_b 260_a 260_b 260_c 260_e 260_f  \
# ...

# %%
df[df['245_a'].astype(str).str.contains('Neviditelné řemeslo',na=False)]['245_c'].iloc[0]
# Out:
# array(['uspořádal Jakub Sedláček ; ilustroval Lukáš Fibrich'],
#       dtype=object)

# %%
df[df['245_a'].astype(str).str.contains('Neviditelné řemeslo',na=False)]['500_a'].iloc[0]
# Out:
# array(['Obálkový podnázev: tajemství redakční práce'], dtype=object)

# %%
df[df['245_a'].astype(str).str.contains('Povídky současných českých',na=False)]
# Out:
# Empty DataFrame
# Columns: [008, 020_a, 020_c, 020_q, 041_a, 041_h, 041_ind1, 044_a, 072_a, 072_x, 080_a, 100_4, 100_7, 100_a, 100_d, 240_l, 245_a, 245_c, 245_n, 245_p, 246_a, 250_a, 250_b, 260_a, 260_b, 260_c, 260_e, 260_f, 260_ind1, 264_a, 264_b, 264_c, 264_ind2, 300_a, 300_b, 300_c, 490_a, 490_v, 500_a, 520_a, 520_b, 521_a, 546_a, 648_a, 650_a, 650_x, 650_y, 650_z, 651_a, 653_a, 655_a, 700_4, 700_7, 700_a, 700_d, 710_4, 710_7, 710_a, 710_b, 830_a, 928_a, 964_a, leader]
# Index: []
