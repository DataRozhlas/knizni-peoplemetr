# %%
import polars as pl
pl.Config(tbl_rows=200)
pl.Config.set_fmt_str_lengths(100)
df = pl.read_parquet("data/cnb_vyber.parquet")

# %%
from src.najdi_rok import najdi_rok

# %%
df = df.with_columns(pl.col('008').map_elements(najdi_rok, return_dtype=int).alias('rok'))

# %%
df.filter(pl.col("rok").is_in(range(1970,1990)) & pl.col('245_a').str.contains('Domy'))
# Out:
# shape: (6, 63)
# ┌────────────────┬───────────┬───────────────┬──────────────┬───┬───────────────┬───────────────┬───────────────┬──────┐
# │ 008            ┆ 020_a     ┆ 020_c         ┆ 020_q        ┆ … ┆ 964_a         ┆ leader        ┆ 001           ┆ rok  │
# │ ---            ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---  │
# │ str            ┆ list[str] ┆ list[str]     ┆ list[str]    ┆   ┆ list[str]     ┆ str           ┆ str           ┆ i64  │
# ╞════════════════╪═══════════╪═══════════════╪══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════╡
# │ 970916s1972    ┆ null      ┆ null          ┆ null         ┆ … ┆ null          ┆ nam a22     1 ┆ bk197300341   ┆ 1972 │
# │ xr     e s     ┆           ┆               ┆              ┆   ┆               ┆ 4500          ┆               ┆      │
# ...

# %%
df.filter(pl.col("rok").is_in(range(1970,1990)) & pl.col('245_a').str.contains('rodinných domů'))
# Out:
# shape: (3, 63)
# ┌───────────────┬───────────┬───────────────┬───────────────┬───┬───────────────┬───────────────┬───────────────┬──────┐
# │ 008           ┆ 020_a     ┆ 020_c         ┆ 020_q         ┆ … ┆ 964_a         ┆ leader        ┆ 001           ┆ rok  │
# │ ---           ┆ ---       ┆ ---           ┆ ---           ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---  │
# │ str           ┆ list[str] ┆ list[str]     ┆ list[str]     ┆   ┆ list[str]     ┆ str           ┆ str           ┆ i64  │
# ╞═══════════════╪═══════════╪═══════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════╡
# │ 970210s1977   ┆ null      ┆ null          ┆ null          ┆ … ┆ ["Domy        ┆ nam a22     1 ┆ bk197800801   ┆ 1977 │
# │ xr            ┆           ┆               ┆               ┆   ┆ rodinné -     ┆ 4500          ┆               ┆      │
# ...

# %%
df.filter(pl.col("rok").is_in(range(1970,1990)) & pl.col('245_a').str.contains('vily'))
# Out:
# shape: (4, 63)
# ┌───────────────┬───────────┬───────────────┬───────────────┬───┬───────────────┬───────────────┬───────────────┬──────┐
# │ 008           ┆ 020_a     ┆ 020_c         ┆ 020_q         ┆ … ┆ 964_a         ┆ leader        ┆ 001           ┆ rok  │
# │ ---           ┆ ---       ┆ ---           ┆ ---           ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---  │
# │ str           ┆ list[str] ┆ list[str]     ┆ list[str]     ┆   ┆ list[str]     ┆ str           ┆ str           ┆ i64  │
# ╞═══════════════╪═══════════╪═══════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════╡
# │ 970116s1972   ┆ null      ┆ null          ┆ ["(Váz.)"]    ┆ … ┆ ["Egypt       ┆ nam a22       ┆ bk197200676   ┆ 1972 │
# │ xr            ┆           ┆               ┆               ┆   ┆ starověký -   ┆ 1a 4500       ┆               ┆      │
# ...

# %%
df.filter(pl.col("rok").is_in(range(1970,1990)) & pl.col('245_a').str.contains('domy'))
# Out:
# shape: (10, 63)
# ┌───────────────┬───────────────┬───────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────┐
# │ 008           ┆ 020_a         ┆ 020_c         ┆ 020_q        ┆ … ┆ 964_a        ┆ leader       ┆ 001          ┆ rok  │
# │ ---           ┆ ---           ┆ ---           ┆ ---          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---  │
# │ str           ┆ list[str]     ┆ list[str]     ┆ list[str]    ┆   ┆ list[str]    ┆ str          ┆ str          ┆ i64  │
# ╞═══════════════╪═══════════════╪═══════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════╡
# │ 970212s1973   ┆ null          ┆ null          ┆ null         ┆ … ┆ ["Byty -     ┆ nam a22      ┆ bk197402049  ┆ 1973 │
# │ xr            ┆               ┆               ┆              ┆   ┆ občané staří ┆ 1  4500      ┆              ┆      │
# ...
