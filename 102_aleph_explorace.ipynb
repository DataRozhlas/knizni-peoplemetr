# %%
import os
import sys
import json
import pandas

# %%
df = pd.read_json('data/ceska_beletrie.json')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\2472164071.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json('data/ceska_beletrie.json')
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\2472164071.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json('data/ceska_beletrie.json')
# ...

# %%
df[df['260_c'].str.contains('2015',na=False)]
# Out:
#                   001      003           005  007  \
# 28582  nkc20122269787  CZ PrNK  2.015053e+13   ta
# 30671  nkc20132469433  CZ PrNK  2.015042e+13   ta
# 31802  nkc20142577200  CZ PrNK  2.024060e+13   ta
# 32597  nkc20142635029  CZ PrNK  2.015022e+13   ta
# 32705  nkc20142638526  CZ PrNK  2.015060e+13   ta
# ...               ...      ...           ...  ...
# 33378  nkc20152695400  CZ PrNK  2.015051e+13   ta
# 33379  nkc20152695404  CZ PrNK  2.015061e+13   ta
# 33419  nkc20152697919  CZ PrNK  2.015061e+13   ta
# 33428  nkc20152698259  CZ PrNK           NaN  NaN
# 39883  cpk20193075338  CZ PrNK  2.019021e+13   ta
#
#                                             008         015_a  \
# 28582    120110m20112015xr a   g      000 f cze  cnb002269787
# 30671    130624s2015    xr a   b      000 f cze  cnb002469433
# 31802    140331s2015    xr a   b      000 j cze  cnb002577200
# 32597    141027s2015    xr a   g      000 j cze  cnb002635029
# ...

# %%
df['260_c'].drop_duplicates().to_list()
# Out:
# ['1982',
#  '1983',
#  '1982-1983',
#  nan,
#  '[1982]',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '[1984]',
#  '[1985]',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '[1990]',
#  '[199-]',
#  '[1991]',
#  '1992',
#  '[1992]',
#  '[1992?]',
#  '1993',
#  'c1992',
#  '[1993]',
#  '[c1992]',
#  '1992 [i.e 1993]',
#  '1994',
#  '[1993?]',
#  '[1994]',
#  '[1994?]',
#  'c1993',
#  '1992 [v tir. spr.] 1993',
#  'c1994',
#  '1995',
#  '1994 [v tir. spr.] 1995',
#  '[1995]',
#  '1963',
#  '1993 [i.e. 1995]',
#  '1894',
#  'c1995',
#  '1996',
#  '[1996]',
#  '1911',
#  '1928',
#  '1997, c1996',
#  '1997',
#  '1997, c1992',
#  '1995, c1994',
#  '1892',
#  '1997, c1994',
#  '1929',
#  '[1997]',
#  '1874',
#  '1924',
#  '1930',
#  '1906',
#  '1889',
#  '1919',
#  '1920',
#  '1993 [v tiráži spr.] 1994, c1983',
#  '1904',
#  '1916',
#  '1922',
#  '1898',
#  '1899',
#  '1891',
#  '1959',
#  '1960',
#  '1995, c1987',
#  '1915',
#  '1927',
#  '1948',
#  '1995, c1993',
#  '1900',
#  '1878',
# ...

# %%
df[df['260_c'].isin([str(x) for x in range(1900,2025)])].groupby('260_c').size()
# Out:
# 260_c
# 1900      86
# 1901      30
# 1902      29
# 1903      35
# 1904      23
#         ...
# 2011    1119
# 2012    1127
# 2013    1070
# 2014    1103
# 2015     172
# Length: 116, dtype: int64

# %%
df.columns.to_list()
# Out:
# ['001',
#  '003',
#  '005',
#  '007',
#  '008',
#  '015_a',
#  '020_q',
#  '020_c',
#  '035_a',
#  '040_a',
#  '040_b',
#  '040_d',
#  '072_ind2',
#  '072_a',
#  '072_x',
#  '072_2',
#  '072_9',
#  '080_a',
#  '080_2',
#  '100_ind1',
#  '100_a',
#  '100_d',
#  '100_7',
#  '100_4',
#  '245_ind1',
#  '245_ind2',
#  '245_a',
#  '245_c',
#  '250_a',
#  '260_a',
#  '260_b',
#  '260_c',
#  '260_f',
#  '300_a',
#  '300_b',
#  '300_c',
#  '500_a',
#  '655_ind2',
#  '655_a',
#  '655_7',
#  '655_2',
#  '700_ind1',
#  '700_a',
#  '700_d',
#  '700_7',
#  '700_4',
#  '856_ind1',
#  '856_ind2',
#  '856_u',
#  '856_y',
#  '964_a',
#  '998_a',
#  '490_ind1',
#  '490_a',
#  '504_a',
#  '600_ind1',
#  '600_ind2',
#  '600_a',
#  '600_c',
#  '600_d',
#  '600_7',
#  '600_2',
#  '830_ind2',
#  '830_a',
#  '260_e',
#  '490_v',
#  '787_ind1',
#  '787_ind2',
#  '787_i',
#  '787_t',
#  '830_n',
#  '040_c',
#  '521_ind1',
#  '521_a',
#  '040_e',
#  '043_a',
#  '045_a',
#  '245_b',
#  '246_ind1',
# ...

# %%
vsechny_jsony = [f for f in os.listdir('data_raw/cnb')]

# %%
ceska_beletrie = []

# %%
with open('data_raw/cnb/cnb_009.json') as pokus:
    pokus = json.loads(pokus.read())

# %%
pokus[0:100]
# Out:
# [{'001': 'nos190244302',
#   '003': 'CZ PrNK',
#   '005': '20001125000000.0',
#   '008': '001125s1920    xr                  cze',
#   '015_a': 'cnb000344943',
#   '040_a': 'ABA001',
#   '040_b': 'cze',
#   '040_c': 'LIA001',
#   '040_d': 'ABA001',
#   '245_ind1': '0',
#   '245_ind2': '0',
#   '245_a': 'Smlouva pro dělnictvo zemědělské v okresu okresní politické správy Domažlice, Klatovy, Horšův Týn a Horažďovice upravená s dodatky ujednanými na společné schůzi zaměstnavatelů a zaměstnaných dne 3. června 1920 v Plzni ...',
#   '260_a': 'Plzeň :',
#   '260_b': 'nákl. vlast.,',
#   '260_c': '1920',
#   '300_a': '18 s. ;',
#   '300_c': 'v. 8°',
#   '998_a': 'http://aleph.nkp.cz/F/?func=direct&doc_number=000344943&local_base=CNB'},
#  {'001': 'nos190244306',
#   '003': 'CZ PrNK',
#   '005': '20130823110622.0',
#   '008': '001125s1922    xr            ||| | cze',
#   '015_a': 'cnb000344947',
#   '040_a': 'ABA001',
#   '040_b': 'cze',
#   '040_c': 'LIA001',
#   '040_d': 'ABA001',
# ...

# %%
for p in pokus:
    if '072_a' in p and p['072_a']:
        if '821.162.3-3' in p['072_a']:
            ceska_beletrie.append(p)

# %%
sys.getsizeof(ceska_beletrie) * 60
# Out:
# 172320

# %%
w

# %%
ceska_beletrie
# Out:
# [{'001': 'nos190244603',
#   '003': 'CZ PrNK',
#   '005': '20230630094032.0',
#   '008': '001225s1907    xr     g      000 j cze',
#   '015_a': 'cnb000345282',
#   '040_a': 'ABA001',
#   '040_b': 'cze',
#   '040_c': 'LIA001',
#   '040_d': 'ABA001',
#   '072_ind2': '7',
#   '072_a': '821.162.3-3',
#   '072_x': 'Česká próza',
#   '072_2': 'Konspekt',
#   '072_9': '25',
#   '080_a': ['821.162.3-32', '(0:82-32)'],
#   '080_2': ['MRF', 'MRF'],
#   '100_ind1': '1',
#   '100_a': 'Sokol Tůma, František,',
#   '100_d': '1855-1925',
#   '100_7': 'jk01120356',
#   '100_4': 'aut',
#   '245_ind1': '1',
#   '245_ind2': '0',
#   '245_a': 'Povídky z pekla /',
#   '245_c': 'napsal Fr. Sokol-Tůma',
#   '260_a': 'Mor. Ostrava :',
#   '260_b': 'nákladem čas. Na Zdar!, orgánu Unie horníků rakouských,',
#   '260_c': '1907',
#   '260_e': '(V Přívoze :',
#   '260_f': 'knihtiskárna Birguse a Riedla)',
#   '300_a': '67, 29, 24, 5, 4 s. ;',
#   '300_c': '8°',
#   '500_a': 'Vl. jméno autora: František Tůma',
# ...

# %%
df = pd.read_json(os.path.join('data_raw/cnb', 'cnb_009.json'))
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\2772864601.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json(os.path.join('data_raw/cnb', 'cnb_009.json'))
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\2772864601.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json(os.path.join('data_raw/cnb', 'cnb_009.json'))
# ...

# %%
df
# Out:
#                 001      003             005  \
# 0      nos190244302  CZ PrNK  20001125000000
# 1      nos190244306  CZ PrNK  20130823110622
# 2      nos190244307  CZ PrNK  20161109145406
# 3      nos190244308  CZ PrNK  20001125000000
# 4      nos190244309  CZ PrNK  20001125000000
# ...             ...      ...             ...
# 19995   bk194603717  CZ PrNK  19980818000000
# 19996   bk194603718  CZ PrNK  19980818000000
# 19997   bk194603719  CZ PrNK  19980818000000
# 19998   bk198100193  CZ PrNK  20150514143216
# 19999   bk198100194  CZ PrNK  20150520135408
#
#                                           008         015_a   040_a 040_b  \
# 0      001125s1920    xr                  cze  cnb000344943  ABA001   cze
# 1      001125s1922    xr            ||| | cze  cnb000344947  ABA001   cze
# 2      001125s1921    xr            ||| | cze  cnb000344948  ABA001   cze
# 3      001125s1925    xr                  cze  cnb000344949  ABA001   cze
# ...

# %%
# Get a list of all JSON files in the directory
json_files = [f for f in os.listdir('data_raw/cnb') if f.endswith('.json')]

# Select 5 files at random
selected_files = random.sample(json_files, 5)

# %%
selected_files
# Out:
# ['cnb_025.json',
#  'cnb_019.json',
#  'cnb_016.json',
#  'cnb_024.json',
#  'cnb_018.json']

# %%
df = pd.DataFrame()
for f in selected_files:
    df = pd.concat([df, pd.read_json(os.path.join('data_raw/cnb',f))])
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\985574115.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.concat([df, pd.read_json(os.path.join('data_raw/cnb',f))])
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\985574115.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.concat([df, pd.read_json(os.path.join('data_raw/cnb',f))])
# ...

# %%
beletrie = df[df.apply(lambda row: row.astype(str).str.contains('beletr')).any(axis=1)]

# %%
sorted(df.columns.to_list())
# Out:
# ['001',
#  '003',
#  '005',
#  '006',
#  '007',
#  '008',
#  '015_a',
#  '015_z',
#  '020_a',
#  '020_c',
#  '020_q',
#  '020_z',
#  '022_a',
#  '022_y',
#  '022_z',
#  '024_a',
#  '024_ind1',
#  '024_q',
#  '024_z',
#  '028_a',
#  '028_b',
#  '028_ind1',
#  '028_ind2',
#  '034_a',
#  '034_b',
#  '034_d',
#  '034_e',
#  '034_f',
#  '034_g',
#  '034_ind1',
#  '035_a',
#  '040_a',
#  '040_b',
#  '040_c',
#  '040_d',
#  '040_e',
#  '041_a',
#  '041_b',
#  '041_d',
#  '041_e',
#  '041_f',
#  '041_g',
#  '041_h',
#  '041_ind1',
#  '041_k',
#  '043_2',
#  '043_a',
#  '043_b',
#  '044_a',
#  '045_a',
#  '047_a',
#  '048_a',
#  '048_b',
#  '048_ind2',
#  '072_2',
#  '072_9',
#  '072_a',
#  '072_ind2',
#  '072_x',
#  '080_2',
#  '080_a',
#  '080_x',
#  '100_4',
#  '100_7',
#  '100_a',
#  '100_b',
#  '100_c',
#  '100_d',
#  '100_ind1',
#  '100_q',
#  '110_4',
#  '110_7',
#  '110_a',
#  '110_b',
#  '110_c',
#  '110_d',
#  '110_ind1',
#  '110_n',
#  '111_4',
#  '111_7',
#  '111_a',
#  '111_c',
# ...

# %%
df[df['041_ind1'] == 0]
# Out:
#                   001      003           005  \
# 0         bk194203514  CZ PrNK  2.009013e+13
# 14        bk194203535  CZ PrNK  2.024043e+13
# 147       bk194204616  CZ PrNK  2.019032e+13
# 148       bk194204617  CZ PrNK  2.008102e+13
# 149       bk194204618  CZ PrNK  2.010011e+13
# ...               ...      ...           ...
# 19946  cpk19990650985  CZ PrNK  2.023012e+13
# 19950  cpk19990650990  CZ PrNK  2.005043e+13
# 19954  cpk19990650994  CZ PrNK  2.004110e+13
# 19962  cpk20010651006  CZ PrNK  2.009043e+13
# 19981  cpk20000651036  CZ PrNK  2.003092e+13
#
#                                           008         015_a            035_a  \
# 0      990423s1933    xr                  cze  cnb000810846  (OCoLC)85667244
# 14     990426s1921    xr ac         000 0 cze  cnb000810867   (OCoLC)5230724
# 147    990525m19411942xr            001 0 lat  cnb000811036  (OCoLC)14749177
# 148    990525s1929    xr                  fre  cnb000811037  (OCoLC)85670531
# ...

# %%
df['041_ind1'].drop_duplicates()
# Out:
# 0     0.0
# 1     NaN
# 70    1.0
# Name: 041_ind1, dtype: float64

# %%
df
# Out:
#                   001      003           005  \
# 0         bk194203514  CZ PrNK  2.009013e+13
# 1         bk194203516  CZ PrNK  2.009022e+13
# 2         bk194203517  CZ PrNK  1.999042e+13
# 3         bk194203518  CZ PrNK  2.018052e+13
# 4         bk194203519  CZ PrNK  2.010111e+13
# ...               ...      ...           ...
# 19995  nkc19990651055  CZ PrNK  2.012011e+13
# 19996  cpk19990651059  CZ PrNK  2.007022e+13
# 19997  cpk20000651061  CZ PrNK  2.009121e+13
# 19998  cpk19990651062  CZ PrNK  2.024013e+13
# 19999  cpk20010651063  CZ PrNK  2.022102e+13
#
#                                             008         015_a  \
# 0        990423s1933    xr                  cze  cnb000810846
# 1        990423s1928    xr                  cze  cnb000810848
# 2        990423q19001942xr                  cze  cnb000810849
# 3        000204s1931    xr     g      000 0 cze  cnb000810850
# 4        990423s1934    xr            001   cze  cnb000810851
# ...

# %%
df.groupby('260_c').size().nlargest(40)
# Out:
# 260_c
# 2005     577
# 2004     574
# 2003     526
# nan      491
# 2002     461
# 2000     383
# 2001     305
# 2006     290
# 1992     175
# 1993     167
# 1940     157
# 1991     107
# 1928      77
# 1930      75
# 1927      71
# 1990      70
# 1938      62
# 1926      59
# 1929      58
# 1893      57
# 1931      57
# p2000     56
# 1898      54
# 1900      53
# p2001     53
# 1894      51
# 1934      51
# 1896      50
# 1886      49
# 1892      49
# 1890      47
# 1897      46
# 1895      45
# 1899      45
# 1932      44
# 1933      44
# 1983      44
# 1921      43
# p2002     42
# p2003     42
# dtype: int64

# %%
slozka = 'data_raw/aleph'

# %%
df = pd.DataFrame()
for f in os.listdir(slozka)[0:2]:
    df = pd.concat([df, pd.read_json(os.path.join(slozka, f), dtype='str')])
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\2687617287.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.concat([df, pd.read_json(os.path.join(slozka, f), dtype='str')])
# C:\Users\micha\AppData\Local\Temp\ipykernel_13432\2687617287.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.concat([df, pd.read_json(os.path.join(slozka, f), dtype='str')])
# ...

# %%
sorted(df.columns.to_list())

# %%
for sloupec in df.columns.to_list():
    print(f"""*****{sloupec.upper()}******""")
    try:
        print(df[sloupec].dropna().drop_duplicates().sample(5))
    except:
        print(df[sloupec].drop_duplicates().sample())
# Out:
# *****001******
# 1420     bk193106140
# 2236       ck9006036
# 2573    nos190248252
# 954        ck9004531
# 1045     bk194405143
# Name: 001, dtype: object
# *****003******
# 0    CZ PrNK
# Name: 003, dtype: object
# *****005******
# 4892    20150609131236.0
# 1342    20210210131203.0
# 1498    20131107154426.0
# 4399    20061018104209.0
# 3084    20121018143837.0
# Name: 005, dtype: object
# *****007******
# 2480         q
# 3594        co
# 385        nan
# 3635    co cga
# 0           tu
# Name: 007, dtype: object
# *****008******
# 3465    000327s2000    xr     e      000 0 eng
# 826     000813s1923    xr            ||| | cze
# 4853    840124s1983    xr           u0|0   cze
# 1188    001023q19982000xr a   g f    000 0 cze
# 3421    001204p20001962xr pfnne fi       n zxx
# Name: 008, dtype: object
# *****015_A******
# 4572    cnb000943478
# 3707    cnb000929431
# 1514    cnb000901915
# 4290    cnb000936721
# 3864    cnb000949326
# Name: 015_a, dtype: object
# *****020_Q******
# ...

# %%
romany = df[df.apply(lambda row: row.astype(str).str.contains('román')).any(axis=1)]

# %%
pd.set_option('display.max_columns', 1000)

# %%
ceske_romany = df[(df['655_a'] == 'české romány') | ((df['655_a'].str.contains('román',na=False)) & (df['040_b'] == df['041_h'])) | (df['072_x'] == 'Česká próza')].reset_index(drop=True)

# %%
ceske_romany.to_json(os.path.join('data_raw','ceske_romany_raw.json'))

# %%
romany_presnejsi
# Out:
#                  001      003               005 007  \
# 292        ck8300418  CZ PrNK  20160510144331.0  tu
# 299        ck8300425  CZ PrNK  20070924093448.0  ta
# 305        ck8300431  CZ PrNK  20150713121737.0  tu
# 306        ck8300433  CZ PrNK  20180124123628.0  tu
# 308        ck8300435  CZ PrNK  20200609094831.0  tu
# ...              ...      ...               ...  ..
# 4921  cpk20000976963  CZ PrNK  20160609105714.0  tu
# 4922  cpk20000976964  CZ PrNK  20120402090522.0  tu
# 4931  cpk20000977000  CZ PrNK  20051130115631.0  tu
# 4944  cpk20000977020  CZ PrNK  20201218104315.0  ta
# 4960  cpk20000977064  CZ PrNK  20040916000000.0  tu
#
#                                          008         015_a      020_q  \
# 292   830214s1982    xr a   e      000 1 cze  cnb000000437   (Váz.) :
# 299   830406s1982    xr ac         000 1 cze  cnb000000444  (Brož.) :
# 305   830331s1982    xr a          0|0 1 cze  cnb000000450   (Váz.) :
# ...

# %%
romany.iloc[[3695]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1714, in _iLocIndexer._get_list_axis(self, key, axis)
#    1713 try:
# -> 1714     return self.obj._take_with_is_copy(key, axis=axis)
#    1715 except IndexError as err:
#    1716     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4144 """
#    4145 Internal version of the `take` method that sets the `_is_copy`
#    4146 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151 See the docstring of `take` for full explanation of the parameters.
#    4152 """
# -> 4153 result = self.take(indices=indices, axis=axis)
#    4154 # Maybe set copy if we didn't actually change the index.
#
# ...

# %%
romany[['020_c','020_q','100_a','100_d','040_b','041_h','245_a','245_b','250_a','260_a','260_b','260_c','964_a','300_c','500_a','550_a','655_a','830_a','072_x']]
# Out:
#           020_c     020_q                            100_a      100_d 040_b  \
# 236   Kčs 32,00  (Váz.) :                    Noll, Dieter,  1927-2008   cze
# 237   Kčs 45,00  (Váz.) :              Selinko, Annemarie,  1914-1986   cze
# 238      24 Kčs  (Váz.) :                 Schickele, René,  1883-1940   cze
# 250   Kčs 17,00  (Váz.) :               Skármeta, Antonio,      1940-   cze
# 251      32 Kčs  (Váz.) :  Fedosejev, Grigorij Anisimovič,  1899-1968   cze
# ...         ...       ...                              ...        ...   ...
# 4753        nan    (Váz.)               Balzac, Honoré de,  1799-1850   cze
# 4767        nan    (Váz.)                    Kopta, Josef,  1894-1962   cze
# 4902        nan    (Váz.)              Rais, Karel Václav,  1859-1926   cze
# 4925        nan    (Váz.)                              nan        nan   cze
# 4972        nan    (váz.)                  Cheyney, Peter,  1896-1951   cze
#
# ...
