# %%
import os
import polars as pl
from src.bez_bordelu import bez_bordelu
from src.najdi_rok import najdi_rok
from src.pocet_stran import pocet_stran
pl.Config(tbl_rows=500)

# %%
df = pl.read_parquet(
    os.path.join("data","cnb_vyber.parquet")
).with_columns(
    pl.col('300_a').map_elements(pocet_stran, return_dtype=int).alias('stran')
).with_columns(
    pl.col('008').map_elements(najdi_rok, return_dtype=int).alias('rok')
).with_columns(
    pl.col('245_a').map_elements(bez_bordelu, return_dtype=str)
)

# %%
pl.read_parquet(os.path.join("data/cnb_sloupce","leader.parquet"))
# Out:
# shape: (1_250_624, 2)
# ┌──────────────────────────┬────────────────┐
# │ leader                   ┆ 001            │
# │ ---                      ┆ ---            │
# │ str                      ┆ str            │
# ╞══════════════════════════╪════════════════╡
# │      nam a22        4500 ┆ ck8300078      │
# │      nam a22        4500 ┆ ck8300080      │
# │      nam a22        4500 ┆ ck8300081      │
# │      nam a22        4500 ┆ ck8300082      │
# │      nam a22        4500 ┆ ck8300083      │
# │      nam a22        4500 ┆ ck8300084      │
# │      nam a22        4500 ┆ ck8300074      │
# │      nam a22        4500 ┆ ck8300086      │
# │      nam a22        4500 ┆ ck8300087      │
# │      nam a22        4500 ┆ ck8300088      │
# │      nam a22        4500 ┆ ck8300089      │
# │      nam a22        4500 ┆ ck8300090      │
# │      nam a22     2  4500 ┆ ck8300091      │
# │      nam a22        4500 ┆ ck8300092      │
# │      nam a22        4500 ┆ ck8300093      │
# ...

# %%
df.filter(pl.col("rok") == 2024).sample().select(pl.col("008")).to_series().to_list()
# Out:
# ['241219s2024    xr     g      000 p cze']

# %%
df.filter(pl.col("rok") == 2024).sample().select(pl.col("008")).to_series().to_list()

# %%
df.filter(pl.col("rok") == 2024).sample()
# Out:
# shape: (1, 64)
# ┌─────────────────┬─────────────────┬───────────┬─────────────────┬───┬────────────────┬────────────────┬───────┬──────┐
# │ 008             ┆ 020_a           ┆ 020_c     ┆ 020_q           ┆ … ┆ leader         ┆ 001            ┆ stran ┆ rok  │
# │ ---             ┆ ---             ┆ ---       ┆ ---             ┆   ┆ ---            ┆ ---            ┆ ---   ┆ ---  │
# │ str             ┆ list[str]       ┆ list[str] ┆ list[str]       ┆   ┆ str            ┆ str            ┆ i64   ┆ i64  │
# ╞═════════════════╪═════════════════╪═══════════╪═════════════════╪═══╪════════════════╪════════════════╪═══════╪══════╡
# │ 240815s2024     ┆ ["978-80-7332-5 ┆ null      ┆ ["(brožováno)"] ┆ … ┆ nam a22      i ┆ nkc20243626816 ┆ 262   ┆ 2024 │
# │ xr     g        ┆ 52-7"]          ┆           ┆                 ┆   ┆ 4500           ┆                ┆       ┆      │
# ...

# %%
df.select(pl.col("020_a")).sample(10)
# Out:
# shape: (10, 1)
# ┌───────────────────────┐
# │ 020_a                 │
# │ ---                   │
# │ list[str]             │
# ╞═══════════════════════╡
# │ null                  │
# │ ["978-80-7435-613-1"] │
# │ ["978-80-7306-436-5"] │
# │ null                  │
# │ null                  │
# │ ["80-901892-0-2"]     │
# │ null                  │
# │ null                  │
# │ null                  │
# │ null                  │
# └───────────────────────┘

# %%
df.filter(pl.col("245_a") == "Po")

# %%
df.explode("020_a").filter(pl.col("020_a") == "987-80-00-02756-2")
# Out:
# shape: (0, 64)
# ┌─────┬───────┬───────────┬───────────┬───┬────────┬─────┬───────┬─────┐
# │ 008 ┆ 020_a ┆ 020_c     ┆ 020_q     ┆ … ┆ leader ┆ 001 ┆ stran ┆ rok │
# │ --- ┆ ---   ┆ ---       ┆ ---       ┆   ┆ ---    ┆ --- ┆ ---   ┆ --- │
# │ str ┆ str   ┆ list[str] ┆ list[str] ┆   ┆ str    ┆ str ┆ i64   ┆ i64 │
# ╞═════╪═══════╪═══════════╪═══════════╪═══╪════════╪═════╪═══════╪═════╡
# └─────┴───────┴───────────┴───────────┴───┴────────┴─────┴───────┴─────┘
