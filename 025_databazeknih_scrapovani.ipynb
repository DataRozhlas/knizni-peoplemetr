# %%
import os
import time
import datetime
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
isbns = pd.read_json(os.path.join('data','sledovat.json'), dtype={'M_isbn':str})['M_isbn'].drop_duplicates().to_list()
print(f"Položek ke stažení: {len(isbns)}")
# Out:
# Položek ke stažení: 2835

# %%
def scrape_dk(isbn):
    
    kniha = {
        'ISBN': isbn,
        'DK_date': datetime.datetime.now().replace(microsecond=0).strftime('%Y-%m-%d %H:%M:%S')
    }
    
    try:
        r = requests.get(f"""https://www.databazeknih.cz/search?q={isbn}""")
        soup = BeautifulSoup(r.text, "html.parser")
    except Exception as e:
        print(e)
        try:
            time.sleep(120)
            r = requests.get(f"""https://www.databazeknih.cz/search?q={isbn}""")
            soup = BeautifulSoup(r.text, "html.parser")
        except:
            return {}
        
    kniha['DK_titul'] = soup.find("title").text.split("-")[0].strip()
    if kniha['DK_titul'] == 'Vyhledávání | Databáze knih':
        kniha['DK_titul'] = None
        return kniha
    
    try:
        kniha['DK_rating'] = int(soup.find(class_=lambda c: c and c.startswith("hodnoceni")).text.split(' ')[0].strip())
    except:
        pass
    try:
        kniha['DK_ratings_count'] = int(soup.find(class_="ratingDetail").text.replace('hodnocení','').replace(' ',''))
    except:
        pass
    
    kniha['DK_tags'] = [s.text for s in soup.find_all(class_="tag")]
    
    try:
        tabulka = soup.find(class_="morePadding")
        for tr in tabulka.find_all('tr'):
            try:
                kniha[f"""DK_{tr.find_all('td')[0].text.strip().replace(" ","_")}"""] = int(tr.find_all('td')[1].text.replace("x","").replace(" ","").strip())
            except:
                pass
    except:
        pass
    
    return kniha

# %%
scrape_dk('978-80-257-0493-6')
# Out:
# {'ISBN': '978-80-257-0493-6',
#  'DK_date': '2024-04-07 13:37:38',
#  'DK_titul': 'Zatím dobrý',
#  'DK_rating': 93,
#  'DK_ratings_count': 558,
#  'DK_tags': ['útěk',
#   'Tři králové',
#   'bratři Mašínové',
#   'komunistický režim',
#   'Magnesia Litera'],
#  'DK_Právě_čtených': 13,
#  'DK_Přečtených': 687,
#  'DK_Čtenářské_výzvě': 71,
#  'DK_Doporučených': 87,
#  'DK_Knihotéce': 178,
#  'DK_Chystám_se_číst': 422,
#  'DK_Chci_si_koupit': 80,
#  'DK_dalších_seznamech': 5}

# %%
current_date = datetime.datetime.now()
date_string = current_date.strftime("%Y_%m_%d")
print(date_string)
# Out:
# 2024_04_07

# %%
if not os.path.exists(f'data_raw/databazeknih/{date_string}'):
    os.makedirs(f'data_raw/databazeknih/{date_string}')

# %%
dknih = []
count = 0
for i in isbns:
    count += 1
    dknih.append(scrape_dk(i))
    if count % 20 == 0:
        pd.DataFrame(dknih).to_json(os.path.join(f'data_raw/databazeknih/{date_string}',f'databazeknih_{date_string}_{(int(count/20)):04d}.json'))
        print(f'databazeknih_{date_string}_{(int(count/20)):04d}.json')
        dknih = []
# Out:
# databazeknih_2024_04_07_0001.json
# databazeknih_2024_04_07_0002.json
# databazeknih_2024_04_07_0003.json
# databazeknih_2024_04_07_0004.json
# databazeknih_2024_04_07_0005.json
# databazeknih_2024_04_07_0006.json
# databazeknih_2024_04_07_0007.json
# databazeknih_2024_04_07_0008.json
# databazeknih_2024_04_07_0009.json
# databazeknih_2024_04_07_0010.json
# databazeknih_2024_04_07_0011.json
# databazeknih_2024_04_07_0012.json
# databazeknih_2024_04_07_0013.json
# databazeknih_2024_04_07_0014.json
# databazeknih_2024_04_07_0015.json
# databazeknih_2024_04_07_0016.json
# databazeknih_2024_04_07_0017.json
# databazeknih_2024_04_07_0018.json
# databazeknih_2024_04_07_0019.json
# databazeknih_2024_04_07_0020.json
# databazeknih_2024_04_07_0021.json
# databazeknih_2024_04_07_0022.json
# databazeknih_2024_04_07_0023.json
# databazeknih_2024_04_07_0024.json
# databazeknih_2024_04_07_0025.json
# databazeknih_2024_04_07_0026.json
# databazeknih_2024_04_07_0027.json
# databazeknih_2024_04_07_0028.json
# databazeknih_2024_04_07_0029.json
# databazeknih_2024_04_07_0030.json
# databazeknih_2024_04_07_0031.json
# databazeknih_2024_04_07_0032.json
# databazeknih_2024_04_07_0033.json
# databazeknih_2024_04_07_0034.json
# databazeknih_2024_04_07_0035.json
# databazeknih_2024_04_07_0036.json
# databazeknih_2024_04_07_0037.json
# databazeknih_2024_04_07_0038.json
# databazeknih_2024_04_07_0039.json
# databazeknih_2024_04_07_0040.json
# databazeknih_2024_04_07_0041.json
# databazeknih_2024_04_07_0042.json
# databazeknih_2024_04_07_0043.json
# databazeknih_2024_04_07_0044.json
# databazeknih_2024_04_07_0045.json
# databazeknih_2024_04_07_0046.json
# databazeknih_2024_04_07_0047.json
# databazeknih_2024_04_07_0048.json
# databazeknih_2024_04_07_0049.json
# databazeknih_2024_04_07_0050.json
# databazeknih_2024_04_07_0051.json
# databazeknih_2024_04_07_0052.json
# databazeknih_2024_04_07_0053.json
# databazeknih_2024_04_07_0054.json
# databazeknih_2024_04_07_0055.json
# databazeknih_2024_04_07_0056.json
# databazeknih_2024_04_07_0057.json
# databazeknih_2024_04_07_0058.json
# databazeknih_2024_04_07_0059.json
# databazeknih_2024_04_07_0060.json
# databazeknih_2024_04_07_0061.json
# databazeknih_2024_04_07_0062.json
# databazeknih_2024_04_07_0063.json
# databazeknih_2024_04_07_0064.json
# databazeknih_2024_04_07_0065.json
# databazeknih_2024_04_07_0066.json
# databazeknih_2024_04_07_0067.json
# databazeknih_2024_04_07_0068.json
# databazeknih_2024_04_07_0069.json
# databazeknih_2024_04_07_0070.json
# databazeknih_2024_04_07_0071.json
# databazeknih_2024_04_07_0072.json
# databazeknih_2024_04_07_0073.json
# databazeknih_2024_04_07_0074.json
# databazeknih_2024_04_07_0075.json
# databazeknih_2024_04_07_0076.json
# databazeknih_2024_04_07_0077.json
# databazeknih_2024_04_07_0078.json
# databazeknih_2024_04_07_0079.json
# databazeknih_2024_04_07_0080.json
# databazeknih_2024_04_07_0081.json
# databazeknih_2024_04_07_0082.json
# databazeknih_2024_04_07_0083.json
# databazeknih_2024_04_07_0084.json
# databazeknih_2024_04_07_0085.json
# databazeknih_2024_04_07_0086.json
# databazeknih_2024_04_07_0087.json
# databazeknih_2024_04_07_0088.json
# databazeknih_2024_04_07_0089.json
# databazeknih_2024_04_07_0090.json
# databazeknih_2024_04_07_0091.json
# databazeknih_2024_04_07_0092.json
# databazeknih_2024_04_07_0093.json
# databazeknih_2024_04_07_0094.json
# databazeknih_2024_04_07_0095.json
# databazeknih_2024_04_07_0096.json
# databazeknih_2024_04_07_0097.json
# databazeknih_2024_04_07_0098.json
# databazeknih_2024_04_07_0099.json
# databazeknih_2024_04_07_0100.json
# databazeknih_2024_04_07_0101.json
# databazeknih_2024_04_07_0102.json
# databazeknih_2024_04_07_0103.json
# databazeknih_2024_04_07_0104.json
# databazeknih_2024_04_07_0105.json
# databazeknih_2024_04_07_0106.json
# databazeknih_2024_04_07_0107.json
# databazeknih_2024_04_07_0108.json
# databazeknih_2024_04_07_0109.json
# databazeknih_2024_04_07_0110.json
# databazeknih_2024_04_07_0111.json
# databazeknih_2024_04_07_0112.json
# databazeknih_2024_04_07_0113.json
# databazeknih_2024_04_07_0114.json
# databazeknih_2024_04_07_0115.json
# databazeknih_2024_04_07_0116.json
# databazeknih_2024_04_07_0117.json
# databazeknih_2024_04_07_0118.json
# databazeknih_2024_04_07_0119.json
# databazeknih_2024_04_07_0120.json
# databazeknih_2024_04_07_0121.json
# databazeknih_2024_04_07_0122.json
# databazeknih_2024_04_07_0123.json
# databazeknih_2024_04_07_0124.json
# databazeknih_2024_04_07_0125.json
# databazeknih_2024_04_07_0126.json
# databazeknih_2024_04_07_0127.json
# databazeknih_2024_04_07_0128.json
# databazeknih_2024_04_07_0129.json
# databazeknih_2024_04_07_0130.json
# databazeknih_2024_04_07_0131.json
# databazeknih_2024_04_07_0132.json
# databazeknih_2024_04_07_0133.json
# databazeknih_2024_04_07_0134.json
# databazeknih_2024_04_07_0135.json
# databazeknih_2024_04_07_0136.json
# databazeknih_2024_04_07_0137.json
# databazeknih_2024_04_07_0138.json
# databazeknih_2024_04_07_0139.json
# databazeknih_2024_04_07_0140.json
# databazeknih_2024_04_07_0141.json
