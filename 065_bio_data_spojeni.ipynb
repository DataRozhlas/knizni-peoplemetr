# %%
import os
import polars as pl

# %%
wikid = pl.read_parquet(os.path.join("data","wikidata.parquet"))
aut = pl.read_parquet(os.path.join("data","aut_vyber.parquet"))

# %%
wikid.shape
# Out:
# (134708, 34)

# %%
aut.shape
# Out:
# (1219819, 34)

# %%
wikid
# Out:
# shape: (134_708, 34)
# ┌────────────┬──────────────┬────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬─────────────┐
# │ 024_a      ┆ ceny         ┆ druh_umrti ┆ facebook     ┆ … ┆ web          ┆ wiki_cs      ┆ wiki_en      ┆ __index_lev │
# │ ---        ┆ ---          ┆ ---        ┆ ---          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ el_0__      │
# │ str        ┆ list[str]    ┆ str        ┆ str          ┆   ┆ str          ┆ str          ┆ str          ┆ ---         │
# │            ┆              ┆            ┆              ┆   ┆              ┆              ┆              ┆ str         │
# ╞════════════╪══════════════╪════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪═════════════╡
# │ Q1063371   ┆ null         ┆ null       ┆ null         ┆ … ┆ null         ┆ https://cs.w ┆ https://en.w ┆ jk01010005  │
# ...

# %%
aut
# Out:
# shape: (1_219_819, 34)
# ┌───────────────┬───────────────┬───────────┬───────────┬───┬───────────────┬───────────┬───────────────┬──────────────┐
# │ 024_2         ┆ 024_a         ┆ 046_f     ┆ 046_g     ┆ … ┆ 678_a         ┆ 856_u     ┆ leader        ┆ 001          │
# │ ---           ┆ ---           ┆ ---       ┆ ---       ┆   ┆ ---           ┆ ---       ┆ ---           ┆ ---          │
# │ list[str]     ┆ list[str]     ┆ list[str] ┆ list[str] ┆   ┆ list[str]     ┆ list[str] ┆ str           ┆ str          │
# ╞═══════════════╪═══════════════╪═══════════╪═══════════╪═══╪═══════════════╪═══════════╪═══════════════╪══════════════╡
# │ null          ┆ null          ┆ ["1931"]  ┆ null      ┆ … ┆ ["Narozen     ┆ null      ┆ nz  a22     n ┆ jk01010001   │
# │               ┆               ┆           ┆           ┆   ┆ 14.12.1931 v  ┆           ┆ 4500          ┆              │
# ...

# %%
df = aut.explode("024_a").explode("100_7").join(wikid, left_on='100_7', right_on='024_a',how='full')

# %%
df
# Out:
# shape: (1_417_645, 68)
# ┌────────────────┬────────────────┬───────────┬───────────┬───┬──────┬────────────────┬────────────────┬───────────────┐
# │ 024_2          ┆ 024_a          ┆ 046_f     ┆ 046_g     ┆ … ┆ web  ┆ wiki_cs        ┆ wiki_en        ┆ __index_level │
# │ ---            ┆ ---            ┆ ---       ┆ ---       ┆   ┆ ---  ┆ ---            ┆ ---            ┆ _0__          │
# │ list[str]      ┆ str            ┆ list[str] ┆ list[str] ┆   ┆ str  ┆ str            ┆ str            ┆ ---           │
# │                ┆                ┆           ┆           ┆   ┆      ┆                ┆                ┆ str           │
# ╞════════════════╪════════════════╪═══════════╪═══════════╪═══╪══════╪════════════════╪════════════════╪═══════════════╡
# │ null           ┆ null           ┆ ["1931"]  ┆ null      ┆ … ┆ null ┆ null           ┆ null           ┆ null          │
# ...

# %%
df.explode("100_a").filter(pl.col('100_a').str.contains('Čapek. Karel'))
# Out:
# shape: (383, 68)
# ┌────────────────┬────────────────┬───────────┬───────────┬───┬──────┬────────────────┬────────────────┬───────────────┐
# │ 024_2          ┆ 024_a          ┆ 046_f     ┆ 046_g     ┆ … ┆ web  ┆ wiki_cs        ┆ wiki_en        ┆ __index_level │
# │ ---            ┆ ---            ┆ ---       ┆ ---       ┆   ┆ ---  ┆ ---            ┆ ---            ┆ _0__          │
# │ list[str]      ┆ str            ┆ list[str] ┆ list[str] ┆   ┆ str  ┆ str            ┆ str            ┆ ---           │
# │                ┆                ┆           ┆           ┆   ┆      ┆                ┆                ┆ str           │
# ╞════════════════╪════════════════╪═══════════╪═══════════╪═══╪══════╪════════════════╪════════════════╪═══════════════╡
# │ ["isni",       ┆ 00000001212720 ┆ ["1890"]  ┆ ["1938"]  ┆ … ┆ null ┆ null           ┆ null           ┆ null          │
# ...

# %%
df
# Out:
# shape: (1_417_645, 68)
# ┌────────────────┬────────────────┬───────────┬───────────┬───┬──────┬────────────────┬────────────────┬───────────────┐
# │ 024_2          ┆ 024_a          ┆ 046_f     ┆ 046_g     ┆ … ┆ web  ┆ wiki_cs        ┆ wiki_en        ┆ __index_level │
# │ ---            ┆ ---            ┆ ---       ┆ ---       ┆   ┆ ---  ┆ ---            ┆ ---            ┆ _0__          │
# │ list[str]      ┆ str            ┆ list[str] ┆ list[str] ┆   ┆ str  ┆ str            ┆ str            ┆ ---           │
# │                ┆                ┆           ┆           ┆   ┆      ┆                ┆                ┆ str           │
# ╞════════════════╪════════════════╪═══════════╪═══════════╪═══╪══════╪════════════════╪════════════════╪═══════════════╡
# │ null           ┆ null           ┆ ["1931"]  ┆ null      ┆ … ┆ null ┆ null           ┆ null           ┆ null          │
# ...
