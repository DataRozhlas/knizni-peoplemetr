# %%
import os
import datetime
import warnings
import polars as pl
import pandas as pd
import altair as alt

from src.najdi_rok import najdi_rok
from src.pocet_stran import pocet_stran
from src.bez_bordelu import bez_bordelu
from src.alt_friendly import alt_friendly
from src.hezke_jmeno import hezke_jmeno
from src.kristi_promin import kristi_promin
from src.zjisti_vazbu import zjisti_vazbu

pl.Config(tbl_rows=100)
alt.data_transformers.disable_max_rows()
alt.themes.register('irozhlas', kristi_promin)
alt.themes.enable('irozhlas')
warnings.filterwarnings('ignore')

# %%
df = pl.read_parquet(os.path.join("data/cnb_sloupce","100.parquet"))
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","leader.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","008.parquet")), left_on="001", right_on="001", how="left")
df = df.to_pandas()
df = df[df["leader"].str[6].isin(["a", "t"])]
df = df[~df["leader"].str[7].isin(["b", "i", "s", " "])]
df = df[(df["008"].str[15:17] == "xr") & (df["008"].str[35:38] == "cze")]
df = pl.from_pandas(df)
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","020.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","022.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","245.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","300.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","655.parquet")), left_on="001", right_on="001", how="left")
df = df.join(pl.read_parquet(os.path.join("data/cnb_sloupce","700.parquet")), left_on="001", right_on="001", how="left")
df = df.explode("022_a").filter(pl.col("022_a").is_null())
df = df.with_columns(pl.col('008').map_elements(najdi_rok, return_dtype=int).alias('rok'))
df = df.with_columns(pl.col('300_a').map_elements(pocet_stran, return_dtype=int).alias('stran'))
df = df.with_columns(pl.col('245_a').map_elements(bez_bordelu, return_dtype=str))
df = df.explode("020_q").with_columns(pl.col("020_q").map_elements(zjisti_vazbu, return_dtype=str).alias('vazba'))
df = df.explode('245_p').with_columns(pl.col('245_p').map_elements(bez_bordelu, return_dtype=str))
df = df.filter(pl.col("stran") > 15)
print(len(df))
df = df.filter((~pl.col("245_h").str.contains("grafika")) | pl.col("245_h").is_null()).unique(subset=["100_a","245_a"], keep="first")
print(len(df))
# Out:
# 727498
# 525308

# %%
aut = pl.read_parquet(os.path.join("data","aut_vyber.parquet"))
cesi = aut.explode("370_c").filter(pl.col("370_c").str.contains("Česk")).explode("100_7").select(pl.col("100_7")).to_series().to_list()
len(cesi)
# Out:
# 364420

# %%
df = df.filter(pl.col("100_7").is_in(cesi))

# %%
vek = pl.read_parquet(os.path.join("data","narozeni-umrti-gender.parquet"))
df = df.join(vek, on="100_7", how="left").with_columns((pl.col("rok") - pl.col("narozeni")).alias("vek"))

# %%
historicky_podil = df.filter(
    pl.col('gender') == 'm').group_by("rok").len().rename({'len':'m'}).join(
    df.filter(pl.col('gender') == 'f').group_by("rok").len().rename({'len':'f'}), on='rok'
).with_columns(((pl.col('f') / (pl.col('m') + pl.col('f'))).alias('podil'))).sort(by='rok').filter(
    pl.col("rok").is_between(1800,2024)).with_columns(
    pl.col("podil").rolling_mean(window_size=2)
    )

# %%
historicky_podil.head(20)
# Out:
# shape: (20, 4)
# ┌──────┬─────┬─────┬──────────┐
# │ rok  ┆ m   ┆ f   ┆ podil    │
# │ ---  ┆ --- ┆ --- ┆ ---      │
# │ i64  ┆ u32 ┆ u32 ┆ f64      │
# ╞══════╪═════╪═════╪══════════╡
# │ 1819 ┆ 13  ┆ 1   ┆ null     │
# │ 1825 ┆ 33  ┆ 1   ┆ 0.05042  │
# │ 1826 ┆ 18  ┆ 2   ┆ 0.064706 │
# │ 1827 ┆ 17  ┆ 2   ┆ 0.102632 │
# │ 1828 ┆ 20  ┆ 1   ┆ 0.076441 │
# │ 1830 ┆ 25  ┆ 2   ┆ 0.060847 │
# │ 1834 ┆ 17  ┆ 1   ┆ 0.064815 │
# │ 1838 ┆ 20  ┆ 1   ┆ 0.051587 │
# │ 1840 ┆ 27  ┆ 1   ┆ 0.041667 │
# │ 1841 ┆ 24  ┆ 1   ┆ 0.037857 │
# │ 1843 ┆ 47  ┆ 2   ┆ 0.040408 │
# │ 1844 ┆ 53  ┆ 1   ┆ 0.029667 │
# │ 1845 ┆ 44  ┆ 1   ┆ 0.02037  │
# │ 1846 ┆ 52  ┆ 1   ┆ 0.020545 │
# │ 1847 ┆ 57  ┆ 1   ┆ 0.018055 │
# │ 1848 ┆ 65  ┆ 1   ┆ 0.016196 │
# │ 1852 ┆ 77  ┆ 1   ┆ 0.013986 │
# │ 1854 ┆ 64  ┆ 1   ┆ 0.014103 │
# │ 1855 ┆ 52  ┆ 1   ┆ 0.017126 │
# │ 1856 ┆ 54  ┆ 1   ┆ 0.018525 │
# └──────┴─────┴─────┴──────────┘

# %%
historicky_podil.tail(20)
# Out:
# shape: (20, 4)
# ┌──────┬──────┬──────┬──────────┐
# │ rok  ┆ m    ┆ f    ┆ podil    │
# │ ---  ┆ ---  ┆ ---  ┆ ---      │
# │ i64  ┆ u32  ┆ u32  ┆ f64      │
# ╞══════╪══════╪══════╪══════════╡
# │ 2005 ┆ 3651 ┆ 1361 ┆ 0.271548 │
# │ 2006 ┆ 3654 ┆ 1510 ┆ 0.292409 │
# │ 2007 ┆ 3809 ┆ 1560 ┆ 0.290557 │
# │ 2008 ┆ 3864 ┆ 1614 ┆ 0.294633 │
# │ 2009 ┆ 3554 ┆ 1569 ┆ 0.306266 │
# │ 2010 ┆ 3720 ┆ 1615 ┆ 0.302718 │
# │ 2011 ┆ 3292 ┆ 1463 ┆ 0.307676 │
# │ 2012 ┆ 3123 ┆ 1467 ┆ 0.319608 │
# │ 2013 ┆ 3534 ┆ 1695 ┆ 0.324154 │
# │ 2014 ┆ 3683 ┆ 1813 ┆ 0.329876 │
# │ 2015 ┆ 3928 ┆ 2068 ┆ 0.344897 │
# │ 2016 ┆ 3641 ┆ 1955 ┆ 0.349357 │
# │ 2017 ┆ 3578 ┆ 1915 ┆ 0.348626 │
# │ 2018 ┆ 3511 ┆ 1958 ┆ 0.358018 │
# │ 2019 ┆ 3245 ┆ 1895 ┆ 0.368677 │
# │ 2020 ┆ 3224 ┆ 1961 ┆ 0.378206 │
# │ 2021 ┆ 3156 ┆ 2064 ┆ 0.395402 │
# │ 2022 ┆ 3000 ┆ 1959 ┆ 0.395039 │
# │ 2023 ┆ 2658 ┆ 1728 ┆ 0.393981 │
# │ 2024 ┆ 2248 ┆ 1480 ┆ 0.396996 │
# └──────┴──────┴──────┴──────────┘

# %%
alt.Chart(
    alt_friendly(historicky_podil.filter(pl.col("rok") >= 1900)), width=300, height=100,
    title=["Podíl ženských autorek na nově vydaných","původních českých knihách všech žánrů"]
).mark_line().encode(
    alt.X('rok:T', title=None, axis=alt.Axis(tickCount=4)),
    alt.Y('podil:Q', axis=alt.Axis(tickCount=4, labelExpr="datum.label * 100 + ' %'", orient='right'), title=None, scale=alt.Scale(domain=[0,0.5]))
).configure_view(stroke='transparent')
# Out:
# alt.Chart(...)

# %%
df_do_sta = df.filter(pl.col("vek") < 100) #.filter(pl.col("rok").is_between(1999,2024))

# %%
ceska_poezie = df_do_sta.sort(by="rok").unique(
        subset=["100_a","245_a"]
    ).explode("655_a").filter(
        pl.col("655_a") == "česká poezie"
)

# %%
df_do_sta.filter(pl.col("rok") == 2012).explode("655_a").group_by("655_a").len().sort(by="len",descending=True)
# Out:
# shape: (553, 2)
# ┌─────────────────────────────────┬─────┐
# │ 655_a                           ┆ len │
# │ ---                             ┆ --- │
# │ str                             ┆ u32 │
# ╞═════════════════════════════════╪═════╡
# │ monografie                      ┆ 602 │
# │ monographs                      ┆ 594 │
# │ učebnice vysokých škol          ┆ 320 │
# │ textbooks (higher)              ┆ 314 │
# │ česká poezie                    ┆ 298 │
# │ Czech poetry                    ┆ 292 │
# │ publikace pro děti              ┆ 254 │
# │ kolektivní monografie           ┆ 253 │
# │ collective monographs           ┆ 252 │
# │ children's literature           ┆ 250 │
# │ příručky                        ┆ 240 │
# │ české romány                    ┆ 238 │
# │ handbooks and manuals           ┆ 237 │
# │ Czech fiction                   ┆ 236 │
# │ české příběhy                   ┆ 175 │
# │ Czech stories                   ┆ 167 │
# │ fotografické publikace          ┆ 158 │
# │ photographical works            ┆ 152 │
# │ populárně-naučné publikace      ┆ 143 │
# │ popular works                   ┆ 142 │
# │ metodické příručky              ┆ 137 │
# │ studie                          ┆ 134 │
# │ informační publikace            ┆ 132 │
# │ studies                         ┆ 131 │
# │ information publications        ┆ 126 │
# │ methodological manuals          ┆ 126 │
# │ essays                          ┆ 122 │
# │ přehledy                        ┆ 120 │
# │ české prózy                     ┆ 114 │
# │ surveys                         ┆ 113 │
# │ Czech prose                     ┆ 110 │
# │ obrazové publikace              ┆ 109 │
# │ pictorial works                 ┆ 107 │
# │ educational texts               ┆ 104 │
# │ učební texty                    ┆ 104 │
# │ české povídky                   ┆ 89  │
# │ autobiografické vzpomínky       ┆ 87  │
# │ Czech short stories             ┆ 86  │
# │ biografie                       ┆ 82  │
# │ autobiographical reminiscences  ┆ 82  │
# │ biography                       ┆ 81  │
# │ jubilejní publikace             ┆ 65  │
# │ sborníky                        ┆ 63  │
# │ úvahy                           ┆ 62  │
# │ jubilee books                   ┆ 62  │
# │ brožury                         ┆ 60  │
# │ brochures                       ┆ 56  │
# │ kuchařské recepty               ┆ 55  │
# │ rozhovory                       ┆ 54  │
# │ cookbooks                       ┆ 54  │
# │ …                               ┆ …   │
# │ jazykové učebnice, texty, přír… ┆ 1   │
# │ statistics                      ┆ 1   │
# │ epigrams                        ┆ 1   │
# │ science fiction prose           ┆ 1   │
# │ reprints                        ┆ 1   │
# │ poezie v próze                  ┆ 1   │
# │ horror tales                    ┆ 1   │
# │ didaktické příběhy              ┆ 1   │
# │ autobiographical novellas       ┆ 1   │
# │ vědecko-fantastické novely      ┆ 1   │
# │ nonfiction comics               ┆ 1   │
# │ vykládací karty                 ┆ 1   │
# │ vědecko-fantastické prózy       ┆ 1   │
# │ filozofická poezie              ┆ 1   │
# │ electronic books                ┆ 1   │
# │ historické komiksy              ┆ 1   │
# │ speciální bibliografie          ┆ 1   │
# │ German fiction                  ┆ 1   │
# │ novellas in German              ┆ 1   │
# │ dialogues                       ┆ 1   │
# │ francouzské romány              ┆ 1   │
# │ pověsti                         ┆ 1   │
# │ erotické novely                 ┆ 1   │
# │ čítanky                         ┆ 1   │
# │ Swedish fiction                 ┆ 1   │
# │ politické romány                ┆ 1   │
# │ language textbooks, texts, han… ┆ 1   │
# │ bachelor's theses               ┆ 1   │
# │ excerpts                        ┆ 1   │
# │ American fiction                ┆ 1   │
# │ travel novels                   ┆ 1   │
# │ biographical prose              ┆ 1   │
# │ rigorózní práce                 ┆ 1   │
# │ americké romány                 ┆ 1   │
# │ naučné komiksy                  ┆ 1   │
# │ prose poems                     ┆ 1   │
# │ satirické romány                ┆ 1   │
# │ jazykové slovníky               ┆ 1   │
# │ epic poetry                     ┆ 1   │
# │ faksimile                       ┆ 1   │
# │ French fiction                  ┆ 1   │
# │ satire                          ┆ 1   │
# │ cestopisné povídky              ┆ 1   │
# │ Polish poetry                   ┆ 1   │
# │ sbírky                          ┆ 1   │
# │ didactic stories                ┆ 1   │
# │ fantasy prózy                   ┆ 1   │
# │ židovské pověsti                ┆ 1   │
# │ fantasy novellas                ┆ 1   │
# │ special bibliography            ┆ 1   │
# └─────────────────────────────────┴─────┘

# %%
ceske_romany = df_do_sta.sort(by="rok").unique(
        subset=["100_a","245_a"]
    ).explode("655_a").filter(
        pl.col("655_a") == "české romány"
)

# %%
ceske_kratke = df_do_sta.sort(by="rok").unique(
        subset=["100_a","245_a"]
    ).explode("655_a").filter(
        pl.col("655_a").is_in(["české novely","české povídky","české příběhy","české prózy"])
)

# %%
df_podil = ceske_romany.filter(
    pl.col("gender") == 'f'
).group_by("rok").len().sort(by="rok").rename({"len":'zeny'}).join(
    ceske_romany.filter(pl.col("gender") == 'm').group_by("rok").len().sort(by="rok").rename({"len":'muzi'}), on='rok'
).with_columns(
    (pl.col('zeny') + pl.col('muzi')).alias('celkem')
).with_columns(
    (pl.col('zeny') / pl.col('celkem')).alias('podil_zen')
).with_columns(pl.lit("romány").alias("zanr")).with_columns(pl.col("podil_zen").rolling_mean(window_size=2))

# %%
df_podil_kratke = ceske_kratke.filter(
    pl.col("gender") == 'f'
).group_by("rok").len().sort(by="rok").rename({"len":'zeny'}).join(
    ceske_kratke.filter(pl.col("gender") == 'm').group_by("rok").len().sort(by="rok").rename({"len":'muzi'}), on='rok'
).with_columns(
    (pl.col('zeny') + pl.col('muzi')).alias('celkem')
).with_columns(
    (pl.col('zeny') / pl.col('celkem')).alias('podil_zen')
).with_columns(pl.lit("kratší prózy").alias("zanr")).with_columns(pl.col("podil_zen").rolling_mean(window_size=2))

# %%
df_podil_poezie = ceska_poezie.filter(
    (pl.col("gender") == 'f')
).group_by("rok").len().sort(by="rok").rename({"len":'zeny'}).join(
    ceska_poezie.filter(pl.col("gender") == 'm').group_by("rok").len().sort(by="rok").rename({"len":'muzi'}), on='rok'
).with_columns(
    (pl.col('zeny') + pl.col('muzi')).alias('celkem')
).with_columns(
    (pl.col('zeny') / pl.col('celkem')).alias('podil_zen')
).with_columns(pl.lit("poezie").alias("zanr")).with_columns(pl.col("podil_zen").rolling_mean(window_size=2))

# %%
alt.Chart(
    alt_friendly(pl.concat([df_podil, df_podil_kratke, df_podil_poezie]).filter(pl.col('rok') >= 2000)), 
    title=alt.Title(["Podíl ženských autorek","na nově vydaných českých knihách"], lineHeight=21), width=250, height=80
         ).mark_line(
         ).encode(
    alt.X("rok:T", title=None, axis=alt.Axis(tickCount=5)),
    alt.Y('podil_zen:Q', title=None, axis=alt.Axis(tickCount=4, labelExpr="datum.label * 100 + ' %'", orient='right'), scale=alt.Scale(domain=[0,0.5])),
    alt.Row("zanr:N",header=alt.Header(labelAngle=0, labelAlign='left', labelAnchor='middle', labelFont='Asap'), sort=["romány","kratší prózy","poezie"], title=None)
).configure_view(stroke='transparent').resolve_scale(y='shared').resolve_axis(x="independent")
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Věková struktura

# %%
cr2 = pl.concat(ceske_romany, .group_by(["gender","vek"]).len().sort(by="vek")
cr2b = ceske_romany.filter(pl.col('rok').is_between(2015,2024)).group_by(["gender","vek"]).len().sort(by="vek")
cr2c = ceske_romany.filter(pl.col('rok').is_between(2000,2010)).group_by(["gender","vek"]).len().sort(by="vek")

# %%
alt.Chart(cr2b.filter(pl.col('gender').is_in(['m','f'])).to_pandas()).mark_line().encode(alt.X("vek"),alt.Y("len"),alt.Color("gender"))
# Out:
# alt.Chart(...)

# %%
alt.Chart(cr2c.filter(pl.col('gender').is_in(['m','f'])).to_pandas()).mark_line().encode(alt.X("vek"),alt.Y("len"),alt.Color("gender"))
# Out:
# alt.Chart(...)

# %%
alt.Chart(cr2.filter(pl.col('gender').is_in(['m','f'])).to_pandas()).mark_line().encode(alt.X("vek"),alt.Y("len"),alt.Color("gender"))
# Out:
# alt.Chart(...)

# %%
alt.Chart(cr2.filter(pl.col('gender').is_in(['m','f'])).to_pandas()).mark_bar().encode(alt.X("vek"),alt.Y("len"),alt.Row("gender"))
# Out:
# alt.Chart(...)

# %%
cr3 = ceske_romany.group_by(["gender","rok"]).agg(pl.col('vek').median())
cr3
# Out:
# shape: (63, 3)
# ┌────────┬──────┬──────┐
# │ gender ┆ rok  ┆ vek  │
# │ ---    ┆ ---  ┆ ---  │
# │ str    ┆ i64  ┆ f64  │
# ╞════════╪══════╪══════╡
# │ null   ┆ 2015 ┆ 36.0 │
# │ null   ┆ 2002 ┆ 58.5 │
# │ f      ┆ 2018 ┆ 45.0 │
# │ m      ┆ 2024 ┆ 51.0 │
# │ m      ┆ 2023 ┆ 53.0 │
# │ m      ┆ 2002 ┆ 55.0 │
# │ m      ┆ 2004 ┆ 51.0 │
# │ f      ┆ 2004 ┆ 49.0 │
# │ m      ┆ 2005 ┆ 53.5 │
# │ f      ┆ 2007 ┆ 47.0 │
# │ null   ┆ 2006 ┆ 45.0 │
# │ null   ┆ 2011 ┆ 53.0 │
# │ f      ┆ 2003 ┆ 51.0 │
# │ f      ┆ 2014 ┆ 46.0 │
# │ f      ┆ 2021 ┆ 41.0 │
# │ m      ┆ 2020 ┆ 57.0 │
# │ f      ┆ 2015 ┆ 48.0 │
# │ m      ┆ 2000 ┆ 55.0 │
# │ m      ┆ 2022 ┆ 51.0 │
# │ m      ┆ 2012 ┆ 53.0 │
# │ f      ┆ 2020 ┆ 44.0 │
# │ m      ┆ 2001 ┆ 55.5 │
# │ null   ┆ 2022 ┆ 38.0 │
# │ f      ┆ 2002 ┆ 50.0 │
# │ f      ┆ 2005 ┆ 51.0 │
# │ m      ┆ 2017 ┆ 57.5 │
# │ m      ┆ 2014 ┆ 54.5 │
# │ m      ┆ 2011 ┆ 54.0 │
# │ f      ┆ 2001 ┆ 49.0 │
# │ m      ┆ 2010 ┆ 52.0 │
# │ f      ┆ 2017 ┆ 46.0 │
# │ null   ┆ 2001 ┆ 15.0 │
# │ null   ┆ 2019 ┆ 61.0 │
# │ f      ┆ 2012 ┆ 49.0 │
# │ f      ┆ 2008 ┆ 48.0 │
# │ m      ┆ 2003 ┆ 56.0 │
# │ null   ┆ 2023 ┆ 39.0 │
# │ m      ┆ 2015 ┆ 56.0 │
# │ f      ┆ 2011 ┆ 48.5 │
# │ f      ┆ 2024 ┆ 42.0 │
# │ m      ┆ 2019 ┆ 52.0 │
# │ m      ┆ 2008 ┆ 53.0 │
# │ f      ┆ 2023 ┆ 42.0 │
# │ f      ┆ 2009 ┆ 53.0 │
# │ f      ┆ 2013 ┆ 49.0 │
# │ f      ┆ 2019 ┆ 44.0 │
# │ f      ┆ 2000 ┆ 44.0 │
# │ m      ┆ 2006 ┆ 56.0 │
# │ f      ┆ 2010 ┆ 49.5 │
# │ f      ┆ 2022 ┆ 43.0 │
# │ m      ┆ 2016 ┆ 52.5 │
# │ m      ┆ 2013 ┆ 57.5 │
# │ null   ┆ 2010 ┆ 32.0 │
# │ null   ┆ 2008 ┆ 30.0 │
# │ null   ┆ 2024 ┆ 40.0 │
# │ m      ┆ 2009 ┆ 54.0 │
# │ null   ┆ 2004 ┆ 26.0 │
# │ null   ┆ 2014 ┆ 33.0 │
# │ m      ┆ 2007 ┆ 56.0 │
# │ f      ┆ 2006 ┆ 47.0 │
# │ m      ┆ 2018 ┆ 55.0 │
# │ m      ┆ 2021 ┆ 54.0 │
# │ f      ┆ 2016 ┆ 47.0 │
# └────────┴──────┴──────┘

# %%
alt.Chart(alt_friendly(cr3.filter(pl.col('gender').is_in(['m','f'])))).mark_line().encode(alt.X("rok"),alt.Y("vek"),alt.Row("gender"))
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Věková struktura, druhý pohled

# %%
pl.concat([ceske_romany, ceske_kratke]).group_by("rok").len().sort(by="rok")
# Out:
# shape: (204, 2)
# ┌──────┬─────┐
# │ rok  ┆ len │
# │ ---  ┆ --- │
# │ i64  ┆ u32 │
# ╞══════╪═════╡
# │ 1804 ┆ 1   │
# │ 1815 ┆ 1   │
# │ 1818 ┆ 1   │
# │ 1819 ┆ 1   │
# │ 1823 ┆ 2   │
# │ 1824 ┆ 1   │
# │ 1825 ┆ 10  │
# │ 1828 ┆ 4   │
# │ 1829 ┆ 2   │
# │ 1830 ┆ 3   │
# │ 1831 ┆ 4   │
# │ 1832 ┆ 1   │
# │ 1833 ┆ 1   │
# │ 1834 ┆ 5   │
# │ 1835 ┆ 2   │
# │ 1837 ┆ 2   │
# │ 1838 ┆ 4   │
# │ 1839 ┆ 1   │
# │ 1840 ┆ 1   │
# │ 1841 ┆ 4   │
# │ 1842 ┆ 6   │
# │ 1843 ┆ 3   │
# │ 1844 ┆ 9   │
# │ 1845 ┆ 3   │
# │ 1846 ┆ 5   │
# │ 1847 ┆ 10  │
# │ 1848 ┆ 5   │
# │ 1849 ┆ 5   │
# │ 1850 ┆ 2   │
# │ 1851 ┆ 3   │
# │ 1852 ┆ 9   │
# │ 1853 ┆ 7   │
# │ 1854 ┆ 8   │
# │ 1855 ┆ 10  │
# │ 1856 ┆ 12  │
# │ 1857 ┆ 15  │
# │ 1858 ┆ 14  │
# │ 1859 ┆ 7   │
# │ 1860 ┆ 7   │
# │ 1861 ┆ 11  │
# │ 1862 ┆ 12  │
# │ 1863 ┆ 9   │
# │ 1864 ┆ 6   │
# │ 1865 ┆ 9   │
# │ 1866 ┆ 9   │
# │ 1867 ┆ 9   │
# │ 1868 ┆ 13  │
# │ 1869 ┆ 11  │
# │ 1870 ┆ 11  │
# │ 1871 ┆ 10  │
# │ …    ┆ …   │
# │ 1976 ┆ 24  │
# │ 1977 ┆ 18  │
# │ 1978 ┆ 27  │
# │ 1979 ┆ 22  │
# │ 1980 ┆ 22  │
# │ 1981 ┆ 22  │
# │ 1982 ┆ 26  │
# │ 1983 ┆ 35  │
# │ 1984 ┆ 40  │
# │ 1985 ┆ 34  │
# │ 1986 ┆ 30  │
# │ 1987 ┆ 22  │
# │ 1988 ┆ 28  │
# │ 1989 ┆ 30  │
# │ 1990 ┆ 52  │
# │ 1991 ┆ 66  │
# │ 1992 ┆ 54  │
# │ 1993 ┆ 30  │
# │ 1994 ┆ 32  │
# │ 1995 ┆ 71  │
# │ 1996 ┆ 41  │
# │ 1997 ┆ 30  │
# │ 1998 ┆ 99  │
# │ 1999 ┆ 243 │
# │ 2000 ┆ 261 │
# │ 2001 ┆ 233 │
# │ 2002 ┆ 251 │
# │ 2003 ┆ 260 │
# │ 2004 ┆ 280 │
# │ 2005 ┆ 300 │
# │ 2006 ┆ 320 │
# │ 2007 ┆ 339 │
# │ 2008 ┆ 379 │
# │ 2009 ┆ 404 │
# │ 2010 ┆ 406 │
# │ 2011 ┆ 426 │
# │ 2012 ┆ 349 │
# │ 2013 ┆ 350 │
# │ 2014 ┆ 379 │
# │ 2015 ┆ 427 │
# │ 2016 ┆ 427 │
# │ 2017 ┆ 428 │
# │ 2018 ┆ 473 │
# │ 2019 ┆ 517 │
# │ 2020 ┆ 518 │
# │ 2021 ┆ 567 │
# │ 2022 ┆ 559 │
# │ 2023 ┆ 525 │
# │ 2024 ┆ 500 │
# │ 2025 ┆ 27  │
# └──────┴─────┘

# %%
pl.concat([ceske_romany, ceske_kratke]).filter(pl.col('rok') >= 2000)
# Out:
# shape: (9_905, 77)
# ┌──────────┬────────────────────────┬────────────────┬────────────────┬───┬──────────┬───────┬────────┬─────┐
# │ 100_ind1 ┆ 100_a                  ┆ 100_7          ┆ 100_4          ┆ … ┆ narozeni ┆ umrti ┆ gender ┆ vek │
# │ ---      ┆ ---                    ┆ ---            ┆ ---            ┆   ┆ ---      ┆ ---   ┆ ---    ┆ --- │
# │ str      ┆ str                    ┆ str            ┆ list[str]      ┆   ┆ i64      ┆ i64   ┆ str    ┆ i64 │
# ╞══════════╪════════════════════════╪════════════════╪════════════════╪═══╪══════════╪═══════╪════════╪═════╡
# │ 1        ┆ Strauss, Josef,        ┆ xx0004281      ┆ ["aut"]        ┆ … ┆ 1963     ┆ null  ┆ m      ┆ 42  │
# │ 1        ┆ Nachtmanová, Petra,    ┆ xx0040379      ┆ ["aut"]        ┆ … ┆ 1972     ┆ null  ┆ f      ┆ 35  │
# │ 1        ┆ Cubeca, Karel,         ┆ mzk2005309135  ┆ ["aut"]        ┆ … ┆ 1960     ┆ null  ┆ m      ┆ 49  │
# │ 1        ┆ Drescher, Alex,        ┆ xx0066461      ┆ ["aut"]        ┆ … ┆ 1972     ┆ null  ┆ m      ┆ 36  │
# │ 1        ┆ Cimický, Jan,          ┆ jk01020718     ┆ ["aut"]        ┆ … ┆ 1948     ┆ null  ┆ m      ┆ 69  │
# │ 1        ┆ Matějovský, Bohumil,   ┆ jo2008420235   ┆ ["aut"]        ┆ … ┆ 1961     ┆ null  ┆ m      ┆ 49  │
# │ 1        ┆ Řeháčková, Věra,       ┆ jn19990209737  ┆ ["aut"]        ┆ … ┆ 1950     ┆ null  ┆ f      ┆ 57  │
# │ 1        ┆ Hofmanová, Jaroslava,  ┆ xx0022910      ┆ ["aut"]        ┆ … ┆ 1963     ┆ null  ┆ f      ┆ 44  │
# │ 1        ┆ Gruber, Václav,        ┆ nlk20010096082 ┆ ["aut"]        ┆ … ┆ 1953     ┆ null  ┆ m      ┆ 66  │
# │ 1        ┆ Šumbera, Jan,          ┆ xx0194094      ┆ ["aut"]        ┆ … ┆ 1991     ┆ null  ┆ m      ┆ 26  │
# │ 1        ┆ Veliká, A. K.,         ┆ xx0242981      ┆ ["aut"]        ┆ … ┆ 1991     ┆ null  ┆ f      ┆ 30  │
# │ 1        ┆ Kanakaredes, Victoria, ┆ osa2011670834  ┆ ["aut"]        ┆ … ┆ 1982     ┆ null  ┆ f      ┆ 29  │
# │ 1        ┆ Niedl, František,      ┆ xx0007788      ┆ ["aut"]        ┆ … ┆ 1949     ┆ null  ┆ m      ┆ 66  │
# │ 1        ┆ Seidlová, Monika,      ┆ xx0223608      ┆ ["aut"]        ┆ … ┆ 1967     ┆ null  ┆ f      ┆ 53  │
# │ 1        ┆ Vanek, Marcel,         ┆ mzk2004148350  ┆ ["aut", "ill"] ┆ … ┆ 1964     ┆ null  ┆ m      ┆ 40  │
# │ 1        ┆ Lukášková, Markéta,    ┆ ola2017970705  ┆ ["aut"]        ┆ … ┆ 1988     ┆ null  ┆ f      ┆ 31  │
# │ 1        ┆ Kavčiak, Vladimír,     ┆ jk01053304     ┆ ["aut"]        ┆ … ┆ 1948     ┆ null  ┆ m      ┆ 61  │
# │ 1        ┆ Jirušková, Blanka,     ┆ xx0074608      ┆ ["aut"]        ┆ … ┆ 1971     ┆ null  ┆ f      ┆ 38  │
# │ 1        ┆ Šochová, Anna,         ┆ xx0016195      ┆ ["aut"]        ┆ … ┆ 1959     ┆ null  ┆ f      ┆ 52  │
# │ 1        ┆ Gruber, Václav,        ┆ nlk20010096082 ┆ ["aut"]        ┆ … ┆ 1953     ┆ null  ┆ m      ┆ 63  │
# │ 1        ┆ Monyová, Simona,       ┆ jn19990218070  ┆ ["aut"]        ┆ … ┆ 1967     ┆ 2011  ┆ f      ┆ 44  │
# │ 1        ┆ Kotleta, František     ┆ xx0123480      ┆ ["aut"]        ┆ … ┆ 1981     ┆ null  ┆ m      ┆ 38  │
# │ 1        ┆ Hrdlička, Pavel,       ┆ xx0159778      ┆ ["aut"]        ┆ … ┆ 1942     ┆ null  ┆ m      ┆ 70  │
# │ 1        ┆ Vitner, Jaromír,       ┆ jo20211131131  ┆ ["aut"]        ┆ … ┆ 1965     ┆ null  ┆ m      ┆ 56  │
# │ 1        ┆ Svobodová, Iveta,      ┆ mzk2003181793  ┆ ["aut"]        ┆ … ┆ 1965     ┆ null  ┆ f      ┆ 40  │
# │ 1        ┆ Bigstain, Sigi,        ┆ jo20201089434  ┆ ["aut"]        ┆ … ┆ 1961     ┆ null  ┆ m      ┆ 59  │
# │ 1        ┆ Táborský, Václav,      ┆ jk01131992     ┆ ["aut"]        ┆ … ┆ 1928     ┆ null  ┆ m      ┆ 77  │
# │ 1        ┆ Volný, Zdeněk,         ┆ jk01150551     ┆ ["aut"]        ┆ … ┆ 1946     ┆ null  ┆ m      ┆ 72  │
# │ 1        ┆ Vaňková, Ludmila,      ┆ jk01141586     ┆ ["aut"]        ┆ … ┆ 1927     ┆ 2022  ┆ f      ┆ 82  │
# │ 1        ┆ Fojtová, Věra,         ┆ jn19990209190  ┆ ["aut"]        ┆ … ┆ 1947     ┆ null  ┆ f      ┆ 57  │
# │ 1        ┆ Pivodová, Kristýna,    ┆ xx0014036      ┆ ["aut"]        ┆ … ┆ 1982     ┆ null  ┆ f      ┆ 34  │
# │ 1        ┆ Šochová, Anna,         ┆ xx0016195      ┆ ["aut"]        ┆ … ┆ 1959     ┆ null  ┆ f      ┆ 49  │
# │ 1        ┆ Přibil, Marek,         ┆ xx0025736      ┆ ["aut", "ill"] ┆ … ┆ 1976     ┆ null  ┆ m      ┆ 43  │
# │ 1        ┆ Šindelářová, Renata,   ┆ xx0004561      ┆ ["aut"]        ┆ … ┆ 1973     ┆ null  ┆ f      ┆ 30  │
# │ 1        ┆ Nezval, Martin,        ┆ jn19990009942  ┆ ["aut"]        ┆ … ┆ 1960     ┆ null  ┆ m      ┆ 52  │
# │ 1        ┆ Stainforth, Alexander, ┆ mzk2003175535  ┆ ["aut"]        ┆ … ┆ 1982     ┆ null  ┆ m      ┆ 29  │
# │ 1        ┆ Šedivá, Milada         ┆ ola2017975108  ┆ ["aut"]        ┆ … ┆ 1943     ┆ null  ┆ f      ┆ 74  │
# │ 1        ┆ Blanářová, Alena,      ┆ xx0235973      ┆ ["aut"]        ┆ … ┆ 1980     ┆ null  ┆ f      ┆ 39  │
# │ 1        ┆ Hanibal, Jiří,         ┆ jk01033407     ┆ ["aut"]        ┆ … ┆ 1929     ┆ 2024  ┆ m      ┆ 77  │
# │ 1        ┆ Novotný, David,        ┆ av2016918461   ┆ ["aut"]        ┆ … ┆ 1982     ┆ null  ┆ m      ┆ 39  │
# │ 1        ┆ Benešová, Dagmar,      ┆ xx0216585      ┆ ["aut"]        ┆ … ┆ 1953     ┆ null  ┆ f      ┆ 70  │
# │ 1        ┆ Körnerová, Hana Marie, ┆ jn19990201037  ┆ ["aut"]        ┆ … ┆ 1954     ┆ null  ┆ f      ┆ 62  │
# │ 1        ┆ Konečná, Ivana Tereza, ┆ jo2016920509   ┆ ["aut"]        ┆ … ┆ 1970     ┆ null  ┆ f      ┆ 49  │
# │ 1        ┆ Romanská, Lydie,       ┆ jk01102658     ┆ ["aut"]        ┆ … ┆ 1943     ┆ null  ┆ f      ┆ 77  │
# │ 1        ┆ Strauss, Josef,        ┆ xx0004281      ┆ ["aut", "pbl"] ┆ … ┆ 1963     ┆ null  ┆ m      ┆ 57  │
# │ 1        ┆ Harasimová, Markéta,   ┆ jn19990209216  ┆ ["aut"]        ┆ … ┆ 1977     ┆ null  ┆ f      ┆ 47  │
# │ 1        ┆ Ráž, Roman,            ┆ jk01102144     ┆ ["aut"]        ┆ … ┆ 1935     ┆ 2022  ┆ m      ┆ 74  │
# │ 1        ┆ Kubátová, Táňa,        ┆ xx0018442      ┆ ["aut"]        ┆ … ┆ 1958     ┆ null  ┆ f      ┆ 49  │
# │ 1        ┆ Prouza, Petr,          ┆ jk01101391     ┆ ["aut"]        ┆ … ┆ 1944     ┆ null  ┆ m      ┆ 67  │
# │ 1        ┆ Galas, Dagmar,         ┆ xx0188153      ┆ ["aut"]        ┆ … ┆ 1958     ┆ null  ┆ f      ┆ 57  │
# │ …        ┆ …                      ┆ …              ┆ …              ┆ … ┆ …        ┆ …     ┆ …      ┆ …   │
# │ 1        ┆ Dubská, Kateřina,      ┆ osa2013757226  ┆ ["aut"]        ┆ … ┆ 1965     ┆ null  ┆ f      ┆ 53  │
# │ 1        ┆ Hanák, Jiří,           ┆ mzk2004228717  ┆ ["aut"]        ┆ … ┆ 1950     ┆ null  ┆ m      ┆ 61  │
# │ 1        ┆ Cimický, Jan,          ┆ jk01020718     ┆ ["aut"]        ┆ … ┆ 1948     ┆ null  ┆ m      ┆ 67  │
# │ 1        ┆ Neumaier, Siegfried,   ┆ jo2010617153   ┆ ["aut"]        ┆ … ┆ 1972     ┆ null  ┆ m      ┆ 46  │
# │ 1        ┆ Novotný, Daniel,       ┆ xx0083171      ┆ ["aut"]        ┆ … ┆ 1979     ┆ null  ┆ m      ┆ 45  │
# │ 1        ┆ Uher, František,       ┆ jk01140612     ┆ ["aut"]        ┆ … ┆ 1936     ┆ null  ┆ m      ┆ 83  │
# │ 1        ┆ Lustig, Arnošt,        ┆ jk01072683     ┆ ["aut"]        ┆ … ┆ 1926     ┆ 2011  ┆ m      ┆ 80  │
# │ 1        ┆ Zrno, Filip,           ┆ jo20211119618  ┆ ["aut"]        ┆ … ┆ 1987     ┆ null  ┆ m      ┆ 36  │
# │ 1        ┆ Slavíček, Jiří,        ┆ mzk2005295078  ┆ ["aut"]        ┆ … ┆ 1942     ┆ null  ┆ m      ┆ 77  │
# │ 1        ┆ Bratršovský, Emil,     ┆ xx0088489      ┆ ["aut"]        ┆ … ┆ 1956     ┆ null  ┆ m      ┆ 56  │
# │ 1        ┆ Píža, Zdeněk,          ┆ xx0016461      ┆ ["aut"]        ┆ … ┆ 1955     ┆ null  ┆ m      ┆ 56  │
# │ 1        ┆ Urban, Radovan,        ┆ jo20010082984  ┆ ["aut"]        ┆ … ┆ 1955     ┆ 2021  ┆ m      ┆ 45  │
# │ 1        ┆ Drozd, Miroslav,       ┆ ola20040304001 ┆ ["aut"]        ┆ … ┆ 1943     ┆ null  ┆ m      ┆ 75  │
# │ 1        ┆ Neuwirth, Štěpán,      ┆ jo20000071174  ┆ ["aut"]        ┆ … ┆ 1944     ┆ null  ┆ m      ┆ 70  │
# │ 1        ┆ Peringer, Jan,         ┆ xx0122567      ┆ ["aut"]        ┆ … ┆ 1933     ┆ null  ┆ m      ┆ 82  │
# │ 1        ┆ Galambica, Ivan,       ┆ xx0013610      ┆ ["aut", "pbl"] ┆ … ┆ 1974     ┆ null  ┆ m      ┆ 46  │
# │ 1        ┆ Mandausová, Klára,     ┆ jx20101217009  ┆ ["aut"]        ┆ … ┆ 1968     ┆ null  ┆ f      ┆ 50  │
# │ 1        ┆ Kantorek, Pavel,       ┆ jn19990009878  ┆ ["aut", "ill"] ┆ … ┆ 1942     ┆ 2017  ┆ m      ┆ 65  │
# │ 1        ┆ Klein, Václav,         ┆ jx20120229015  ┆ ["aut"]        ┆ … ┆ 1940     ┆ null  ┆ m      ┆ 73  │
# │ 1        ┆ Řezníček, František,   ┆ xx0005953      ┆ ["aut"]        ┆ … ┆ 1978     ┆ null  ┆ m      ┆ 37  │
# │ 1        ┆ Nowicki, Arnold,       ┆ xx0018939      ┆ ["aut"]        ┆ … ┆ 1953     ┆ null  ┆ m      ┆ 51  │
# │ 1        ┆ Indrová, Petra,        ┆ mzk2018986442  ┆ ["aut"]        ┆ … ┆ 1970     ┆ null  ┆ f      ┆ 48  │
# │ 1        ┆ Kratochvil, Jiří,      ┆ jn19990209413  ┆ ["aut"]        ┆ … ┆ 1940     ┆ null  ┆ m      ┆ 75  │
# │ 1        ┆ Svěrák, Zdeněk,        ┆ jk01121890     ┆ ["aut"]        ┆ … ┆ 1936     ┆ null  ┆ m      ┆ 75  │
# │ 1        ┆ Dousková, Irena,       ┆ jn19990216043  ┆ ["aut"]        ┆ … ┆ 1964     ┆ null  ┆ f      ┆ 38  │
# │ 1        ┆ Řehounek, Jan,         ┆ jn20001005682  ┆ ["aut"]        ┆ … ┆ 1950     ┆ null  ┆ m      ┆ 72  │
# │ 1        ┆ Medek, Leonard,        ┆ xx0009389      ┆ ["aut"]        ┆ … ┆ 1962     ┆ null  ┆ m      ┆ 41  │
# │ 1        ┆ Raichl, Jiří,          ┆ xx0224757      ┆ ["aut"]        ┆ … ┆ 1966     ┆ null  ┆ m      ┆ 52  │
# │ 1        ┆ Váchal, Jan,           ┆ jn19981002371  ┆ ["aut"]        ┆ … ┆ 1960     ┆ null  ┆ m      ┆ 49  │
# │ 1        ┆ Emingerová, Dana,      ┆ jo20000080535  ┆ ["aut"]        ┆ … ┆ 1961     ┆ null  ┆ f      ┆ 59  │
# │ 1        ┆ Přibyl, Tomáš,         ┆ xx0215147      ┆ ["aut"]        ┆ … ┆ 1976     ┆ null  ┆ m      ┆ 41  │
# │ 1        ┆ Beneš, Jan,            ┆ jk01011587     ┆ ["aut"]        ┆ … ┆ 1936     ┆ 2007  ┆ m      ┆ 65  │
# │ 1        ┆ Kraus, Ivan,           ┆ jn19981001677  ┆ ["aut"]        ┆ … ┆ 1939     ┆ null  ┆ m      ┆ 63  │
# │ 1        ┆ Provazník, Josef,      ┆ ola20191044041 ┆ ["aut"]        ┆ … ┆ 1979     ┆ null  ┆ m      ┆ 41  │
# │ 1        ┆ Čeliš, Eduard,         ┆ jx20111213047  ┆ ["aut", "pht"] ┆ … ┆ 1945     ┆ null  ┆ m      ┆ 70  │
# │ 1        ┆ Moučková, Miroslava,   ┆ ola2003165575  ┆ ["aut"]        ┆ … ┆ 1954     ┆ null  ┆ f      ┆ 46  │
# │ 1        ┆ Křesadlo, Jan,         ┆ jn19981001717  ┆ ["aut"]        ┆ … ┆ 1926     ┆ 1995  ┆ m      ┆ 80  │
# │ 1        ┆ Vorlíčková, Kristýna,  ┆ jn20020217018  ┆ ["aut"]        ┆ … ┆ 1981     ┆ 2018  ┆ f      ┆ 20  │
# │ 1        ┆ Adlerová, Martina,     ┆ xx0252318      ┆ ["aut"]        ┆ … ┆ 1972     ┆ null  ┆ f      ┆ 49  │
# │ 1        ┆ Šabach, Petr,          ┆ jn19990201046  ┆ ["aut"]        ┆ … ┆ 1951     ┆ 2017  ┆ m      ┆ 63  │
# │ 1        ┆ Bazger, Petr,          ┆ xx0246232      ┆ ["aut"]        ┆ … ┆ 1974     ┆ null  ┆ m      ┆ 46  │
# │ 1        ┆ Vaner, Vojtěch,        ┆ jo20000080603  ┆ ["aut"]        ┆ … ┆ 1975     ┆ null  ┆ m      ┆ 44  │
# │ 1        ┆ Ševčíková, Jaroslava,  ┆ jo2008428028   ┆ ["aut"]        ┆ … ┆ 1967     ┆ null  ┆ f      ┆ 41  │
# │ 1        ┆ Dostál, Aleš,          ┆ jk01022772     ┆ ["aut"]        ┆ … ┆ 1946     ┆ null  ┆ m      ┆ 69  │
# │ 1        ┆ Gruber, Václav,        ┆ nlk20010096082 ┆ ["aut"]        ┆ … ┆ 1953     ┆ null  ┆ m      ┆ 70  │
# │ 1        ┆ Bergman, Richard,      ┆ jk01011806     ┆ ["aut"]        ┆ … ┆ 1956     ┆ null  ┆ m      ┆ 68  │
# │ 1        ┆ Szkandera, Antonín,    ┆ mzk2006323139  ┆ ["aut"]        ┆ … ┆ 1949     ┆ null  ┆ m      ┆ 60  │
# │ 1        ┆ Hrušková, Hanka,       ┆ mzk2002109829  ┆ ["aut"]        ┆ … ┆ 1968     ┆ null  ┆ f      ┆ 34  │
# │ 1        ┆ Pořízka, Dušan,        ┆ xx0186244      ┆ ["aut"]        ┆ … ┆ 1963     ┆ null  ┆ m      ┆ 58  │
# │ 1        ┆ Sebastiani, Ida,       ┆ xx0077325      ┆ ["aut"]        ┆ … ┆ 1964     ┆ null  ┆ f      ┆ 45  │
# └──────────┴────────────────────────┴────────────────┴────────────────┴───┴──────────┴───────┴────────┴─────┘

# %%
# Out:
# 4667

# %%
hranicni_rok = 2010
zavedeni = df.filter(pl.col('rok').is_between(1980,hranicni_rok)).select(pl.col('100_7')).to_series().to_list()
print(len(zavedeni))
struktura_zavedenych = pl.concat([ceske_romany, ceske_kratke]).filter(pl.col('rok') > hranicni_rok).filter(pl.col('100_7').is_in(zavedeni)).group_by(['gender','vek']).len().sort(by='vek')
struktura_zavedenych_m = struktura_zavedenych.filter(pl.col('gender') == 'm').with_columns(pl.col('len').rolling_mean(window_size=3))
struktura_zavedenych_f = struktura_zavedenych.filter(pl.col('gender') == 'f').with_columns(pl.col('len').rolling_mean(window_size=3))
struktura_zavedenych = pl.concat([struktura_zavedenych_m, struktura_zavedenych_f])

alt.Chart(struktura_zavedenych.to_pandas()).mark_line().encode(alt.X('vek'),alt.Y('len'),alt.Color('gender'))
# Out:
# 126207
# alt.Chart(...)

# %%
struktura_zavedenych.filter(pl.col('vek').is_between(47,52)).sort(by='vek')
# Out:
# shape: (12, 3)
# ┌────────┬─────┬───────────┐
# │ gender ┆ vek ┆ len       │
# │ ---    ┆ --- ┆ ---       │
# │ str    ┆ i64 ┆ f64       │
# ╞════════╪═════╪═══════════╡
# │ m      ┆ 47  ┆ 66.0      │
# │ f      ┆ 47  ┆ 70.666667 │
# │ m      ┆ 48  ┆ 68.0      │
# │ f      ┆ 48  ┆ 73.0      │
# │ m      ┆ 49  ┆ 71.0      │
# │ f      ┆ 49  ┆ 71.0      │
# │ m      ┆ 50  ┆ 63.666667 │
# │ f      ┆ 50  ┆ 68.666667 │
# │ m      ┆ 51  ┆ 69.333333 │
# │ f      ┆ 51  ┆ 62.0      │
# │ m      ┆ 52  ┆ 64.666667 │
# │ f      ┆ 52  ┆ 61.0      │
# └────────┴─────┴───────────┘

# %%
pl.concat([ceske_romany, ceske_kratke]).filter(pl.col('rok') >= 2000).group_by('vek').len()
# Out:
# shape: (87, 2)
# ┌─────┬─────┐
# │ vek ┆ len │
# │ --- ┆ --- │
# │ i64 ┆ u32 │
# ╞═════╪═════╡
# │ 21  ┆ 50  │
# │ 18  ┆ 23  │
# │ 15  ┆ 12  │
# │ 24  ┆ 57  │
# │ 42  ┆ 191 │
# │ 33  ┆ 164 │
# │ 48  ┆ 179 │
# │ 27  ┆ 93  │
# │ 45  ┆ 187 │
# │ 36  ┆ 208 │
# │ 39  ┆ 193 │
# │ 30  ┆ 139 │
# │ 69  ┆ 160 │
# │ 66  ┆ 150 │
# │ 60  ┆ 193 │
# │ 51  ┆ 192 │
# │ 54  ┆ 193 │
# │ 72  ┆ 145 │
# │ 63  ┆ 161 │
# │ 57  ┆ 210 │
# │ 87  ┆ 29  │
# │ 96  ┆ 6   │
# │ 84  ┆ 42  │
# │ 90  ┆ 29  │
# │ 78  ┆ 100 │
# │ 93  ┆ 8   │
# │ 81  ┆ 70  │
# │ 75  ┆ 139 │
# │ 99  ┆ 5   │
# │ 16  ┆ 10  │
# │ 13  ┆ 1   │
# │ 37  ┆ 156 │
# │ 34  ┆ 177 │
# │ 22  ┆ 48  │
# │ 31  ┆ 159 │
# │ 19  ┆ 26  │
# │ 25  ┆ 68  │
# │ 40  ┆ 180 │
# │ 28  ┆ 96  │
# │ 55  ┆ 196 │
# │ 58  ┆ 189 │
# │ 49  ┆ 198 │
# │ 52  ┆ 185 │
# │ 43  ┆ 159 │
# │ 46  ┆ 187 │
# │ 64  ┆ 183 │
# │ 61  ┆ 177 │
# │ 79  ┆ 86  │
# │ 70  ┆ 179 │
# │ 85  ┆ 37  │
# │ 76  ┆ 125 │
# │ 67  ┆ 149 │
# │ 82  ┆ 59  │
# │ 88  ┆ 29  │
# │ 73  ┆ 144 │
# │ 94  ┆ 6   │
# │ 91  ┆ 22  │
# │ 97  ┆ 6   │
# │ 23  ┆ 48  │
# │ 32  ┆ 149 │
# │ 29  ┆ 131 │
# │ 26  ┆ 91  │
# │ 14  ┆ 4   │
# │ 20  ┆ 42  │
# │ 17  ┆ 22  │
# │ 50  ┆ 195 │
# │ 41  ┆ 201 │
# │ 53  ┆ 176 │
# │ 35  ┆ 177 │
# │ 56  ┆ 198 │
# │ 47  ┆ 222 │
# │ 38  ┆ 193 │
# │ 44  ┆ 179 │
# │ 74  ┆ 127 │
# │ 71  ┆ 142 │
# │ 80  ┆ 84  │
# │ 68  ┆ 160 │
# │ 59  ┆ 201 │
# │ 65  ┆ 173 │
# │ 62  ┆ 160 │
# │ 77  ┆ 114 │
# │ 86  ┆ 35  │
# │ 95  ┆ 9   │
# │ 92  ┆ 13  │
# │ 83  ┆ 61  │
# │ 98  ┆ 3   │
# │ 89  ┆ 30  │
# └─────┴─────┘
