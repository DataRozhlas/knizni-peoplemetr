# %%
import os
import re
import json
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
odkud = 'downloads/wikidata/autority'

# %%
def najdi_letopocet(x):
    try:
        return int(re.search(r"\d{4}",x).group())
    except:
        return None

# %%
len([f for f in os.listdir("downloads/wikidata/autority")])
# Out:
# 134208

# %%
medailony = []
pocitadlo = 0

for f in [f for f in os.listdir("downloads/wikidata/autority")]:

    pocitadlo += 1
    if pocitadlo % 1000 == 0:
        print(f"{pocitadlo:006}: {f}")
    
    medailon = {}
    with open(os.path.join('downloads/wikidata/autority', f), 'r', encoding='utf-8') as file:
        
        wd = json.loads(file.read())
        q = f[:-5]
        medailon['024_a'] = q

        try:
            medailon['label_cs'] = wd['entities'][q]['labels']['cs']['value']
        except:
            pass
        try:
            medailon['label_en'] = wd['entities'][q]['labels']['en']['value']
        except:
            pass
        try:
            medailon['popis_cs'] = wd['entities'][q]['descriptions']['cs']['value']
        except:
            pass
        try:
            medailon['popis_en'] = wd['entities'][q]['descriptions']['en']['value']
        except:
            pass

        try:
            medailon['w_narozeni_presne'] = wd['entities'][q]['claims']['P569'][0]['mainsnak']['datavalue']['value']['time']
        except:
            pass
        try:
            medailon['w_umrti_presne'] = wd['entities'][q]['claims']['P570'][0]['mainsnak']['datavalue']['value']['time']
        except:
            pass
        
        try:
            medailon['w_narozeni'] = najdi_letopocet(medailon['w_narozeni_presne'])
        except:
            pass
        try:
            medailon['w_umrti'] = najdi_letopocet(medailon['w_umrti_presne'])
        except:
            pass
        
        try:
            medailon['w_gender'] = wd['entities'][q]['claims']['P21'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['obcanstvi'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P27']]
        except:
            pass
        try:
            medailon['w_misto_narozeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P19']]
        except:
            pass
        try:
            medailon['w_misto_umrti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P20']]
        except:
            pass
        try:
            medailon['druh_umrti'] = wd['entities'][q]['claims']['P1196'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['pricina_umrti'] = wd['entities'][q]['claims']['P509'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass      
        try:
            medailon['vezeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2632']]
        except:
            pass
        try:
            medailon['profese'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P106']]
        except:
            pass
        try:
            medailon['strany'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P102']]
        except:
            pass
        try:
            medailon['skoly'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P69']]
        except:
            pass
        try:
            medailon['udalosti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P793']]
        except:
            pass
        try:
            medailon['role'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2868']]
        except:
            pass
        try:
            medailon['ceny'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P166']]
        except:
            pass
        try:
            medailon['manzelstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P26']]
        except:
            pass
        try:
            medailon['partnerstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P451']]
        except:
            pass
        try:
            medailon['sourozenectvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P3373']]
        except:
            pass
        try:
            medailon['potomstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P40']]
        except:
            pass       

        try:
            medailon['facebook'] = wd['entities'][q]['claims']['P2013'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['twitter'] = wd['entities'][q]['claims']['P2002'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['instagram'] = wd['entities'][q]['claims']['P2003'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['web'] = wd['entities'][q]['claims']['P856'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['wiki_cs'] = wd['entities'][q]['sitelinks']['cswiki']['url']
        except:
            pass
        try:
            medailon['wiki_en'] = wd['entities'][q]['sitelinks']['enwiki']['url']
        except:
            pass
        
        try:
            medailon['jazykove_verze'] = [z.split(".wikipedia")[0].split("//")[1] for z in set(list([x for x in [hodnoty['url'] for popisky, hodnoty in wd['entities'][q]['sitelinks'].items()]])) if "wikipedia" in z]
        except:
            pass
    
    medailony.append(medailon)
# Out:
# 001000: Q102663761.json
# 002000: Q105163003.json
# 003000: Q106926110.json
# 004000: Q1079466.json
# 005000: Q109061.json
# 006000: Q110477161.json
# 007000: Q112153.json
# 008000: Q112348175.json
# 009000: Q112353201.json
# 010000: Q112368728.json
# 011000: Q112375034.json
# 012000: Q112384578.json
# 013000: Q112391430.json
# 014000: Q112400668.json
# 015000: Q112411291.json
# 016000: Q112423744.json
# 017000: Q112446032.json
# 018000: Q112476461.json
# 019000: Q112506403.json
# 020000: Q112544858.json
# 021000: Q113527402.json
# 022000: Q114781527.json
# 023000: Q11717354.json
# 024000: Q118396307.json
# 025000: Q11985880.json
# 026000: Q12022756.json
# 027000: Q12026294.json
# 028000: Q120358642.json
# 029000: Q12049512.json
# 030000: Q120573830.json
# 031000: Q120576157.json
# 032000: Q120579611.json
# 033000: Q120584931.json
# 034000: Q120589061.json
# 035000: Q120593019.json
# 036000: Q120601547.json
# 037000: Q120608991.json
# 038000: Q12076707.json
# 039000: Q12279088.json
# 040000: Q124304299.json
# 041000: Q125476831.json
# 042000: Q127277655.json
# 043000: Q130267106.json
# 044000: Q13422629.json
# 045000: Q1399671.json
# 046000: Q1500009.json
# 047000: Q15432075.json
# 048000: Q1578227.json
# 049000: Q1602884.json
# 050000: Q165108.json
# 051000: Q168994.json
# 052000: Q17311778.json
# 053000: Q18042590.json
# 054000: Q18661788.json
# 055000: Q19288931.json
# 056000: Q19918433.json
# 057000: Q2061062.json
# 058000: Q21153552.json
# 059000: Q21551711.json
# 060000: Q22530.json
# 061000: Q236950.json
# 062000: Q2458684.json
# 063000: Q2589897.json
# 064000: Q27075049.json
# 065000: Q28213696.json
# 066000: Q29066611.json
# 067000: Q3017501.json
# 068000: Q313324.json
# 069000: Q325696.json
# 070000: Q3374340.json
# 071000: Q3527370.json
# 072000: Q3718714.json
# 073000: Q386698.json
# 074000: Q4137236.json
# 075000: Q4243064.json
# 076000: Q4355090.json
# 077000: Q448592.json
# 078000: Q465721.json
# 079000: Q47630892.json
# 080000: Q4958416.json
# 081000: Q51202604.json
# 082000: Q5258442.json
# 083000: Q5442265.json
# 084000: Q55390637.json
# 085000: Q5587938.json
# 086000: Q56559844.json
# 087000: Q57451515.json
# 088000: Q587178.json
# 089000: Q5955067.json
# 090000: Q60451948.json
# 091000: Q611959.json
# 092000: Q62083963.json
# 093000: Q63615124.json
# 094000: Q65028231.json
# 095000: Q67145852.json
# 096000: Q695702.json
# 097000: Q7173090.json
# 098000: Q7362180.json
# 099000: Q7651966.json
# 100000: Q7938870.json
# 101000: Q830712.json
# 102000: Q862412.json
# 103000: Q88716456.json
# 104000: Q9098157.json
# 105000: Q93047573.json
# 106000: Q9382594.json
# 107000: Q94870788.json
# 108000: Q95072912.json
# 109000: Q95083086.json
# 110000: Q95100722.json
# 111000: Q95112444.json
# 112000: Q95135954.json
# 113000: Q95146592.json
# 114000: Q95151312.json
# 115000: Q95155498.json
# 116000: Q95165379.json
# 117000: Q95168795.json
# 118000: Q95175032.json
# 119000: Q95177378.json
# 120000: Q95183098.json
# 121000: Q95214458.json
# 122000: Q95227975.json
# 123000: Q95334373.json
# 124000: Q95365748.json
# 125000: Q95376984.json
# 126000: Q95390717.json
# 127000: Q95396566.json
# 128000: Q95437417.json
# 129000: Q95449200.json
# 130000: Q95460502.json
# 131000: Q95474642.json
# 132000: Q95489658.json
# 133000: Q970649.json
# 134000: Q99472037.json

# %%
medailony[5:100]
# Out:
# [{'024_a': 'Q1000542',
#   'label_cs': 'Christina Kauschke',
#   'label_en': 'Christina Kauschke',
#   'popis_en': 'German linguist',
#   'w_narozeni_presne': '+1964-01-01T00:00:00Z',
#   'w_narozeni': 1964,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q1295'],
#   'profese': ['Q14467526', 'Q1622272', 'Q11762416'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1000592',
#   'label_cs': 'Tyson Fury',
#   'label_en': 'Tyson Fury',
#   'popis_cs': 'britský boxer',
#   'popis_en': 'British boxer (born 1988)',
#   'w_narozeni_presne': '+1988-08-12T00:00:00Z',
#   'w_narozeni': 1988,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q145'],
#   'w_misto_narozeni': ['Q18125'],
#   'profese': ['Q11338576', 'Q2066131'],
#   'ceny': ['Q55042186', 'Q4114674'],
#   'manzelstvo': ['Q124608281'],
#   'sourozenectvo': ['Q64585041'],
#   'facebook': 'TysonFuryGypsyKing',
#   'twitter': 'Tyson_Fury',
#   'instagram': 'gypsyking101',
#   'web': 'https://tyson-fury.com/',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Tyson_Fury',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Tyson_Fury',
#   'jazykove_verze': ['bg',
#    'de',
#    'th',
#    'no',
#    'tr',
#    'ar',
#    'cy',
#    'ga',
#    'es',
#    'bn',
#    'fa',
#    'sl',
#    'pl',
#    'en',
#    'uz',
#    'sv',
#    'da',
#    'ru',
#    'zh',
#    'cs',
#    'ro',
#    'ko',
#    'pt',
#    'hy',
#    'nl',
#    'it',
#    'uk',
#    'et',
#    'hr',
#    'kcg',
#    'vi',
#    'ja',
#    'simple',
#    'he',
#    'arz',
#    'fr',
#    'fi']},
#  {'024_a': 'Q100061677',
#   'label_cs': 'Karlachovy sady',
#   'label_en': 'Karlachovy sady',
#   'popis_cs': 'veřejný park v areálu vyšehradské pevnosti v Praze',
#   'popis_en': 'park in Prague-Vyšehrad',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Karlachovy_sady',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q1000649',
#   'label_cs': 'András Ferkai',
#   'label_en': 'András Ferkai',
#   'popis_en': 'Hungarian architect',
#   'w_narozeni_presne': '+1953-06-07T00:00:00Z',
#   'w_narozeni': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q42973'],
#   'ceny': ['Q1466124', 'Q1220788'],
#   'jazykove_verze': ['hu', 'eo', 'arz']},
#  {'024_a': 'Q1000729',
#   'label_cs': 'Ferreira de Castro',
#   'label_en': 'José Maria Ferreira de Castro',
#   'popis_en': 'Portuguese writer and journalist',
#   'w_narozeni_presne': '+1898-05-24T00:00:00Z',
#   'w_umrti_presne': '+1974-06-29T00:00:00Z',
#   'w_narozeni': 1898,
#   'w_umrti': 1974,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q45'],
#   'w_misto_narozeni': ['Q18468715'],
#   'w_misto_umrti': ['Q36433'],
#   'pricina_umrti': 'Q3010352',
#   'profese': ['Q1930187', 'Q36180'],
#   'manzelstvo': ['Q123853170'],
#   'partnerstvo': ['Q122652621'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ferreira_de_Castro',
#   'jazykove_verze': ['de',
#    'it',
#    'gl',
#    'en',
#    'ro',
#    'ar',
#    'eu',
#    'arz',
#    'fr',
#    'hu',
#    'ru',
#    'uk',
#    'es',
#    'fi',
#    'pt']},
#  {'024_a': 'Q100090749',
#   'label_cs': 'Robin R. Means Coleman',
#   'label_en': 'Robin R. Means Coleman',
#   'popis_cs': 'Americká odbornice na komunikační studia, vysokoškolská učitelka, zaměřuje se na mediální studia, kulturní diverzitu a kulturní politiku černých, inkluzi, management vzdělávání; filmová producentka dokumentárního filmu "Horror Noire: A History of Bla',
#   'popis_en': 'American author, scholar and educator',
#   'w_narozeni_presne': '+1969-01-01T00:00:00Z',
#   'w_narozeni': 1969,
#   'w_gender': 'Q6581072',
#   'profese': ['Q28389', 'Q36180', 'Q3282637', 'Q462390', 'Q1622272'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Robin_R._Means_Coleman',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q1000985',
#   'label_cs': 'Milan Pacanda',
#   'label_en': 'Milan Pacanda',
#   'popis_cs': 'český fotbalista',
#   'popis_en': 'Czech football forward',
#   'w_narozeni_presne': '+1978-02-28T00:00:00Z',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q213'],
#   'w_misto_narozeni': ['Q146342'],
#   'profese': ['Q937857'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Milan_Pacanda',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Milan_Pacanda',
#   'jazykove_verze': ['it', 'arz', 'cs', 'de', 'en']},
#  {'024_a': 'Q1001',
#   'label_cs': 'Mahátma Gándhí',
#   'label_en': 'Mahatma Gandhi',
#   'popis_cs': 'indický politik',
#   'popis_en': 'Indian independence activist (1869–1948)',
#   'w_narozeni_presne': '+1869-10-02T00:00:00Z',
#   'w_umrti_presne': '+1948-01-30T00:00:00Z',
#   'w_narozeni': 1869,
#   'w_umrti': 1948,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q129286', 'Q1775277', 'Q668'],
#   'w_misto_narozeni': ['Q6419912'],
#   'w_misto_umrti': ['Q1381516'],
#   'druh_umrti': 'Q149086',
#   'pricina_umrti': 'Q2140674',
#   'vezeni': ['Q142534', 'Q2344976', 'Q142534', 'Q142534'],
#   'profese': ['Q82955',
#    'Q808967',
#    'Q15958642',
#    'Q1930187',
#    'Q4964182',
#    'Q18814623',
#    'Q11774202',
#    'Q17351648',
#    'Q1021386',
#    'Q11774156',
#    'Q22336956',
#    'Q16323111',
#    'Q3242115',
#    'Q36180',
#    'Q185351',
#    'Q30242234'],
#   'strany': ['Q10225'],
#   'skoly': ['Q4722851', 'Q1233784', 'Q193196', 'Q100148173'],
#   'ceny': ['Q207826', 'Q727815', 'Q2469664', 'Q6967959', 'Q2423226'],
#   'manzelstvo': ['Q264908'],
#   'sourozenectvo': ['Q100778818',
#    'Q100778893',
#    'Q100778902',
#    'Q100779061',
#    'Q100779088'],
#   'potomstvo': ['Q1390715', 'Q1280678', 'Q185403', 'Q732728'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Mah%C3%A1tma_G%C3%A1ndh%C3%AD',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Mahatma_Gandhi',
#   'jazykove_verze': ['ur',
#    'mn',
#    'fr',
#    'bs',
#    'bcl',
#    'ckb',
#    'ln',
#    'ka',
#    'pms',
#    'cs',
#    'th',
#    'eu',
#    'dtp',
#    'gom',
#    'skr',
#    'an',
#    'fi',
#    'oc',
#    'pap',
#    'lfn',
#    'bh',
#    'lt',
#    'ast',
#    'fy',
#    'tg',
#    'is',
#    'ca',
#    'ia',
#    'nl',
#    'zh',
#    'zh-yue',
#    'gcr',
#    'no',
#    'zh-classical',
#    'su',
#    'ky',
#    'gl',
#    'kn',
#    'ml',
#    'hif',
#    'hr',
#    'sv',
#    'el',
#    'pa',
#    'gd',
#    'pt',
#    'be',
#    'tl',
#    'la',
#    'co',
#    'kk',
#    'be-tarask',
#    'kab',
#    'sah',
#    'hu',
#    'ga',
#    'ps',
#    'lmo',
#    'io',
#    'os',
#    'yi',
#    'ary',
#    'ta',
#    'xmf',
#    'ban',
#    'qu',
#    'ha',
#    'am',
#    'dty',
#    'fiu-vro',
#    'nn',
#    'vec',
#    'ku',
#    'tt',
#    'ang',
#    'uz',
#    'jam',
#    'km',
#    'ts',
#    'sk',
#    'sh',
#    'or',
#    'sco',
#    'tly',
#    'ar',
#    'sat',
#    'si',
#    'pnb',
#    'mnw',
#    'ba',
#    'xal',
#    'war',
#    'dv',
#    'mzn',
#    'es',
#    'gu',
#    'btm',
#    'ht',
#    'hyw',
#    'cy',
#    'pcd',
#    'tyv',
#    'bxr',
#    'uk',
#    'tr',
#    'lez',
#    'mg',
#    'ru',
#    'tcy',
#    'arz',
#    'bjn',
#    'hi',
#    'simple',
#    'wuu',
#    'mhr',
#    'mt',
#    'br',
#    'frp',
#    'gn',
#    'mai',
#    'et',
#    'sq',
#    'vo',
#    'kw',
#    'cv',
#    'lb',
#    'yo',
#    'ja',
#    'ilo',
#    'ro',
#    'sc',
#    'mni',
#    'id',
#    'sa',
#    'bg',
#    'ce',
#    'ceb',
#    'bpy',
#    'so',
#    'tpi',
#    'azb',
#    'olo',
#    'kbd',
#    'diq',
#    'ay',
#    'li',
#    'lo',
#    'fa',
#    'eo',
#    'my',
#    'sl',
#    'bn',
#    'zh-min-nan',
#    'vi',
#    'lv',
#    'jv',
#    'ug',
#    'rue',
#    'mk',
#    'mr',
#    'ks',
#    'awa',
#    'it',
#    'ko',
#    'pl',
#    'ss',
#    'min',
#    'de',
#    'en',
#    'te',
#    'sd',
#    'as',
#    'gan',
#    'rmy',
#    'bat-smg',
#    'da',
#    'lad',
#    'sw',
#    'anp',
#    'scn',
#    'ady',
#    'shi',
#    'frr',
#    'af',
#    'he',
#    'vep',
#    'ne',
#    'dsb',
#    'ms',
#    'kaa',
#    'sr',
#    'new',
#    'als',
#    'kbp',
#    'fo',
#    'hy',
#    'avk',
#    'az',
#    'nds',
#    'tk',
#    'crh']},
#  {'024_a': 'Q1001072',
#   'label_cs': 'Salomon Sachs',
#   'label_en': 'Salomo Sachs',
#   'popis_en': 'Jewish Prussian Government Building Inspector, architect, civil servant, mathematician and writer (1772–1855)',
#   'w_narozeni_presne': '+1772-12-22T00:00:00Z',
#   'w_umrti_presne': '+1855-05-14T00:00:00Z',
#   'w_narozeni': 1772,
#   'w_umrti': 1855,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q27306'],
#   'w_misto_narozeni': ['Q64'],
#   'w_misto_umrti': ['Q64'],
#   'profese': ['Q42973',
#    'Q36180',
#    'Q170790',
#    'Q11063',
#    'Q901402',
#    'Q212238',
#    'Q37226'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Salomo_Sachs',
#   'jazykove_verze': ['en', 'arz', 'nl', 'ar', 'pl', 'de']},
#  {'024_a': 'Q1001077',
#   'label_cs': 'Sergej Vladimirovič Dikovskij',
#   'label_en': 'Sergey Dikovsky',
#   'popis_en': 'Soviet writer',
#   'w_narozeni_presne': '+1907-03-01T00:00:00Z',
#   'w_umrti_presne': '+1940-01-06T00:00:00Z',
#   'w_narozeni': 1907,
#   'w_umrti': 1940,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q34266', 'Q2305208', 'Q15180'],
#   'w_misto_narozeni': ['Q649'],
#   'w_misto_umrti': ['Q214054'],
#   'profese': ['Q36180', 'Q1930187', 'Q12144794'],
#   'ceny': ['Q960966'],
#   'jazykove_verze': ['de', 'fr', 'fi', 'ru']},
#  {'024_a': 'Q100114213',
#   'label_cs': 'Damian Duffy',
#   'label_en': 'Damian Duffy',
#   'popis_en': 'American comics artist',
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'profese': ['Q715301', 'Q109517242', 'Q17098559', 'Q1622272'],
#   'skoly': ['Q457281'],
#   'ceny': ['Q842614', 'Q110165665'],
#   'twitter': 'DamianD2Duffy',
#   'web': 'http://damianduffy.net',
#   'jazykove_verze': ['sv']},
#  {'024_a': 'Q100133408',
#   'label_cs': 'R. Z. Kobiela',
#   'w_narozeni_presne': '+1902-01-01T00:00:00Z',
#   'w_umrti_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q191793'],
#   'profese': ['Q193391', 'Q1930187', 'Q36180', 'Q23656820'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100138089',
#   'label_cs': 'John Jennings',
#   'label_en': 'John Jennings',
#   'popis_en': 'American illustrator (born 1970)',
#   'w_narozeni_presne': '+1970-00-00T00:00:00Z',
#   'w_narozeni': 1970,
#   'w_gender': 'Q6581097',
#   'profese': ['Q644687',
#    'Q109517242',
#    'Q17098559',
#    'Q3658608',
#    'Q5322166',
#    'Q19829999',
#    'Q1622272'],
#   'ceny': ['Q110165665'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100144439',
#   'label_cs': 'Ivan Medeši',
#   'label_en': 'Ivan Medeši',
#   'popis_cs': 'Rusínský básník a prozaik působící v Srbsku. Publikuje básně, povídky, fejetony i reportáže. Pracuje jako pomocný pedagog základní školy a gymnázia.',
#   'popis_en': 'poet and novelist',
#   'w_narozeni_presne': '+1982-01-12T00:00:00Z',
#   'w_narozeni': 1982,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q511216'],
#   'profese': ['Q36180',
#    'Q49757',
#    'Q12144794',
#    'Q1231865',
#    'Q82594',
#    'Q2070313'],
#   'ceny': ['Q9150528'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Ivan_Mede%C5%A1i',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100146632',
#   'label_cs': 'Salmá Samar Damlūjī',
#   'label_en': 'Salma Samar Damluji',
#   'popis_cs': 'Britsko-irácká architektka, vysokoškolská pedagožka, specializace na islámskou architekturu.',
#   'popis_en': 'Iraqi British architect, professor and author',
#   'w_narozeni_presne': '+1954-01-01T00:00:00Z',
#   'w_narozeni': 1954,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q3820'],
#   'profese': ['Q36180', 'Q42973', 'Q1622272'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Salma_Samar_Damluji',
#   'jazykove_verze': ['ar', 'en']},
#  {'024_a': 'Q100151669',
#   'label_cs': 'Stanislav Klika',
#   'label_en': 'Stanislav Klika',
#   'popis_cs': 'pražský novinář, spisovatel a nakladatel (1885-1942)',
#   'popis_en': 'Czech journalist, writer and publisher (1885-1942)',
#   'w_narozeni_presne': '+1885-00-00T00:00:00Z',
#   'w_umrti_presne': '+1942-06-18T00:00:00Z',
#   'w_narozeni': 1885,
#   'w_umrti': 1942,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q378120', 'Q1085'],
#   'w_misto_umrti': ['Q942842'],
#   'profese': ['Q36180',
#    'Q2516866',
#    'Q356139',
#    'Q12144794',
#    'Q6051619',
#    'Q3391743'],
#   'manzelstvo': ['Q106286463'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001547',
#   'label_cs': 'Hambye',
#   'label_en': 'Hambye',
#   'popis_cs': 'obec v departementu Manche ve Francii',
#   'popis_en': 'commune in Manche, France',
#   'facebook': 'hambye',
#   'web': 'http://www.hambye.fr',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Hambye',
#   'jazykove_verze': ['sk',
#    'eo',
#    'de',
#    'diq',
#    'ms',
#    'pms',
#    'sv',
#    'war',
#    'ceb',
#    'kk',
#    'oc',
#    'zh',
#    'en',
#    'pl',
#    'pt',
#    'nl',
#    'vi',
#    'la',
#    'bug',
#    'fr',
#    'hu',
#    'zh-min-nan',
#    'ro',
#    'fi',
#    'lld',
#    'ca',
#    'ce',
#    'sr',
#    'tt',
#    'es',
#    'uk',
#    'uz',
#    'eu',
#    'it',
#    'fy',
#    'sh',
#    'vec',
#    'el']},
#  {'024_a': 'Q100154933',
#   'label_cs': 'Thomas R. Sinclair',
#   'label_en': 'Thomas R. Sinclair',
#   'popis_cs': 'americký rostlinný fyziolog, vysokoškolský pedagog, zaměřený na fyziologii a ekologii rostlin, změny klimatu, vodu a rostlinnou výrobu',
#   'popis_en': '1944-',
#   'w_narozeni_presne': '+1944-01-01T00:00:00Z',
#   'w_narozeni': 1944,
#   'w_gender': 'Q6581097',
#   'profese': ['Q60244908', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001591',
#   'label_cs': 'La Bernerie-en-Retz',
#   'label_en': 'La Bernerie-en-Retz',
#   'popis_cs': 'obec v departementu Loire-Atlantique ve Francii',
#   'popis_en': 'commune in Loire-Atlantique, France',
#   'web': 'http://www.mairie-labernerie.fr',
#   'wiki_en': 'https://en.wikipedia.org/wiki/La_Bernerie-en-Retz',
#   'jazykove_verze': ['vo',
#    'sr',
#    'nrm',
#    'nl',
#    'eo',
#    'ca',
#    'eu',
#    'pt',
#    'war',
#    'sl',
#    'ce',
#    'hu',
#    'ur',
#    'lld',
#    'sk',
#    'it',
#    'ms',
#    'pms',
#    'sh',
#    'ast',
#    'pl',
#    'br',
#    'en',
#    'de',
#    'la',
#    'ku',
#    'bm',
#    'zh-min-nan',
#    'simple',
#    'sv',
#    'mg',
#    'cy',
#    'tt',
#    'ro',
#    'uk',
#    'vi',
#    'es',
#    'vec',
#    'ceb',
#    'oc',
#    'fr',
#    'diq',
#    'zh']},
#  {'024_a': 'Q100163576',
#   'label_cs': 'Vasyl‘ Mychajlovyč Slobodjan',
#   'label_en': 'Vasyl Slobodian',
#   'popis_cs': 'ukrajinský historik zaměřený na sakrální architekturu, autor prací z oboru',
#   'popis_en': 'Ukrainian historian',
#   'w_narozeni_presne': '+1951-09-21T00:00:00Z',
#   'w_narozeni': 1951,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q212'],
#   'w_misto_narozeni': ['Q36036'],
#   'profese': ['Q201788', 'Q1595570', 'Q36180'],
#   'skoly': ['Q1817355'],
#   'ceny': ['Q12143927'],
#   'jazykove_verze': ['uk']},
#  {'024_a': 'Q1001716',
#   'label_cs': 'Leopold Fischer',
#   'label_en': 'Leopold Fischer',
#   'popis_cs': 'Jezuitský kněz a historik. Roku 1718 vstoupil do jezuitského řádu. Narozen 28. 3. 1703 ve Vídni, zemřel 11. 4. 1787 tamtéž.',
#   'w_narozeni_presne': '+1703-03-28T00:00:00Z',
#   'w_umrti_presne': '+1787-04-11T00:00:00Z',
#   'w_narozeni': 1703,
#   'w_umrti': 1787,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q153136'],
#   'w_misto_narozeni': ['Q1741'],
#   'w_misto_umrti': ['Q1741'],
#   'profese': ['Q250867', 'Q201788', 'Q432386', 'Q37226'],
#   'jazykove_verze': ['hu']},
#  {'024_a': 'Q100200',
#   'label_cs': 'Norbert Buske',
#   'label_en': 'Norbert Buske',
#   'popis_en': 'German politician and theologian',
#   'w_narozeni_presne': '+1936-01-02T00:00:00Z',
#   'w_umrti_presne': '+2023-10-20T00:00:00Z',
#   'w_narozeni': 1936,
#   'w_umrti': 2023,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183', 'Q16957'],
#   'w_misto_narozeni': ['Q50960'],
#   'profese': ['Q82955', 'Q1234713'],
#   'strany': ['Q49762'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Norbert_Buske',
#   'jazykove_verze': ['pl', 'en', 'de', 'arz']},
#  {'024_a': 'Q100207',
#   'label_cs': 'Marie Luise Droop',
#   'label_en': 'Marie Luise Droop',
#   'popis_en': 'German writer, director and producer (1890-1959)',
#   'w_narozeni_presne': '+1890-01-15T00:00:00Z',
#   'w_umrti_presne': '+1959-08-22T00:00:00Z',
#   'w_narozeni': 1890,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q393'],
#   'w_misto_umrti': ['Q505495'],
#   'profese': ['Q28389', 'Q3282637'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Marie_Luise_Droop',
#   'jazykove_verze': ['en', 'arz', 'de']},
#  {'024_a': 'Q100217',
#   'label_cs': 'Kareen Zebroff',
#   'label_en': 'Kareen Zebroff',
#   'popis_en': 'Canadian-based author, actor and television host specialising in yoga',
#   'w_narozeni_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q502441'],
#   'profese': ['Q947873'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Kareen_Zebroff',
#   'jazykove_verze': ['en', 'uz', 'arz', 'de']},
#  {'024_a': 'Q100233',
#   'label_cs': 'Udo Weilacher',
#   'label_en': 'Udo Weilacher',
#   'popis_en': 'German landscape architect, author and Professor for Landscape Architecture',
#   'w_narozeni_presne': '+1963-01-01T00:00:00Z',
#   'w_narozeni': 1963,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q3758'],
#   'profese': ['Q2815948', 'Q1622272'],
#   'skoly': ['Q157808'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Udo_Weilacher',
#   'jazykove_verze': ['en', 'de', 'arz']},
#  {'024_a': 'Q100243280'},
#  {'024_a': 'Q100267570',
#   'label_cs': 'Léon Carez',
#   'label_en': 'Léon Carez',
#   'w_narozeni_presne': '+1854-11-13T00:00:00Z',
#   'w_umrti_presne': '+1932-01-28T00:00:00Z',
#   'w_narozeni': 1854,
#   'w_umrti': 1932,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q2845753', 'Q90'],
#   'w_misto_umrti': ['Q1078086'],
#   'profese': ['Q520549', 'Q1734662', 'Q189010'],
#   'skoly': ['Q3064332'],
#   'ceny': ['Q10855271', 'Q56649459'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100267949',
#   'label_cs': 'Jacqueline Chénieux-Gendron',
#   'label_en': 'Jacqueline Chénieux-Gendron',
#   'popis_en': 'author',
#   'w_narozeni_presne': '+1939-11-19T00:00:00Z',
#   'w_umrti_presne': '+2022-09-01T00:00:00Z',
#   'w_narozeni': 1939,
#   'w_umrti': 2022,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q548924'],
#   'w_misto_umrti': ['Q169293'],
#   'profese': ['Q36180'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100269537',
#   'label_cs': 'Alice Travers',
#   'label_en': 'Alice Travers',
#   'popis_en': 'researcher',
#   'w_narozeni_presne': '+1979-05-02T00:00:00Z',
#   'w_narozeni': 1979,
#   'w_gender': 'Q6581072',
#   'profese': ['Q201788', 'Q1864603', 'Q1493121', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q1878600', 'Q999763', 'Q1394262', 'Q1430113', 'Q1394262'],
#   'ceny': ['Q3332320'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100272216',
#   'label_cs': 'Mìkalaj Mìkalajevìč Mjazha',
#   'label_en': 'Nikolaĭ Nikolaevich Mezga',
#   'popis_en': 'Belarusian historian',
#   'w_narozeni_presne': '+1965-05-31T00:00:00Z',
#   'w_narozeni': 1965,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q15180', 'Q184'],
#   'w_misto_narozeni': ['Q21659780'],
#   'profese': ['Q901', 'Q1622272', 'Q201788'],
#   'skoly': ['Q2630637'],
#   'jazykove_verze': ['be']},
#  {'024_a': 'Q100273554',
#   'label_cs': 'Johannes Kaspar',
#   'label_en': 'Johannes Kaspar',
#   'popis_cs': 'německý právník, advokát a vysokoškolský pedagog zaměřený na trestní právo hmotné a obchodní, nápravu a mediaci, právní a filozofické aspekty trestního práva, ústavní právo, teorii zločinu a na empirický výzkum sankcí',
#   'w_narozeni_presne': '+1976-01-01T00:00:00Z',
#   'w_narozeni': 1976,
#   'w_gender': 'Q6581097',
#   'profese': ['Q185351', 'Q1622272', 'Q40348'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100276619',
#   'label_cs': 'Christian Larsen',
#   'label_en': 'Christian Larsen',
#   'popis_cs': 'Narozen v r. 1956 v Basileji. Lékař.',
#   'w_narozeni_presne': '+1956-00-00T00:00:00Z',
#   'w_narozeni': 1956,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q39'],
#   'w_misto_narozeni': ['Q78'],
#   'profese': ['Q39631'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1002810',
#   'label_cs': 'Imre Forbáth',
#   'label_en': 'Imre Forbáth',
#   'w_narozeni_presne': '+1898-11-17T00:00:00Z',
#   'w_umrti_presne': '+1967-05-16T00:00:00Z',
#   'w_narozeni': 1898,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q190522', 'Q855069'],
#   'w_misto_umrti': ['Q146342'],
#   'profese': ['Q49757', 'Q1930187', 'Q36180'],
#   'jazykove_verze': ['hu', 'fr']},
#  {'024_a': 'Q100282',
#   'label_cs': 'Reinhard Woltman',
#   'label_en': 'Reinhard Woltman',
#   'popis_en': 'hydraulic engineer from Germany',
#   'w_narozeni_presne': '+1757-01-01T00:00:00Z',
#   'w_umrti_presne': '+1837-01-01T00:00:00Z',
#   'w_narozeni': 1757,
#   'w_umrti': 1837,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q164079'],
#   'w_misto_narozeni': ['Q177362'],
#   'w_misto_umrti': ['Q1055'],
#   'profese': ['Q13582652', 'Q901', 'Q36180', 'Q978044'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Reinhard_Woltman',
#   'jazykove_verze': ['de', 'arz', 'fr', 'sv', 'en']},
#  {'024_a': 'Q100296521',
#   'label_cs': 'Paul Joseph Schulte',
#   'label_en': 'Paul J. Schulte',
#   'popis_en': 'forest science researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1650915'],
#   'skoly': ['Q219563', 'Q230492'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100301646',
#   'label_cs': 'Amy Ansehl',
#   'label_en': 'Amy Ansehl',
#   'popis_cs': 'Americká vysokoškolská profesorka a zdravotní sestra.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'profese': ['Q1622272', 'Q186360'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302130',
#   'label_cs': 'Noel Armenakas',
#   'label_en': 'Noel A. Armenakas',
#   'popis_cs': 'americký lékař, urolog, chirurg a vysokoškolský učitel, zaměřený na urologické operace, rekonstrukční chirurgii a úrazy',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581097',
#   'profese': ['Q17345122', 'Q774306', 'Q1622272'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302588',
#   'label_cs': 'Deborah Campbell',
#   'label_en': 'Deborah E. Campbell',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581072',
#   'profese': ['Q28569455', 'Q1622272'],
#   'skoly': ['Q681025'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302980',
#   'label_cs': 'James E. Cottrell',
#   'label_en': 'James E. Cottrell',
#   'popis_cs': 'americký anesteziolog a vysokoškolský pedagog zaměřený zejména na neuroanestezii',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni_presne': '+1942-01-01T00:00:00Z',
#   'w_narozeni': 1942,
#   'w_gender': 'Q6581097',
#   'profese': ['Q28837', 'Q1622272'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100303696'},
#  {'024_a': 'Q100304023',
#   'label_cs': 'Dennis Alexander',
#   'label_en': 'Dennis Alexander',
#   'popis_cs': 'Americký hudební skladatel a klavírista, učitel hry na klavír. Autor publikací z oboru.',
#   'popis_en': 'American composer',
#   'w_narozeni_presne': '+1947-12-10T00:00:00Z',
#   'w_narozeni': 1947,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q647127'],
#   'profese': ['Q36834', 'Q713200', 'Q16145150', 'Q639669', 'Q486748'],
#   'facebook': 'Dennis-Alexander-Music-136237939764680',
#   'web': 'http://dennisalexander.com/',
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100308989',
#   'label_cs': 'Rodrick Wallace',
#   'label_en': 'Rodrick Wallace',
#   'popis_cs': 'Americký odborník v oblasti epidemiologie duševního zdraví, zabývá se dopady veřejné politiky, diskriminace a ekonomického úpadku na veřejné zdraví. Publikace v oboru.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q100'],
#   'profese': ['Q12765408', 'Q901'],
#   'skoly': ['Q9008737'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100312952',
#   'label_cs': 'Veronika Máková',
#   'label_en': 'Veronika Máková',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q593644', 'Q901'],
#   'skoly': ['Q1291752'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100314247',
#   'label_cs': 'John Collins',
#   'label_en': 'John W Collins',
#   'popis_cs': 'americký odborník na ošetřovatelství, ošetřovatelskou péči na konci života, multikulturní ošetřovatelství a vzdělávání zdravotních sester v této oblasti, vysokoškolský pedagog',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1622272'],
#   'skoly': ['Q5316093'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100318248',
#   'label_cs': 'M. Iqbal R. Khan',
#   'label_en': 'M Iqbal R Khan',
#   'popis_cs': 'botanik, vysokoškolský pedagog a výzkumný pracovník se zaměřením na fyziologii a genomiku rostlin, rostlinný genom a fytohormony',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q2374149', 'Q1622272', 'Q901'],
#   'skoly': ['Q196544'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100319795',
#   'label_cs': 'Mariusz Jerzy Golecki',
#   'label_en': 'Mariusz Golecki',
#   'popis_en': 'jurist, bureaucrat, university teacher',
#   'w_narozeni_presne': '+1974-04-23T00:00:00Z',
#   'w_narozeni': 1974,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q36'],
#   'w_misto_narozeni': ['Q270'],
#   'profese': ['Q185351', 'Q82955', 'Q16533', 'Q40348', 'Q1622272'],
#   'skoly': ['Q144488', 'Q35794'],
#   'manzelstvo': ['Q84098931'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100319915',
#   'label_cs': 'Eric Cervini',
#   'label_en': 'Eric Cervini',
#   'popis_cs': 'americký historik, zaměřený na problematiku LGBT',
#   'popis_en': 'American historian and writer',
#   'w_narozeni_presne': '+1992-01-01T00:00:00Z',
#   'w_narozeni': 1992,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q99'],
#   'profese': ['Q36180', 'Q201788'],
#   'skoly': ['Q14711406', 'Q13371'],
#   'ceny': ['Q121334212'],
#   'facebook': 'ericcervini',
#   'twitter': 'ericcervini',
#   'instagram': 'ericcervini',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Eric_Cervini',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100319998',
#   'label_cs': 'Ann Napolitano',
#   'label_en': 'Ann Napolitano',
#   'popis_cs': 'Americká spisovatelka, autorka románů a redaktorka. Dříve vysokoškolská lektorka tvůrčího psaní.',
#   'popis_en': 'American writer',
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180', 'Q1622272', 'Q876864'],
#   'twitter': 'napolitanoann',
#   'web': 'https://annnapolitano.com',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ann_Napolitano',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100324298',
#   'label_cs': 'Elwin Huaman',
#   'label_en': 'Elwin Huaman',
#   'popis_cs': 'peruánský počítačový vědec a vysokoškolský pedagog, působící v Rakousku, zaměřený na sémantický web, vědomostní grafy a data',
#   'popis_en': 'Peruvian computer scientist',
#   'w_narozeni_presne': '+1990-07-01T00:00:00Z',
#   'w_narozeni': 1990,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q419'],
#   'w_misto_narozeni': ['Q27194667'],
#   'profese': ['Q82594', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q6156603', 'Q308963', 'Q2303432', 'Q875788'],
#   'sourozenectvo': ['Q115660783', 'Q115660896', 'Q115660799'],
#   'twitter': 'ElwinHuaman',
#   'web': 'http://elwin.huamanquispe.com/',
#   'jazykove_verze': []},
#  {'024_a': 'Q100324868',
#   'label_cs': 'Jana Bartošová',
#   'label_en': 'Jana Bartošová',
#   'popis_cs': 'česká historička a archivářka',
#   'w_narozeni_presne': '+1971-01-01T00:00:00Z',
#   'w_narozeni': 1971,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'profese': ['Q201788', 'Q635734'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100325331',
#   'label_cs': 'Giona A. Nazzaro',
#   'label_en': 'Giona A. Nazzaro',
#   'popis_en': 'Italian film critic',
#   'w_narozeni_presne': '+1965-01-01T00:00:00Z',
#   'w_narozeni': 1965,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q38'],
#   'w_misto_narozeni': ['Q72'],
#   'profese': ['Q4220892', 'Q978044', 'Q36180'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Giona_A._Nazzaro',
#   'jazykove_verze': ['it', 'en', 'arz']},
#  {'024_a': 'Q100327408',
#   'label_cs': 'Bronisława Kokoszyńska',
#   'label_en': 'Bronisława Kokoszyńska',
#   'w_narozeni_presne': '+1897-01-01T00:00:00Z',
#   'w_umrti_presne': '+1959-01-01T00:00:00Z',
#   'w_narozeni': 1897,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q36'],
#   'w_misto_narozeni': ['Q1973720'],
#   'w_misto_umrti': ['Q31487'],
#   'profese': ['Q520549', 'Q1622272'],
#   'skoly': ['Q80207'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100333885',
#   'label_cs': 'Jaroslav Boukal',
#   'label_en': 'Jaroslav Boukal',
#   'popis_cs': '* 1902 Jeníkovice u Hradce Králové † ? ? JUDr.; vedoucí knihkupecký a nakladatelský pracovník.',
#   'w_narozeni_presne': '+1902-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q2024848'],
#   'profese': ['Q2516866', 'Q1607826', 'Q333634', 'Q185351'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100334014',
#   'label_cs': 'Bohuslav Kavka',
#   'label_en': 'Bohuslav Kavka',
#   'w_narozeni_presne': '+1869-00-00T00:00:00Z',
#   'w_umrti_presne': '+1914-05-04T00:00:00Z',
#   'w_narozeni': 1869,
#   'w_umrti': 1914,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q1085'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1607826', 'Q2516866'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348318',
#   'label_cs': 'Richard Lederer',
#   'label_en': 'Richard Lederer',
#   'popis_cs': 'Prof. dr. med., lékař, pediatr, vyučoval na vídeňské univerzitě, v roce 1938 emigroval do Bagdádu .',
#   'popis_en': 'pediatrician and university teacher',
#   'w_narozeni_presne': '+1885-06-11T00:00:00Z',
#   'w_umrti_presne': '+1941-00-00T00:00:00Z',
#   'w_narozeni': 1885,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q384544'],
#   'w_misto_umrti': ['Q1530'],
#   'profese': ['Q39631', 'Q1919436', 'Q1622272'],
#   'manzelstvo': ['Q113389335'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348525',
#   'label_cs': 'Roberto Rea',
#   'label_en': 'Roberto Rea',
#   'popis_en': 'Italian philologist',
#   'w_narozeni_presne': '+1973-01-25T00:00:00Z',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q38'],
#   'w_misto_narozeni': ['Q116440'],
#   'profese': ['Q1622272', 'Q13418253'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003501',
#   'label_cs': 'András Frank',
#   'label_en': 'András Frank',
#   'popis_en': 'Hungarian mathematician',
#   'w_narozeni_presne': '+1949-06-03T00:00:00Z',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q170790'],
#   'skoly': ['Q390287', 'Q369839'],
#   'ceny': ['Q1301832'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Andr%C3%A1s_Frank',
#   'jazykove_verze': ['arz', 'pt', 'de', 'en', 'hu', 'ar', 'eo']},
#  {'024_a': 'Q100353158',
#   'label_cs': 'Robert J. Callan',
#   'label_en': 'Robert J. Callan',
#   'popis_cs': 'veterinární lékař a vysokoškolský učitel, zaměřený na infekční nemoci hospodářských zvířat',
#   'popis_en': 'veterinary researcher at Colorado State University',
#   'w_gender': 'Q6581097',
#   'profese': ['Q202883', 'Q12119633', 'Q1622272'],
#   'skoly': ['Q838330'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100356218',
#   'label_cs': 'Caroline Campbell',
#   'label_en': 'Caroline Campbell',
#   'popis_en': 'British museum curator',
#   'w_narozeni_presne': '+1973-06-23T00:00:00Z',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q27'],
#   'w_misto_narozeni': ['Q10686'],
#   'profese': ['Q674426', 'Q1792450'],
#   'skoly': ['Q734266', 'Q734266', 'Q34433'],
#   'twitter': 'campbell_c_m',
#   'instagram': 'carolinecampbelllondon',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Caroline_Campbell_(museum_director)',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100356308',
#   'label_cs': 'Byron Augustin',
#   'label_en': 'Byron Augustin',
#   'popis_en': 'Professor of geography',
#   'w_narozeni_presne': '+1941-00-00T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q959512'],
#   'profese': ['Q1622272', 'Q901402'],
#   'skoly': ['Q5680304', 'Q52413', 'Q1783608'],
#   'ceny': ['Q100351031', 'Q100355835'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100358334',
#   'label_cs': 'Ludvík Ratolístka',
#   'label_en': 'Ludvík Ratolístka',
#   'w_narozeni_presne': '+1886-00-00T00:00:00Z',
#   'w_umrti_presne': '+1953-00-00T00:00:00Z',
#   'w_narozeni': 1886,
#   'w_umrti': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q43453'],
#   'w_misto_umrti': ['Q1085'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003615',
#   'label_cs': 'Franz Josef Beranek',
#   'label_en': 'Franz Josef Beranek',
#   'popis_en': 'German university teacher and writer (1902-1967)',
#   'w_narozeni_presne': '+1902-08-08T00:00:00Z',
#   'w_umrti_presne': '+1967-08-11T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q581478'],
#   'w_misto_umrti': ['Q3874'],
#   'profese': ['Q1622272', 'Q36180', 'Q13418253', 'Q14467526', 'Q12347522'],
#   'strany': ['Q7320'],
#   'skoly': ['Q102398072', 'Q102398197', 'Q102398119'],
#   'jazykove_verze': ['de', 'hu']},
#  {'024_a': 'Q100366',
#   'label_cs': 'Wilhelm Herchenbach',
#   'label_en': 'Wilhelm Herchenbach',
#   'popis_en': 'German writer; author',
#   'w_narozeni_presne': '+1818-11-13T00:00:00Z',
#   'w_umrti_presne': '+1889-12-14T00:00:00Z',
#   'w_narozeni': 1818,
#   'w_umrti': 1889,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q43287'],
#   'w_misto_narozeni': ['Q254171'],
#   'w_misto_umrti': ['Q1718'],
#   'profese': ['Q36180'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Wilhelm_Herchenbach',
#   'jazykove_verze': ['arz', 'en', 'de']},
#  {'024_a': 'Q100375832',
#   'label_cs': 'Ronald Voullié',
#   'label_en': 'Ronald Voullié',
#   'popis_en': 'German translator (1952-2020)',
#   'w_narozeni_presne': '+1952-05-18T00:00:00Z',
#   'w_umrti_presne': '+2020-09-29T00:00:00Z',
#   'w_narozeni': 1952,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q24879'],
#   'profese': ['Q333634', 'Q2599593'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100378',
#   'label_cs': 'Valentin Triller',
#   'label_en': 'Valentin Triller',
#   'popis_cs': 'německý skladatel, duchovní a spisovatel',
#   'popis_en': 'German composer, parson and writer (1493-1579)',
#   'w_narozeni_presne': '+1493-01-01T00:00:00Z',
#   'w_umrti_presne': '+1579-00-00T00:00:00Z',
#   'w_narozeni': 1493,
#   'w_umrti': 1579,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q746395'],
#   'w_misto_umrti': ['Q389412'],
#   'profese': ['Q36834', 'Q955464', 'Q36180', 'Q96236305'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Valentin_Triller',
#   'jazykove_verze': ['cs', 'no', 'pl', 'de']},
#  {'024_a': 'Q100383505',
#   'label_cs': 'Helga Hipp',
#   'label_en': 'Helga Hipp',
#   'popis_cs': 'Německá germanistka, nederlandistka a vysokoškolská pedagožka.',
#   'w_narozeni_presne': '+1934-09-24T00:00:00Z',
#   'w_umrti_presne': '+1996-04-07T00:00:00Z',
#   'w_narozeni': 1934,
#   'w_umrti': 1996,
#   'w_gender': 'Q6581072',
#   'profese': ['Q2599593', 'Q19513109', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100383608',
#   'label_cs': 'Arnulf Rüssel',
#   'label_en': 'Arnulf Rüssel',
#   'w_narozeni_presne': '+1902-05-25T00:00:00Z',
#   'w_umrti_presne': '+1978-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1978,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q247868'],
#   'profese': ['Q212980'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100383628',
#   'label_cs': 'Robert Schulz',
#   'label_en': 'Robert Wilhelm Schulz',
#   'w_narozeni_presne': '+1914-01-25T00:00:00Z',
#   'w_umrti_presne': '+2000-10-22T00:00:00Z',
#   'w_narozeni': 1914,
#   'w_umrti': 2000,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q16957'],
#   'w_misto_narozeni': ['Q518889'],
#   'profese': ['Q2306091'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100384019',
#   'label_cs': 'Jiří Myszak',
#   'label_en': 'Jiří Myszak',
#   'popis_cs': 'český akademický sochař',
#   'w_narozeni_presne': '+1925-03-02T00:00:00Z',
#   'w_umrti_presne': '+1990-04-07T00:00:00Z',
#   'w_narozeni': 1925,
#   'w_umrti': 1990,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q523489'],
#   'w_misto_umrti': ['Q8385'],
#   'profese': ['Q1281618'],
#   'skoly': ['Q414009'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Ji%C5%99%C3%AD_Myszak',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100384723',
#   'label_cs': 'Jaroslav Škarohlíd',
#   'label_en': 'Jaroslav Škarohlíd',
#   'popis_cs': 'malíř, grafik, ilustrátor',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni_presne': '+1925-01-24T00:00:00Z',
#   'w_umrti_presne': '+2012-10-15T00:00:00Z',
#   'w_narozeni': 1925,
#   'w_umrti': 2012,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100384811',
#   'label_cs': 'Jan Čech',
#   'label_en': 'Jan Cech',
#   'popis_cs': 'letecký mechanik, autor prací o letectví a kosmonautice',
#   'w_narozeni_presne': '+1950-00-00T00:00:00Z',
#   'w_narozeni': 1950,
#   'w_gender': 'Q6581097',
#   'profese': ['Q1430683', 'Q15980158'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100385831',
#   'label_cs': 'Vojtěch V. Sláma',
#   'label_en': 'Vojtech V. Sláma',
#   'popis_cs': 'český fotograf, člen skupiny Česká Paralaxa',
#   'w_narozeni_presne': '+1974-04-06T00:00:00Z',
#   'w_narozeni': 1974,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q33231'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003886',
#   'label_cs': 'Fričovce',
#   'label_en': 'Fričovce',
#   'popis_cs': 'obec na Slovensku v okrese Prešov',
#   'popis_en': 'municipality of Slovakia',
#   'web': 'https://www.obecfricovce.sk',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Fri%C4%8Dovce',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Fri%C4%8Dovce',
#   'jazykove_verze': ['fr',
#    'eo',
#    'ce',
#    'hu',
#    'sh',
#    'tt',
#    'es',
#    'de',
#    'sk',
#    'cs',
#    'uk',
#    'ms',
#    'war',
#    'zh-min-nan',
#    'it',
#    'rue',
#    'nl',
#    'pl',
#    'pt',
#    'ca',
#    'en',
#    'eu',
#    'ro',
#    'sr']},
#  {'024_a': 'Q100390636',
#   'label_cs': 'John L. Sullivan',
#   'label_en': 'John L. Sullivan',
#   'popis_en': 'academic, college faculty, Professor of Media and Communication',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1622272'],
#   'skoly': ['Q49117'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100390701',
#   'label_cs': 'Petr Řehoř',
#   'label_en': 'Petr Řehoř',
#   'popis_cs': 'výtvarník, malíř',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni_presne': '+1949-04-26T00:00:00Z',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q158275'],
#   'profese': ['Q1028181',
#    'Q1925963',
#    'Q780596',
#    'Q37226',
#    'Q33231',
#    'Q333634',
#    'Q1229025'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394177',
#   'label_cs': 'Sasan Saatchi',
#   'label_en': 'Sassan S Saatchi',
#   'popis_en': 'researcher',
#   'profese': ['Q1622272'],
#   'skoly': ['Q432637'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394621',
#   'label_cs': 'Witold Jurasz',
#   'label_en': 'Witold Jurasz',
#   'popis_en': 'Polish journalist, diplomat',
#   'w_narozeni_presne': '+1975-07-20T00:00:00Z',
#   'w_narozeni': 1975,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q36'],
#   'profese': ['Q1930187', 'Q193391'],
#   'skoly': ['Q144488'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100400535',
#   'label_cs': 'Yasemin Besen-Cassino',
#   'label_en': 'Yasemin Besen–Cassino',
#   'popis_en': 'American sociologist',
#   'w_narozeni_presne': '+1978-12-27T00:00:00Z',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q406'],
#   'profese': ['Q2306091'],
#   'skoly': ['Q896267', 'Q969850'],
#   'manzelstvo': ['Q100752805'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Yasemin_Besen%E2%80%93Cassino',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100406682',
#   'label_cs': 'Karolína Kamberská',
#   'label_en': 'Karolína Kamberská',
#   'popis_cs': 'česká písničkářka a autorka kuchařek',
#   'w_narozeni_presne': '+1972-00-00T00:00:00Z',
#   'w_narozeni': 1972,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q146307'],
#   'profese': ['Q488205', 'Q1495660'],
#   'skoly': ['Q31519'],
#   'manzelstvo': ['Q20057968'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Karol%C3%ADna_Kambersk%C3%A1',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100407335',
#   'label_cs': 'Rudolf Brož',
#   'label_en': 'Rudolf Brož',
#   'w_narozeni_presne': '+1880-00-00T00:00:00Z',
#   'w_umrti_presne': '+1939-12-31T00:00:00Z',
#   'w_narozeni': 1880,
#   'w_umrti': 1939,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q12034750'],
#   'w_misto_umrti': ['Q1085', 'Q662985'],
#   'profese': ['Q333634', 'Q2516866', 'Q82955'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100411',
#   'label_cs': 'Ulrich Willerding',
#   'label_en': 'Ulrich Willerding',
#   'popis_en': 'American botanist (1932-2021)',
#   'w_narozeni_presne': '+1932-01-01T00:00:00Z',
#   'w_umrti_presne': '+2021-12-20T00:00:00Z',
#   'w_narozeni': 1932,
#   'w_umrti': 2021,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q518204'],
#   'w_misto_umrti': ['Q3033'],
#   'profese': ['Q3621491',
#    'Q4773904',
#    'Q2374149',
#    'Q1622272',
#    'Q32518759',
#    'Q30059961'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ulrich_Willerding',
#   'jazykove_verze': ['de', 'arz', 'en']},
#  {'024_a': 'Q100415128',
#   'label_cs': 'Peter K. Lommatzsch',
#   'label_en': 'Peter Karl Lommatzsch',
#   'w_narozeni_presne': '+1934-12-20T00:00:00Z',
#   'w_umrti_presne': '+2020-11-23T00:00:00Z',
#   'w_narozeni': 1934,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q57782'],
#   'w_misto_umrti': ['Q2079'],
#   'profese': ['Q12013238', 'Q39631', 'Q1622272'],
#   'manzelstvo': ['Q106169513'],
#   'potomstvo': ['Q106166221'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004158',
#   'label_cs': 'Frédéric Eichhoff',
#   'label_en': 'Frédéric Eichhoff',
#   'popis_en': 'writer',
#   'w_narozeni_presne': '+1799-08-17T00:00:00Z',
#   'w_umrti_presne': '+1875-05-10T00:00:00Z',
#   'w_narozeni': 1799,
#   'w_umrti': 1875,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q42810'],
#   'w_misto_umrti': ['Q245546', 'Q90'],
#   'profese': ['Q2251335', 'Q36180', 'Q13418253', 'Q14467526', 'Q1622272'],
#   'udalosti': ['Q201676'],
#   'ceny': ['Q10855271'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ric_Eichhoff',
#   'jazykove_verze': ['fr', 'da', 'hu', 'sv', 'en', 'ru']},
#  {'024_a': 'Q100416047',
#   'label_cs': 'Marie Hovorková',
#   'label_en': 'Marie Hovorková',
#   'popis_cs': 'autorka knihy o alternativní léčbě, tzv. léčení vírou',
#   'w_narozeni_presne': '+1952-00-00T00:00:00Z',
#   'w_narozeni': 1952,
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100416283',
#   'label_cs': 'Thecla z Coudenhove',
#   'label_en': 'Thecla Coudenhove-Honrichs',
#   'popis_cs': 'česká šlechtična, manželka Františka Coudenhove-Honrichse (1865-1912), posledního majitele zámku Kunštát.',
#   'popis_en': 'writer',
#   'w_narozeni_presne': '+1865-05-31T00:00:00Z',
#   'w_umrti_presne': '+1933-03-27T00:00:00Z',
#   'w_narozeni': 1865,
#   'w_umrti': 1933,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1756960'],
#   'w_misto_umrti': ['Q1381784'],
#   'profese': ['Q36180'],
#   'manzelstvo': ['Q94933498'],
#   'potomstvo': ['Q94919745'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417561',
#   'label_cs': 'Václav Vaculovič',
#   'label_en': 'Václav Vaculovič',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni_presne': '+1957-01-01T00:00:00Z',
#   'w_narozeni': 1957,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'w_misto_narozeni': ['Q81137'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417809',
#   'label_cs': 'Jan Mácha',
#   'label_en': 'Jan Mácha',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni_presne': '+1926-09-16T00:00:00Z',
#   'w_umrti_presne': '+1984-11-07T00:00:00Z',
#   'w_narozeni': 1926,
#   'w_umrti': 1984,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1008696'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1028181', 'Q1925963', 'Q644687', 'Q6051619'],
#   'skoly': ['Q414009'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421384',
#   'label_cs': 'Anna Boog',
#   'label_en': 'Anna Boog',
#   'popis_en': "Austrian children's writer",
#   'w_narozeni_presne': '+1894-06-16T00:00:00Z',
#   'w_narozeni': 1894,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q40'],
#   'w_misto_narozeni': ['Q39193'],
#   'profese': ['Q4853732'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421794',
#   'label_cs': 'Miloslav Urban',
#   'label_en': 'Miloslav Urban',
#   'popis_cs': 'autor cestopisných vzpomínek',
#   'w_narozeni_presne': '+1932-00-00T00:00:00Z',
#   'w_umrti_presne': '+2010-00-00T00:00:00Z',
#   'w_narozeni': 1932,
#   'w_umrti': 2010,
#   'w_gender': 'Q6581097',
#   'profese': ['Q3579035'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004275',
#   'label_cs': 'Fridrich Jakub Fuker',
#   'label_en': 'Frigyes Jakab Fuker',
#   'popis_cs': 'německý lékař',
#   'popis_en': 'German physician',
#   'w_narozeni_presne': '+1748-01-01T00:00:00Z',
#   'w_umrti_presne': '+1805-01-01T00:00:00Z',
#   'w_narozeni': 1748,
#   'w_umrti': 1805,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q25409'],
#   'w_misto_umrti': ['Q304304'],
#   'profese': ['Q39631', 'Q897317', 'Q21771805', 'Q36180', 'Q901402', 'Q18805'],
#   'skoly': ['Q368998'],
#   'jazykove_verze': ['hu', 'sk']},
#  {'024_a': 'Q100429039',
#   'label_cs': 'Martina Mináriková',
#   'label_en': 'Martina Mináriková',
#   'popis_cs': 'slovenská šperkařka',
#   'popis_en': 'jewelry designer',
#   'w_narozeni_presne': '+1968-05-07T00:00:00Z',
#   'w_narozeni': 1968,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q1780'],
#   'profese': ['Q336221', 'Q1281618', 'Q2519376'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100430173',
#   'label_cs': 'Otakar Mlejnek',
#   'label_en': 'Otakar Mlejnek',
#   'popis_cs': 'chirurg, lodní lékař, autor vzpomínek',
#   'w_narozeni_presne': '+1930-00-00T00:00:00Z',
#   'w_narozeni': 1930,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q63855'],
#   'profese': ['Q774306', 'Q325855', 'Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100433950',
#   'label_cs': 'Kurt Ziemke',
#   'label_en': 'Kurt Ziemke',
#   'popis_en': 'German diplomat',
#   'w_narozeni_presne': '+1888-01-02T00:00:00Z',
#   'w_umrti_presne': '+1965-07-18T00:00:00Z',
#   'w_narozeni': 1888,
#   'w_umrti': 1965,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q41252'],
#   'profese': ['Q1136290'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100443143',
#   'label_cs': 'Dana Ďuricová',
#   'label_en': 'Dana Duricova',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q1650915'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100450',
#   'label_cs': 'Stephan Fridolin',
#   'label_en': 'Stephan Fridolin',
#   'popis_en': 'German Franciscan',
#   'w_narozeni_presne': '+1430-01-01T00:00:00Z',
#   'w_umrti_presne': '+1498-01-01T00:00:00Z',
#   'w_narozeni': 1430,
#   'w_umrti': 1498,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q82741'],
#   'profese': ['Q36180', 'Q432386'],
#   'jazykove_verze': ['de', 'fr']}]

# %%
import sys
sys.getsizeof(medailony)
# Out:
# 1140568

# %%
text = "text"
sys.getsizeof(text)
# Out:
# 45

# %%
df = pd.read_json(os.path.join("data_raw","autority_wikidataids.json")).reset_index(drop=False)

# %%
df
# Out:
#                  index       024_a
# 0           jk01010005    Q1063371
# 1           jk01010022   Q12028104
# 2           jk01010023     Q640512
# 3           jk01010026   Q12055885
# 4           jk01010030     Q634048
# ...                ...         ...
# 134825   zmp2016925673   Q13582412
# 134826   zmp2016925675  Q112503439
# 134827  zmp20191037071   Q26208443
# 134828  zmp20191054500     Q825192
# 134829  zmp20211116840  Q107140306
#
# [134830 rows x 2 columns]

# %%
df = df.merge(pd.DataFrame(medailony), on='024_a').set_index('index')

# %%
df.sample(20)
# Out:
#                         024_a                     label_cs  \
# index
# jn19981001651       Q16665678  Leontij Vasiljevič Kopeckij
# xx0227479           Q93380020          Anne-Sophie Baumann
# jn20011121002       Q95077192                 Marta Ehlová
# jk01101138          Q95102295              Jakub Procházka
# jk01081427         Q110659131             Stanislav Michal
# xx0041706            Q1658374            Ildikó von Kürthy
# uk20231195113       Q97064617              R. V. G. Tasker
# jn20000710356       Q95076820                   Josef Krůs
# mzk2004148356         Q216205                  Fred Wander
# kup19940000055042  Q112385288           Stanislav Laichman
# xx0319768          Q127604537                Magda Szpecht
# jn20010602757         Q151403               Thomas Carlyle
# jn20000602926       Q12764348                Daniel Hevier
# xx0271412           Q93233490                    Carl Laga
# xx0018381           Q95465526               Dora Čančíková
# mzk2002110293       Q95111657                   Jiří Baláš
# jcu2013741653       Q21263946               Hermann Hacker
# jo20221137083         Q510221                Wavrin Maître
# jo20000071106         Q896846                 Brad Meltzer
# jn20000604548         Q231944              Ann Radcliffová
#
#                                   label_en  \
# index
# jn19981001651             Leontij Kopeckij
# xx0227479              Anne-Sophie Baumann
# jn20011121002                 Marta Ehlová
# jk01101138                 Jakub Procházka
# jk01081427                Stanislav Michal
# xx0041706                Ildikó von Kürthy
# uk20231195113                R.V.G. Tasker
# jn20000710356                   Josef Krůs
# mzk2004148356                  Fred Wander
# kup19940000055042       Stanislav Laichman
# xx0319768                    Magda Szpecht
# jn20010602757               Thomas Carlyle
# jn20000602926                Daniel Hevier
# xx0271412                        Carl Laga
# xx0018381                   Dora Čančíková
# mzk2002110293                   Jiří Baláš
# jcu2013741653      Hermann Heinrich Hacker
# jo20221137083             Master of Wavrin
# jo20000071106                 Brad Meltzer
# jn20000604548                Ann Radcliffe
#
#                                                             popis_en  \
# index
# jn19981001651                                                    NaN
# xx0227479                                                        NaN
# jn20011121002                                                    NaN
# jk01101138                                                       NaN
# jk01081427                                                       NaN
# xx0041706                               German journalist and author
# uk20231195113                                                    NaN
# jn20000710356                                                    NaN
# mzk2004148356                                        Austrian writer
# kup19940000055042                                                NaN
# xx0319768                                                        NaN
# jn20010602757      Scottish essayist, historian and philosopher (...
# jn20000602926                                          Slovak writer
# xx0271412                                                        NaN
# xx0018381                                                        NaN
# mzk2002110293                                                    NaN
# jcu2013741653                                    German entomologist
# jo20221137083                                         French painter
# jo20000071106                                                 writer
# jn20000604548      English author and pioneer of the Gothic novel...
#
#                        w_narozeni_presne         w_umrti_presne  w_narozeni  \
# index
# jn19981001651      +1894-08-22T00:00:00Z  +1976-04-04T00:00:00Z      1894.0
# xx0227479          +1970-00-00T00:00:00Z                    NaN      1970.0
# jn20011121002      +1946-06-02T00:00:00Z                    NaN      1946.0
# jk01101138         +1818-07-22T00:00:00Z  +1893-09-25T00:00:00Z      1818.0
# jk01081427                           NaN                    NaN         NaN
# xx0041706          +1968-01-20T00:00:00Z                    NaN      1968.0
# uk20231195113      +1895-08-31T00:00:00Z  +1976-01-01T00:00:00Z      1895.0
# jn20000710356      +1937-03-03T00:00:00Z                    NaN      1937.0
# mzk2004148356      +1917-01-05T00:00:00Z  +2006-07-10T00:00:00Z      1917.0
# kup19940000055042  +1946-00-00T00:00:00Z                    NaN      1946.0
# xx0319768          +1990-01-01T00:00:00Z                    NaN      1990.0
# jn20010602757      +1795-12-04T00:00:00Z  +1881-02-05T00:00:00Z      1795.0
# jn20000602926      +1955-12-06T00:00:00Z                    NaN      1955.0
# xx0271412          +1924-10-29T00:00:00Z                    NaN      1924.0
# xx0018381          +1977-06-03T00:00:00Z                    NaN      1977.0
# mzk2002110293      +1938-10-03T00:00:00Z  +1989-12-13T00:00:00Z      1938.0
# jcu2013741653      +1951-01-01T00:00:00Z                    NaN      1951.0
# jo20221137083      +1450-00-00T00:00:00Z                    NaN      1450.0
# jo20000071106      +1970-04-01T00:00:00Z                    NaN      1970.0
# jn20000604548      +1764-07-09T00:00:00Z  +1823-02-07T00:00:00Z      1764.0
#
#                    w_umrti  w_gender                obcanstvi  \
# index
# jn19981001651       1976.0  Q6581097                      NaN
# xx0227479              NaN  Q6581072                      NaN
# jn20011121002          NaN  Q6581072                      NaN
# jk01101138          1893.0  Q6581097                      NaN
# jk01081427             NaN  Q6581097                      NaN
# xx0041706              NaN  Q6581072                   [Q183]
# uk20231195113       1976.0  Q6581097                   [Q145]
# jn20000710356          NaN  Q6581097                      NaN
# mzk2004148356       2006.0  Q6581097                    [Q40]
# kup19940000055042      NaN  Q6581097                      NaN
# xx0319768              NaN  Q6581072                      NaN
# jn20010602757       1881.0  Q6581097  [Q174193, Q22, Q161885]
# jn20000602926          NaN  Q6581097           [Q214, Q33946]
# xx0271412              NaN  Q6581097                      NaN
# xx0018381              NaN  Q6581072                      NaN
# mzk2002110293       1989.0  Q6581097                      NaN
# jcu2013741653          NaN  Q6581097                   [Q183]
# jo20221137083          NaN  Q6581097                   [Q142]
# jo20000071106          NaN  Q6581097                    [Q30]
# jn20000604548       1823.0  Q6581072       [Q161885, Q174193]
#
#                   w_misto_narozeni w_misto_umrti  \
# index
# jn19981001651                  NaN       [Q1085]
# xx0227479                      NaN           NaN
# jn20011121002                  NaN           NaN
# jk01101138                     NaN      [Q14960]
# jk01081427                     NaN           NaN
# xx0041706                  [Q1017]           NaN
# uk20231195113                  NaN           NaN
# jn20000710356              [Q1780]           NaN
# mzk2004148356              [Q1741]       [Q1741]
# kup19940000055042              NaN           NaN
# xx0319768                      NaN           NaN
# jn20010602757           [Q1015818]         [Q84]
# jn20000602926              [Q1780]           NaN
# xx0271412                      NaN           NaN
# xx0018381                [Q171018]           NaN
# mzk2002110293             [Q14960]     [Q146363]
# jcu2013741653                  NaN           NaN
# jo20221137083                  NaN           NaN
# jo20000071106             [Q18419]           NaN
# jn20000604548            [Q123624]         [Q84]
#
#                                                              profese  \
# index
# jn19981001651                       [Q14467526, Q14972848, Q1622272]
# xx0227479                                                   [Q36180]
# jn20011121002                                       [Q40348, Q36180]
# jk01101138                                                 [Q250867]
# jk01081427                                                       NaN
# xx0041706                                         [Q1930187, Q36180]
# uk20231195113      [Q2259532, Q3400985, Q37226, Q1234713, Q198299...
# jn20000710356                                                    NaN
# mzk2004148356                                     [Q36180, Q1930187]
# kup19940000055042                                        [Q10872101]
# xx0319768                                                        NaN
# jn20010602757      [Q14467526, Q13570226, Q201788, Q333634, Q1707...
# jn20000602926                      [Q36180, Q49757, Q28389, Q333634]
# xx0271412                                         [Q42603, Q1622272]
# xx0018381                     [Q3391743, Q644687, Q1925963, Q266569]
# mzk2002110293                                               [Q33231]
# jcu2013741653                                             [Q3055126]
# jo20221137083                                              [Q998628]
# jo20000071106                   [Q28389, Q6625963, Q36180, Q4853732]
# jn20000604548                                     [Q6625963, Q36180]
#
#                                                                 ceny  \
# index
# jn19981001651                                                    NaN
# xx0227479                                                        NaN
# jn20011121002                                                    NaN
# jk01101138                                                       NaN
# jk01081427                                                       NaN
# xx0041706                                                  [Q791970]
# uk20231195113                                                    NaN
# jn20000710356                                                    NaN
# mzk2004148356      [Q1377631, Q548088, Q306324, Q2417243, Q137174...
# kup19940000055042                                                NaN
# xx0319768                                                        NaN
# jn20010602757                        [Q15056034, Q52382875, Q156478]
# jn20000602926                                                    NaN
# xx0271412                                                        NaN
# xx0018381                                                        NaN
# mzk2002110293                                                    NaN
# jcu2013741653                                                    NaN
# jo20221137083                                                    NaN
# jo20000071106                                                    NaN
# jn20000604548                                                    NaN
#
#                                                       jazykove_verze  \
# index
# jn19981001651                                               [ru, cs]
# xx0227479                                                         []
# jn20011121002                                                     []
# jk01101138                                                        []
# jk01081427                                                        []
# xx0041706                                               [de, hu, bg]
# uk20231195113                                                     []
# jn20000710356                                                     []
# mzk2004148356                          [es, en, it, arz, fi, eo, de]
# kup19940000055042                                                 []
# xx0319768                                                         []
# jn20010602757      [azb, nn, arz, da, tr, be-tarask, id, simple, ...
# jn20000602926                                               [cs, sk]
# xx0271412                                                         []
# xx0018381                                                         []
# mzk2002110293                                                     []
# jcu2013741653                                                   [en]
# jo20221137083                               [pl, en, it, fr, de, nl]
# jo20000071106         [pt, ko, arz, bg, fr, it, en, de, es, ru, azb]
# jn20000604548      [tt, el, br, fa, mk, fi, ar, da, it, nl, la, h...
#
#                                                             popis_cs  \
# index
# jn19981001651                     rusko-český lingvista a lexikograf
# xx0227479                          francouzská autorka knih pro děti
# jn20011121002                         česká advokátka a spisovatelka
# jk01101138         Narozen 22.7.1818 v Pavlovicích, zemřel 25.9.1...
# jk01081427                                                       NaN
# xx0041706                                                        NaN
# uk20231195113                                                    NaN
# jn20000710356      Narozen 3.3.1937 v Bratislavě (Slovensko), půs...
# mzk2004148356                                    rakouský spisovatel
# kup19940000055042     anatom, autor učebnic a výukových videozáznamů
# xx0319768          Polská novinářka, performerka a divadelní reži...
# jn20010602757                          skotský spisovatel a historik
# jn20000602926                       slovenský spisovatel a vydavatel
# xx0271412          belgický kněz a vysokoškolský pedagog zaměřený...
# xx0018381          Narozena 3. 6. 1977 ve Zlíně. Výtvarnice, ilus...
# mzk2002110293                                         český fotograf
# jcu2013741653                                                    NaN
# jo20221137083      Anonymní iluminátor z druhé poloviny 15. stole...
# jo20000071106                                                    NaN
# jn20000604548                                  anglická spisovatelka
#
#                                                              wiki_cs  \
# index
# jn19981001651      https://cs.wikipedia.org/wiki/Leontij_Vasiljev...
# xx0227479                                                        NaN
# jn20011121002                                                    NaN
# jk01101138                                                       NaN
# jk01081427                                                       NaN
# xx0041706                                                        NaN
# uk20231195113                                                    NaN
# jn20000710356                                                    NaN
# mzk2004148356                                                    NaN
# kup19940000055042                                                NaN
# xx0319768                                                        NaN
# jn20010602757           https://cs.wikipedia.org/wiki/Thomas_Carlyle
# jn20000602926            https://cs.wikipedia.org/wiki/Daniel_Hevier
# xx0271412                                                        NaN
# xx0018381                                                        NaN
# mzk2002110293                                                    NaN
# jcu2013741653                                                    NaN
# jo20221137083                                                    NaN
# jo20000071106                                                    NaN
# jn20000604548      https://cs.wikipedia.org/wiki/Ann_Radcliffov%C...
#
#                                                              wiki_en  \
# index
# jn19981001651                                                    NaN
# xx0227479                                                        NaN
# jn20011121002                                                    NaN
# jk01101138                                                       NaN
# jk01081427                                                       NaN
# xx0041706                                                        NaN
# uk20231195113                                                    NaN
# jn20000710356                                                    NaN
# mzk2004148356              https://en.wikipedia.org/wiki/Fred_Wander
# kup19940000055042                                                NaN
# xx0319768                                                        NaN
# jn20010602757           https://en.wikipedia.org/wiki/Thomas_Carlyle
# jn20000602926                                                    NaN
# xx0271412                                                        NaN
# xx0018381                                                        NaN
# mzk2002110293                                                    NaN
# jcu2013741653      https://en.wikipedia.org/wiki/Hermann_Heinrich...
# jo20221137083         https://en.wikipedia.org/wiki/Master_of_Wavrin
# jo20000071106             https://en.wikipedia.org/wiki/Brad_Meltzer
# jn20000604548            https://en.wikipedia.org/wiki/Ann_Radcliffe
#
#                   druh_umrti pricina_umrti                     vezeni  \
# index
# jn19981001651       Q3739104        Q12078                        NaN
# xx0227479                NaN           NaN                        NaN
# jn20011121002            NaN           NaN                        NaN
# jk01101138               NaN           NaN                        NaN
# jk01081427               NaN           NaN                        NaN
# xx0041706                NaN           NaN                        NaN
# uk20231195113            NaN           NaN                        NaN
# jn20000710356            NaN           NaN                        NaN
# mzk2004148356            NaN           NaN  [Q7341, Q247958, Q152802]
# kup19940000055042        NaN           NaN                        NaN
# xx0319768                NaN           NaN                        NaN
# jn20010602757            NaN           NaN                        NaN
# jn20000602926            NaN           NaN                        NaN
# xx0271412                NaN           NaN                        NaN
# xx0018381                NaN           NaN                        NaN
# mzk2002110293            NaN           NaN                        NaN
# jcu2013741653            NaN           NaN                        NaN
# jo20221137083            NaN           NaN                        NaN
# jo20000071106            NaN           NaN                        NaN
# jn20000604548       Q3739104        Q12192                        NaN
#
#                       strany                          skoly   manzelstvo  \
# index
# jn19981001651            NaN             [Q31519, Q1458695]          NaN
# xx0227479                NaN                            NaN          NaN
# jn20011121002            NaN                            NaN          NaN
# jk01101138               NaN                            NaN          NaN
# jk01081427               NaN                            NaN          NaN
# xx0041706                NaN                            NaN          NaN
# uk20231195113            NaN                            NaN          NaN
# jn20000710356            NaN                            NaN          NaN
# mzk2004148356      [Q161118]                            NaN     [Q89932]
# kup19940000055042        NaN                            NaN          NaN
# xx0319768                NaN                            NaN          NaN
# jn20010602757            NaN            [Q160302, Q4767906]   [Q6152913]
# jn20000602926            NaN                            NaN          NaN
# xx0271412                NaN                            NaN          NaN
# xx0018381                NaN                            NaN          NaN
# mzk2002110293            NaN                            NaN          NaN
# jcu2013741653            NaN                            NaN          NaN
# jo20221137083            NaN                            NaN          NaN
# jo20000071106            NaN  [Q230492, Q1149089, Q7056097]          NaN
# jn20000604548            NaN                            NaN  [Q89127446]
#
#                   partnerstvo potomstvo sourozenectvo facebook twitter  \
# index
# jn19981001651             NaN       NaN           NaN      NaN     NaN
# xx0227479                 NaN       NaN           NaN      NaN     NaN
# jn20011121002             NaN       NaN           NaN      NaN     NaN
# jk01101138                NaN       NaN           NaN      NaN     NaN
# jk01081427                NaN       NaN           NaN      NaN     NaN
# xx0041706                 NaN       NaN           NaN      NaN     NaN
# uk20231195113             NaN       NaN           NaN      NaN     NaN
# jn20000710356             NaN       NaN           NaN      NaN     NaN
# mzk2004148356             NaN       NaN           NaN      NaN     NaN
# kup19940000055042         NaN       NaN           NaN      NaN     NaN
# xx0319768                 NaN       NaN           NaN      NaN     NaN
# jn20010602757             NaN       NaN   [Q18530228]      NaN     NaN
# jn20000602926             NaN       NaN           NaN      NaN     NaN
# xx0271412                 NaN       NaN           NaN      NaN     NaN
# xx0018381                 NaN       NaN           NaN      NaN     NaN
# mzk2002110293             NaN       NaN           NaN      NaN     NaN
# jcu2013741653             NaN       NaN           NaN      NaN     NaN
# jo20221137083             NaN       NaN           NaN      NaN     NaN
# jo20000071106             NaN       NaN           NaN      NaN     NaN
# jn20000604548             NaN       NaN           NaN      NaN     NaN
#
#                   instagram                          web udalosti       role
# index
# jn19981001651           NaN                          NaN      NaN        NaN
# xx0227479               NaN                          NaN      NaN        NaN
# jn20011121002           NaN                          NaN      NaN        NaN
# jk01101138              NaN                          NaN      NaN        NaN
# jk01081427              NaN                          NaN      NaN        NaN
# xx0041706               NaN                          NaN      NaN        NaN
# uk20231195113           NaN                          NaN      NaN        NaN
# jn20000710356           NaN                          NaN      NaN        NaN
# mzk2004148356           NaN                          NaN      NaN        NaN
# kup19940000055042       NaN                          NaN      NaN        NaN
# xx0319768               NaN                          NaN      NaN        NaN
# jn20010602757           NaN                          NaN      NaN        NaN
# jn20000602926           NaN                          NaN      NaN        NaN
# xx0271412               NaN                          NaN      NaN        NaN
# xx0018381               NaN                          NaN      NaN        NaN
# mzk2002110293           NaN                          NaN      NaN        NaN
# jcu2013741653           NaN                          NaN      NaN        NaN
# jo20221137083           NaN                          NaN      NaN  [Q474968]
# jo20000071106           NaN  http://www.bradmeltzer.com/      NaN        NaN
# jn20000604548           NaN                          NaN      NaN        NaN

# %%
df[df.index == 'Q93240837']
# Out:
# Empty DataFrame
# Columns: [024_a, label_cs, label_en, popis_en, w_narozeni_presne, w_umrti_presne, w_narozeni, w_umrti, w_gender, obcanstvi, w_misto_narozeni, w_misto_umrti, profese, ceny, jazykove_verze, popis_cs, wiki_cs, wiki_en, druh_umrti, pricina_umrti, vezeni, strany, skoly, manzelstvo, partnerstvo, potomstvo, sourozenectvo, facebook, twitter, instagram, web, udalosti, role]
# Index: []

# %%
df[df['024_a'] == 'Q571203']
# Out:
#               024_a       label_cs       label_en  \
# index
# jk01100136  Q571203  Karel Poláček  Karel Poláček
#
#                                                      popis_en  \
# index
# jk01100136  Czech humorist, publicist, bookwriter, scriptw...
#
#                 w_narozeni_presne         w_umrti_presne  w_narozeni  w_umrti  \
# index
# jk01100136  +1892-03-22T00:00:00Z  +1945-01-21T00:00:00Z      1892.0   1945.0
#
#             w_gender          obcanstvi w_misto_narozeni  \
# index
# jk01100136  Q6581097  [Q533534, Q33946]       [Q1000091]
#
#                       w_misto_umrti  \
# index
# jk01100136  [Q105084, Q7342, Q7341]
#
#                                                    profese         ceny  \
# index
# jk01100136  [Q36180, Q28389, Q1930187, Q69423232, Q876864]  [Q42794387]
#
#                                            jazykove_verze  \
# index
# jk01100136  [fr, de, fa, sk, arz, uk, it, eo, cs, en, ru]
#
#                                                      popis_cs  \
# index
# jk01100136  český humorista, novinář, romanopisec, scenári...
#
#                                                       wiki_cs  \
# index
# jk01100136  https://cs.wikipedia.org/wiki/Karel_Pol%C3%A1%...
#
#                                                       wiki_en druh_umrti  \
# index
# jk01100136  https://en.wikipedia.org/wiki/Karel_Pol%C3%A1%...        NaN
#
#            pricina_umrti              vezeni strany        skoly  \
# index
# jk01100136           NaN  [Q7341, Q15111616]    NaN  [Q12047389]
#
#               manzelstvo  partnerstvo potomstvo             sourozenectvo  \
# index
# jk01100136  [Q105573892]  [Q95459535]       NaN  [Q105573905, Q105574064]
#
#            facebook twitter instagram  web                           udalosti  \
# index
# jk01100136      NaN     NaN       NaN  NaN  [Q5883980, Q104055388, Q76358503]
#
#                   role
# index
# jk01100136  [Q5883980]

# %%
df[df['024_a'] == 'Q16861736']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                    w_narozeni_presne w_umrti_presne  w_narozeni  w_umrti  \
# index
# jx20100301005  +1984-01-16T00:00:00Z            NaN      1984.0      NaN
#
#                w_gender obcanstvi w_misto_narozeni w_misto_umrti  \
# index
# jx20100301005  Q6581097    [Q213]         [Q14960]           NaN
#
#                                                       profese ceny  \
# index
# jx20100301005  [Q36180, Q1930187, Q6051619, Q822146, Q333634]  NaN
#
#               jazykove_verze          popis_cs  \
# index
# jx20100301005           [cs]  český publicista
#
#                                                          wiki_cs wiki_en  \
# index
# jx20100301005  https://cs.wikipedia.org/wiki/Michal_Ka%C5%A1p...     NaN
#
#               druh_umrti pricina_umrti vezeni strany      skoly manzelstvo  \
# index
# jx20100301005        NaN           NaN    NaN    NaN  [Q763586]        NaN
#
#               partnerstvo potomstvo sourozenectvo  facebook   twitter  \
# index
# jx20100301005         NaN       NaN           NaN  kasparek  kasparek
#
#                             instagram                            web udalosti  \
# index
# jx20100301005  jakovzdynaprostopresny  http://www.michalkasparek.cz/      NaN
#
#               role
# index
# jx20100301005  NaN

# %%
df[df.index == 'jx20100301005']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                    w_narozeni_presne w_umrti_presne  w_narozeni  w_umrti  \
# index
# jx20100301005  +1984-01-16T00:00:00Z            NaN      1984.0      NaN
#
#                w_gender obcanstvi w_misto_narozeni w_misto_umrti  \
# index
# jx20100301005  Q6581097    [Q213]         [Q14960]           NaN
#
#                                                       profese ceny  \
# index
# jx20100301005  [Q36180, Q1930187, Q6051619, Q822146, Q333634]  NaN
#
#               jazykove_verze          popis_cs  \
# index
# jx20100301005           [cs]  český publicista
#
#                                                          wiki_cs wiki_en  \
# index
# jx20100301005  https://cs.wikipedia.org/wiki/Michal_Ka%C5%A1p...     NaN
#
#               druh_umrti pricina_umrti vezeni strany      skoly manzelstvo  \
# index
# jx20100301005        NaN           NaN    NaN    NaN  [Q763586]        NaN
#
#               partnerstvo potomstvo sourozenectvo  facebook   twitter  \
# index
# jx20100301005         NaN       NaN           NaN  kasparek  kasparek
#
#                             instagram                            web udalosti  \
# index
# jx20100301005  jakovzdynaprostopresny  http://www.michalkasparek.cz/      NaN
#
#               role
# index
# jx20100301005  NaN

# %%
df.sample(10)
# Out:
#                      024_a                   label_cs  \
# index
# jk01040727       Q95362458             Milan Hendrych
# jk01080964       Q56751281  Gustav Narcis Mayerhoffer
# hka2018984314    Q18197666                   J. Marni
# jk01030454       Q95149708            František Emler
# xx0274381       Q106783351           Daniela Sodomová
# mzk20241215208  Q124580001                Peter Takáč
# av20231205463     Q3166621                Jean Baudry
# xx0173540        Q95157438               Josef Prouza
# mzk2008459031   Q120582776             Zdeněk Schmied
# mzk2004236733   Q112385731               Renata Halmo
#
#                                  label_en                      popis_en  \
# index
# jk01040727                 Milan Hendrych                           NaN
# jk01080964      Gustav Narcis Mayerhoffer  Czech translator (1865-1941)
# hka2018984314                Jeanne Marni                 French writer
# jk01030454                František Emler                           NaN
# xx0274381                Daniela Sodomová                           NaN
# mzk20241215208                Peter Takáč                           NaN
# av20231205463           Jean-Louis Baudry     French writer (1930-2015)
# xx0173540                    Josef Prouza                           NaN
# mzk2008459031                         NaN                           NaN
# mzk2004236733                Renata Halmo                           NaN
#
#                     w_narozeni_presne         w_umrti_presne  w_narozeni  \
# index
# jk01040727      +1929-01-18T00:00:00Z  +1988-12-05T00:00:00Z      1929.0
# jk01080964      +1865-01-09T00:00:00Z  +1941-10-14T00:00:00Z      1865.0
# hka2018984314   +1848-08-18T00:00:00Z  +1910-01-01T00:00:00Z      1848.0
# jk01030454      +1912-07-26T00:00:00Z  +1992-05-24T00:00:00Z      1912.0
# xx0274381       +1982-12-09T00:00:00Z                    NaN      1982.0
# mzk20241215208  +1991-01-01T00:00:00Z                    NaN      1991.0
# av20231205463   +1930-03-02T00:00:00Z  +2015-10-03T00:00:00Z      1930.0
# xx0173540       +1957-11-07T00:00:00Z  +2023-12-01T00:00:00Z      1957.0
# mzk2008459031                     NaN                    NaN         NaN
# mzk2004236733                     NaN  +2016-09-21T00:00:00Z         NaN
#
#                 w_umrti  w_gender obcanstvi     w_misto_narozeni  \
# index
# jk01040727       1988.0  Q6581097  [Q33946]              [Q1085]
# jk01080964       1941.0  Q6581097  [Q33946]            [Q986070]
# hka2018984314    1910.0  Q6581072    [Q142]              [Q7880]
# jk01030454       1992.0  Q6581097  [Q33946]  [Q1018341, Q470380]
# xx0274381           NaN  Q6581072       NaN  [Q985465, Q1015273]
# mzk20241215208      NaN  Q6581097       NaN                  NaN
# av20231205463    2015.0  Q6581097    [Q142]       [Q187153, Q90]
# xx0173540        2023.0  Q6581097       NaN             [Q81137]
# mzk2008459031       NaN       NaN       NaN                  NaN
# mzk2004236733    2016.0  Q6581072       NaN                  NaN
#
#                  w_misto_umrti  \
# index
# jk01040727             [Q1085]
# jk01080964             [Q1085]
# hka2018984314        [Q234205]
# jk01030454             [Q1085]
# xx0274381                  NaN
# mzk20241215208             NaN
# av20231205463   [Q191066, Q90]
# xx0173540              [Q1085]
# mzk2008459031              NaN
# mzk2004236733              NaN
#
#                                                           profese ceny  \
# index
# jk01040727         [Q12144794, Q214917, Q36180, Q3455803, Q28389]  NaN
# jk01080964                                      [Q333634, Q36180]  NaN
# hka2018984314                         [Q1930187, Q36180, Q214917]  NaN
# jk01030454                          [Q1028181, Q1925963, Q644687]  NaN
# xx0274381       [Q1759246, Q28389, Q214917, Q73306227, Q704285...  NaN
# mzk20241215208                                                NaN  NaN
# av20231205463                                  [Q36180, Q5322166]  NaN
# xx0173540       [Q876864, Q49757, Q487596, Q2490358, Q188094, ...  NaN
# mzk2008459031                                                 NaN  NaN
# mzk2004236733                                          [Q1231865]  NaN
#
#                                    jazykove_verze  \
# index
# jk01040727                                     []
# jk01080964                                     []
# hka2018984314   [arz, ar, fr, es, id, de, en, ru]
# jk01030454                                     []
# xx0274381                                    [cs]
# mzk20241215208                                 []
# av20231205463               [en, fr, sv, arz, fa]
# xx0173540                                      []
# mzk2008459031                                  []
# mzk2004236733                                  []
#
#                                                          popis_cs  \
# index
# jk01040727      Narozen 18.1.1929 v Praze, zemřel 5.12.1988 v ...
# jk01080964                                      český překladatel
# hka2018984314                                                 NaN
# jk01030454      Narozen 26.7.1912 v Přelouči, zemřel 25.5.1992...
# xx0274381       Narozena 9. 12. 1982 v Rakovníku. Scenáristka,...
# mzk20241215208  Slovenský vysokoškolský učitel zaměřený na far...
# av20231205463                                                 NaN
# xx0173540       Narozen 7. 11. 1957 v Olomouci. Ing., redaktor...
# mzk2008459031   Mgr., právník, práce z pracovněprávní legislat...
# mzk2004236733   Zemřela 21. 9. 2016. PhDr., Ph.D., vysokoškols...
#
#                                                           wiki_cs  \
# index
# jk01040727                                                    NaN
# jk01080964                                                    NaN
# hka2018984314                                                 NaN
# jk01030454                                                    NaN
# xx0274381       https://cs.wikipedia.org/wiki/Daniela_Sodomov%...
# mzk20241215208                                                NaN
# av20231205463                                                 NaN
# xx0173540                                                     NaN
# mzk2008459031                                                 NaN
# mzk2004236733                                                 NaN
#
#                                                         wiki_en druh_umrti  \
# index
# jk01040727                                                  NaN        NaN
# jk01080964                                                  NaN        NaN
# hka2018984314        https://en.wikipedia.org/wiki/Jeanne_Marni        NaN
# jk01030454                                                  NaN        NaN
# xx0274381                                                   NaN        NaN
# mzk20241215208                                              NaN        NaN
# av20231205463   https://en.wikipedia.org/wiki/Jean-Louis_Baudry        NaN
# xx0173540                                                   NaN        NaN
# mzk2008459031                                               NaN        NaN
# mzk2004236733                                               NaN        NaN
#
#                pricina_umrti vezeni strany       skoly    manzelstvo  \
# index
# jk01040727               NaN    NaN    NaN         NaN           NaN
# jk01080964               NaN    NaN    NaN         NaN           NaN
# hka2018984314            NaN    NaN    NaN         NaN           NaN
# jk01030454               NaN    NaN    NaN   [Q414009]           NaN
# xx0274381                NaN    NaN    NaN         NaN  [Q110905134]
# mzk20241215208           NaN    NaN    NaN         NaN           NaN
# av20231205463            NaN    NaN    NaN         NaN           NaN
# xx0173540                NaN    NaN    NaN  [Q1063665]           NaN
# mzk2008459031            NaN    NaN    NaN         NaN           NaN
# mzk2004236733            NaN    NaN    NaN         NaN           NaN
#
#                partnerstvo potomstvo sourozenectvo facebook twitter instagram  \
# index
# jk01040727             NaN       NaN           NaN      NaN     NaN       NaN
# jk01080964             NaN       NaN           NaN      NaN     NaN       NaN
# hka2018984314          NaN       NaN           NaN      NaN     NaN       NaN
# jk01030454             NaN       NaN           NaN      NaN     NaN       NaN
# xx0274381              NaN       NaN           NaN      NaN     NaN       NaN
# mzk20241215208         NaN       NaN           NaN      NaN     NaN       NaN
# av20231205463          NaN       NaN           NaN      NaN     NaN       NaN
# xx0173540              NaN       NaN           NaN      NaN     NaN       NaN
# mzk2008459031          NaN       NaN           NaN      NaN     NaN       NaN
# mzk2004236733          NaN       NaN           NaN      NaN     NaN       NaN
#
#                 web udalosti role
# index
# jk01040727      NaN      NaN  NaN
# jk01080964      NaN      NaN  NaN
# hka2018984314   NaN      NaN  NaN
# jk01030454      NaN      NaN  NaN
# xx0274381       NaN      NaN  NaN
# mzk20241215208  NaN      NaN  NaN
# av20231205463   NaN      NaN  NaN
# xx0173540       NaN      NaN  NaN
# mzk2008459031   NaN      NaN  NaN
# mzk2004236733   NaN      NaN  NaN

# %%
df.to_json(os.path.join('data_raw','wikidata_raw.json'))

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134708 entries, jk01010005 to zmp20211116840
# Data columns (total 33 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   024_a              134708 non-null  object
#  1   label_cs           133718 non-null  object
#  2   label_en           124971 non-null  object
#  3   popis_en           73887 non-null   object
#  4   w_narozeni_presne  116619 non-null  object
#  5   w_umrti_presne     57162 non-null   object
#  6   w_narozeni         116619 non-null  float64
#  7   w_umrti            57162 non-null   float64
#  8   w_gender           126671 non-null  object
#  9   obcanstvi          68024 non-null   object
#  10  w_misto_narozeni   87514 non-null   object
#  11  w_misto_umrti      43528 non-null   object
#  12  profese            115301 non-null  object
#  13  ceny               22414 non-null   object
#  14  jazykove_verze     134360 non-null  object
#  15  popis_cs           93294 non-null   object
#  16  wiki_cs            25055 non-null   object
#  17  wiki_en            33381 non-null   object
#  18  druh_umrti         3364 non-null    object
#  19  pricina_umrti      4045 non-null    object
#  20  vezeni             1013 non-null    object
#  21  strany             5701 non-null    object
#  22  skoly              38491 non-null   object
#  23  manzelstvo         7834 non-null    object
#  24  partnerstvo        766 non-null     object
#  25  potomstvo          6381 non-null    object
#  26  sourozenectvo      4617 non-null    object
#  27  facebook           2858 non-null    object
#  28  twitter            3603 non-null    object
#  29  instagram          1509 non-null    object
#  30  web                9241 non-null    object
#  31  udalosti           1207 non-null    object
#  32  role               1496 non-null    object
# dtypes: float64(2), object(31)
# memory usage: 233.1 MB

# %%
df.columns
# Out:
# Index(['024_a', 'label_cs', 'label_en', 'popis_en', 'w_narozeni_presne',
#        'w_umrti_presne', 'w_narozeni', 'w_umrti', 'w_gender', 'obcanstvi',
#        'w_misto_narozeni', 'w_misto_umrti', 'profese', 'ceny',
#        'jazykove_verze', 'popis_cs', 'wiki_cs', 'wiki_en', 'druh_umrti',
#        'pricina_umrti', 'vezeni', 'strany', 'skoly', 'manzelstvo',
#        'partnerstvo', 'potomstvo', 'sourozenectvo', 'facebook', 'twitter',
#        'instagram', 'web', 'udalosti', 'role'],
#       dtype='object')

# %%
for sloupec in df.columns.to_list():
    print(f"{sloupec}: {int(len(df[df[sloupec].notnull()])/len(df)*100)} %")
# Out:
# 024_a: 100 %
# label_cs: 99 %
# label_en: 92 %
# popis_en: 54 %
# w_narozeni_presne: 86 %
# w_umrti_presne: 42 %
# w_narozeni: 86 %
# w_umrti: 42 %
# w_gender: 94 %
# obcanstvi: 50 %
# w_misto_narozeni: 64 %
# w_misto_umrti: 32 %
# profese: 85 %
# ceny: 16 %
# jazykove_verze: 99 %
# popis_cs: 69 %
# wiki_cs: 18 %
# wiki_en: 24 %
# druh_umrti: 2 %
# pricina_umrti: 3 %
# vezeni: 0 %
# strany: 4 %
# skoly: 28 %
# manzelstvo: 5 %
# partnerstvo: 0 %
# potomstvo: 4 %
# sourozenectvo: 3 %
# facebook: 2 %
# twitter: 2 %
# instagram: 1 %
# web: 6 %
# udalosti: 0 %
# role: 1 %
