# %%
import os
import re
import json
import pandas as pd

# %%
odkud = 'downloads/wikidata/autority'

# %%
def najdi_letopocet(x):
    try:
        return int(re.search(r"\d{4}",x).group())
    except:
        return None

# %%
gendery = {
    'Q6581097':'m',
    'Q6581072':'f',
    'Q2449503':'tm',
    'Q1052281':'tf',
    'Q48270':'nb',
    'Q189125':'trans',
    'Q121307094':'im',
    'Q93954933': 'demiboy',
    'Q1399232':'faʻafafine',
    'Q12964198':'genderqueer',
    'Q27679766': 'tm',
    'Q113124952': '?'
}

# %%
len([f for f in os.listdir("downloads/wikidata/autority")])
# Out:
# 131212

# %%
medailony = []
pocitadlo = 0

for f in [f for f in os.listdir("downloads/wikidata/autority")]:

    pocitadlo += 1
    if pocitadlo % 1000 == 0:
        print(f"{pocitadlo:006}: {f}")
    
    medailon = {}
    with open(os.path.join('downloads/wikidata/autority', f), 'r', encoding='utf-8') as file:
        
        wd = json.loads(file.read())
        q = f[:-5]
        medailon['024_a'] = q

        try:
            medailon['label_cs'] = wd['entities'][q]['labels']['cs']['value']
        except:
            pass
        try:
            medailon['label_en'] = wd['entities'][q]['labels']['en']['value']
        except:
            pass
        try:
            medailon['popis_cs'] = wd['entities'][q]['descriptions']['cs']['value']
        except:
            pass
        try:
            medailon['popis_en'] = wd['entities'][q]['descriptions']['en']['value']
        except:
            pass
        
        try:
            medailon['w_narozeni'] = najdi_letopocet(wd['entities'][q]['claims']['P569'][0]['mainsnak']['datavalue']['value']['time'])
        except:
            pass
        try:
            medailon['w_umrti'] = najdi_letopocet(wd['entities'][q]['claims']['P570'][0]['mainsnak']['datavalue']['value']['time'])
        except:
            pass
        try:
            medailon['w_gender'] = wd['entities'][q]['claims']['P21'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['obcanstvi'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P27']]
        except:
            pass
        try:
            medailon['w_misto_narozeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P19']]
        except:
            pass
        try:
            medailon['w_misto_umrti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P20']]
        except:
            pass
        try:
            medailon['druh_umrti'] = wd['entities'][q]['claims']['P1196'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['pricina_umrti'] = wd['entities'][q]['claims']['P509'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass      
        try:
            medailon['vezeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2632']]
        except:
            pass
        try:
            medailon['profese'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P106']]
        except:
            pass
        try:
            medailon['strany'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P102']]
        except:
            pass
        try:
            medailon['skoly'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P69']]
        except:
            pass
        try:
            medailon['udalosti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P793']]
        except:
            pass
        try:
            medailon['role'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2868']]
        except:
            pass
        try:
            medailon['manzelstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P26']]
        except:
            pass
        try:
            medailon['partnerstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P451']]
        except:
            pass
        try:
            medailon['sourozenectvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P3373']]
        except:
            pass
        try:
            medailon['potomstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P40']]
        except:
            pass       

        try:
            medailon['facebook'] = wd['entities'][q]['claims']['P2013'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['twitter'] = wd['entities'][q]['claims']['P2002'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['instagram'] = wd['entities'][q]['claims']['P2003'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['web'] = wd['entities'][q]['claims']['P856'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        
        try:
            medailon['jazykove_verze'] = [z.split(".wikipedia")[0].split("//")[1] for z in set(list([x for x in [hodnoty['url'] for popisky, hodnoty in wd['entities'][q]['sitelinks'].items()]])) if "wikipedia" in z]
        except:
            pass
    
    medailony.append(medailon)
# Out:
# 001000: Q102801061.json
# 002000: Q105353757.json
# 003000: Q106983378.json
# 004000: Q10820050.json
# 005000: Q109491547.json
# 006000: Q110787083.json
# 007000: Q112342826.json
# 008000: Q112349172.json
# 009000: Q112361768.json
# 010000: Q112370966.json
# 011000: Q112378439.json
# 012000: Q112386613.json
# 013000: Q112393668.json
# 014000: Q112404391.json
# 015000: Q112415316.json
# 016000: Q112428290.json
# 017000: Q112456136.json
# 018000: Q112487942.json
# 019000: Q112519385.json
# 020000: Q112560525.json
# 021000: Q113791549.json
# 022000: Q116262492.json
# 023000: Q11769070.json
# 024000: Q11910328.json
# 025000: Q12018531.json
# 026000: Q12025069.json
# 027000: Q12031957.json
# 028000: Q12044019.json
# 029000: Q120572931.json
# 030000: Q120575194.json
# 031000: Q120578274.json
# 032000: Q120583617.json
# 033000: Q120587318.json
# 034000: Q120591722.json
# 035000: Q120597421.json
# 036000: Q120605997.json
# 037000: Q120615644.json
# 038000: Q1222096.json
# 039000: Q12379619.json
# 040000: Q125263.json
# 041000: Q1271.json
# 042000: Q130031.json
# 043000: Q13534569.json
# 044000: Q1436392.json
# 045000: Q1508580.json
# 046000: Q15454791.json
# 047000: Q15830324.json
# 048000: Q16137573.json
# 049000: Q166876.json
# 050000: Q17043452.json
# 051000: Q1748401.json
# 052000: Q18341589.json
# 053000: Q18924925.json
# 054000: Q19630154.json
# 055000: Q201739.json
# 056000: Q2087343.json
# 057000: Q2144912.json
# 058000: Q219912.json
# 059000: Q232391.json
# 060000: Q2420577.json
# 061000: Q2549768.json
# 062000: Q26710231.json
# 063000: Q27985584.json
# 064000: Q28936036.json
# 065000: Q30066743.json
# 066000: Q311931.json
# 067000: Q321691.json
# 068000: Q33592009.json
# 069000: Q3512061.json
# 070000: Q37030.json
# 071000: Q3858116.json
# 072000: Q4136090.json
# 073000: Q4244192.json
# 074000: Q43588359.json
# 075000: Q4496039.json
# 076000: Q467676.json
# 077000: Q4764732.json
# 078000: Q498409.json
# 079000: Q51549893.json
# 080000: Q5298323.json
# 081000: Q54852007.json
# 082000: Q55619874.json
# 083000: Q55949653.json
# 084000: Q56887261.json
# 085000: Q57902533.json
# 086000: Q5919700.json
# 087000: Q59679526.json
# 088000: Q60815978.json
# 089000: Q6160709.json
# 090000: Q62655757.json
# 091000: Q642995.json
# 092000: Q65964592.json
# 093000: Q6810270.json
# 094000: Q70906747.json
# 095000: Q729450.json
# 096000: Q75418937.json
# 097000: Q7822312.json
# 098000: Q81188087.json
# 099000: Q85417790.json
# 100000: Q88013031.json
# 101000: Q90284941.json
# 102000: Q9256667.json
# 103000: Q93435739.json
# 104000: Q94810846.json
# 105000: Q95071772.json
# 106000: Q95080910.json
# 107000: Q95099364.json
# 108000: Q95109782.json
# 109000: Q95134431.json
# 110000: Q95144450.json
# 111000: Q95150839.json
# 112000: Q95154387.json
# 113000: Q95165019.json
# 114000: Q95167965.json
# 115000: Q95174716.json
# 116000: Q95176751.json
# 117000: Q95182640.json
# 118000: Q95214137.json
# 119000: Q95224306.json
# 120000: Q95332557.json
# 121000: Q95365290.json
# 122000: Q95375813.json
# 123000: Q95390061.json
# 124000: Q95395841.json
# 125000: Q95436761.json
# 126000: Q95447792.json
# 127000: Q95459612.json
# 128000: Q95473678.json
# 129000: Q95487882.json
# 130000: Q96954.json
# 131000: Q99460718.json

# %%
medailony[5:100]
# Out:
# [{'024_a': 'Q1000542',
#   'label_cs': 'Christina Kauschke',
#   'label_en': 'Christina Kauschke',
#   'popis_en': 'German linguist',
#   'w_narozeni': 1964,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q1295'],
#   'profese': ['Q14467526', 'Q1622272', 'Q11762416'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1000592',
#   'label_cs': 'Tyson Fury',
#   'label_en': 'Tyson Fury',
#   'popis_cs': 'britský boxer',
#   'popis_en': 'British boxer (born 1988)',
#   'w_narozeni': 1988,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q145'],
#   'w_misto_narozeni': ['Q18125'],
#   'profese': ['Q11338576', 'Q2066131'],
#   'manzelstvo': ['Q124608281'],
#   'sourozenectvo': ['Q64585041'],
#   'facebook': 'TysonFuryGypsyKing',
#   'twitter': 'Tyson_Fury',
#   'instagram': 'gypsyking101',
#   'web': 'https://tyson-fury.com/',
#   'jazykove_verze': ['bg',
#    'ko',
#    'hy',
#    'simple',
#    'hr',
#    'bn',
#    'uz',
#    'pl',
#    'cy',
#    'de',
#    'arz',
#    'ar',
#    'pt',
#    'it',
#    'fi',
#    'da',
#    'fr',
#    'th',
#    'ro',
#    'uk',
#    'ja',
#    'es',
#    'no',
#    'sv',
#    'ru',
#    'fa',
#    'he',
#    'kcg',
#    'cs',
#    'sl',
#    'nl',
#    'en',
#    'zh',
#    'vi',
#    'ga',
#    'tr',
#    'et']},
#  {'024_a': 'Q1000649',
#   'label_cs': 'András Ferkai',
#   'label_en': 'András Ferkai',
#   'popis_en': 'Hungarian architect',
#   'w_narozeni': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q42973'],
#   'jazykove_verze': ['hu', 'eo', 'arz']},
#  {'024_a': 'Q1000729',
#   'label_cs': 'Ferreira de Castro',
#   'label_en': 'José Maria Ferreira de Castro',
#   'popis_en': 'Portuguese writer and journalist',
#   'w_narozeni': 1898,
#   'w_umrti': 1974,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q45'],
#   'w_misto_narozeni': ['Q18468715'],
#   'w_misto_umrti': ['Q36433'],
#   'pricina_umrti': 'Q3010352',
#   'profese': ['Q1930187', 'Q36180'],
#   'manzelstvo': ['Q123853170'],
#   'partnerstvo': ['Q122652621'],
#   'jazykove_verze': ['de',
#    'en',
#    'it',
#    'uk',
#    'ru',
#    'gl',
#    'fi',
#    'pt',
#    'arz',
#    'ar',
#    'ro',
#    'eu',
#    'fr',
#    'es',
#    'hu']},
#  {'024_a': 'Q100090749',
#   'label_cs': 'Robin R. Means Coleman',
#   'label_en': 'Robin R. Means Coleman',
#   'popis_cs': 'Americká odbornice na komunikační studia, vysokoškolská učitelka, zaměřuje se na mediální studia, kulturní diverzitu a kulturní politiku černých, inkluzi, management vzdělávání; filmová producentka dokumentárního filmu "Horror Noire: A History of Bla',
#   'popis_en': 'American author, scholar and educator',
#   'w_narozeni': 1969,
#   'w_gender': 'Q6581072',
#   'profese': ['Q28389', 'Q36180', 'Q3282637', 'Q462390', 'Q1622272'],
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q1000985',
#   'label_cs': 'Milan Pacanda',
#   'label_en': 'Milan Pacanda',
#   'popis_cs': 'český fotbalista',
#   'popis_en': 'Czech football forward',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q213'],
#   'w_misto_narozeni': ['Q146342'],
#   'profese': ['Q937857'],
#   'jazykove_verze': ['de', 'cs', 'en', 'it', 'arz']},
#  {'024_a': 'Q1001',
#   'label_cs': 'Mahátma Gándhí',
#   'label_en': 'Mahatma Gandhi',
#   'popis_cs': 'indický politik',
#   'popis_en': 'Indian independence activist (1869–1948)',
#   'w_narozeni': 1869,
#   'w_umrti': 1948,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q129286', 'Q1775277', 'Q668'],
#   'w_misto_narozeni': ['Q6419912'],
#   'w_misto_umrti': ['Q1381516'],
#   'druh_umrti': 'Q149086',
#   'pricina_umrti': 'Q2140674',
#   'vezeni': ['Q142534', 'Q2344976', 'Q142534', 'Q142534'],
#   'profese': ['Q82955',
#    'Q808967',
#    'Q15958642',
#    'Q1930187',
#    'Q4964182',
#    'Q18814623',
#    'Q11774202',
#    'Q17351648',
#    'Q1021386',
#    'Q11774156',
#    'Q22336956',
#    'Q16323111',
#    'Q3242115',
#    'Q36180',
#    'Q185351',
#    'Q30242234'],
#   'strany': ['Q10225'],
#   'skoly': ['Q4722851', 'Q1233784', 'Q193196', 'Q100148173'],
#   'manzelstvo': ['Q264908'],
#   'sourozenectvo': ['Q100778818',
#    'Q100778893',
#    'Q100778902',
#    'Q100779061',
#    'Q100779088'],
#   'potomstvo': ['Q1390715', 'Q1280678', 'Q185403', 'Q732728'],
#   'jazykove_verze': ['ca',
#    'ckb',
#    'mr',
#    'eu',
#    'fr',
#    'ln',
#    'lmo',
#    'shi',
#    'ky',
#    'frr',
#    'zh',
#    'btm',
#    'gn',
#    'anp',
#    'tyv',
#    'mk',
#    'ug',
#    'tr',
#    'os',
#    'sco',
#    'zh-classical',
#    'ko',
#    'tl',
#    'hu',
#    'ban',
#    'dty',
#    'ha',
#    'hyw',
#    'ml',
#    'hr',
#    'mg',
#    'si',
#    'gan',
#    'ht',
#    'sr',
#    'ts',
#    'ang',
#    'be',
#    'xmf',
#    'ka',
#    'kbd',
#    'pcd',
#    'io',
#    'fa',
#    'kw',
#    'fy',
#    'pnb',
#    'lo',
#    'br',
#    'lv',
#    'tg',
#    'et',
#    'dv',
#    'uk',
#    'rue',
#    'dsb',
#    'ba',
#    'vi',
#    'fi',
#    'oc',
#    'or',
#    'tly',
#    'war',
#    'so',
#    'pa',
#    'tk',
#    'avk',
#    'fo',
#    'mni',
#    'ps',
#    'sl',
#    'be-tarask',
#    'hi',
#    'en',
#    'gl',
#    'ro',
#    'am',
#    'as',
#    'de',
#    'cv',
#    'mai',
#    'uz',
#    'id',
#    'dtp',
#    'bat-smg',
#    'sah',
#    'skr',
#    'yi',
#    'bpy',
#    'ga',
#    'qu',
#    'hif',
#    'sk',
#    'pms',
#    'hy',
#    'ia',
#    'az',
#    'vo',
#    'lez',
#    'bg',
#    'tpi',
#    'ilo',
#    'nds',
#    'sq',
#    'bjn',
#    'ary',
#    'he',
#    'new',
#    'is',
#    'th',
#    'km',
#    'bn',
#    'wuu',
#    'an',
#    'gd',
#    'cs',
#    'ur',
#    'ja',
#    'jam',
#    'eo',
#    'ast',
#    'kbp',
#    'kk',
#    'ne',
#    'el',
#    'pap',
#    'nl',
#    'rmy',
#    'bxr',
#    'kab',
#    'azb',
#    'tcy',
#    'co',
#    'ks',
#    'lb',
#    'pl',
#    'ar',
#    'bh',
#    'fiu-vro',
#    'kaa',
#    'mhr',
#    'ss',
#    'ta',
#    'als',
#    'lfn',
#    'lad',
#    'xal',
#    'tt',
#    'ms',
#    'bcl',
#    'kn',
#    'jv',
#    'no',
#    'pt',
#    'frp',
#    'ru',
#    'zh-yue',
#    'ay',
#    'ady',
#    'ceb',
#    'sat',
#    'su',
#    'te',
#    'scn',
#    'vec',
#    'zh-min-nan',
#    'ku',
#    'crh',
#    'li',
#    'my',
#    'sa',
#    'sd',
#    'mnw',
#    'diq',
#    'yo',
#    'min',
#    'sw',
#    'bs',
#    'cy',
#    'arz',
#    'ce',
#    'mn',
#    'nn',
#    'mt',
#    'simple',
#    'af',
#    'es',
#    'it',
#    'gu',
#    'sh',
#    'la',
#    'lt',
#    'gcr',
#    'mzn',
#    'da',
#    'awa',
#    'sc',
#    'gom',
#    'olo',
#    'sv',
#    'vep']},
#  {'024_a': 'Q1001077',
#   'label_cs': 'Sergej Vladimirovič Dikovskij',
#   'label_en': 'Sergey Dikovsky',
#   'popis_en': 'Soviet writer',
#   'w_narozeni': 1907,
#   'w_umrti': 1940,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q34266', 'Q2305208', 'Q15180'],
#   'w_misto_narozeni': ['Q649'],
#   'w_misto_umrti': ['Q214054'],
#   'profese': ['Q36180', 'Q1930187', 'Q12144794'],
#   'jazykove_verze': ['de', 'fr', 'fi', 'ru']},
#  {'024_a': 'Q100114213',
#   'label_cs': 'Damian Duffy',
#   'label_en': 'Damian Duffy',
#   'popis_en': 'American comics artist',
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'profese': ['Q715301', 'Q109517242', 'Q17098559', 'Q1622272'],
#   'skoly': ['Q457281'],
#   'twitter': 'DamianD2Duffy',
#   'web': 'http://damianduffy.net',
#   'jazykove_verze': ['sv']},
#  {'024_a': 'Q100133408',
#   'label_cs': 'R. Z. Kobiela',
#   'w_narozeni': 1902,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q191793'],
#   'profese': ['Q193391', 'Q1930187', 'Q36180', 'Q23656820'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100138089',
#   'label_cs': 'John Jennings',
#   'label_en': 'John Jennings',
#   'popis_en': 'American illustrator (born 1970)',
#   'w_narozeni': 1970,
#   'w_gender': 'Q6581097',
#   'profese': ['Q644687',
#    'Q109517242',
#    'Q17098559',
#    'Q3658608',
#    'Q5322166',
#    'Q19829999',
#    'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100144439',
#   'label_cs': 'Ivan Medeši',
#   'label_en': 'Ivan Medeši',
#   'popis_cs': 'Rusínský básník a prozaik působící v Srbsku. Publikuje básně, povídky, fejetony i reportáže. Pracuje jako pomocný pedagog základní školy a gymnázia.',
#   'popis_en': 'poet and novelist',
#   'w_narozeni': 1982,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q511216'],
#   'profese': ['Q36180',
#    'Q49757',
#    'Q12144794',
#    'Q1231865',
#    'Q82594',
#    'Q2070313'],
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100146632',
#   'label_cs': 'Salmá Samar Damlūjī',
#   'label_en': 'Salma Samar Damluji',
#   'popis_cs': 'Britsko-irácká architektka, vysokoškolská pedagožka, specializace na islámskou architekturu.',
#   'popis_en': 'Iraqi British architect, professor and author',
#   'w_narozeni': 1954,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q3820'],
#   'profese': ['Q36180', 'Q42973', 'Q1622272'],
#   'jazykove_verze': ['en', 'ar']},
#  {'024_a': 'Q100151669',
#   'label_cs': 'Stanislav Klika',
#   'label_en': 'Stanislav Klika',
#   'popis_cs': 'pražský novinář, spisovatel a nakladatel (1885-1942)',
#   'popis_en': 'Czech journalist, writer and publisher (1885-1942)',
#   'w_narozeni': 1885,
#   'w_umrti': 1942,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q378120', 'Q1085'],
#   'w_misto_umrti': ['Q942842'],
#   'profese': ['Q36180',
#    'Q2516866',
#    'Q356139',
#    'Q12144794',
#    'Q6051619',
#    'Q3391743'],
#   'manzelstvo': ['Q106286463'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001547',
#   'label_cs': 'Hambye',
#   'label_en': 'Hambye',
#   'popis_cs': 'obec v departementu Manche ve Francii',
#   'popis_en': 'commune in Manche, France',
#   'facebook': 'hambye',
#   'web': 'http://www.hambye.fr',
#   'jazykove_verze': ['bug',
#    'nl',
#    'ro',
#    'hu',
#    'ceb',
#    'ms',
#    'oc',
#    'sv',
#    'zh',
#    'de',
#    'diq',
#    'sh',
#    'pms',
#    'uk',
#    'zh-min-nan',
#    'fr',
#    'vec',
#    'es',
#    'tt',
#    'pt',
#    'ca',
#    'uz',
#    'el',
#    'kk',
#    'it',
#    'fy',
#    'la',
#    'war',
#    'eu',
#    'vi',
#    'ce',
#    'lld',
#    'pl',
#    'sr',
#    'en',
#    'fi',
#    'sk',
#    'eo']},
#  {'024_a': 'Q100154933',
#   'label_cs': 'Thomas R. Sinclair',
#   'label_en': 'Thomas R. Sinclair',
#   'popis_cs': 'americký rostlinný fyziolog, vysokoškolský pedagog, zaměřený na fyziologii a ekologii rostlin, změny klimatu, vodu a rostlinnou výrobu',
#   'popis_en': '1944-',
#   'w_narozeni': 1944,
#   'w_gender': 'Q6581097',
#   'profese': ['Q60244908', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001591',
#   'label_cs': 'La Bernerie-en-Retz',
#   'label_en': 'La Bernerie-en-Retz',
#   'popis_cs': 'obec v departementu Loire-Atlantique ve Francii',
#   'popis_en': 'commune in Loire-Atlantique, France',
#   'web': 'http://www.mairie-labernerie.fr',
#   'jazykove_verze': ['diq',
#    'lld',
#    'ku',
#    'pt',
#    'vi',
#    'vo',
#    'sk',
#    'it',
#    'ro',
#    'eo',
#    'fr',
#    'ceb',
#    'eu',
#    'en',
#    'war',
#    'hu',
#    'bm',
#    'ms',
#    'sr',
#    'mg',
#    'es',
#    'sh',
#    'tt',
#    'pms',
#    'sv',
#    'ast',
#    'uk',
#    'ur',
#    'nrm',
#    'oc',
#    'zh',
#    'pl',
#    'de',
#    'br',
#    'cy',
#    'la',
#    'zh-min-nan',
#    'simple',
#    'ce',
#    'vec',
#    'nl',
#    'ca',
#    'sl']},
#  {'024_a': 'Q100163576',
#   'label_cs': 'Vasyl‘ Mychajlovyč Slobodjan',
#   'label_en': 'Vasyl Slobodian',
#   'popis_cs': 'ukrajinský historik zaměřený na sakrální architekturu, autor prací z oboru',
#   'popis_en': 'Ukrainian historian',
#   'w_narozeni': 1951,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q212'],
#   'w_misto_narozeni': ['Q36036'],
#   'profese': ['Q201788', 'Q1595570', 'Q36180'],
#   'skoly': ['Q1817355'],
#   'jazykove_verze': ['uk']},
#  {'024_a': 'Q1001716',
#   'label_cs': 'Leopold Fischer',
#   'label_en': 'Leopold Fischer',
#   'popis_cs': 'Jezuitský kněz a historik. Roku 1718 vstoupil do jezuitského řádu. Narozen 28. 3. 1703 ve Vídni, zemřel 11. 4. 1787 tamtéž.',
#   'w_narozeni': 1703,
#   'w_umrti': 1787,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q153136'],
#   'w_misto_narozeni': ['Q1741'],
#   'w_misto_umrti': ['Q1741'],
#   'profese': ['Q250867', 'Q201788', 'Q432386', 'Q37226'],
#   'jazykove_verze': ['hu']},
#  {'024_a': 'Q100200',
#   'label_cs': 'Norbert Buske',
#   'label_en': 'Norbert Buske',
#   'popis_en': 'German politician and theologian',
#   'w_narozeni': 1936,
#   'w_umrti': 2023,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183', 'Q16957'],
#   'w_misto_narozeni': ['Q50960'],
#   'profese': ['Q82955', 'Q1234713'],
#   'strany': ['Q49762'],
#   'jazykove_verze': ['pl', 'en', 'de', 'arz']},
#  {'024_a': 'Q100207',
#   'label_cs': 'Marie Luise Droop',
#   'label_en': 'Marie Luise Droop',
#   'popis_en': 'German writer, director and producer (1890-1959)',
#   'w_narozeni': 1890,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q393'],
#   'w_misto_umrti': ['Q505495'],
#   'profese': ['Q28389', 'Q3282637'],
#   'jazykove_verze': ['arz', 'en', 'de']},
#  {'024_a': 'Q100217',
#   'label_cs': 'Kareen Zebroff',
#   'label_en': 'Kareen Zebroff',
#   'popis_en': 'Canadian-based author, actor and television host specialising in yoga',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q502441'],
#   'profese': ['Q947873'],
#   'jazykove_verze': ['uz', 'de', 'en', 'arz']},
#  {'024_a': 'Q100233',
#   'label_cs': 'Udo Weilacher',
#   'label_en': 'Udo Weilacher',
#   'popis_en': 'German landscape architect, author and Professor for Landscape Architecture',
#   'w_narozeni': 1963,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q3758'],
#   'profese': ['Q2815948', 'Q1622272'],
#   'skoly': ['Q157808'],
#   'jazykove_verze': ['arz', 'de', 'en']},
#  {'024_a': 'Q100243280'},
#  {'024_a': 'Q100267570',
#   'label_cs': 'Léon Carez',
#   'label_en': 'Léon Carez',
#   'w_narozeni': 1854,
#   'w_umrti': 1932,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q2845753', 'Q90'],
#   'w_misto_umrti': ['Q1078086'],
#   'profese': ['Q520549', 'Q1734662', 'Q189010'],
#   'skoly': ['Q3064332'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100267949',
#   'label_cs': 'Jacqueline Chénieux-Gendron',
#   'label_en': 'Jacqueline Chénieux-Gendron',
#   'popis_en': 'author',
#   'w_narozeni': 1939,
#   'w_umrti': 2022,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q548924'],
#   'w_misto_umrti': ['Q169293'],
#   'profese': ['Q36180'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100269537',
#   'label_cs': 'Alice Travers',
#   'label_en': 'Alice Travers',
#   'popis_en': 'researcher',
#   'w_narozeni': 1979,
#   'w_gender': 'Q6581072',
#   'profese': ['Q201788', 'Q1864603', 'Q1493121', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q1878600', 'Q999763', 'Q1394262', 'Q1430113', 'Q1394262'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100272216',
#   'label_cs': 'Mìkalaj Mìkalajevìč Mjazha',
#   'label_en': 'Nikolaĭ Nikolaevich Mezga',
#   'popis_en': 'Belarusian historian',
#   'w_narozeni': 1965,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q15180', 'Q184'],
#   'w_misto_narozeni': ['Q21659780'],
#   'profese': ['Q901', 'Q1622272', 'Q201788'],
#   'skoly': ['Q2630637'],
#   'jazykove_verze': ['be']},
#  {'024_a': 'Q100273554',
#   'label_cs': 'Johannes Kaspar',
#   'label_en': 'Johannes Kaspar',
#   'popis_cs': 'německý právník, advokát a vysokoškolský pedagog zaměřený na trestní právo hmotné a obchodní, nápravu a mediaci, právní a filozofické aspekty trestního práva, ústavní právo, teorii zločinu a na empirický výzkum sankcí',
#   'w_narozeni': 1976,
#   'w_gender': 'Q6581097',
#   'profese': ['Q185351', 'Q1622272', 'Q40348'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100276619',
#   'label_cs': 'Christian Larsen',
#   'label_en': 'Christian Larsen',
#   'popis_cs': 'Narozen v r. 1956 v Basileji. Lékař.',
#   'w_narozeni': 1956,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q39'],
#   'w_misto_narozeni': ['Q78'],
#   'profese': ['Q39631'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1002810',
#   'label_cs': 'Imre Forbáth',
#   'label_en': 'Imre Forbáth',
#   'w_narozeni': 1898,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q190522', 'Q855069'],
#   'w_misto_umrti': ['Q146342'],
#   'profese': ['Q49757', 'Q1930187', 'Q36180'],
#   'jazykove_verze': ['fr', 'hu']},
#  {'024_a': 'Q100282',
#   'label_cs': 'Reinhard Woltman',
#   'label_en': 'Reinhard Woltman',
#   'popis_en': 'hydraulic engineer from Germany',
#   'w_narozeni': 1757,
#   'w_umrti': 1837,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q164079'],
#   'w_misto_narozeni': ['Q177362'],
#   'w_misto_umrti': ['Q1055'],
#   'profese': ['Q13582652', 'Q901', 'Q36180', 'Q978044'],
#   'jazykove_verze': ['arz', 'fr', 'en', 'sv', 'de']},
#  {'024_a': 'Q100296521',
#   'label_cs': 'Paul Joseph Schulte',
#   'label_en': 'Paul J. Schulte',
#   'popis_en': 'forest science researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1650915'],
#   'skoly': ['Q219563', 'Q230492'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100301646',
#   'label_cs': 'Amy Ansehl',
#   'label_en': 'Amy Ansehl',
#   'popis_cs': 'Americká vysokoškolská profesorka a zdravotní sestra.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'profese': ['Q1622272', 'Q186360'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302130',
#   'label_cs': 'Noel Armenakas',
#   'label_en': 'Noel A. Armenakas',
#   'popis_cs': 'americký lékař, urolog, chirurg a vysokoškolský učitel, zaměřený na urologické operace, rekonstrukční chirurgii a úrazy',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581097',
#   'profese': ['Q17345122', 'Q774306', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302588',
#   'label_cs': 'Deborah Campbell',
#   'label_en': 'Deborah E. Campbell',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581072',
#   'profese': ['Q28569455', 'Q1622272'],
#   'skoly': ['Q681025'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302980',
#   'label_cs': 'James E. Cottrell',
#   'label_en': 'James E. Cottrell',
#   'popis_cs': 'americký anesteziolog a vysokoškolský pedagog zaměřený zejména na neuroanestezii',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni': 1942,
#   'w_gender': 'Q6581097',
#   'profese': ['Q28837', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100303696'},
#  {'024_a': 'Q100304023',
#   'label_cs': 'Dennis Alexander',
#   'label_en': 'Dennis Alexander',
#   'popis_cs': 'Americký hudební skladatel a klavírista, učitel hry na klavír. Autor publikací z oboru.',
#   'popis_en': 'American composer',
#   'w_narozeni': 1947,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q647127'],
#   'profese': ['Q36834', 'Q713200', 'Q16145150', 'Q639669', 'Q486748'],
#   'facebook': 'Dennis-Alexander-Music-136237939764680',
#   'web': 'http://dennisalexander.com/',
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100308989',
#   'label_cs': 'Rodrick Wallace',
#   'label_en': 'Rodrick Wallace',
#   'popis_cs': 'Americký odborník v oblasti epidemiologie duševního zdraví, zabývá se dopady veřejné politiky, diskriminace a ekonomického úpadku na veřejné zdraví. Publikace v oboru.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q100'],
#   'profese': ['Q12765408', 'Q901'],
#   'skoly': ['Q9008737'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100312952',
#   'label_cs': 'Veronika Máková',
#   'label_en': 'Veronika Máková',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q593644', 'Q901'],
#   'skoly': ['Q1291752'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100314247',
#   'label_cs': 'John Collins',
#   'label_en': 'John W Collins',
#   'popis_cs': 'americký odborník na ošetřovatelství, ošetřovatelskou péči na konci života, multikulturní ošetřovatelství a vzdělávání zdravotních sester v této oblasti, vysokoškolský pedagog',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1622272'],
#   'skoly': ['Q5316093'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100318248',
#   'label_cs': 'M. Iqbal R. Khan',
#   'label_en': 'M Iqbal R Khan',
#   'popis_cs': 'botanik, vysokoškolský pedagog a výzkumný pracovník se zaměřením na fyziologii a genomiku rostlin, rostlinný genom a fytohormony',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q2374149', 'Q1622272', 'Q901'],
#   'skoly': ['Q196544'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100319915',
#   'label_cs': 'Eric Cervini',
#   'label_en': 'Eric Cervini',
#   'popis_cs': 'americký historik, zaměřený na problematiku LGBT',
#   'popis_en': 'American historian and writer',
#   'w_narozeni': 1992,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q99'],
#   'profese': ['Q36180', 'Q201788'],
#   'skoly': ['Q14711406', 'Q13371'],
#   'facebook': 'ericcervini',
#   'twitter': 'ericcervini',
#   'instagram': 'ericcervini',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100319998',
#   'label_cs': 'Ann Napolitano',
#   'label_en': 'Ann Napolitano',
#   'popis_cs': 'Americká spisovatelka, autorka románů a redaktorka. Dříve vysokoškolská lektorka tvůrčího psaní.',
#   'popis_en': 'American writer',
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180', 'Q1622272', 'Q876864'],
#   'twitter': 'napolitanoann',
#   'web': 'https://annnapolitano.com',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100324298',
#   'label_cs': 'Elwin Huaman',
#   'label_en': 'Elwin Huaman',
#   'popis_cs': 'peruánský počítačový vědec a vysokoškolský pedagog, působící v Rakousku, zaměřený na sémantický web, vědomostní grafy a data',
#   'popis_en': 'Peruvian computer scientist',
#   'w_narozeni': 1990,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q419'],
#   'w_misto_narozeni': ['Q27194667'],
#   'profese': ['Q82594', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q6156603', 'Q308963', 'Q2303432', 'Q875788'],
#   'sourozenectvo': ['Q115660783', 'Q115660896', 'Q115660799'],
#   'twitter': 'ElwinHuaman',
#   'web': 'http://elwin.huamanquispe.com/',
#   'jazykove_verze': []},
#  {'024_a': 'Q100324868',
#   'label_cs': 'Jana Bartošová',
#   'label_en': 'Jana Bartošová',
#   'popis_cs': 'česká historička a archivářka',
#   'w_narozeni': 1971,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'profese': ['Q201788', 'Q635734'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100327408',
#   'label_cs': 'Bronisława Kokoszyńska',
#   'label_en': 'Bronisława Kokoszyńska',
#   'w_narozeni': 1897,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q36'],
#   'w_misto_narozeni': ['Q1973720'],
#   'w_misto_umrti': ['Q31487'],
#   'profese': ['Q520549', 'Q1622272'],
#   'skoly': ['Q80207'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100333885',
#   'label_cs': 'Jaroslav Boukal',
#   'label_en': 'Jaroslav Boukal',
#   'popis_cs': '* 1902 Jeníkovice u Hradce Králové † ? ? JUDr.; vedoucí knihkupecký a nakladatelský pracovník.',
#   'w_narozeni': 1902,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q2024848'],
#   'profese': ['Q2516866', 'Q1607826', 'Q333634', 'Q185351'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100334014',
#   'label_cs': 'Bohuslav Kavka',
#   'label_en': 'Bohuslav Kavka',
#   'w_narozeni': 1869,
#   'w_umrti': 1914,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q1085'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1607826', 'Q2516866'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348318',
#   'label_cs': 'Richard Lederer',
#   'label_en': 'Richard Lederer',
#   'popis_cs': 'Prof. dr. med., lékař, pediatr, vyučoval na vídeňské univerzitě, v roce 1938 emigroval do Bagdádu .',
#   'popis_en': 'pediatrician and university teacher',
#   'w_narozeni': 1885,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q384544'],
#   'w_misto_umrti': ['Q1530'],
#   'profese': ['Q39631', 'Q1919436', 'Q1622272'],
#   'manzelstvo': ['Q113389335'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348525',
#   'label_cs': 'Roberto Rea',
#   'label_en': 'Roberto Rea',
#   'popis_en': 'Italian philologist',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q38'],
#   'w_misto_narozeni': ['Q116440'],
#   'profese': ['Q1622272', 'Q13418253'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003501',
#   'label_cs': 'András Frank',
#   'label_en': 'András Frank',
#   'popis_en': 'Hungarian mathematician',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q170790'],
#   'skoly': ['Q390287', 'Q369839'],
#   'jazykove_verze': ['de', 'pt', 'ar', 'hu', 'eo', 'arz', 'en']},
#  {'024_a': 'Q100353158',
#   'label_cs': 'Robert J. Callan',
#   'label_en': 'Robert J. Callan',
#   'popis_cs': 'veterinární lékař a vysokoškolský učitel, zaměřený na infekční nemoci hospodářských zvířat',
#   'popis_en': 'veterinary researcher at Colorado State University',
#   'w_gender': 'Q6581097',
#   'profese': ['Q202883', 'Q12119633', 'Q1622272'],
#   'skoly': ['Q838330'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100356218',
#   'label_cs': 'Caroline Campbell',
#   'label_en': 'Caroline Campbell',
#   'popis_en': 'British museum curator',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q27'],
#   'w_misto_narozeni': ['Q10686'],
#   'profese': ['Q674426', 'Q1792450'],
#   'skoly': ['Q734266', 'Q734266', 'Q34433'],
#   'twitter': 'campbell_c_m',
#   'instagram': 'carolinecampbelllondon',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100356308',
#   'label_cs': 'Byron Augustin',
#   'label_en': 'Byron Augustin',
#   'popis_en': 'Professor of geography',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q959512'],
#   'profese': ['Q1622272', 'Q901402'],
#   'skoly': ['Q5680304', 'Q52413', 'Q1783608'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100358334',
#   'label_cs': 'Ludvík Ratolístka',
#   'label_en': 'Ludvík Ratolístka',
#   'w_narozeni': 1886,
#   'w_umrti': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q43453'],
#   'w_misto_umrti': ['Q1085'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003615',
#   'label_cs': 'Franz Josef Beranek',
#   'label_en': 'Franz Josef Beranek',
#   'popis_en': 'German university teacher and writer (1902-1967)',
#   'w_narozeni': 1902,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q581478'],
#   'w_misto_umrti': ['Q3874'],
#   'profese': ['Q1622272', 'Q36180', 'Q13418253', 'Q14467526', 'Q12347522'],
#   'strany': ['Q7320'],
#   'skoly': ['Q102398072', 'Q102398197', 'Q102398119'],
#   'jazykove_verze': ['hu', 'de']},
#  {'024_a': 'Q100366',
#   'label_cs': 'Wilhelm Herchenbach',
#   'label_en': 'Wilhelm Herchenbach',
#   'popis_en': 'German writer; author',
#   'w_narozeni': 1818,
#   'w_umrti': 1889,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q43287'],
#   'w_misto_narozeni': ['Q254171'],
#   'w_misto_umrti': ['Q1718'],
#   'profese': ['Q36180'],
#   'jazykove_verze': ['en', 'de', 'arz']},
#  {'024_a': 'Q100375832',
#   'label_cs': 'Ronald Voullié',
#   'label_en': 'Ronald Voullié',
#   'popis_en': 'German translator (1952-2020)',
#   'w_narozeni': 1952,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q24879'],
#   'profese': ['Q333634', 'Q2599593'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100378',
#   'label_cs': 'Valentin Triller',
#   'label_en': 'Valentin Triller',
#   'popis_cs': 'německý skladatel, duchovní a spisovatel',
#   'popis_en': 'German composer, parson and writer (1493-1579)',
#   'w_narozeni': 1493,
#   'w_umrti': 1579,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q746395'],
#   'w_misto_umrti': ['Q389412'],
#   'profese': ['Q36834', 'Q955464', 'Q36180', 'Q96236305'],
#   'jazykove_verze': ['no', 'cs', 'pl', 'de']},
#  {'024_a': 'Q100383505',
#   'label_cs': 'Helga Hipp',
#   'label_en': 'Helga Hipp',
#   'popis_cs': 'Německá germanistka, nederlandistka a vysokoškolská pedagožka.',
#   'w_narozeni': 1934,
#   'w_umrti': 1996,
#   'w_gender': 'Q6581072',
#   'profese': ['Q2599593', 'Q19513109', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100383608',
#   'label_cs': 'Arnulf Rüssel',
#   'label_en': 'Arnulf Rüssel',
#   'w_narozeni': 1902,
#   'w_umrti': 1978,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q247868'],
#   'profese': ['Q212980'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100383628',
#   'label_cs': 'Robert Schulz',
#   'label_en': 'Robert Wilhelm Schulz',
#   'w_narozeni': 1914,
#   'w_umrti': 2000,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q16957'],
#   'w_misto_narozeni': ['Q518889'],
#   'profese': ['Q2306091'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100384019',
#   'label_cs': 'Jiří Myszak',
#   'label_en': 'Jiří Myszak',
#   'popis_cs': 'český akademický sochař',
#   'w_narozeni': 1925,
#   'w_umrti': 1990,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q523489'],
#   'w_misto_umrti': ['Q8385'],
#   'profese': ['Q1281618'],
#   'skoly': ['Q414009'],
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100384723',
#   'label_cs': 'Jaroslav Škarohlíd',
#   'label_en': 'Jaroslav Škarohlíd',
#   'popis_cs': 'malíř, grafik, ilustrátor',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni': 1925,
#   'w_umrti': 2012,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100384811',
#   'label_cs': 'Jan Čech',
#   'label_en': 'Jan Cech',
#   'popis_cs': 'letecký mechanik, autor prací o letectví a kosmonautice',
#   'w_narozeni': 1950,
#   'w_gender': 'Q6581097',
#   'profese': ['Q1430683', 'Q15980158'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100385831',
#   'label_cs': 'Vojtěch V. Sláma',
#   'label_en': 'Vojtech V. Sláma',
#   'popis_cs': 'český fotograf, člen skupiny Česká Paralaxa',
#   'w_narozeni': 1974,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q33231'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003886',
#   'label_cs': 'Fričovce',
#   'label_en': 'Fričovce',
#   'popis_cs': 'obec na Slovensku v okrese Prešov',
#   'popis_en': 'municipality of Slovakia',
#   'web': 'https://www.obecfricovce.sk',
#   'jazykove_verze': ['zh-min-nan',
#    'war',
#    'eo',
#    'fr',
#    'eu',
#    'ca',
#    'tt',
#    'sr',
#    'uk',
#    'ro',
#    'pl',
#    'sk',
#    'nl',
#    'rue',
#    'es',
#    'en',
#    'sh',
#    'cs',
#    'hu',
#    'ce',
#    'de',
#    'pt',
#    'it',
#    'ms']},
#  {'024_a': 'Q100390701',
#   'label_cs': 'Petr Řehoř',
#   'label_en': 'Petr Řehoř',
#   'popis_cs': 'výtvarník, malíř',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q158275'],
#   'profese': ['Q1028181',
#    'Q1925963',
#    'Q780596',
#    'Q37226',
#    'Q33231',
#    'Q333634',
#    'Q1229025'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394177',
#   'label_cs': 'Sasan Saatchi',
#   'label_en': 'Sassan S Saatchi',
#   'popis_en': 'researcher',
#   'profese': ['Q1622272'],
#   'skoly': ['Q432637'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394621',
#   'label_cs': 'Witold Jurasz',
#   'label_en': 'Witold Jurasz',
#   'popis_en': 'Polish journalist, diplomat',
#   'w_narozeni': 1975,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q36'],
#   'profese': ['Q1930187', 'Q193391'],
#   'skoly': ['Q144488'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100400535',
#   'label_cs': 'Yasemin Besen-Cassino',
#   'label_en': 'Yasemin Besen–Cassino',
#   'popis_en': 'American sociologist',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q406'],
#   'profese': ['Q2306091'],
#   'skoly': ['Q896267', 'Q969850'],
#   'manzelstvo': ['Q100752805'],
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100406682',
#   'label_cs': 'Karolína Kamberská',
#   'label_en': 'Karolína Kamberská',
#   'popis_cs': 'česká písničkářka a autorka kuchařek',
#   'w_narozeni': 1972,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q146307'],
#   'profese': ['Q488205', 'Q1495660'],
#   'skoly': ['Q31519'],
#   'manzelstvo': ['Q20057968'],
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100407335',
#   'label_cs': 'Rudolf Brož',
#   'label_en': 'Rudolf Brož',
#   'w_narozeni': 1880,
#   'w_umrti': 1939,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q12034750'],
#   'w_misto_umrti': ['Q1085', 'Q662985'],
#   'profese': ['Q333634', 'Q2516866', 'Q82955'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100411',
#   'label_cs': 'Ulrich Willerding',
#   'label_en': 'Ulrich Willerding',
#   'popis_en': 'American botanist (1932-2021)',
#   'w_narozeni': 1932,
#   'w_umrti': 2021,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q518204'],
#   'w_misto_umrti': ['Q3033'],
#   'profese': ['Q3621491',
#    'Q4773904',
#    'Q2374149',
#    'Q1622272',
#    'Q32518759',
#    'Q30059961'],
#   'jazykove_verze': ['de', 'en', 'arz']},
#  {'024_a': 'Q100415128',
#   'label_cs': 'Peter K. Lommatzsch',
#   'label_en': 'Peter Karl Lommatzsch',
#   'w_narozeni': 1934,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q57782'],
#   'w_misto_umrti': ['Q2079'],
#   'profese': ['Q12013238', 'Q39631', 'Q1622272'],
#   'manzelstvo': ['Q106169513'],
#   'potomstvo': ['Q106166221'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004158',
#   'label_cs': 'Frédéric Eichhoff',
#   'label_en': 'Frédéric Eichhoff',
#   'popis_en': 'writer',
#   'w_narozeni': 1799,
#   'w_umrti': 1875,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q42810'],
#   'w_misto_umrti': ['Q245546', 'Q90'],
#   'profese': ['Q2251335', 'Q36180', 'Q13418253', 'Q14467526', 'Q1622272'],
#   'udalosti': ['Q201676'],
#   'jazykove_verze': ['fr', 'ru', 'sv', 'hu', 'en', 'da']},
#  {'024_a': 'Q100416047',
#   'label_cs': 'Marie Hovorková',
#   'label_en': 'Marie Hovorková',
#   'popis_cs': 'autorka knihy o alternativní léčbě, tzv. léčení vírou',
#   'w_narozeni': 1952,
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100416283',
#   'label_cs': 'Thecla z Coudenhove',
#   'label_en': 'Thecla Coudenhove-Honrichs',
#   'popis_cs': 'česká šlechtična, manželka Františka Coudenhove-Honrichse (1865-1912), posledního majitele zámku Kunštát.',
#   'popis_en': 'writer',
#   'w_narozeni': 1865,
#   'w_umrti': 1933,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1756960'],
#   'w_misto_umrti': ['Q1381784'],
#   'profese': ['Q36180'],
#   'manzelstvo': ['Q94933498'],
#   'potomstvo': ['Q94919745'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417561',
#   'label_cs': 'Václav Vaculovič',
#   'label_en': 'Václav Vaculovič',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni': 1957,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'w_misto_narozeni': ['Q81137'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417809',
#   'label_cs': 'Jan Mácha',
#   'label_en': 'Jan Mácha',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni': 1926,
#   'w_umrti': 1984,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1008696'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1028181', 'Q1925963', 'Q644687', 'Q6051619'],
#   'skoly': ['Q414009'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421384',
#   'label_cs': 'Anna Boog',
#   'label_en': 'Anna Boog',
#   'popis_en': "Austrian children's writer",
#   'w_narozeni': 1894,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q40'],
#   'w_misto_narozeni': ['Q39193'],
#   'profese': ['Q4853732'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421794',
#   'label_cs': 'Miloslav Urban',
#   'label_en': 'Miloslav Urban',
#   'popis_cs': 'autor cestopisných vzpomínek',
#   'w_narozeni': 1932,
#   'w_umrti': 2010,
#   'w_gender': 'Q6581097',
#   'profese': ['Q3579035'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004275',
#   'label_cs': 'Fridrich Jakub Fuker',
#   'label_en': 'Frigyes Jakab Fuker',
#   'popis_cs': 'německý lékař',
#   'popis_en': 'German physician',
#   'w_narozeni': 1748,
#   'w_umrti': 1805,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q25409'],
#   'w_misto_umrti': ['Q304304'],
#   'profese': ['Q39631', 'Q897317', 'Q21771805', 'Q36180', 'Q901402', 'Q18805'],
#   'skoly': ['Q368998'],
#   'jazykove_verze': ['hu', 'sk']},
#  {'024_a': 'Q100429039',
#   'label_cs': 'Martina Mináriková',
#   'label_en': 'Martina Mináriková',
#   'popis_cs': 'slovenská šperkařka',
#   'popis_en': 'jewelry designer',
#   'w_narozeni': 1968,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q1780'],
#   'profese': ['Q336221', 'Q1281618', 'Q2519376'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100430173',
#   'label_cs': 'Otakar Mlejnek',
#   'label_en': 'Otakar Mlejnek',
#   'popis_cs': 'chirurg, lodní lékař, autor vzpomínek',
#   'w_narozeni': 1930,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q63855'],
#   'profese': ['Q774306', 'Q325855', 'Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100433950',
#   'label_cs': 'Kurt Ziemke',
#   'label_en': 'Kurt Ziemke',
#   'popis_en': 'German diplomat',
#   'w_narozeni': 1888,
#   'w_umrti': 1965,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q41252'],
#   'profese': ['Q1136290'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100443143',
#   'label_cs': 'Dana Ďuricová',
#   'label_en': 'Dana Duricova',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q1650915'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100450',
#   'label_cs': 'Stephan Fridolin',
#   'label_en': 'Stephan Fridolin',
#   'popis_en': 'German Franciscan',
#   'w_narozeni': 1430,
#   'w_umrti': 1498,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q82741'],
#   'profese': ['Q36180', 'Q432386'],
#   'jazykove_verze': ['de', 'fr']},
#  {'024_a': 'Q1004517',
#   'label_cs': 'Samuel Fabry',
#   'label_en': 'Sámuel Fábri',
#   'w_narozeni': 1769,
#   'w_umrti': 1826,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'profese': ['Q96236305',
#    'Q28319434',
#    'Q21591523',
#    'Q37226',
#    'Q333634',
#    'Q49757'],
#   'jazykove_verze': ['hu']},
#  {'024_a': 'Q1004532',
#   'label_cs': 'Zoltán Fábry',
#   'label_en': 'Zoltán Fábry',
#   'w_narozeni': 1897,
#   'w_umrti': 1970,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28', 'Q33946'],
#   'w_misto_narozeni': ['Q392547'],
#   'w_misto_umrti': ['Q392547'],
#   'profese': ['Q201788'],
#   'jazykove_verze': ['eo', 'sk', 'hu']},
#  {'024_a': 'Q100454750',
#   'label_cs': 'Koji Miura',
#   'label_en': 'Kōji Miura',
#   'popis_en': 'Japanese mangaka',
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q17'],
#   'profese': ['Q191633', 'Q11892507', 'Q17098559'],
#   'twitter': 'Amzk0303',
#   'jazykove_verze': ['en', 'ja', 'zh']},
#  {'024_a': 'Q100457406',
#   'label_cs': 'Chelsey A. Juarez',
#   'label_en': 'Chelsey Juarez',
#   'popis_en': 'researcher',
#   'profese': ['Q1650915'],
#   'skoly': ['Q108122', 'Q1047293', 'Q168756'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100457421',
#   'label_cs': 'Amanda C. Cote',
#   'label_en': 'Amanda C Cote',
#   'popis_en': 'researcher',
#   'profese': ['Q1930187', 'Q1622272'],
#   'jazykove_verze': []}]

# %%
import sys
sys.getsizeof(medailony)
# Out:
# 1140568

# %%
text = "text"
sys.getsizeof(text)
# Out:
# 45

# %%
df = pd.read_json(os.path.join("data_raw","autority_wikidataids.json")).reset_index(drop=False)

# %%
df
# Out:
#                  index       024_a
# 0           jk01010005    Q1063371
# 1           jk01010022   Q12028104
# 2           jk01010023     Q640512
# 3           jk01010026   Q12055885
# 4           jk01010030     Q634048
# ...                ...         ...
# 131824   zmp2016925673   Q13582412
# 131825   zmp2016925675  Q112503439
# 131826  zmp20191037071   Q26208443
# 131827  zmp20191054500     Q825192
# 131828  zmp20211116840  Q107140306
#
# [131829 rows x 2 columns]

# %%
df = df.merge(pd.DataFrame(medailony), on='024_a').set_index('index')

# %%
df.sample(20)
# Out:
#                      024_a                         label_cs  \
# index
# mzk2004246511    Q21599502                   Jana Nováčková
# xx0197996        Q61161314                 Lucie Whitehouse
# ola20231201079     Q330775  Abraham b. Semuel ha Ibn Hasday
# xx0318292       Q126477453                    Jana Šilarová
# ola2012729333   Q120589570            Monica Pierazzi Mitri
# xx0312117         Q3395388                  Polly Matzinger
# jk01131209      Q112350029                Rudolf Štechmiler
# mzk2008434047    Q95169241                  Eva Brucknerová
# xx0309881        Q48841387               Stanisław Migórski
# mzk2003202108   Q120574932                    Gabriel Vereš
# mzk2014831690   Q120592449                      Jan Kyselka
# jk01140127       Q95074914                  František Trnka
# jk01120941       Q25451651                       Petr Starý
# jo20000082894      Q379290                 Jacint Verdaguer
# jo20221146174    Q23956657                Bertrand Soubelet
# jk01140219       Q95151525                  Antonín Trousil
# xx0205334          Q249978                        Eva Klein
# xx0306938         Q2159349                    Roberta Frank
# js20020610002   Q112369440                 Milada Bartošová
# jn20000605223      Q105994                  Patrick Süskind
#
#                                              label_en  \
# index
# mzk2004246511                          Jana Nováčková
# xx0197996                            Lucie Whitehouse
# ola20231201079  Abraham ben Samuel ibn Hasdai ha-Levi
# xx0318292                               Jana Šilarová
# ola2012729333                   Monica Pierazzi Mitri
# xx0312117                             Polly Matzinger
# jk01131209                                        NaN
# mzk2008434047                         Eva Brucknerová
# xx0309881                          Stanisław Migórski
# mzk2003202108                                     NaN
# mzk2014831690                             Jan Kyselka
# jk01140127                            František Trnka
# jk01120941                                 Petr Starý
# jo20000082894                        Jacint Verdaguer
# jo20221146174                       Bertrand Soubelet
# jk01140219                            Antonín Trousil
# xx0205334                                   Eva Klein
# xx0306938                               Roberta Frank
# js20020610002                                     NaN
# jn20000605223                         Patrick Süskind
#
#                                                          popis_en  w_narozeni  \
# index
# mzk2004246511                                  Czech psychologist      1949.0
# xx0197996                                             (born 1975)      1975.0
# ola20231201079  late 13th century translator from Arabic to He...      1180.0
# xx0318292                                                     NaN      1970.0
# ola2012729333                                                 NaN         NaN
# xx0312117                                   American immunologist      1947.0
# jk01131209                                                    NaN      1917.0
# mzk2008434047                                                 NaN      1981.0
# xx0309881                                    Polish mathematician      2000.0
# mzk2003202108                                                 NaN         NaN
# mzk2014831690                                                 NaN         NaN
# jk01140127                                                    NaN      1882.0
# jk01120941                                     Czech entomologist      1933.0
# jo20000082894                 Catalan writer and poet (1845-1902)      1845.0
# jo20221146174                   General of the French Gendarmerie      1959.0
# jk01140219                                                    NaN      1881.0
# xx0205334                             Hungarian-Swedish biologist      1925.0
# xx0306938                                    American philologist      1941.0
# js20020610002                                                 NaN      1926.0
# jn20000605223                      German writer and screenwriter      1949.0
#
#                 w_umrti  w_gender   obcanstvi  w_misto_narozeni w_misto_umrti  \
# index
# mzk2004246511       NaN  Q6581072         NaN           [Q1780]           NaN
# xx0197996           NaN  Q6581072         NaN               NaN           NaN
# ola20231201079   1240.0  Q6581097   [Q204920]           [Q1492]       [Q1492]
# xx0318292           NaN  Q6581072         NaN               NaN           NaN
# ola2012729333       NaN  Q6581072         NaN               NaN           NaN
# xx0312117           NaN  Q6581072         NaN         [Q208866]           NaN
# jk01131209       1958.0  Q6581097         NaN               NaN       [Q1085]
# mzk2008434047       NaN  Q6581072         NaN               NaN           NaN
# xx0309881           NaN  Q6581097       [Q36]               NaN           NaN
# mzk2003202108       NaN  Q6581097         NaN               NaN           NaN
# mzk2014831690       NaN       NaN         NaN               NaN           NaN
# jk01140127       1944.0  Q6581097         NaN  [Q72567, Q72661]           NaN
# jk01120941          NaN  Q6581097    [Q33946]           [Q1085]           NaN
# jo20000082894    1902.0  Q6581097       [Q29]          [Q13782]    [Q2297480]
# jo20221146174       NaN  Q6581097      [Q142]         [Q232135]           NaN
# jk01140219       1962.0  Q6581097    [Q33946]           [Q1085]       [Q1085]
# xx0205334           NaN  Q6581072  [Q28, Q34]           [Q1781]           NaN
# xx0306938           NaN  Q6581072       [Q30]             [Q60]           NaN
# js20020610002       NaN  Q6581072         NaN               NaN           NaN
# jn20000605223       NaN  Q6581097      [Q183]       [Q19834493]           NaN
#
#                 ... manzelstvo partnerstvo potomstvo sourozenectvo facebook  \
# index           ...
# mzk2004246511   ...        NaN         NaN       NaN           NaN      NaN
# xx0197996       ...        NaN         NaN       NaN           NaN      NaN
# ola20231201079  ...        NaN         NaN       NaN           NaN      NaN
# xx0318292       ...        NaN         NaN       NaN           NaN      NaN
# ola2012729333   ...        NaN         NaN       NaN           NaN      NaN
# xx0312117       ...        NaN         NaN       NaN           NaN      NaN
# jk01131209      ...        NaN         NaN       NaN           NaN      NaN
# mzk2008434047   ...        NaN         NaN       NaN           NaN      NaN
# xx0309881       ...        NaN         NaN       NaN           NaN      NaN
# mzk2003202108   ...        NaN         NaN       NaN           NaN      NaN
# mzk2014831690   ...        NaN         NaN       NaN           NaN      NaN
# jk01140127      ...        NaN         NaN       NaN           NaN      NaN
# jk01120941      ...        NaN         NaN       NaN           NaN      NaN
# jo20000082894   ...        NaN         NaN       NaN           NaN      NaN
# jo20221146174   ...        NaN         NaN       NaN           NaN      NaN
# jk01140219      ...        NaN         NaN       NaN           NaN      NaN
# xx0205334       ...  [Q513281]         NaN       NaN           NaN      NaN
# xx0306938       ...        NaN         NaN       NaN           NaN      NaN
# js20020610002   ...        NaN         NaN       NaN           NaN      NaN
# jn20000605223   ...        NaN         NaN       NaN           NaN      NaN
#
#                twitter instagram                         web udalosti role
# index
# mzk2004246511      NaN       NaN                         NaN      NaN  NaN
# xx0197996          NaN       NaN                         NaN      NaN  NaN
# ola20231201079     NaN       NaN                         NaN      NaN  NaN
# xx0318292          NaN       NaN                         NaN      NaN  NaN
# ola2012729333      NaN       NaN                         NaN      NaN  NaN
# xx0312117          NaN       NaN                         NaN      NaN  NaN
# jk01131209         NaN       NaN                         NaN      NaN  NaN
# mzk2008434047      NaN       NaN                         NaN      NaN  NaN
# xx0309881          NaN       NaN                         NaN      NaN  NaN
# mzk2003202108      NaN       NaN                         NaN      NaN  NaN
# mzk2014831690      NaN       NaN                         NaN      NaN  NaN
# jk01140127         NaN       NaN                         NaN      NaN  NaN
# jk01120941         NaN       NaN                         NaN      NaN  NaN
# jo20000082894      NaN       NaN  https://www.verdaguer.cat/      NaN  NaN
# jo20221146174      NaN       NaN                         NaN      NaN  NaN
# jk01140219         NaN       NaN                         NaN      NaN  NaN
# xx0205334          NaN       NaN                         NaN      NaN  NaN
# xx0306938          NaN       NaN                         NaN      NaN  NaN
# js20020610002      NaN       NaN                         NaN      NaN  NaN
# jn20000605223      NaN       NaN                         NaN      NaN  NaN
#
# [20 rows x 28 columns]

# %%
df[df.index == 'Q93240837']
# Out:
# Empty DataFrame
# Columns: [024_a, label_cs, label_en, popis_en, w_narozeni, w_umrti, w_gender, obcanstvi, w_misto_narozeni, w_misto_umrti, profese, jazykove_verze, popis_cs, druh_umrti, pricina_umrti, vezeni, strany, skoly, manzelstvo, partnerstvo, potomstvo, sourozenectvo, facebook, twitter, instagram, web, udalosti, role]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df['024_a'] == 'Q571203']
# Out:
#               024_a       label_cs       label_en  \
# index
# jk01100136  Q571203  Karel Poláček  Karel Poláček
#
#                                                      popis_en  w_narozeni  \
# index
# jk01100136  Czech humorist, publicist, bookwriter, scriptw...      1892.0
#
#             w_umrti  w_gender          obcanstvi w_misto_narozeni  \
# index
# jk01100136   1945.0  Q6581097  [Q533534, Q33946]       [Q1000091]
#
#                       w_misto_umrti  ...    manzelstvo  partnerstvo potomstvo  \
# index                                ...
# jk01100136  [Q105084, Q7342, Q7341]  ...  [Q105573892]  [Q95459535]       NaN
#
#                        sourozenectvo facebook twitter instagram  web  \
# index
# jk01100136  [Q105573905, Q105574064]      NaN     NaN       NaN  NaN
#
#                                      udalosti        role
# index
# jk01100136  [Q5883980, Q104055388, Q76358503]  [Q5883980]
#
# [1 rows x 28 columns]

# %%
df[df['024_a'] == 'Q16861736']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                w_narozeni  w_umrti  w_gender obcanstvi w_misto_narozeni  \
# index
# jx20100301005      1984.0      NaN  Q6581097    [Q213]         [Q14960]
#
#               w_misto_umrti  ... manzelstvo partnerstvo potomstvo  \
# index                        ...
# jx20100301005           NaN  ...        NaN         NaN       NaN
#
#               sourozenectvo  facebook   twitter               instagram  \
# index
# jx20100301005           NaN  kasparek  kasparek  jakovzdynaprostopresny
#
#                                          web udalosti role
# index
# jx20100301005  http://www.michalkasparek.cz/      NaN  NaN
#
# [1 rows x 28 columns]

# %%
df[df.index == 'jx20100301005']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                w_narozeni  w_umrti  w_gender obcanstvi w_misto_narozeni  \
# index
# jx20100301005      1984.0      NaN  Q6581097    [Q213]         [Q14960]
#
#               w_misto_umrti  ... manzelstvo partnerstvo potomstvo  \
# index                        ...
# jx20100301005           NaN  ...        NaN         NaN       NaN
#
#               sourozenectvo  facebook   twitter               instagram  \
# index
# jx20100301005           NaN  kasparek  kasparek  jakovzdynaprostopresny
#
#                                          web udalosti role
# index
# jx20100301005  http://www.michalkasparek.cz/      NaN  NaN
#
# [1 rows x 28 columns]

# %%
df['w_gender'] = df['w_gender'].replace(gendery)

# %%
df.sample(10)
# Out:
#                      024_a                   label_cs  \
# index
# jn20000603101      Q315020            Henri Charrière
# jk01030612       Q95070048            Miloslav Fábera
# jk01091324      Q112348564            Vladimír Osvald
# xx0119349       Q112429320           Susan M. Kleiner
# ntk20231208338  Q108759695      Georg Christoph Löwel
# xx0309538       Q102350689  Amélie Pokorná Zedníčková
# ntk20241224179  Q111770892      Karl Henrike Sivesind
# jcu2011621702     Q1306795           Peter B. Steiner
# mzk2006355780   Q112400758        Vladimíra Khelerová
# osd20231184182    Q7183244           Philip W. Bonsal
#
#                                  label_en  \
# index
# jn20000603101             Henri Charrière
# jk01030612                Miloslav Fábera
# jk01091324                Vladimír Osvald
# xx0119349                Susan M. Kleiner
# ntk20231208338      Georg Christoph Löwel
# xx0309538       Amélie Pokorná Zedníčková
# ntk20241224179       Karl Henrik Sivesind
# jcu2011621702            Peter B. Steiner
# mzk2006355780         Vladimíra Khelerová
# osd20231184182              Philip Bonsal
#
#                                              popis_en  w_narozeni  w_umrti  \
# index
# jn20000603101   French convict and author (1906-1973)      1906.0   1973.0
# jk01030612                                        NaN      1912.0   1988.0
# jk01091324                                        NaN      1925.0      NaN
# xx0119349                                         NaN      1957.0      NaN
# ntk20231208338                                    NaN      1768.0   1835.0
# xx0309538                               Czech actress      2004.0      NaN
# ntk20241224179                                b. 1962      1962.0      NaN
# jcu2011621702                    German art historian      1942.0      NaN
# mzk2006355780                                     NaN      1961.0      NaN
# osd20231184182                      American diplomat      1903.0   1995.0
#
#                w_gender obcanstvi w_misto_narozeni w_misto_umrti  ...  \
# index                                                             ...
# jn20000603101         m    [Q142]        [Q166525]       [Q2807]  ...
# jk01030612            m  [Q33946]        [Q260233]       [Q1085]  ...
# jk01091324            m       NaN              NaN           NaN  ...
# xx0119349             f       NaN              NaN           NaN  ...
# ntk20231208338        m    [Q183]              NaN     [Q155984]  ...
# xx0309538             f    [Q213]          [Q1085]           NaN  ...
# ntk20241224179        m       NaN              NaN           NaN  ...
# jcu2011621702         m    [Q183]          [Q1726]           NaN  ...
# mzk2006355780       NaN       NaN              NaN           NaN  ...
# osd20231184182        m     [Q30]            [Q60]         [Q61]  ...
#
#                manzelstvo partnerstvo potomstvo sourozenectvo facebook  \
# index
# jn20000603101         NaN         NaN       NaN           NaN      NaN
# jk01030612            NaN         NaN       NaN           NaN      NaN
# jk01091324            NaN         NaN       NaN           NaN      NaN
# xx0119349             NaN         NaN       NaN           NaN      NaN
# ntk20231208338        NaN         NaN       NaN           NaN      NaN
# xx0309538             NaN         NaN       NaN           NaN      NaN
# ntk20241224179        NaN         NaN       NaN           NaN      NaN
# jcu2011621702         NaN         NaN       NaN           NaN      NaN
# mzk2006355780         NaN         NaN       NaN           NaN      NaN
# osd20231184182        NaN         NaN       NaN           NaN      NaN
#
#                twitter instagram  web udalosti role
# index
# jn20000603101      NaN       NaN  NaN      NaN  NaN
# jk01030612         NaN       NaN  NaN      NaN  NaN
# jk01091324         NaN       NaN  NaN      NaN  NaN
# xx0119349          NaN       NaN  NaN      NaN  NaN
# ntk20231208338     NaN       NaN  NaN      NaN  NaN
# xx0309538          NaN       NaN  NaN      NaN  NaN
# ntk20241224179     NaN       NaN  NaN      NaN  NaN
# jcu2011621702      NaN       NaN  NaN      NaN  NaN
# mzk2006355780      NaN       NaN  NaN      NaN  NaN
# osd20231184182     NaN       NaN  NaN      NaN  NaN
#
# [10 rows x 28 columns]

# %%
df.to_json(os.path.join('data_raw','wikidata_raw.json'))

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131714 entries, jk01010005 to zmp20211116840
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   024_a             131714 non-null  object
#  1   label_cs          130825 non-null  object
#  2   label_en          122117 non-null  object
#  3   popis_en          72022 non-null   object
#  4   w_narozeni        114494 non-null  float64
#  5   w_umrti           56114 non-null   float64
#  6   w_gender          124138 non-null  object
#  7   obcanstvi         66677 non-null   object
#  8   w_misto_narozeni  85966 non-null   object
#  9   w_misto_umrti     42774 non-null   object
#  10  profese           112734 non-null  object
#  11  jazykove_verze    131371 non-null  object
#  12  popis_cs          91938 non-null   object
#  13  druh_umrti        3291 non-null    object
#  14  pricina_umrti     3967 non-null    object
#  15  vezeni            1004 non-null    object
#  16  strany            5624 non-null    object
#  17  skoly             37724 non-null   object
#  18  manzelstvo        7686 non-null    object
#  19  partnerstvo       748 non-null     object
#  20  potomstvo         6269 non-null    object
#  21  sourozenectvo     4543 non-null    object
#  22  facebook          2788 non-null    object
#  23  twitter           3511 non-null    object
#  24  instagram         1463 non-null    object
#  25  web               8997 non-null    object
#  26  udalosti          1189 non-null    object
#  27  role              1488 non-null    object
# dtypes: float64(2), object(26)
# memory usage: 196.0 MB

# %%
df.columns
# Out:
# Index(['024_a', 'label_cs', 'label_en', 'popis_en', 'w_narozeni', 'w_umrti',
#        'w_gender', 'obcanstvi', 'w_misto_narozeni', 'w_misto_umrti', 'profese',
#        'jazykove_verze', 'popis_cs', 'druh_umrti', 'pricina_umrti', 'vezeni',
#        'strany', 'skoly', 'manzelstvo', 'partnerstvo', 'potomstvo',
#        'sourozenectvo', 'facebook', 'twitter', 'instagram', 'web', 'udalosti',
#        'role'],
#       dtype='object')

# %%
for sloupec in df.columns.to_list():
    print(f"{sloupec}: {int(len(df[df[sloupec].notnull()])/len(df)*100)} %")
# Out:
# 024_a: 100 %
# label_cs: 99 %
# label_en: 92 %
# popis_en: 54 %
# w_narozeni: 86 %
# w_umrti: 42 %
# w_gender: 94 %
# obcanstvi: 50 %
# w_misto_narozeni: 65 %
# w_misto_umrti: 32 %
# profese: 85 %
# jazykove_verze: 99 %
# popis_cs: 69 %
# druh_umrti: 2 %
# pricina_umrti: 3 %
# vezeni: 0 %
# strany: 4 %
# skoly: 28 %
# manzelstvo: 5 %
# partnerstvo: 0 %
# potomstvo: 4 %
# sourozenectvo: 3 %
# facebook: 2 %
# twitter: 2 %
# instagram: 1 %
# web: 6 %
# udalosti: 0 %
# role: 1 %

# %%
import numpy as np

# %%
df[~(df['w_gender'].isin(['m','f']) | (df['w_gender'].isnull()))].sort_values(by='w_narozeni').head(10)
# Out:
#                     024_a              label_cs                 label_en  \
# index
# xx0265864         Q381854       Casimir Pulaski          Casimir Pulaski
# mzk20241212732    Q186486                Hačikó                  Hachikō
# xx0318306        Q5488684          Esdras Parra             Esdras Parra
# ola20241229011  Q16238689                 Antis                    Antis
# xx0022901         Q682037  Deirdre N. McCloskey        Deirdre McCloskey
# xx0284093          Q81649            Jeff Jones  Jeffrey Catherine Jones
# jcu2013782543     Q453592        Raewyn Connell           Raewyn Connell
# jcu2011623111     Q535129      Joan Roughgarden         Joan Roughgarden
# xx0011950         Q298221          Kathy Reichs             Kathy Reichs
# xx0301122       Q24234798             Alex Gino                Alex Gino
#
#                                                          popis_en  w_narozeni  \
# index
# xx0265864       Polish nobleman, general in the American Revol...      1745.0
# mzk20241212732                                              Akita      1923.0
# xx0318306                                       Venezuelan writer      1939.0
# ola20241229011                            German Shepherd war dog      1939.0
# xx0022901                           American economist & academic      1942.0
# xx0284093                                      artist (1944-2011)      1944.0
# jcu2013782543                      Australian sociologist (1944-)      1944.0
# jcu2011623111                                  American ecologist      1946.0
# xx0011950             American writer and forensic anthropologist      1948.0
# xx0301122                         American children's book writer      1950.0
#
#                 w_umrti     w_gender       obcanstvi w_misto_narozeni  \
# index
# xx0265864        1779.0           im  [Q172107, Q30]           [Q270]
# mzk20241212732   1935.0       Q44148             NaN        [Q329996]
# xx0318306        2004.0           tf          [Q717]       [Q2475168]
# ola20241229011   1953.0       Q44148             NaN         [Q21211]
# xx0022901           NaN           tf           [Q30]        [Q485172]
# xx0284093        2011.0           tf           [Q30]         [Q23556]
# jcu2013782543       NaN           tf          [Q408]          [Q3130]
# jcu2011623111       NaN           tf           [Q30]        [Q138391]
# xx0011950           NaN            ?           [Q30]          [Q1297]
# xx0301122           NaN  genderqueer           [Q30]            [Q60]
#
#                       w_misto_umrti  ... manzelstvo partnerstvo    potomstvo  \
# index                                ...
# xx0265864         [Q83813, Q774537]  ...        NaN         NaN          NaN
# mzk20241212732  [Q428811, Q7473516]  ...        NaN         NaN          NaN
# xx0318306                   [Q1533]  ...        NaN         NaN          NaN
# ola20241229011                  NaN  ...        NaN         NaN          NaN
# xx0022901                       NaN  ...        NaN         NaN          NaN
# xx0284093                  [Q23556]  ...  [Q469794]         NaN          NaN
# jcu2013782543                   NaN  ...        NaN         NaN          NaN
# jcu2011623111                   NaN  ...        NaN         NaN          NaN
# xx0011950                       NaN  ...        NaN         NaN  [Q20901596]
# xx0301122                       NaN  ...        NaN         NaN          NaN
#
#                sourozenectvo          facebook      twitter    instagram  \
# index
# xx0265864                NaN               NaN          NaN          NaN
# mzk20241212732           NaN               NaN          NaN          NaN
# xx0318306                NaN               NaN          NaN          NaN
# ola20241229011           NaN               NaN          NaN          NaN
# xx0022901                NaN               NaN          NaN          NaN
# xx0284093                NaN               NaN          NaN          NaN
# jcu2013782543            NaN               NaN          NaN          NaN
# jcu2011623111            NaN               NaN          NaN          NaN
# xx0011950                NaN  kathyreichsbooks  KathyReichs  kathyreichs
# xx0301122                NaN    authoralexgino       lxgino          NaN
#
#                                                            web    udalosti  \
# index
# xx0265864                                                  NaN         NaN
# mzk20241212732                                             NaN         NaN
# xx0318306                                                  NaN         NaN
# ola20241229011                                             NaN         NaN
# xx0022901                        https://deirdremccloskey.com/  [Q7458534]
# xx0284093                                                  NaN         NaN
# jcu2013782543                                              NaN         NaN
# jcu2011623111   https://profiles.stanford.edu/joan-roughgarden  [Q7458534]
# xx0011950                           http://www.kathyreichs.com         NaN
# xx0301122                             http://www.alexgino.com/         NaN
#
#                role
# index
# xx0265864       NaN
# mzk20241212732  NaN
# xx0318306       NaN
# ola20241229011  NaN
# xx0022901       NaN
# xx0284093       NaN
# jcu2013782543   NaN
# jcu2011623111   NaN
# xx0011950       NaN
# xx0301122       NaN
#
# [10 rows x 28 columns]

# %%
df[df['instagram'].notnull()]
# Out:
#                     024_a            label_cs            label_en  \
# index
# jk01032549        Q333187          Karel Gott          Karel Gott
# jk01090889      Q12021821   Irena Obermannová   Irena Obermannová
# ja20020044781     Q131725           Joan Baez           Joan Baez
# jn19981002583   Q12037625        Miloš Čermák        Miloš Čermák
# jn20000401597   Q10774019           Aleš Lamr           Aleš Lamr
# ...                   ...                 ...                 ...
# xx0277604      Q104006647       Tracy Andreen       Tracy Andreen
# xx0277921      Q114388697         Radim Pařík                 NaN
# xx0278251      Q115775348    Lucie Macháčková    Lucie Macháčková
# xx0300030      Q110885299  Scarlett St. Clair  Scarlett St. Clair
# xx0310238      Q124626217        Mike Maihack        Mike Maihack
#
#                                                       popis_en  w_narozeni  \
# index
# jk01032549                              Czech singer and actor      1939.0
# jk01090889                                    Czech bookwriter      1962.0
# ja20020044781  American contemporary folk musician (born 1941)      1941.0
# jn19981002583                                  Czech publicist      1968.0
# jn20000401597                         Czech artist (1943–2024)      1943.0
# ...                                                        ...         ...
# xx0277604                                         screenwriter      1967.0
# xx0277921                                        Czech manager      1979.0
# xx0278251                                                  NaN      1986.0
# xx0300030                                      Muscogee writer         NaN
# xx0310238                                                  NaN      1979.0
#
#                w_umrti w_gender       obcanstvi w_misto_narozeni  \
# index
# jk01032549      2019.0        m  [Q33946, Q213]         [Q43453]
# jk01090889         NaN        f          [Q213]          [Q1085]
# ja20020044781      NaN        f           [Q30]         [Q18432]
# jn19981002583      NaN        m          [Q213]          [Q1085]
# jn20000401597   2024.0        m        [Q33946]         [Q81137]
# ...                ...      ...             ...              ...
# xx0277604          NaN        f             NaN              NaN
# xx0277921          NaN        m          [Q213]         [Q14960]
# xx0278251          NaN        f          [Q213]       [Q2641539]
# xx0300030          NaN        f           [Q30]              NaN
# xx0310238          NaN        m             NaN              NaN
#
#                   w_misto_umrti  ...    manzelstvo partnerstvo  \
# index                            ...
# jk01032549     [Q1085, Q942842]  ...   [Q12022044]         NaN
# jk01090889                  NaN  ...           NaN         NaN
# ja20020044781               NaN  ...    [Q1174678]      [Q392]
# jn19981002583               NaN  ...   [Q12051406]         NaN
# jn20000401597           [Q1085]  ...  [Q120965893]         NaN
# ...                         ...  ...           ...         ...
# xx0277604                   NaN  ...           NaN         NaN
# xx0277921                   NaN  ...           NaN         NaN
# xx0278251                   NaN  ...           NaN         NaN
# xx0300030                   NaN  ...           NaN         NaN
# xx0310238                   NaN  ...           NaN         NaN
#
#                                                   potomstvo  \
# index
# jk01032549     [Q69636036, Q69636338, Q69559369, Q69636817]
# jk01090889                           [Q11132273, Q12050051]
# ja20020044781                                   [Q93483594]
# jn19981002583                                  [Q110798840]
# jn20000401597                                   [Q98544705]
# ...                                                     ...
# xx0277604                                               NaN
# xx0277921                                               NaN
# xx0278251                                               NaN
# xx0300030                                               NaN
# xx0310238                                               NaN
#
#                       sourozenectvo               facebook      twitter  \
# index
# jk01032549                      NaN              gottkarel          NaN
# jk01090889                      NaN      irena.obermannova          NaN
# ja20020044781  [Q449554, Q93483627]       officialjoanbaez    joancbaez
# jn19981002583                   NaN           milos.cermak       cermak
# jn20000401597                   NaN                    NaN          NaN
# ...                             ...                    ...          ...
# xx0277604              [Q104014162]                    NaN          NaN
# xx0277921                       NaN            radim.parik          NaN
# xx0278251                       NaN           komickalucie          NaN
# xx0300030                       NaN  authorscarlettstclair          NaN
# xx0310238                       NaN                    NaN  mikemaihack
#
#                            instagram                               web  \
# index
# jk01032549         officialkarelgott          http://www.karelgott.com
# jk01090889       irena_ober_official   https://www.irenaobermannova.cz
# ja20020044781              joancbaez           http://www.joanbaez.com
# jn19981002583            miloscermak      https://www.miloscermak.com/
# jn20000401597               aleslamr                               NaN
# ...                              ...                               ...
# xx0277604              tracy_andreen                               NaN
# xx0277921                 radimparik   https://www.fascinating.academy
# xx0278251                 lucielotka   https://www.luciemachackova.cz/
# xx0300030      authorscarlettstclair  https://www.scarlettstclair.com/
# xx0310238                mikemaihack    https://operationspacecat.com/
#
#               udalosti role
# index
# jk01032549         NaN  NaN
# jk01090889         NaN  NaN
# ja20020044781      NaN  NaN
# jn19981002583      NaN  NaN
# jn20000401597      NaN  NaN
# ...                ...  ...
# xx0277604          NaN  NaN
# xx0277921          NaN  NaN
# xx0278251          NaN  NaN
# xx0300030          NaN  NaN
# xx0310238          NaN  NaN
#
# [1463 rows x 28 columns]

# %%
vsechny_hodnoty = []
for sloupec in df.columns.to_list():
    sl = df.explode(sloupec)[sloupec].drop_duplicates().to_list()
    for s in sl:
        if str(s)[0] == 'Q':
            vsechny_hodnoty.append(s)
vsechny_hodnoty = list(set(vsechny_hodnoty))

# %%
len(vsechny_hodnoty)
# Out:
# 192176

# %%
vsechny_hodnoty[0:100]
# Out:
# ['Q124567274',
#  'Q160533',
#  'Q113044516',
#  'Q11878431',
#  'Q1875450',
#  'Q112462079',
#  'Q12043571',
#  'Q15431332',
#  'Q67461071',
#  'Q112556241',
#  'Q55677786',
#  'Q120584859',
#  'Q93221542',
#  'Q1797162',
#  'Q95143754',
#  'Q3509699',
#  'Q3851427',
#  'Q1232342',
#  'Q92921206',
#  'Q518455',
#  'Q112348963',
#  'Q120580140',
#  'Q95373719',
#  'Q1174512',
#  'Q316806',
#  'Q11767710',
#  'Q5242848',
#  'Q95183200',
#  'Q119798',
#  'Q5709847',
#  'Q117326005',
#  'Q515423',
#  'Q59610518',
#  'Q95397614',
#  'Q6726319',
#  'Q22244440',
#  'Q15987316',
#  'Q1682322',
#  'Q38048584',
#  'Q1647993',
#  'Q112364251',
#  'Q314195',
#  'Q4959739',
#  'Q116961584',
#  'Q95163574',
#  'Q28869851',
#  'Q11933808',
#  'Q2661974',
#  'Q112402951',
#  'Q95151687',
#  'Q112523689',
#  'Q95455547',
#  'Q95396006',
#  'Q24052413',
#  'Q245479',
#  'Q95115803',
#  'Q55674135',
#  'Q62066545',
#  'Q112466658',
#  'Q782682',
#  'Q95156007',
#  'Q112366201',
#  'Q753096',
#  'Q381375',
#  'Q112362018',
#  'Q59532634',
#  'Q120572170',
#  'Q1013858',
#  'Q728489',
#  'Q1170269',
#  'Q6369293',
#  'Q112350052',
#  'Q4177081',
#  'Q1091476',
#  'Q95178796',
#  'Q112345842',
#  'Q110619942',
#  'Q3509984',
#  'Q43033',
#  'Q61743208',
#  'Q66371087',
#  'Q1729151',
#  'Q995649',
#  'Q62937069',
#  'Q6319456',
#  'Q112348931',
#  'Q109488118',
#  'Q47500015',
#  'Q89598042',
#  'Q12034205',
#  'Q116947645',
#  'Q272272',
#  'Q112402711',
#  'Q306673',
#  'Q95214639',
#  'Q8420324',
#  'Q21997905',
#  'Q15391941',
#  'Q95217076',
#  'Q126325606']

# %%
with open(os.path.join("data_raw","wikidata_seznam_properties.json"), "w+", encoding="utf-8") as wdata_properties:
    wdata_properties.write(json.dumps(vsechny_hodnoty))
