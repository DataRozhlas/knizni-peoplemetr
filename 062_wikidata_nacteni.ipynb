# %%
import os
import re
import json
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
odkud = 'downloads/wikidata/autority'

# %%
def najdi_letopocet(x):
    try:
        return int(re.search(r"\d{4}",x).group())
    except:
        return None

# %%
len([f for f in os.listdir("downloads/wikidata/autority")])
# Out:
# 137104

# %%
medailony = []
pocitadlo = 0

for f in [f for f in os.listdir("downloads/wikidata/autority")]:

    pocitadlo += 1
    if pocitadlo % 1000 == 0:
        print(f"{pocitadlo:006}: {f}")
    
    medailon = {}
    with open(os.path.join('downloads/wikidata/autority', f), 'r', encoding='utf-8') as file:
        
        wd = json.loads(file.read())
        q = f[:-5]
        medailon['024_a'] = q

        try:
            medailon['label_cs'] = wd['entities'][q]['labels']['cs']['value']
        except:
            pass
        try:
            medailon['label_en'] = wd['entities'][q]['labels']['en']['value']
        except:
            pass
        try:
            medailon['popis_cs'] = wd['entities'][q]['descriptions']['cs']['value']
        except:
            pass
        try:
            medailon['popis_en'] = wd['entities'][q]['descriptions']['en']['value']
        except:
            pass

        try:
            medailon['w_narozeni_presne'] = wd['entities'][q]['claims']['P569'][0]['mainsnak']['datavalue']['value']['time']
        except:
            pass
        try:
            medailon['w_umrti_presne'] = wd['entities'][q]['claims']['P570'][0]['mainsnak']['datavalue']['value']['time']
        except:
            pass
        
        try:
            medailon['w_narozeni'] = najdi_letopocet(medailon['w_narozeni_presne'])
        except:
            pass
        try:
            medailon['w_umrti'] = najdi_letopocet(medailon['w_umrti_presne'])
        except:
            pass
        
        try:
            medailon['w_gender'] = wd['entities'][q]['claims']['P21'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['obcanstvi'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P27']]
        except:
            pass
        try:
            medailon['w_misto_narozeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P19']]
        except:
            pass
        try:
            medailon['w_misto_umrti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P20']]
        except:
            pass
        try:
            medailon['druh_umrti'] = wd['entities'][q]['claims']['P1196'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['pricina_umrti'] = wd['entities'][q]['claims']['P509'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass      
        try:
            medailon['vezeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2632']]
        except:
            pass
        try:
            medailon['profese'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P106']]
        except:
            pass
        try:
            medailon['strany'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P102']]
        except:
            pass
        try:
            medailon['skoly'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P69']]
        except:
            pass
        try:
            medailon['udalosti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P793']]
        except:
            pass
        try:
            medailon['role'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2868']]
        except:
            pass
        try:
            medailon['ceny'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P166']]
        except:
            pass
        try:
            medailon['manzelstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P26']]
        except:
            pass
        try:
            medailon['partnerstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P451']]
        except:
            pass
        try:
            medailon['sourozenectvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P3373']]
        except:
            pass
        try:
            medailon['potomstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P40']]
        except:
            pass       

        try:
            medailon['facebook'] = wd['entities'][q]['claims']['P2013'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['twitter'] = wd['entities'][q]['claims']['P2002'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['instagram'] = wd['entities'][q]['claims']['P2003'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['web'] = wd['entities'][q]['claims']['P856'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['wiki_cs'] = wd['entities'][q]['sitelinks']['cswiki']['url']
        except:
            pass
        try:
            medailon['wiki_en'] = wd['entities'][q]['sitelinks']['enwiki']['url']
        except:
            pass
        
        try:
            medailon['jazykove_verze'] = [z.split(".wikipedia")[0].split("//")[1] for z in set(list([x for x in [hodnoty['url'] for popisky, hodnoty in wd['entities'][q]['sitelinks'].items()]])) if "wikipedia" in z]
        except:
            pass
    
    medailony.append(medailon)
# Out:
# 001000: Q102438335.json
# 002000: Q105022652.json
# 003000: Q106714830.json
# 004000: Q10773869.json
# 005000: Q108754933.json
# 006000: Q110212662.json
# 007000: Q111745668.json
# 008000: Q112347067.json
# 009000: Q112351272.json
# 010000: Q112366064.json
# 011000: Q112373360.json
# 012000: Q112382370.json
# 013000: Q112389308.json
# 014000: Q112397855.json
# 015000: Q112408877.json
# 016000: Q112419684.json
# 017000: Q112437875.json
# 018000: Q112465824.json
# 019000: Q112497392.json
# 020000: Q112532915.json
# 021000: Q112565944.json
# 022000: Q113808310.json
# 023000: Q11630.json
# 024000: Q1176727.json
# 025000: Q11904708.json
# 026000: Q12017486.json
# 027000: Q12024103.json
# 028000: Q12028478.json
# 029000: Q12039219.json
# 030000: Q120572359.json
# 031000: Q120574799.json
# 032000: Q120577426.json
# 033000: Q120582701.json
# 034000: Q120586408.json
# 035000: Q120590704.json
# 036000: Q120595626.json
# 037000: Q120603362.json
# 038000: Q120612818.json
# 039000: Q1213171.json
# 040000: Q123154253.json
# 041000: Q124615096.json
# 042000: Q125726218.json
# 043000: Q12762214.json
# 044000: Q130340596.json
# 045000: Q1336951.json
# 046000: Q1383799.json
# 047000: Q14748195.json
# 048000: Q15304459.json
# 049000: Q15637656.json
# 050000: Q15972212.json
# 051000: Q1629433.json
# 052000: Q1680036.json
# 053000: Q17138339.json
# 054000: Q17617360.json
# 055000: Q18435902.json
# 056000: Q189599.json
# 057000: Q1965442.json
# 058000: Q20164738.json
# 059000: Q20851135.json
# 060000: Q21396177.json
# 061000: Q217985.json
# 062000: Q23037986.json
# 063000: Q24003248.json
# 064000: Q25229870.json
# 065000: Q26255697.json
# 066000: Q27523627.json
# 067000: Q28498158.json
# 068000: Q29433288.json
# 069000: Q304825.json
# 070000: Q315707.json
# 071000: Q328055.json
# 072000: Q339611.json
# 073000: Q3563122.json
# 074000: Q3738380.json
# 075000: Q3892825.json
# 076000: Q4141829.json
# 077000: Q42469477.json
# 078000: Q435584.json
# 079000: Q4485021.json
# 080000: Q465121.json
# 081000: Q4757771.json
# 082000: Q4942396.json
# 083000: Q51095988.json
# 084000: Q5238137.json
# 085000: Q541374.json
# 086000: Q55236295.json
# 087000: Q55838530.json
# 088000: Q56390673.json
# 089000: Q57320726.json
# 090000: Q58325259.json
# 091000: Q59528779.json
# 092000: Q60036357.json
# 093000: Q60975130.json
# 094000: Q6181766.json
# 095000: Q63029484.json
# 096000: Q6463134.json
# 097000: Q66246076.json
# 098000: Q6830314.json
# 099000: Q70964360.json
# 100000: Q72936564.json
# 101000: Q75185027.json
# 102000: Q7803497.json
# 103000: Q8049716.json
# 104000: Q84751.json
# 105000: Q87401516.json
# 106000: Q89529326.json
# 107000: Q91772134.json
# 108000: Q93239650.json
# 109000: Q94451751.json
# 110000: Q94934324.json
# 111000: Q95075233.json
# 112000: Q95088176.json
# 113000: Q95102905.json
# 114000: Q95120166.json
# 115000: Q95137902.json
# 116000: Q95148942.json
# 117000: Q95152029.json
# 118000: Q95157308.json
# 119000: Q95166149.json
# 120000: Q95170287.json
# 121000: Q95175552.json
# 122000: Q95178317.json
# 123000: Q95202168.json
# 124000: Q95214932.json
# 125000: Q95234599.json
# 126000: Q95361635.json
# 127000: Q95367579.json
# 128000: Q95379169.json
# 129000: Q95391629.json
# 130000: Q95398220.json
# 131000: Q95438832.json
# 132000: Q95453972.json
# 133000: Q95463653.json
# 134000: Q95477053.json
# 135000: Q95557091.json
# 136000: Q973185.json
# 137000: Q99625389.json

# %%
medailony[5:100]
# Out:
# [{'024_a': 'Q1000542',
#   'label_cs': 'Christina Kauschke',
#   'label_en': 'Christina Kauschke',
#   'popis_en': 'German linguist',
#   'w_narozeni_presne': '+1964-01-01T00:00:00Z',
#   'w_narozeni': 1964,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q1295'],
#   'profese': ['Q14467526', 'Q1622272', 'Q11762416'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1000592',
#   'label_cs': 'Tyson Fury',
#   'label_en': 'Tyson Fury',
#   'popis_cs': 'britský boxer',
#   'popis_en': 'British boxer (born 1988)',
#   'w_narozeni_presne': '+1988-08-12T00:00:00Z',
#   'w_narozeni': 1988,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q145'],
#   'w_misto_narozeni': ['Q18125'],
#   'profese': ['Q11338576', 'Q2066131'],
#   'ceny': ['Q55042186', 'Q4114674'],
#   'manzelstvo': ['Q124608281'],
#   'sourozenectvo': ['Q64585041'],
#   'facebook': 'TysonFuryGypsyKing',
#   'twitter': 'Tyson_Fury',
#   'instagram': 'gypsyking101',
#   'web': 'https://tyson-fury.com/',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Tyson_Fury',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Tyson_Fury',
#   'jazykove_verze': ['cy',
#    'simple',
#    'sv',
#    'ro',
#    'bn',
#    'th',
#    'pt',
#    'hy',
#    'uz',
#    'fr',
#    'cs',
#    'kcg',
#    'hr',
#    'ar',
#    'no',
#    'uk',
#    'fa',
#    'zh',
#    'nl',
#    'de',
#    'vi',
#    'pl',
#    'sl',
#    'ja',
#    'en',
#    'he',
#    'es',
#    'et',
#    'fi',
#    'bg',
#    'it',
#    'da',
#    'ga',
#    'ko',
#    'tr',
#    'arz',
#    'ru']},
#  {'024_a': 'Q100061677',
#   'label_cs': 'Karlachovy sady',
#   'label_en': 'Karlachovy sady',
#   'popis_cs': 'veřejný park v areálu vyšehradské pevnosti v Praze',
#   'popis_en': 'park in Prague-Vyšehrad',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Karlachovy_sady',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q1000649',
#   'label_cs': 'András Ferkai',
#   'label_en': 'András Ferkai',
#   'popis_en': 'Hungarian architect',
#   'w_narozeni_presne': '+1953-06-07T00:00:00Z',
#   'w_narozeni': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q42973'],
#   'ceny': ['Q1466124', 'Q1220788'],
#   'jazykove_verze': ['arz', 'eo', 'hu']},
#  {'024_a': 'Q1000729',
#   'label_cs': 'Ferreira de Castro',
#   'label_en': 'José Maria Ferreira de Castro',
#   'popis_en': 'Portuguese writer and journalist',
#   'w_narozeni_presne': '+1898-05-24T00:00:00Z',
#   'w_umrti_presne': '+1974-06-29T00:00:00Z',
#   'w_narozeni': 1898,
#   'w_umrti': 1974,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q45'],
#   'w_misto_narozeni': ['Q18468715'],
#   'w_misto_umrti': ['Q36433'],
#   'pricina_umrti': 'Q3010352',
#   'profese': ['Q1930187', 'Q36180'],
#   'manzelstvo': ['Q123853170'],
#   'partnerstvo': ['Q122652621'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ferreira_de_Castro',
#   'jazykove_verze': ['uk',
#    'pt',
#    'it',
#    'es',
#    'hu',
#    'ro',
#    'ru',
#    'fr',
#    'en',
#    'fi',
#    'ar',
#    'arz',
#    'de',
#    'gl',
#    'eu']},
#  {'024_a': 'Q100090749',
#   'label_cs': 'Robin R. Means Coleman',
#   'label_en': 'Robin R. Means Coleman',
#   'popis_cs': 'Americká odbornice na komunikační studia, vysokoškolská učitelka, zaměřuje se na mediální studia, kulturní diverzitu a kulturní politiku černých, inkluzi, management vzdělávání; filmová producentka dokumentárního filmu "Horror Noire: A History of Bla',
#   'popis_en': 'American author, scholar and educator',
#   'w_narozeni_presne': '+1969-01-01T00:00:00Z',
#   'w_narozeni': 1969,
#   'w_gender': 'Q6581072',
#   'profese': ['Q28389', 'Q36180', 'Q3282637', 'Q462390', 'Q1622272'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Robin_R._Means_Coleman',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q1000985',
#   'label_cs': 'Milan Pacanda',
#   'label_en': 'Milan Pacanda',
#   'popis_cs': 'český fotbalista',
#   'popis_en': 'Czech football forward',
#   'w_narozeni_presne': '+1978-02-28T00:00:00Z',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q213'],
#   'w_misto_narozeni': ['Q146342'],
#   'profese': ['Q937857'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Milan_Pacanda',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Milan_Pacanda',
#   'jazykove_verze': ['it', 'arz', 'en', 'de', 'cs']},
#  {'024_a': 'Q1001',
#   'label_cs': 'Mahátma Gándhí',
#   'label_en': 'Mahatma Gandhi',
#   'popis_cs': 'indický politik',
#   'popis_en': 'Indian independence activist (1869–1948)',
#   'w_narozeni_presne': '+1869-10-02T00:00:00Z',
#   'w_umrti_presne': '+1948-01-30T00:00:00Z',
#   'w_narozeni': 1869,
#   'w_umrti': 1948,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q129286', 'Q1775277', 'Q668'],
#   'w_misto_narozeni': ['Q6419912'],
#   'w_misto_umrti': ['Q1381516'],
#   'druh_umrti': 'Q149086',
#   'pricina_umrti': 'Q2140674',
#   'vezeni': ['Q142534', 'Q2344976', 'Q142534', 'Q142534'],
#   'profese': ['Q82955',
#    'Q808967',
#    'Q15958642',
#    'Q1930187',
#    'Q4964182',
#    'Q18814623',
#    'Q11774202',
#    'Q17351648',
#    'Q1021386',
#    'Q11774156',
#    'Q22336956',
#    'Q16323111',
#    'Q3242115',
#    'Q36180',
#    'Q185351',
#    'Q30242234'],
#   'strany': ['Q10225'],
#   'skoly': ['Q4722851', 'Q1233784', 'Q193196', 'Q100148173'],
#   'ceny': ['Q207826', 'Q727815', 'Q2469664', 'Q6967959', 'Q2423226'],
#   'manzelstvo': ['Q264908'],
#   'sourozenectvo': ['Q100778818',
#    'Q100778893',
#    'Q100778902',
#    'Q100779061',
#    'Q100779088'],
#   'potomstvo': ['Q1390715', 'Q1280678', 'Q185403', 'Q732728'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Mah%C3%A1tma_G%C3%A1ndh%C3%AD',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Mahatma_Gandhi',
#   'jazykove_verze': ['azb',
#    'et',
#    'si',
#    'ht',
#    'en',
#    'cv',
#    'fi',
#    'bjn',
#    'it',
#    'sd',
#    'ang',
#    'frr',
#    'so',
#    'jam',
#    'zh-yue',
#    'kbd',
#    'tcy',
#    'az',
#    'pms',
#    'rue',
#    'bpy',
#    'la',
#    'dtp',
#    'gd',
#    'be',
#    'mg',
#    'sq',
#    'ml',
#    'kbp',
#    'fiu-vro',
#    'de',
#    'ary',
#    'arz',
#    'awa',
#    'bg',
#    'hr',
#    'yo',
#    'sv',
#    'mni',
#    'nn',
#    'os',
#    'pt',
#    'oc',
#    'pcd',
#    'ro',
#    'ka',
#    'ks',
#    'ms',
#    'tt',
#    'sc',
#    'mr',
#    'ss',
#    'ug',
#    'gan',
#    'zh-classical',
#    'cs',
#    'bs',
#    'frp',
#    'sr',
#    'lo',
#    'zh-min-nan',
#    'bxr',
#    'fy',
#    'el',
#    'ps',
#    'af',
#    'simple',
#    'avk',
#    'ta',
#    'pnb',
#    'ast',
#    'br',
#    'km',
#    'li',
#    'id',
#    'nl',
#    'scn',
#    'lb',
#    'ia',
#    'mnw',
#    'bat-smg',
#    'qu',
#    'tg',
#    'tpi',
#    'ts',
#    'diq',
#    'ne',
#    'ku',
#    'tl',
#    'gom',
#    'tly',
#    'als',
#    'hif',
#    'lfn',
#    'te',
#    'kaa',
#    'gu',
#    'ky',
#    'sco',
#    'th',
#    'no',
#    'yi',
#    'ur',
#    'xmf',
#    'bh',
#    'ay',
#    'fo',
#    'sw',
#    'ba',
#    'crh',
#    'an',
#    'su',
#    'tyv',
#    'vi',
#    'eo',
#    'min',
#    'ru',
#    'btm',
#    'ko',
#    'am',
#    'uk',
#    'my',
#    'cy',
#    'mt',
#    'ceb',
#    'gl',
#    'uz',
#    'nds',
#    'tr',
#    'sa',
#    'mai',
#    'hy',
#    'ckb',
#    'sk',
#    'ga',
#    'bn',
#    'as',
#    'lad',
#    'sat',
#    'ban',
#    'eu',
#    'ha',
#    'dsb',
#    'hu',
#    'mzn',
#    'fr',
#    'sah',
#    'vec',
#    'zh',
#    'or',
#    'dv',
#    'gn',
#    'kw',
#    'hi',
#    'anp',
#    'shi',
#    'kk',
#    'pa',
#    'xal',
#    'lt',
#    'kn',
#    'ar',
#    'mk',
#    'olo',
#    'ce',
#    'sl',
#    'ln',
#    'pap',
#    'jv',
#    'wuu',
#    'lv',
#    'es',
#    'kab',
#    'da',
#    'pl',
#    'fa',
#    'bcl',
#    'war',
#    'ady',
#    'sh',
#    'ilo',
#    'co',
#    'rmy',
#    'new',
#    'gcr',
#    'hyw',
#    'ja',
#    'mhr',
#    'io',
#    'is',
#    'vo',
#    'be-tarask',
#    'tk',
#    'mn',
#    'ca',
#    'he',
#    'vep',
#    'skr',
#    'dty',
#    'lez',
#    'lmo']},
#  {'024_a': 'Q1001072',
#   'label_cs': 'Salomon Sachs',
#   'label_en': 'Salomo Sachs',
#   'popis_en': 'Jewish Prussian Government Building Inspector, architect, civil servant, mathematician and writer (1772–1855)',
#   'w_narozeni_presne': '+1772-12-22T00:00:00Z',
#   'w_umrti_presne': '+1855-05-14T00:00:00Z',
#   'w_narozeni': 1772,
#   'w_umrti': 1855,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q27306'],
#   'w_misto_narozeni': ['Q64'],
#   'w_misto_umrti': ['Q64'],
#   'profese': ['Q42973',
#    'Q36180',
#    'Q170790',
#    'Q11063',
#    'Q901402',
#    'Q212238',
#    'Q37226'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Salomo_Sachs',
#   'jazykove_verze': ['ar', 'de', 'pl', 'en', 'nl', 'arz']},
#  {'024_a': 'Q1001077',
#   'label_cs': 'Sergej Vladimirovič Dikovskij',
#   'label_en': 'Sergey Dikovsky',
#   'popis_en': 'Soviet writer',
#   'w_narozeni_presne': '+1907-03-01T00:00:00Z',
#   'w_umrti_presne': '+1940-01-06T00:00:00Z',
#   'w_narozeni': 1907,
#   'w_umrti': 1940,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q34266', 'Q2305208', 'Q15180'],
#   'w_misto_narozeni': ['Q649'],
#   'w_misto_umrti': ['Q214054'],
#   'profese': ['Q36180', 'Q1930187', 'Q12144794'],
#   'ceny': ['Q960966'],
#   'jazykove_verze': ['ru', 'fr', 'fi', 'de']},
#  {'024_a': 'Q100114213',
#   'label_cs': 'Damian Duffy',
#   'label_en': 'Damian Duffy',
#   'popis_en': 'American comics artist',
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'profese': ['Q715301', 'Q109517242', 'Q17098559', 'Q1622272'],
#   'skoly': ['Q457281'],
#   'ceny': ['Q842614', 'Q110165665'],
#   'twitter': 'DamianD2Duffy',
#   'web': 'http://damianduffy.net',
#   'jazykove_verze': ['sv']},
#  {'024_a': 'Q100133408',
#   'label_cs': 'R. Z. Kobiela',
#   'w_narozeni_presne': '+1902-01-01T00:00:00Z',
#   'w_umrti_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q191793'],
#   'profese': ['Q193391', 'Q1930187', 'Q36180', 'Q23656820'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100138089',
#   'label_cs': 'John Jennings',
#   'label_en': 'John Jennings',
#   'popis_en': 'American illustrator (born 1970)',
#   'w_narozeni_presne': '+1970-00-00T00:00:00Z',
#   'w_narozeni': 1970,
#   'w_gender': 'Q6581097',
#   'profese': ['Q644687',
#    'Q109517242',
#    'Q17098559',
#    'Q3658608',
#    'Q5322166',
#    'Q19829999',
#    'Q1622272'],
#   'ceny': ['Q110165665'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100144439',
#   'label_cs': 'Ivan Medeši',
#   'label_en': 'Ivan Medeši',
#   'popis_cs': 'Rusínský básník a prozaik působící v Srbsku. Publikuje básně, povídky, fejetony i reportáže. Pracuje jako pomocný pedagog základní školy a gymnázia.',
#   'popis_en': 'poet and novelist',
#   'w_narozeni_presne': '+1982-01-12T00:00:00Z',
#   'w_narozeni': 1982,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q511216'],
#   'profese': ['Q36180',
#    'Q49757',
#    'Q12144794',
#    'Q1231865',
#    'Q82594',
#    'Q2070313'],
#   'ceny': ['Q9150528'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Ivan_Mede%C5%A1i',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100146632',
#   'label_cs': 'Salmá Samar Damlūjī',
#   'label_en': 'Salma Samar Damluji',
#   'popis_cs': 'Britsko-irácká architektka, vysokoškolská pedagožka, specializace na islámskou architekturu.',
#   'popis_en': 'Iraqi British architect, professor and author',
#   'w_narozeni_presne': '+1954-01-01T00:00:00Z',
#   'w_narozeni': 1954,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q3820'],
#   'profese': ['Q36180', 'Q42973', 'Q1622272'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Salma_Samar_Damluji',
#   'jazykove_verze': ['ar', 'en']},
#  {'024_a': 'Q100151669',
#   'label_cs': 'Stanislav Klika',
#   'label_en': 'Stanislav Klika',
#   'popis_cs': 'pražský novinář, spisovatel a nakladatel (1885-1942)',
#   'popis_en': 'Czech journalist, writer and publisher (1885-1942)',
#   'w_narozeni_presne': '+1885-00-00T00:00:00Z',
#   'w_umrti_presne': '+1942-06-18T00:00:00Z',
#   'w_narozeni': 1885,
#   'w_umrti': 1942,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q378120', 'Q1085'],
#   'w_misto_umrti': ['Q942842'],
#   'profese': ['Q36180',
#    'Q2516866',
#    'Q356139',
#    'Q12144794',
#    'Q6051619',
#    'Q3391743'],
#   'manzelstvo': ['Q106286463'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001547',
#   'label_cs': 'Hambye',
#   'label_en': 'Hambye',
#   'popis_cs': 'obec v departementu Manche ve Francii',
#   'popis_en': 'commune in Manche, France',
#   'facebook': 'hambye',
#   'web': 'http://www.hambye.fr',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Hambye',
#   'jazykove_verze': ['vi',
#    'diq',
#    'ca',
#    'zh',
#    'hu',
#    'sr',
#    'pms',
#    'ceb',
#    'la',
#    'ms',
#    'en',
#    'sk',
#    'pt',
#    'nl',
#    'it',
#    'war',
#    'eo',
#    'bug',
#    'vec',
#    'lld',
#    'zh-min-nan',
#    'pl',
#    'eu',
#    'fi',
#    'es',
#    'fr',
#    'uk',
#    'fy',
#    'sv',
#    'oc',
#    'kk',
#    'el',
#    'tt',
#    'ro',
#    'sh',
#    'uz',
#    'ce',
#    'de']},
#  {'024_a': 'Q100154933',
#   'label_cs': 'Thomas R. Sinclair',
#   'label_en': 'Thomas R. Sinclair',
#   'popis_cs': 'americký rostlinný fyziolog, vysokoškolský pedagog, zaměřený na fyziologii a ekologii rostlin, změny klimatu, vodu a rostlinnou výrobu',
#   'popis_en': '1944-',
#   'w_narozeni_presne': '+1944-01-01T00:00:00Z',
#   'w_narozeni': 1944,
#   'w_gender': 'Q6581097',
#   'profese': ['Q60244908', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001591',
#   'label_cs': 'La Bernerie-en-Retz',
#   'label_en': 'La Bernerie-en-Retz',
#   'popis_cs': 'obec v departementu Loire-Atlantique ve Francii',
#   'popis_en': 'commune in Loire-Atlantique, France',
#   'web': 'http://www.mairie-labernerie.fr',
#   'wiki_en': 'https://en.wikipedia.org/wiki/La_Bernerie-en-Retz',
#   'jazykove_verze': ['hu',
#    'nl',
#    'ro',
#    'sk',
#    'vi',
#    'cy',
#    'eo',
#    'diq',
#    'zh',
#    'la',
#    'nrm',
#    'vec',
#    'ceb',
#    'ur',
#    'simple',
#    'bm',
#    'de',
#    'lld',
#    'sv',
#    'pl',
#    'ast',
#    'ms',
#    'eu',
#    'oc',
#    'br',
#    'pms',
#    'uk',
#    'zh-min-nan',
#    'it',
#    'en',
#    'war',
#    'sr',
#    'sh',
#    'fr',
#    'mg',
#    'pt',
#    'tt',
#    'ce',
#    'ca',
#    'ku',
#    'es',
#    'vo',
#    'sl']},
#  {'024_a': 'Q100163576',
#   'label_cs': 'Vasyl‘ Mychajlovyč Slobodjan',
#   'label_en': 'Vasyl Slobodian',
#   'popis_cs': 'ukrajinský historik zaměřený na sakrální architekturu, autor prací z oboru',
#   'popis_en': 'Ukrainian historian',
#   'w_narozeni_presne': '+1951-09-21T00:00:00Z',
#   'w_narozeni': 1951,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q212'],
#   'w_misto_narozeni': ['Q36036'],
#   'profese': ['Q201788', 'Q1595570', 'Q36180'],
#   'skoly': ['Q1817355'],
#   'ceny': ['Q12143927'],
#   'jazykove_verze': ['uk']},
#  {'024_a': 'Q1001716',
#   'label_cs': 'Leopold Fischer',
#   'label_en': 'Leopold Fischer',
#   'popis_cs': 'Jezuitský kněz a historik. Roku 1718 vstoupil do jezuitského řádu. Narozen 28. 3. 1703 ve Vídni, zemřel 11. 4. 1787 tamtéž.',
#   'w_narozeni_presne': '+1703-03-28T00:00:00Z',
#   'w_umrti_presne': '+1787-04-11T00:00:00Z',
#   'w_narozeni': 1703,
#   'w_umrti': 1787,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q153136'],
#   'w_misto_narozeni': ['Q1741'],
#   'w_misto_umrti': ['Q1741'],
#   'profese': ['Q250867', 'Q201788', 'Q432386', 'Q37226'],
#   'jazykove_verze': ['hu']},
#  {'024_a': 'Q100200',
#   'label_cs': 'Norbert Buske',
#   'label_en': 'Norbert Buske',
#   'popis_en': 'German politician and theologian',
#   'w_narozeni_presne': '+1936-01-02T00:00:00Z',
#   'w_umrti_presne': '+2023-10-20T00:00:00Z',
#   'w_narozeni': 1936,
#   'w_umrti': 2023,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183', 'Q16957'],
#   'w_misto_narozeni': ['Q50960'],
#   'profese': ['Q82955', 'Q1234713'],
#   'strany': ['Q49762'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Norbert_Buske',
#   'jazykove_verze': ['en', 'pl', 'de', 'arz']},
#  {'024_a': 'Q100207',
#   'label_cs': 'Marie Luise Droop',
#   'label_en': 'Marie Luise Droop',
#   'popis_en': 'German writer, director and producer (1890-1959)',
#   'w_narozeni_presne': '+1890-01-15T00:00:00Z',
#   'w_umrti_presne': '+1959-08-22T00:00:00Z',
#   'w_narozeni': 1890,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q393'],
#   'w_misto_umrti': ['Q505495'],
#   'profese': ['Q28389', 'Q3282637'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Marie_Luise_Droop',
#   'jazykove_verze': ['de', 'arz', 'en']},
#  {'024_a': 'Q100217',
#   'label_cs': 'Kareen Zebroff',
#   'label_en': 'Kareen Zebroff',
#   'popis_en': 'Canadian-based author, actor and television host specialising in yoga',
#   'w_narozeni_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q502441'],
#   'profese': ['Q947873'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Kareen_Zebroff',
#   'jazykove_verze': ['uz', 'de', 'arz', 'en']},
#  {'024_a': 'Q100233',
#   'label_cs': 'Udo Weilacher',
#   'label_en': 'Udo Weilacher',
#   'popis_en': 'German landscape architect, author and Professor for Landscape Architecture',
#   'w_narozeni_presne': '+1963-01-01T00:00:00Z',
#   'w_narozeni': 1963,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q3758'],
#   'profese': ['Q2815948', 'Q1622272'],
#   'skoly': ['Q157808'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Udo_Weilacher',
#   'jazykove_verze': ['en', 'de', 'arz']},
#  {'024_a': 'Q100243280'},
#  {'024_a': 'Q100267570',
#   'label_cs': 'Léon Carez',
#   'label_en': 'Léon Carez',
#   'w_narozeni_presne': '+1854-11-13T00:00:00Z',
#   'w_umrti_presne': '+1932-01-28T00:00:00Z',
#   'w_narozeni': 1854,
#   'w_umrti': 1932,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q2845753', 'Q90'],
#   'w_misto_umrti': ['Q1078086'],
#   'profese': ['Q520549', 'Q1734662', 'Q189010'],
#   'skoly': ['Q3064332'],
#   'ceny': ['Q10855271', 'Q56649459'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100267949',
#   'label_cs': 'Jacqueline Chénieux-Gendron',
#   'label_en': 'Jacqueline Chénieux-Gendron',
#   'popis_en': 'author',
#   'w_narozeni_presne': '+1939-11-19T00:00:00Z',
#   'w_umrti_presne': '+2022-09-01T00:00:00Z',
#   'w_narozeni': 1939,
#   'w_umrti': 2022,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q548924'],
#   'w_misto_umrti': ['Q169293'],
#   'profese': ['Q36180'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100269537',
#   'label_cs': 'Alice Travers',
#   'label_en': 'Alice Travers',
#   'popis_en': 'researcher',
#   'w_narozeni_presne': '+1979-05-02T00:00:00Z',
#   'w_narozeni': 1979,
#   'w_gender': 'Q6581072',
#   'profese': ['Q201788', 'Q1864603', 'Q1493121', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q1878600', 'Q999763', 'Q1394262', 'Q1430113', 'Q1394262'],
#   'ceny': ['Q3332320'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100272216',
#   'label_cs': 'Mìkalaj Mìkalajevìč Mjazha',
#   'label_en': 'Nikolaĭ Nikolaevich Mezga',
#   'popis_en': 'Belarusian historian',
#   'w_narozeni_presne': '+1965-05-31T00:00:00Z',
#   'w_narozeni': 1965,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q15180', 'Q184'],
#   'w_misto_narozeni': ['Q21659780'],
#   'profese': ['Q901', 'Q1622272', 'Q201788'],
#   'skoly': ['Q2630637'],
#   'jazykove_verze': ['be']},
#  {'024_a': 'Q100273554',
#   'label_cs': 'Johannes Kaspar',
#   'label_en': 'Johannes Kaspar',
#   'popis_cs': 'německý právník, advokát a vysokoškolský pedagog zaměřený na trestní právo hmotné a obchodní, nápravu a mediaci, právní a filozofické aspekty trestního práva, ústavní právo, teorii zločinu a na empirický výzkum sankcí',
#   'w_narozeni_presne': '+1976-01-01T00:00:00Z',
#   'w_narozeni': 1976,
#   'w_gender': 'Q6581097',
#   'profese': ['Q185351', 'Q1622272', 'Q40348'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100276619',
#   'label_cs': 'Christian Larsen',
#   'label_en': 'Christian Larsen',
#   'popis_cs': 'Narozen v r. 1956 v Basileji. Lékař.',
#   'w_narozeni_presne': '+1956-00-00T00:00:00Z',
#   'w_narozeni': 1956,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q39'],
#   'w_misto_narozeni': ['Q78'],
#   'profese': ['Q39631'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1002810',
#   'label_cs': 'Imre Forbáth',
#   'label_en': 'Imre Forbáth',
#   'w_narozeni_presne': '+1898-11-17T00:00:00Z',
#   'w_umrti_presne': '+1967-05-16T00:00:00Z',
#   'w_narozeni': 1898,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q190522', 'Q855069'],
#   'w_misto_umrti': ['Q146342'],
#   'profese': ['Q49757', 'Q1930187', 'Q36180'],
#   'jazykove_verze': ['hu', 'fr']},
#  {'024_a': 'Q100282',
#   'label_cs': 'Reinhard Woltman',
#   'label_en': 'Reinhard Woltman',
#   'popis_en': 'hydraulic engineer from Germany',
#   'w_narozeni_presne': '+1757-01-01T00:00:00Z',
#   'w_umrti_presne': '+1837-01-01T00:00:00Z',
#   'w_narozeni': 1757,
#   'w_umrti': 1837,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q164079'],
#   'w_misto_narozeni': ['Q177362'],
#   'w_misto_umrti': ['Q1055'],
#   'profese': ['Q13582652', 'Q901', 'Q36180', 'Q978044'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Reinhard_Woltman',
#   'jazykove_verze': ['sv', 'fr', 'en', 'arz', 'de']},
#  {'024_a': 'Q100296521',
#   'label_cs': 'Paul Joseph Schulte',
#   'label_en': 'Paul J. Schulte',
#   'popis_en': 'forest science researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1650915'],
#   'skoly': ['Q219563', 'Q230492'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100301646',
#   'label_cs': 'Amy Ansehl',
#   'label_en': 'Amy Ansehl',
#   'popis_cs': 'Americká vysokoškolská profesorka a zdravotní sestra.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'profese': ['Q1622272', 'Q186360'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302130',
#   'label_cs': 'Noel Armenakas',
#   'label_en': 'Noel A. Armenakas',
#   'popis_cs': 'americký lékař, urolog, chirurg a vysokoškolský učitel, zaměřený na urologické operace, rekonstrukční chirurgii a úrazy',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581097',
#   'profese': ['Q17345122', 'Q774306', 'Q1622272'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302588',
#   'label_cs': 'Deborah Campbell',
#   'label_en': 'Deborah E. Campbell',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581072',
#   'profese': ['Q28569455', 'Q1622272'],
#   'skoly': ['Q681025'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302980',
#   'label_cs': 'James E. Cottrell',
#   'label_en': 'James E. Cottrell',
#   'popis_cs': 'americký anesteziolog a vysokoškolský pedagog zaměřený zejména na neuroanestezii',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni_presne': '+1942-01-01T00:00:00Z',
#   'w_narozeni': 1942,
#   'w_gender': 'Q6581097',
#   'profese': ['Q28837', 'Q1622272'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100303696'},
#  {'024_a': 'Q100304023',
#   'label_cs': 'Dennis Alexander',
#   'label_en': 'Dennis Alexander',
#   'popis_cs': 'Americký hudební skladatel a klavírista, učitel hry na klavír. Autor publikací z oboru.',
#   'popis_en': 'American composer',
#   'w_narozeni_presne': '+1947-12-10T00:00:00Z',
#   'w_narozeni': 1947,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q647127'],
#   'profese': ['Q36834', 'Q713200', 'Q16145150', 'Q639669', 'Q486748'],
#   'facebook': 'Dennis-Alexander-Music-136237939764680',
#   'web': 'http://dennisalexander.com/',
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100308989',
#   'label_cs': 'Rodrick Wallace',
#   'label_en': 'Rodrick Wallace',
#   'popis_cs': 'Americký odborník v oblasti epidemiologie duševního zdraví, zabývá se dopady veřejné politiky, diskriminace a ekonomického úpadku na veřejné zdraví. Publikace v oboru.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q100'],
#   'profese': ['Q12765408', 'Q901'],
#   'skoly': ['Q9008737'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100312952',
#   'label_cs': 'Veronika Máková',
#   'label_en': 'Veronika Máková',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q593644', 'Q901'],
#   'skoly': ['Q1291752'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100314247',
#   'label_cs': 'John Collins',
#   'label_en': 'John W Collins',
#   'popis_cs': 'americký odborník na ošetřovatelství, ošetřovatelskou péči na konci života, multikulturní ošetřovatelství a vzdělávání zdravotních sester v této oblasti, vysokoškolský pedagog',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1622272'],
#   'skoly': ['Q5316093'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100318248',
#   'label_cs': 'M. Iqbal R. Khan',
#   'label_en': 'M Iqbal R Khan',
#   'popis_cs': 'botanik, vysokoškolský pedagog a výzkumný pracovník se zaměřením na fyziologii a genomiku rostlin, rostlinný genom a fytohormony',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q2374149', 'Q1622272', 'Q901'],
#   'skoly': ['Q196544'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100319795',
#   'label_cs': 'Mariusz Jerzy Golecki',
#   'label_en': 'Mariusz Golecki',
#   'popis_en': 'jurist, bureaucrat, university teacher',
#   'w_narozeni_presne': '+1974-04-23T00:00:00Z',
#   'w_narozeni': 1974,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q36'],
#   'w_misto_narozeni': ['Q270'],
#   'profese': ['Q185351', 'Q82955', 'Q16533', 'Q40348', 'Q1622272'],
#   'skoly': ['Q144488', 'Q35794'],
#   'manzelstvo': ['Q84098931'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100319915',
#   'label_cs': 'Eric Cervini',
#   'label_en': 'Eric Cervini',
#   'popis_cs': 'americký historik, zaměřený na problematiku LGBT',
#   'popis_en': 'American historian and writer',
#   'w_narozeni_presne': '+1992-01-01T00:00:00Z',
#   'w_narozeni': 1992,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q99'],
#   'profese': ['Q36180', 'Q201788'],
#   'skoly': ['Q14711406', 'Q13371'],
#   'ceny': ['Q121334212'],
#   'facebook': 'ericcervini',
#   'twitter': 'ericcervini',
#   'instagram': 'ericcervini',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Eric_Cervini',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100319998',
#   'label_cs': 'Ann Napolitano',
#   'label_en': 'Ann Napolitano',
#   'popis_cs': 'Americká spisovatelka, autorka románů a redaktorka. Dříve vysokoškolská lektorka tvůrčího psaní.',
#   'popis_en': 'American writer',
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180', 'Q1622272', 'Q876864'],
#   'twitter': 'napolitanoann',
#   'web': 'https://annnapolitano.com',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ann_Napolitano',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100324298',
#   'label_cs': 'Elwin Huaman',
#   'label_en': 'Elwin Huaman',
#   'popis_cs': 'peruánský počítačový vědec a vysokoškolský pedagog, působící v Rakousku, zaměřený na sémantický web, vědomostní grafy a data',
#   'popis_en': 'Peruvian computer scientist',
#   'w_narozeni_presne': '+1990-07-01T00:00:00Z',
#   'w_narozeni': 1990,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q419'],
#   'w_misto_narozeni': ['Q27194667'],
#   'profese': ['Q82594', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q6156603', 'Q308963', 'Q2303432', 'Q875788'],
#   'sourozenectvo': ['Q115660783', 'Q115660896', 'Q115660799'],
#   'twitter': 'ElwinHuaman',
#   'web': 'http://elwin.huamanquispe.com/',
#   'jazykove_verze': []},
#  {'024_a': 'Q100324868',
#   'label_cs': 'Jana Bartošová',
#   'label_en': 'Jana Bartošová',
#   'popis_cs': 'česká historička a archivářka',
#   'w_narozeni_presne': '+1971-01-01T00:00:00Z',
#   'w_narozeni': 1971,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'profese': ['Q201788', 'Q635734'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100325331',
#   'label_cs': 'Giona A. Nazzaro',
#   'label_en': 'Giona A. Nazzaro',
#   'popis_en': 'Italian film critic',
#   'w_narozeni_presne': '+1965-01-01T00:00:00Z',
#   'w_narozeni': 1965,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q38'],
#   'w_misto_narozeni': ['Q72'],
#   'profese': ['Q4220892', 'Q978044', 'Q36180'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Giona_A._Nazzaro',
#   'jazykove_verze': ['it', 'arz', 'en']},
#  {'024_a': 'Q100327408',
#   'label_cs': 'Bronisława Kokoszyńska',
#   'label_en': 'Bronisława Kokoszyńska',
#   'w_narozeni_presne': '+1897-01-01T00:00:00Z',
#   'w_umrti_presne': '+1959-01-01T00:00:00Z',
#   'w_narozeni': 1897,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q36'],
#   'w_misto_narozeni': ['Q1973720'],
#   'w_misto_umrti': ['Q31487'],
#   'profese': ['Q520549', 'Q1622272'],
#   'skoly': ['Q80207'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100333885',
#   'label_cs': 'Jaroslav Boukal',
#   'label_en': 'Jaroslav Boukal',
#   'popis_cs': '* 1902 Jeníkovice u Hradce Králové † ? ? JUDr.; vedoucí knihkupecký a nakladatelský pracovník.',
#   'w_narozeni_presne': '+1902-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q2024848'],
#   'profese': ['Q2516866', 'Q1607826', 'Q333634', 'Q185351'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100334014',
#   'label_cs': 'Bohuslav Kavka',
#   'label_en': 'Bohuslav Kavka',
#   'w_narozeni_presne': '+1869-00-00T00:00:00Z',
#   'w_umrti_presne': '+1914-05-04T00:00:00Z',
#   'w_narozeni': 1869,
#   'w_umrti': 1914,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q1085'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1607826', 'Q2516866'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348318',
#   'label_cs': 'Richard Lederer',
#   'label_en': 'Richard Lederer',
#   'popis_cs': 'Prof. dr. med., lékař, pediatr, vyučoval na vídeňské univerzitě, v roce 1938 emigroval do Bagdádu .',
#   'popis_en': 'pediatrician and university teacher',
#   'w_narozeni_presne': '+1885-06-11T00:00:00Z',
#   'w_umrti_presne': '+1941-00-00T00:00:00Z',
#   'w_narozeni': 1885,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q384544'],
#   'w_misto_umrti': ['Q1530'],
#   'profese': ['Q39631', 'Q1919436', 'Q1622272'],
#   'manzelstvo': ['Q113389335'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348525',
#   'label_cs': 'Roberto Rea',
#   'label_en': 'Roberto Rea',
#   'popis_en': 'Italian philologist',
#   'w_narozeni_presne': '+1973-01-25T00:00:00Z',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q38'],
#   'w_misto_narozeni': ['Q116440'],
#   'profese': ['Q1622272', 'Q13418253'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003501',
#   'label_cs': 'András Frank',
#   'label_en': 'András Frank',
#   'popis_en': 'Hungarian mathematician',
#   'w_narozeni_presne': '+1949-06-03T00:00:00Z',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q170790'],
#   'skoly': ['Q390287', 'Q369839'],
#   'ceny': ['Q1301832'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Andr%C3%A1s_Frank',
#   'jazykove_verze': ['eo', 'pt', 'hu', 'en', 'ar', 'de', 'arz']},
#  {'024_a': 'Q100353158',
#   'label_cs': 'Robert J. Callan',
#   'label_en': 'Robert J. Callan',
#   'popis_cs': 'veterinární lékař a vysokoškolský učitel, zaměřený na infekční nemoci hospodářských zvířat',
#   'popis_en': 'veterinary researcher at Colorado State University',
#   'w_gender': 'Q6581097',
#   'profese': ['Q202883', 'Q12119633', 'Q1622272'],
#   'skoly': ['Q838330'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100356218',
#   'label_cs': 'Caroline Campbell',
#   'label_en': 'Caroline Campbell',
#   'popis_en': 'British museum curator',
#   'w_narozeni_presne': '+1973-06-23T00:00:00Z',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q27'],
#   'w_misto_narozeni': ['Q10686'],
#   'profese': ['Q674426', 'Q1792450'],
#   'skoly': ['Q734266', 'Q734266', 'Q34433'],
#   'twitter': 'campbell_c_m',
#   'instagram': 'carolinecampbelllondon',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Caroline_Campbell_(museum_director)',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100356308',
#   'label_cs': 'Byron Augustin',
#   'label_en': 'Byron Augustin',
#   'popis_en': 'Professor of geography',
#   'w_narozeni_presne': '+1941-00-00T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q959512'],
#   'profese': ['Q1622272', 'Q901402'],
#   'skoly': ['Q5680304', 'Q52413', 'Q1783608'],
#   'ceny': ['Q100351031', 'Q100355835'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100358334',
#   'label_cs': 'Ludvík Ratolístka',
#   'label_en': 'Ludvík Ratolístka',
#   'w_narozeni_presne': '+1886-00-00T00:00:00Z',
#   'w_umrti_presne': '+1953-00-00T00:00:00Z',
#   'w_narozeni': 1886,
#   'w_umrti': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q43453'],
#   'w_misto_umrti': ['Q1085'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003615',
#   'label_cs': 'Franz Josef Beranek',
#   'label_en': 'Franz Josef Beranek',
#   'popis_en': 'German university teacher and writer (1902-1967)',
#   'w_narozeni_presne': '+1902-08-08T00:00:00Z',
#   'w_umrti_presne': '+1967-08-11T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q581478'],
#   'w_misto_umrti': ['Q3874'],
#   'profese': ['Q1622272', 'Q36180', 'Q13418253', 'Q14467526', 'Q12347522'],
#   'strany': ['Q7320'],
#   'skoly': ['Q102398072', 'Q102398197', 'Q102398119'],
#   'jazykove_verze': ['de', 'hu']},
#  {'024_a': 'Q100366',
#   'label_cs': 'Wilhelm Herchenbach',
#   'label_en': 'Wilhelm Herchenbach',
#   'popis_en': 'German writer; author',
#   'w_narozeni_presne': '+1818-11-13T00:00:00Z',
#   'w_umrti_presne': '+1889-12-14T00:00:00Z',
#   'w_narozeni': 1818,
#   'w_umrti': 1889,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q43287'],
#   'w_misto_narozeni': ['Q254171'],
#   'w_misto_umrti': ['Q1718'],
#   'profese': ['Q36180'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Wilhelm_Herchenbach',
#   'jazykove_verze': ['de', 'arz', 'en']},
#  {'024_a': 'Q100375832',
#   'label_cs': 'Ronald Voullié',
#   'label_en': 'Ronald Voullié',
#   'popis_en': 'German translator (1952-2020)',
#   'w_narozeni_presne': '+1952-05-18T00:00:00Z',
#   'w_umrti_presne': '+2020-09-29T00:00:00Z',
#   'w_narozeni': 1952,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q24879'],
#   'profese': ['Q333634', 'Q2599593'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100378',
#   'label_cs': 'Valentin Triller',
#   'label_en': 'Valentin Triller',
#   'popis_cs': 'německý skladatel, duchovní a spisovatel',
#   'popis_en': 'German composer, parson and writer (1493-1579)',
#   'w_narozeni_presne': '+1493-01-01T00:00:00Z',
#   'w_umrti_presne': '+1579-00-00T00:00:00Z',
#   'w_narozeni': 1493,
#   'w_umrti': 1579,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q746395'],
#   'w_misto_umrti': ['Q389412'],
#   'profese': ['Q36834', 'Q955464', 'Q36180', 'Q96236305'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Valentin_Triller',
#   'jazykove_verze': ['cs', 'pl', 'de', 'no']},
#  {'024_a': 'Q100383505',
#   'label_cs': 'Helga Hipp',
#   'label_en': 'Helga Hipp',
#   'popis_cs': 'Německá germanistka, nederlandistka a vysokoškolská pedagožka.',
#   'w_narozeni_presne': '+1934-09-24T00:00:00Z',
#   'w_umrti_presne': '+1996-04-07T00:00:00Z',
#   'w_narozeni': 1934,
#   'w_umrti': 1996,
#   'w_gender': 'Q6581072',
#   'profese': ['Q2599593', 'Q19513109', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100383608',
#   'label_cs': 'Arnulf Rüssel',
#   'label_en': 'Arnulf Rüssel',
#   'w_narozeni_presne': '+1902-05-25T00:00:00Z',
#   'w_umrti_presne': '+1978-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1978,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q247868'],
#   'profese': ['Q212980'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100383628',
#   'label_cs': 'Robert Schulz',
#   'label_en': 'Robert Wilhelm Schulz',
#   'w_narozeni_presne': '+1914-01-25T00:00:00Z',
#   'w_umrti_presne': '+2000-10-22T00:00:00Z',
#   'w_narozeni': 1914,
#   'w_umrti': 2000,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q16957'],
#   'w_misto_narozeni': ['Q518889'],
#   'profese': ['Q2306091'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100384019',
#   'label_cs': 'Jiří Myszak',
#   'label_en': 'Jiří Myszak',
#   'popis_cs': 'český akademický sochař',
#   'w_narozeni_presne': '+1925-03-02T00:00:00Z',
#   'w_umrti_presne': '+1990-04-07T00:00:00Z',
#   'w_narozeni': 1925,
#   'w_umrti': 1990,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q523489'],
#   'w_misto_umrti': ['Q8385'],
#   'profese': ['Q1281618'],
#   'skoly': ['Q414009'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Ji%C5%99%C3%AD_Myszak',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100384723',
#   'label_cs': 'Jaroslav Škarohlíd',
#   'label_en': 'Jaroslav Škarohlíd',
#   'popis_cs': 'malíř, grafik, ilustrátor',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni_presne': '+1925-01-24T00:00:00Z',
#   'w_umrti_presne': '+2012-10-15T00:00:00Z',
#   'w_narozeni': 1925,
#   'w_umrti': 2012,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100384811',
#   'label_cs': 'Jan Čech',
#   'label_en': 'Jan Cech',
#   'popis_cs': 'letecký mechanik, autor prací o letectví a kosmonautice',
#   'w_narozeni_presne': '+1950-00-00T00:00:00Z',
#   'w_narozeni': 1950,
#   'w_gender': 'Q6581097',
#   'profese': ['Q1430683', 'Q15980158'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100385831',
#   'label_cs': 'Vojtěch V. Sláma',
#   'label_en': 'Vojtech V. Sláma',
#   'popis_cs': 'český fotograf, člen skupiny Česká Paralaxa',
#   'w_narozeni_presne': '+1974-04-06T00:00:00Z',
#   'w_narozeni': 1974,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q33231'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003886',
#   'label_cs': 'Fričovce',
#   'label_en': 'Fričovce',
#   'popis_cs': 'obec na Slovensku v okrese Prešov',
#   'popis_en': 'municipality of Slovakia',
#   'web': 'https://www.obecfricovce.sk',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Fri%C4%8Dovce',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Fri%C4%8Dovce',
#   'jazykove_verze': ['ro',
#    'pl',
#    'ce',
#    'hu',
#    'uk',
#    'de',
#    'nl',
#    'eo',
#    'ca',
#    'es',
#    'rue',
#    'ms',
#    'sk',
#    'eu',
#    'war',
#    'it',
#    'sr',
#    'sh',
#    'fr',
#    'cs',
#    'zh-min-nan',
#    'pt',
#    'en',
#    'tt']},
#  {'024_a': 'Q100390636',
#   'label_cs': 'John L. Sullivan',
#   'label_en': 'John L. Sullivan',
#   'popis_en': 'academic, college faculty, Professor of Media and Communication',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1622272'],
#   'skoly': ['Q49117'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100390701',
#   'label_cs': 'Petr Řehoř',
#   'label_en': 'Petr Řehoř',
#   'popis_cs': 'výtvarník, malíř',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni_presne': '+1949-04-26T00:00:00Z',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q158275'],
#   'profese': ['Q1028181',
#    'Q1925963',
#    'Q780596',
#    'Q37226',
#    'Q33231',
#    'Q333634',
#    'Q1229025'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394177',
#   'label_cs': 'Sasan Saatchi',
#   'label_en': 'Sassan S Saatchi',
#   'popis_en': 'researcher',
#   'profese': ['Q1622272'],
#   'skoly': ['Q432637'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394621',
#   'label_cs': 'Witold Jurasz',
#   'label_en': 'Witold Jurasz',
#   'popis_en': 'Polish journalist, diplomat',
#   'w_narozeni_presne': '+1975-07-20T00:00:00Z',
#   'w_narozeni': 1975,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q36'],
#   'profese': ['Q1930187', 'Q193391'],
#   'skoly': ['Q144488'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100400535',
#   'label_cs': 'Yasemin Besen-Cassino',
#   'label_en': 'Yasemin Besen–Cassino',
#   'popis_en': 'American sociologist',
#   'w_narozeni_presne': '+1978-12-27T00:00:00Z',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q406'],
#   'profese': ['Q2306091'],
#   'skoly': ['Q896267', 'Q969850'],
#   'manzelstvo': ['Q100752805'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Yasemin_Besen%E2%80%93Cassino',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100406682',
#   'label_cs': 'Karolína Kamberská',
#   'label_en': 'Karolína Kamberská',
#   'popis_cs': 'česká písničkářka a autorka kuchařek',
#   'w_narozeni_presne': '+1972-00-00T00:00:00Z',
#   'w_narozeni': 1972,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q146307'],
#   'profese': ['Q488205', 'Q1495660'],
#   'skoly': ['Q31519'],
#   'manzelstvo': ['Q20057968'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Karol%C3%ADna_Kambersk%C3%A1',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100407335',
#   'label_cs': 'Rudolf Brož',
#   'label_en': 'Rudolf Brož',
#   'w_narozeni_presne': '+1880-00-00T00:00:00Z',
#   'w_umrti_presne': '+1939-12-31T00:00:00Z',
#   'w_narozeni': 1880,
#   'w_umrti': 1939,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q12034750'],
#   'w_misto_umrti': ['Q1085', 'Q662985'],
#   'profese': ['Q333634', 'Q2516866', 'Q82955'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100411',
#   'label_cs': 'Ulrich Willerding',
#   'label_en': 'Ulrich Willerding',
#   'popis_en': 'American botanist (1932-2021)',
#   'w_narozeni_presne': '+1932-01-01T00:00:00Z',
#   'w_umrti_presne': '+2021-12-20T00:00:00Z',
#   'w_narozeni': 1932,
#   'w_umrti': 2021,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q518204'],
#   'w_misto_umrti': ['Q3033'],
#   'profese': ['Q3621491',
#    'Q4773904',
#    'Q2374149',
#    'Q1622272',
#    'Q32518759',
#    'Q30059961'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ulrich_Willerding',
#   'jazykove_verze': ['en', 'de', 'arz']},
#  {'024_a': 'Q100415128',
#   'label_cs': 'Peter K. Lommatzsch',
#   'label_en': 'Peter Karl Lommatzsch',
#   'w_narozeni_presne': '+1934-12-20T00:00:00Z',
#   'w_umrti_presne': '+2020-11-23T00:00:00Z',
#   'w_narozeni': 1934,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q57782'],
#   'w_misto_umrti': ['Q2079'],
#   'profese': ['Q12013238', 'Q39631', 'Q1622272'],
#   'manzelstvo': ['Q106169513'],
#   'potomstvo': ['Q106166221'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004158',
#   'label_cs': 'Frédéric Eichhoff',
#   'label_en': 'Frédéric Eichhoff',
#   'popis_en': 'writer',
#   'w_narozeni_presne': '+1799-08-17T00:00:00Z',
#   'w_umrti_presne': '+1875-05-10T00:00:00Z',
#   'w_narozeni': 1799,
#   'w_umrti': 1875,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q42810'],
#   'w_misto_umrti': ['Q245546', 'Q90'],
#   'profese': ['Q2251335', 'Q36180', 'Q13418253', 'Q14467526', 'Q1622272'],
#   'udalosti': ['Q201676'],
#   'ceny': ['Q10855271'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ric_Eichhoff',
#   'jazykove_verze': ['ru', 'en', 'da', 'sv', 'fr', 'hu']},
#  {'024_a': 'Q100416047',
#   'label_cs': 'Marie Hovorková',
#   'label_en': 'Marie Hovorková',
#   'popis_cs': 'autorka knihy o alternativní léčbě, tzv. léčení vírou',
#   'w_narozeni_presne': '+1952-00-00T00:00:00Z',
#   'w_narozeni': 1952,
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100416283',
#   'label_cs': 'Thecla z Coudenhove',
#   'label_en': 'Thecla Coudenhove-Honrichs',
#   'popis_cs': 'česká šlechtična, manželka Františka Coudenhove-Honrichse (1865-1912), posledního majitele zámku Kunštát.',
#   'popis_en': 'writer',
#   'w_narozeni_presne': '+1865-05-31T00:00:00Z',
#   'w_umrti_presne': '+1933-03-27T00:00:00Z',
#   'w_narozeni': 1865,
#   'w_umrti': 1933,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1756960'],
#   'w_misto_umrti': ['Q1381784'],
#   'profese': ['Q36180'],
#   'manzelstvo': ['Q94933498'],
#   'potomstvo': ['Q94919745'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100416989',
#   'label_cs': 'Edith Heralth',
#   'label_en': 'Edith Heralth',
#   'popis_en': 'Austrian writer',
#   'w_narozeni_presne': '+1892-02-15T00:00:00Z',
#   'w_umrti_presne': '+1945-04-09T00:00:00Z',
#   'w_narozeni': 1892,
#   'w_umrti': 1945,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q533534', 'Q40'],
#   'w_misto_narozeni': ['Q1741'],
#   'w_misto_umrti': ['Q1741'],
#   'profese': ['Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417561',
#   'label_cs': 'Václav Vaculovič',
#   'label_en': 'Václav Vaculovič',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni_presne': '+1957-01-01T00:00:00Z',
#   'w_narozeni': 1957,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'w_misto_narozeni': ['Q81137'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417809',
#   'label_cs': 'Jan Mácha',
#   'label_en': 'Jan Mácha',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni_presne': '+1926-09-16T00:00:00Z',
#   'w_umrti_presne': '+1984-11-07T00:00:00Z',
#   'w_narozeni': 1926,
#   'w_umrti': 1984,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1008696'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1028181', 'Q1925963', 'Q644687', 'Q6051619'],
#   'skoly': ['Q414009'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421384',
#   'label_cs': 'Anna Boog',
#   'label_en': 'Anna Boog',
#   'popis_en': "Austrian children's writer",
#   'w_narozeni_presne': '+1894-06-16T00:00:00Z',
#   'w_narozeni': 1894,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q40'],
#   'w_misto_narozeni': ['Q39193'],
#   'profese': ['Q4853732'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421794',
#   'label_cs': 'Miloslav Urban',
#   'label_en': 'Miloslav Urban',
#   'popis_cs': 'autor cestopisných vzpomínek',
#   'w_narozeni_presne': '+1932-00-00T00:00:00Z',
#   'w_umrti_presne': '+2010-00-00T00:00:00Z',
#   'w_narozeni': 1932,
#   'w_umrti': 2010,
#   'w_gender': 'Q6581097',
#   'profese': ['Q3579035'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004275',
#   'label_cs': 'Fridrich Jakub Fuker',
#   'label_en': 'Frigyes Jakab Fuker',
#   'popis_cs': 'německý lékař',
#   'popis_en': 'German physician',
#   'w_narozeni_presne': '+1748-01-01T00:00:00Z',
#   'w_umrti_presne': '+1805-01-01T00:00:00Z',
#   'w_narozeni': 1748,
#   'w_umrti': 1805,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q25409'],
#   'w_misto_umrti': ['Q304304'],
#   'profese': ['Q39631', 'Q897317', 'Q21771805', 'Q36180', 'Q901402', 'Q18805'],
#   'skoly': ['Q368998'],
#   'jazykove_verze': ['hu', 'sk']},
#  {'024_a': 'Q100429039',
#   'label_cs': 'Martina Mináriková',
#   'label_en': 'Martina Mináriková',
#   'popis_cs': 'slovenská šperkařka',
#   'popis_en': 'jewelry designer',
#   'w_narozeni_presne': '+1968-05-07T00:00:00Z',
#   'w_narozeni': 1968,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q1780'],
#   'profese': ['Q336221', 'Q1281618', 'Q2519376'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100430173',
#   'label_cs': 'Otakar Mlejnek',
#   'label_en': 'Otakar Mlejnek',
#   'popis_cs': 'chirurg, lodní lékař, autor vzpomínek',
#   'w_narozeni_presne': '+1930-00-00T00:00:00Z',
#   'w_narozeni': 1930,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q63855'],
#   'profese': ['Q774306', 'Q325855', 'Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100433950',
#   'label_cs': 'Kurt Ziemke',
#   'label_en': 'Kurt Ziemke',
#   'popis_en': 'German diplomat',
#   'w_narozeni_presne': '+1888-01-02T00:00:00Z',
#   'w_umrti_presne': '+1965-07-18T00:00:00Z',
#   'w_narozeni': 1888,
#   'w_umrti': 1965,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q41252'],
#   'profese': ['Q1136290'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100443143',
#   'label_cs': 'Dana Ďuricová',
#   'label_en': 'Dana Duricova',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q1650915'],
#   'jazykove_verze': []}]

# %%
import sys
sys.getsizeof(medailony)
# Out:
# 1140568

# %%
text = "text"
sys.getsizeof(text)
# Out:
# 45

# %%
df = pd.read_json(os.path.join("data_raw","autority_wikidataids.json")).reset_index(drop=False)

# %%
df
# Out:
#                  index       024_a
# 0           jk01010005    Q1063371
# 1           jk01010022   Q12028104
# 2           jk01010023     Q640512
# 3           jk01010026   Q12055885
# 4           jk01010030     Q634048
# ...                ...         ...
# 137683   zmp2016925673   Q13582412
# 137684   zmp2016925675  Q112503439
# 137685  zmp20191037071   Q26208443
# 137686  zmp20191054500     Q825192
# 137687  zmp20211116840  Q107140306
#
# [137688 rows x 2 columns]

# %%
df = df.merge(pd.DataFrame(medailony), on='024_a').set_index('index')

# %%
df.sample(20)
# Out:
#                      024_a                label_cs                label_en  \
# index
# av20241242667     Q1677505  Jacob Gråberg af Hemsö  Jacob Graberg af Hemsŏ
# jn19990004994     Q3093059       Théodore Gosselin       Théodore Gosselin
# xx0148607        Q89574996             Megan Crewe             Megan Crewe
# hka0112541         Q276352         Josef Adam Arco    Joseph Adam von Arco
# jn20030919011      Q123291      Otto Ernst Schmidt              Otto Ernst
# jk01081211       Q95436317           Věra Menclová           Věra Menclová
# xx0022968           Q77795             Hugo Rahner             Hugo Rahner
# xx0321782          Q202561         Pont-de-l'Arche         Pont-de-l'Arche
# xx0229829         Q3242928          Ken’ičiró Mogi                Ken Mogi
# jn19981001970     Q2428037          Cezar Petrescu          Cezar Petrescu
# jk01010711       Q95097690            Josef Balvín            Josef Balvín
# xx0082257        Q12032679           Lajos Tárkony           Lajos Tárkony
# jx20060328001     Q9175734     Bogusław Czechowicz     Bogusław Czechowicz
# ola2004220078   Q120575260          Jana Kalousová          Jana Kalousová
# mzk2005269844    Q95373485       Barbora Mykisková       Barbora Mykisková
# mzk20231206423   Q25189910             Andrew King             Andrew King
# ola2003201118    Q95179622      Marta Zahradníková      Marta Zahradníková
# jcu2011672451      Q714219       Philippe Verdelot       Philippe Verdelot
# jx20041119011   Q120576249             Jiří Bernas                     NaN
# mzk20231178602      Q93634     Michael D. C. Drout     Michael D. C. Drout
#
#                                                    popis_en  \
# index
# av20241242667                  Swedish librarian and author
# jn19990004994                   French historian and writer
# xx0148607                       Canadian young adult writer
# hka0112541                      Austrian priest (1733-1802)
# jn20030919011            German poet and author (1862-1926)
# jk01081211                                              NaN
# xx0022968                                 German theologian
# xx0321782                           commune in Eure, France
# xx0229829                                Japanese scientist
# jn19981001970                               Romanian writer
# jk01010711                                              NaN
# xx0082257                     Hungarian writer, Esperantist
# jx20060328001                          Polish art historian
# ola2004220078                                           NaN
# mzk2005269844                                           NaN
# mzk20231206423                         professor of English
# ola2003201118                                           NaN
# jcu2011672451                               French composer
# jx20041119011                                           NaN
# mzk20231178602  Professor of English and Tolkien researcher
#
#                     w_narozeni_presne         w_umrti_presne  w_narozeni  \
# index
# av20241242667   +1775-05-07T00:00:00Z  +1847-11-29T00:00:00Z      1775.0
# jn19990004994   +1855-10-07T00:00:00Z  +1935-02-07T00:00:00Z      1855.0
# xx0148607       +1980-01-01T00:00:00Z                    NaN      1980.0
# hka0112541      +1733-01-27T00:00:00Z  +1802-06-03T00:00:00Z      1733.0
# jn20030919011   +1862-10-07T00:00:00Z  +1926-03-05T00:00:00Z      1862.0
# jk01081211      +1938-01-29T00:00:00Z                    NaN      1938.0
# xx0022968       +1900-05-03T00:00:00Z  +1968-12-21T00:00:00Z      1900.0
# xx0321782                         NaN                    NaN         NaN
# xx0229829       +1962-01-01T00:00:00Z                    NaN      1962.0
# jn19981001970   +1892-12-01T00:00:00Z  +1961-03-09T00:00:00Z      1892.0
# jk01010711      +1889-12-14T00:00:00Z  +1944-01-01T00:00:00Z      1889.0
# xx0082257       +1902-00-00T00:00:00Z  +1978-07-15T00:00:00Z      1902.0
# jx20060328001   +1967-01-01T00:00:00Z                    NaN      1967.0
# ola2004220078                     NaN                    NaN         NaN
# mzk2005269844   +1970-04-26T00:00:00Z                    NaN      1970.0
# mzk20231206423  +1957-01-01T00:00:00Z                    NaN      1957.0
# ola2003201118   +1940-03-04T00:00:00Z  +2005-01-01T00:00:00Z      1940.0
# jcu2011672451                     NaN  +1552-01-01T00:00:00Z         NaN
# jx20041119011                     NaN                    NaN         NaN
# mzk20231178602  +1968-01-01T00:00:00Z                    NaN      1968.0
#
#                 w_umrti  w_gender obcanstvi      w_misto_narozeni  \
# index
# av20241242667    1847.0  Q6581097     [Q34]  [Q1027830, Q1343999]
# jn19990004994    1935.0  Q6581097    [Q142]           [Q30738255]
# xx0148607           NaN  Q6581072       NaN                [Q172]
# hka0112541       1802.0  Q6581097     [Q40]              [Q34713]
# jn20030919011    1926.0  Q6581097    [Q183]               [Q1597]
# jk01081211          NaN  Q6581072       NaN              [Q36989]
# xx0022968        1968.0  Q6581097    [Q183]              [Q82917]
# xx0321782           NaN       NaN       NaN                   NaN
# xx0229829           NaN  Q6581097     [Q17]             [Q234087]
# jn19981001970    1961.0  Q6581097    [Q218]           [Q12113776]
# jk01010711       1944.0  Q6581097       NaN            [Q2150506]
# xx0082257        1978.0  Q6581097     [Q28]               [Q1781]
# jx20060328001       NaN  Q6581097     [Q36]                   NaN
# ola2004220078       NaN       NaN       NaN                   NaN
# mzk2005269844       NaN  Q6581072       NaN                   NaN
# mzk20231206423      NaN  Q6581097       NaN                   NaN
# ola2003201118    2005.0  Q6581072       NaN               [Q1085]
# jcu2011672451    1552.0  Q6581097    [Q142]             [Q271130]
# jx20041119011       NaN       NaN       NaN                   NaN
# mzk20231178602      NaN  Q6581097     [Q30]                   NaN
#
#                     w_misto_umrti  \
# index
# av20241242667             [Q2044]
# jn19990004994      [Q90, Q533037]
# xx0148607                     NaN
# hka0112541      [Q13298, Q659818]
# jn20030919011             [Q1606]
# jk01081211                    NaN
# xx0022968                 [Q1726]
# xx0321782                     NaN
# xx0229829                     NaN
# jn19981001970            [Q19660]
# jk01010711                    NaN
# xx0082257                     NaN
# jx20060328001                 NaN
# ola2004220078                 NaN
# mzk2005269844                 NaN
# mzk20231206423                NaN
# ola2003201118                 NaN
# jcu2011672451             [Q2044]
# jx20041119011                 NaN
# mzk20231178602                NaN
#
#                                                           profese  \
# index
# av20241242667      [Q182436, Q482980, Q193391, Q2732142, Q901402]
# jn19990004994                                   [Q36180, Q201788]
# xx0148607                             [Q36180, Q212980, Q1030095]
# hka0112541                          [Q250867, Q25393460, Q611644]
# jn20030919011                           [Q36180, Q214917, Q49757]
# jk01081211                                   [Q13570226, Q333634]
# xx0022968        [Q1743122, Q1622272, Q250867, Q1234713, Q201788]
# xx0321782                                                     NaN
# xx0229829                                       [Q14565186, Q901]
# jn19981001970     [Q1930187, Q36180, Q4853732, Q333634, Q6051619]
# jk01010711                                               [Q37226]
# xx0082257           [Q860918, Q36180, Q1930187, Q333634, Q599151]
# jx20060328001                                          [Q1792450]
# ola2004220078                                                 NaN
# mzk2005269844                                                 NaN
# mzk20231206423                    [Q3400985, Q17167049, Q1622272]
# ola2003201118                                           [Q635734]
# jcu2011672451                                  [Q36834, Q1076502]
# jx20041119011                                                 NaN
# mzk20231178602  [Q36180, Q1622272, Q18844224, Q17167049, Q4263...
#
#                                                              ceny  \
# index
# av20241242667                                                 NaN
# jn19990004994   [Q10855195, Q16830747, Q52349666, Q3404419, Q9...
# xx0148607                                                     NaN
# hka0112541                                                    NaN
# jn20030919011                                                 NaN
# jk01081211                                                    NaN
# xx0022968                         [Q59693579, Q306590, Q18591931]
# xx0321782                                                     NaN
# xx0229829                                   [Q4377186, Q11537457]
# jn19981001970                                                 NaN
# jk01010711                                                    NaN
# xx0082257                                                     NaN
# jx20060328001                                                 NaN
# ola2004220078                                                 NaN
# mzk2005269844                                                 NaN
# mzk20231206423                                                NaN
# ola2003201118                                                 NaN
# jcu2011672451                                                 NaN
# jx20041119011                                                 NaN
# mzk20231178602                                                NaN
#
#                                                    jazykove_verze  \
# index
# av20241242667                                    [sv, fr, de, it]
# jn19990004994                       [ar, de, arz, it, sv, en, fr]
# xx0148607                                                    [en]
# hka0112541                                       [pl, it, de, cs]
# jn20030919011                            [ru, ar, fi, fr, ca, de]
# jk01081211                                                     []
# xx0022968       [de, es, pt, sr, eo, cs, ca, fa, fr, en, sk, arz]
# xx0321782       [hu, ast, vo, ku, bug, es, vi, ce, nl, sv, uk,...
# xx0229829                            [pl, de, zh, ja, simple, en]
# jn19981001970           [arz, pl, it, en, et, fr, ru, ro, pt, sv]
# jk01010711                                                     []
# xx0082257                                                [eo, cs]
# jx20060328001                                                [pl]
# ola2004220078                                                  []
# mzk2005269844                                                  []
# mzk20231206423                                               [en]
# ola2003201118                                                  []
# jcu2011672451   [fr, el, es, fi, he, it, cs, gl, ja, pl, pt, d...
# jx20041119011                                                  []
# mzk20231178602                                   [es, en, fr, de]
#
#                                                          popis_cs  \
# index
# av20241242667                                                 NaN
# jn19990004994                                                 NaN
# xx0148607       kanadská spisovatelka knih pro mládež, psychol...
# hka0112541             biskup královéhradecký a hradecko-sekavský
# jn20030919011                                                 NaN
# jk01081211      Narozena 29.1.1938 v Pardubicích. PhDr., asist...
# xx0022968                      německý jezuita, teolog a historik
# xx0321782                     obec v departementu Eure ve Francii
# xx0229829                               japonský kognitivní vědec
# jn19981001970                                                 NaN
# jk01010711      Narozen 14.12.1889 v Onomyšli, zemřel 1944. Uč...
# xx0082257                                                     NaN
# jx20060328001                                                 NaN
# ola2004220078   MUDr., pediatrička. Práce z oboru dětského lék...
# mzk2005269844   Narozena 26.4.1970 ve Valaškém Meziříčí. Spolu...
# mzk20231206423                                                NaN
# ola2003201118   Narozena 4.3.1940 v Praze, zemřela 2005. Archi...
# jcu2011672451              italský skladatel francouzského původu
# jx20041119011                                  učebnice svařování
# mzk20231178602                                                NaN
#
#                                                          wiki_cs  \
# index
# av20241242667                                                NaN
# jn19990004994                                                NaN
# xx0148607                                                    NaN
# hka0112541       https://cs.wikipedia.org/wiki/Josef_Adam_z_Arco
# jn20030919011                                                NaN
# jk01081211                                                   NaN
# xx0022968              https://cs.wikipedia.org/wiki/Hugo_Rahner
# xx0321782        https://cs.wikipedia.org/wiki/Pont-de-l%27Arche
# xx0229829                                                    NaN
# jn19981001970                                                NaN
# jk01010711                                                   NaN
# xx0082257       https://cs.wikipedia.org/wiki/Lajos_T%C3%A1rkony
# jx20060328001                                                NaN
# ola2004220078                                                NaN
# mzk2005269844                                                NaN
# mzk20231206423                                               NaN
# ola2003201118                                                NaN
# jcu2011672451    https://cs.wikipedia.org/wiki/Philippe_Verdelot
# jx20041119011                                                NaN
# mzk20231178602                                               NaN
#
#                                                           wiki_en druh_umrti  \
# index
# av20241242667                                                 NaN        NaN
# jn19990004994   https://en.wikipedia.org/wiki/Th%C3%A9odore_Go...        NaN
# xx0148607               https://en.wikipedia.org/wiki/Megan_Crewe        NaN
# hka0112541                                                    NaN        NaN
# jn20030919011                                                 NaN        NaN
# jk01081211                                                    NaN        NaN
# xx0022968               https://en.wikipedia.org/wiki/Hugo_Rahner   Q3739104
# xx0321782         https://en.wikipedia.org/wiki/Pont-de-l%27Arche        NaN
# xx0229829                  https://en.wikipedia.org/wiki/Ken_Mogi        NaN
# jn19981001970        https://en.wikipedia.org/wiki/Cezar_Petrescu        NaN
# jk01010711                                                    NaN        NaN
# xx0082257                                                     NaN        NaN
# jx20060328001                                                 NaN        NaN
# ola2004220078                                                 NaN        NaN
# mzk2005269844                                                 NaN        NaN
# mzk20231206423  https://en.wikipedia.org/wiki/Andrew_King_(pro...        NaN
# ola2003201118                                                 NaN        NaN
# jcu2011672451     https://en.wikipedia.org/wiki/Philippe_Verdelot        NaN
# jx20041119011                                                 NaN        NaN
# mzk20231178602  https://en.wikipedia.org/wiki/Michael_D._C._Drout        NaN
#
#                pricina_umrti     vezeni                           strany  \
# index
# av20241242667            NaN        NaN                              NaN
# jn19990004994            NaN        NaN                              NaN
# xx0148607                NaN        NaN                              NaN
# hka0112541               NaN        NaN                              NaN
# jn20030919011            NaN        NaN                              NaN
# jk01081211               NaN        NaN                              NaN
# xx0022968             Q11085        NaN                              NaN
# xx0321782                NaN        NaN                              NaN
# xx0229829                NaN        NaN                              NaN
# jn19981001970            NaN        NaN  [Q1855102, Q303668, Q105946588]
# jk01010711               NaN  [Q318861]                              NaN
# xx0082257                NaN        NaN                              NaN
# jx20060328001            NaN        NaN                              NaN
# ola2004220078            NaN        NaN                              NaN
# mzk2005269844            NaN        NaN                              NaN
# mzk20231206423           NaN        NaN                              NaN
# ola2003201118            NaN        NaN                              NaN
# jcu2011672451            NaN        NaN                              NaN
# jx20041119011            NaN        NaN                              NaN
# mzk20231178602           NaN        NaN                              NaN
#
#                                                             skoly manzelstvo  \
# index
# av20241242667                                                 NaN        NaN
# jn19990004994                                                 NaN        NaN
# xx0148607                                              [Q7338134]        NaN
# hka0112541                                                    NaN        NaN
# jn20030919011                                                 NaN        NaN
# jk01081211                                                    NaN        NaN
# xx0022968                                               [Q875788]        NaN
# xx0321782                                                     NaN        NaN
# xx0229829       [Q56348529, Q86498471, Q86627628, Q11524768, Q...        NaN
# jn19981001970                                          [Q1523902]        NaN
# jk01010711                                                    NaN        NaN
# xx0082257                                                     NaN        NaN
# jx20060328001                                           [Q315658]        NaN
# ola2004220078                                                 NaN        NaN
# mzk2005269844                                                 NaN        NaN
# mzk20231206423                              [Q1432632, Q20713236]        NaN
# ola2003201118                                                 NaN        NaN
# jcu2011672451                                                 NaN        NaN
# jx20041119011                                                 NaN        NaN
# mzk20231178602                                 [Q190080, Q579968]        NaN
#
#                partnerstvo    potomstvo sourozenectvo             facebook  \
# index
# av20241242667          NaN          NaN           NaN                  NaN
# jn19990004994          NaN  [Q17486069]   [Q90660119]                  NaN
# xx0148607              NaN          NaN           NaN                  NaN
# hka0112541             NaN          NaN           NaN                  NaN
# jn20030919011          NaN  [Q19674711]           NaN                  NaN
# jk01081211             NaN          NaN           NaN                  NaN
# xx0022968              NaN          NaN      [Q57317]                  NaN
# xx0321782              NaN          NaN           NaN                  NaN
# xx0229829              NaN          NaN           NaN  kenichiromogiqualia
# jn19981001970          NaN          NaN           NaN                  NaN
# jk01010711             NaN          NaN           NaN                  NaN
# xx0082257              NaN          NaN           NaN                  NaN
# jx20060328001          NaN          NaN           NaN                  NaN
# ola2004220078          NaN          NaN           NaN                  NaN
# mzk2005269844          NaN          NaN           NaN                  NaN
# mzk20231206423         NaN          NaN           NaN                  NaN
# ola2003201118          NaN          NaN           NaN                  NaN
# jcu2011672451          NaN          NaN           NaN                  NaN
# jx20041119011          NaN          NaN           NaN                  NaN
# mzk20231178602         NaN          NaN           NaN                  NaN
#
#                       twitter  instagram                           web  \
# index
# av20241242667             NaN        NaN                           NaN
# jn19990004994             NaN        NaN                           NaN
# xx0148607                 NaN        NaN         http://megancrewe.com
# hka0112541                NaN        NaN                           NaN
# jn20030919011             NaN        NaN                           NaN
# jk01081211                NaN        NaN                           NaN
# xx0022968                 NaN        NaN                           NaN
# xx0321782            pda_info        NaN   http://www.pontdelarche.fr/
# xx0229829       kenichiromogi  qualiaken  http://qualia-manifesto.com/
# jn19981001970             NaN        NaN                           NaN
# jk01010711                NaN        NaN                           NaN
# xx0082257                 NaN        NaN                           NaN
# jx20060328001             NaN        NaN                           NaN
# ola2004220078             NaN        NaN                           NaN
# mzk2005269844             NaN        NaN                           NaN
# mzk20231206423            NaN        NaN                           NaN
# ola2003201118             NaN        NaN                           NaN
# jcu2011672451             NaN        NaN                           NaN
# jx20041119011             NaN        NaN                           NaN
# mzk20231178602            NaN        NaN                           NaN
#
#                udalosti role
# index
# av20241242667       NaN  NaN
# jn19990004994       NaN  NaN
# xx0148607           NaN  NaN
# hka0112541          NaN  NaN
# jn20030919011       NaN  NaN
# jk01081211          NaN  NaN
# xx0022968           NaN  NaN
# xx0321782           NaN  NaN
# xx0229829           NaN  NaN
# jn19981001970       NaN  NaN
# jk01010711          NaN  NaN
# xx0082257           NaN  NaN
# jx20060328001       NaN  NaN
# ola2004220078       NaN  NaN
# mzk2005269844       NaN  NaN
# mzk20231206423      NaN  NaN
# ola2003201118       NaN  NaN
# jcu2011672451       NaN  NaN
# jx20041119011       NaN  NaN
# mzk20231178602      NaN  NaN

# %%
df[df.index == 'Q93240837']
# Out:
# Empty DataFrame
# Columns: [024_a, label_cs, label_en, popis_en, w_narozeni_presne, w_umrti_presne, w_narozeni, w_umrti, w_gender, obcanstvi, w_misto_narozeni, w_misto_umrti, profese, ceny, jazykove_verze, popis_cs, wiki_cs, wiki_en, druh_umrti, pricina_umrti, vezeni, strany, skoly, manzelstvo, partnerstvo, potomstvo, sourozenectvo, facebook, twitter, instagram, web, udalosti, role]
# Index: []

# %%
df[df['024_a'] == 'Q571203']
# Out:
#               024_a       label_cs       label_en  \
# index
# jk01100136  Q571203  Karel Poláček  Karel Poláček
#
#                                                      popis_en  \
# index
# jk01100136  Czech humorist, publicist, bookwriter, scriptw...
#
#                 w_narozeni_presne         w_umrti_presne  w_narozeni  w_umrti  \
# index
# jk01100136  +1892-03-22T00:00:00Z  +1945-01-21T00:00:00Z      1892.0   1945.0
#
#             w_gender          obcanstvi w_misto_narozeni  \
# index
# jk01100136  Q6581097  [Q533534, Q33946]       [Q1000091]
#
#                       w_misto_umrti  \
# index
# jk01100136  [Q105084, Q7342, Q7341]
#
#                                                    profese         ceny  \
# index
# jk01100136  [Q36180, Q28389, Q1930187, Q69423232, Q876864]  [Q42794387]
#
#                                            jazykove_verze  \
# index
# jk01100136  [de, uk, fa, ru, en, eo, fr, it, cs, arz, sk]
#
#                                                      popis_cs  \
# index
# jk01100136  český humorista, novinář, romanopisec, scenári...
#
#                                                       wiki_cs  \
# index
# jk01100136  https://cs.wikipedia.org/wiki/Karel_Pol%C3%A1%...
#
#                                                       wiki_en druh_umrti  \
# index
# jk01100136  https://en.wikipedia.org/wiki/Karel_Pol%C3%A1%...        NaN
#
#            pricina_umrti              vezeni strany        skoly  \
# index
# jk01100136           NaN  [Q7341, Q15111616]    NaN  [Q12047389]
#
#               manzelstvo  partnerstvo potomstvo             sourozenectvo  \
# index
# jk01100136  [Q105573892]  [Q95459535]       NaN  [Q105573905, Q105574064]
#
#            facebook twitter instagram  web                           udalosti  \
# index
# jk01100136      NaN     NaN       NaN  NaN  [Q5883980, Q104055388, Q76358503]
#
#                   role
# index
# jk01100136  [Q5883980]

# %%
df[df['024_a'] == 'Q16861736']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                    w_narozeni_presne w_umrti_presne  w_narozeni  w_umrti  \
# index
# jx20100301005  +1984-01-16T00:00:00Z            NaN      1984.0      NaN
#
#                w_gender obcanstvi w_misto_narozeni w_misto_umrti  \
# index
# jx20100301005  Q6581097    [Q213]         [Q14960]           NaN
#
#                                                       profese ceny  \
# index
# jx20100301005  [Q36180, Q1930187, Q6051619, Q822146, Q333634]  NaN
#
#               jazykove_verze          popis_cs  \
# index
# jx20100301005           [cs]  český publicista
#
#                                                          wiki_cs wiki_en  \
# index
# jx20100301005  https://cs.wikipedia.org/wiki/Michal_Ka%C5%A1p...     NaN
#
#               druh_umrti pricina_umrti vezeni strany      skoly manzelstvo  \
# index
# jx20100301005        NaN           NaN    NaN    NaN  [Q763586]        NaN
#
#               partnerstvo potomstvo sourozenectvo  facebook   twitter  \
# index
# jx20100301005         NaN       NaN           NaN  kasparek  kasparek
#
#                             instagram                            web udalosti  \
# index
# jx20100301005  jakovzdynaprostopresny  http://www.michalkasparek.cz/      NaN
#
#               role
# index
# jx20100301005  NaN

# %%
df[df.index == 'jx20100301005']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                    w_narozeni_presne w_umrti_presne  w_narozeni  w_umrti  \
# index
# jx20100301005  +1984-01-16T00:00:00Z            NaN      1984.0      NaN
#
#                w_gender obcanstvi w_misto_narozeni w_misto_umrti  \
# index
# jx20100301005  Q6581097    [Q213]         [Q14960]           NaN
#
#                                                       profese ceny  \
# index
# jx20100301005  [Q36180, Q1930187, Q6051619, Q822146, Q333634]  NaN
#
#               jazykove_verze          popis_cs  \
# index
# jx20100301005           [cs]  český publicista
#
#                                                          wiki_cs wiki_en  \
# index
# jx20100301005  https://cs.wikipedia.org/wiki/Michal_Ka%C5%A1p...     NaN
#
#               druh_umrti pricina_umrti vezeni strany      skoly manzelstvo  \
# index
# jx20100301005        NaN           NaN    NaN    NaN  [Q763586]        NaN
#
#               partnerstvo potomstvo sourozenectvo  facebook   twitter  \
# index
# jx20100301005         NaN       NaN           NaN  kasparek  kasparek
#
#                             instagram                            web udalosti  \
# index
# jx20100301005  jakovzdynaprostopresny  http://www.michalkasparek.cz/      NaN
#
#               role
# index
# jx20100301005  NaN

# %%
df.sample(10)
# Out:
#                     024_a                 label_cs        label_en  \
# index
# jo20231189216   Q96748268                 Jan Okóń             NaN
# jk01063501      Q64848391              Bohumil Krs     Bohumil Krs
# xx0081008       Q19818371               Jiří Brůna      Jiří Brůna
# jn19992000718       Q5592  Michelangelo Buonarroti    Michelangelo
# xx0128153       Q95244039               Adam Borek      Adam Borek
# mzk2007411110  Q112408142         František Mikula             NaN
# jn20000807028  Q112361847           Oliete Lourdes  Oliete Lourdes
# kpwa6296        Q88978469            Pavel Steiger   Pavel Steiger
# xx0314039      Q110747069               Peter Arlt      Peter Arlt
# xx0079318         Q463132            Gerald Scarfe   Gerald Scarfe
#
#                                                         popis_en  \
# index
# jo20231189216                                                NaN
# jk01063501                                                   NaN
# xx0081008                                                    NaN
# jn19992000718  Italian sculptor, painter, architect and poet ...
# xx0128153                                                    NaN
# mzk2007411110                                                NaN
# jn20000807028                                                NaN
# kpwa6296                                                     NaN
# xx0314039                                                    NaN
# xx0079318              English cartoonist, illustrator, animator
#
#                    w_narozeni_presne         w_umrti_presne  w_narozeni  \
# index
# jo20231189216  +1906-05-20T00:00:00Z  +1972-06-30T00:00:00Z      1906.0
# jk01063501     +1890-06-23T00:00:00Z  +1962-05-17T00:00:00Z      1890.0
# xx0081008      +1955-07-26T00:00:00Z                    NaN      1955.0
# jn19992000718  +1475-03-06T00:00:00Z  +1564-02-18T00:00:00Z      1475.0
# xx0128153      +1947-06-21T00:00:00Z                    NaN      1947.0
# mzk2007411110  +1935-00-00T00:00:00Z                    NaN      1935.0
# jn20000807028  +1942-00-00T00:00:00Z                    NaN      1942.0
# kpwa6296       +1941-06-15T00:00:00Z                    NaN      1941.0
# xx0314039      +1943-12-18T00:00:00Z                    NaN      1943.0
# xx0079318      +1936-06-01T00:00:00Z                    NaN      1936.0
#
#                w_umrti  w_gender       obcanstvi w_misto_narozeni  \
# index
# jo20231189216   1972.0  Q6581097             NaN         [Q31487]
# jk01063501      1962.0  Q6581097        [Q33946]         [Q43453]
# xx0081008          NaN  Q6581097          [Q213]          [Q1085]
# jn19992000718   1564.0  Q6581097  [Q148540, Q38]         [Q52069]
# xx0128153          NaN  Q6581097             NaN         [Q36989]
# mzk2007411110      NaN  Q6581097             NaN       [Q1870062]
# jn20000807028      NaN       NaN             NaN              NaN
# kpwa6296           NaN  Q6581097        [Q33946]          [Q1085]
# xx0314039          NaN  Q6581097        [Q16957]          [Q2814]
# xx0079318          NaN  Q6581097          [Q145]       [Q2153758]
#
#               w_misto_umrti  \
# index
# jo20231189216        [Q270]
# jk01063501         [Q43453]
# xx0081008               NaN
# jn19992000718        [Q220]
# xx0128153               NaN
# mzk2007411110     [Q998679]
# jn20000807028           NaN
# kpwa6296                NaN
# xx0314039               NaN
# xx0079318               NaN
#
#                                                          profese  \
# index
# jo20231189216                                          [Q212980]
# jk01063501     [Q2707485, Q644687, Q1028181, Q37226, Q1229025...
# xx0081008                                               [Q49757]
# jn19992000718  [Q1281618, Q14623005, Q1028181, Q42973, Q49757...
# xx0128153                                              [Q212980]
# mzk2007411110                      [Q1231865, Q3330547, Q201788]
# jn20000807028                                                NaN
# kpwa6296                            [Q520549, Q219477, Q6051619]
# xx0314039                                                    NaN
# xx0079318      [Q3658608, Q644687, Q5322166, Q266569, Q200012...
#
#                                 ceny  \
# index
# jo20231189216                    NaN
# jk01063501                       NaN
# xx0081008                        NaN
# jn19992000718                    NaN
# xx0128153                        NaN
# mzk2007411110                    NaN
# jn20000807028                    NaN
# kpwa6296                         NaN
# xx0314039                        NaN
# xx0079318      [Q12201477, Q3445914]
#
#                                                   jazykove_verze  \
# index
# jo20231189216                                                 []
# jk01063501                                                    []
# xx0081008                                                   [cs]
# jn19992000718  [gan, min, hy, fo, ab, am, lt, bat-smg, ka, ks...
# xx0128153                                                     []
# mzk2007411110                                                 []
# jn20000807028                                                 []
# kpwa6296                                                    [cs]
# xx0314039                                                   [de]
# xx0079318      [en, pl, sv, fr, ru, es, ms, pt, nl, cs, eo, k...
#
#                                                         popis_cs  \
# index
# jo20231189216                                                NaN
# jk01063501       umělec, narozen 23. 6. 1890, zemřel 17. 5. 1962
# xx0081008                                           český básník
# jn19992000718       renesanční sochař, malíř, architekt a básník
# xx0128153      Narozen 21.6.1947 v Pardubicích. Dětský psycho...
# mzk2007411110  Narozen 1935. Pedagog, kronikář obce Tupesy, r...
# jn20000807028                                                NaN
# kpwa6296       český geolog, křesťanský publicista, misionář,...
# xx0314039      Německý historik umění, vysokoškolský pedagog,...
# xx0079318                    anglický karikaturista a ilustrátor
#
#                                                          wiki_cs  \
# index
# jo20231189216                                                NaN
# jk01063501                                                   NaN
# xx0081008      https://cs.wikipedia.org/wiki/Ji%C5%99%C3%AD_B...
# jn19992000718  https://cs.wikipedia.org/wiki/Michelangelo_Buo...
# xx0128153                                                    NaN
# mzk2007411110                                                NaN
# jn20000807028                                                NaN
# kpwa6296             https://cs.wikipedia.org/wiki/Pavel_Steiger
# xx0314039                                                    NaN
# xx0079318            https://cs.wikipedia.org/wiki/Gerald_Scarfe
#
#                                                    wiki_en druh_umrti  \
# index
# jo20231189216                                          NaN        NaN
# jk01063501                                             NaN        NaN
# xx0081008                                              NaN        NaN
# jn19992000718   https://en.wikipedia.org/wiki/Michelangelo        NaN
# xx0128153                                              NaN        NaN
# mzk2007411110                                          NaN        NaN
# jn20000807028                                          NaN        NaN
# kpwa6296                                               NaN        NaN
# xx0314039                                              NaN        NaN
# xx0079318      https://en.wikipedia.org/wiki/Gerald_Scarfe        NaN
#
#               pricina_umrti vezeni strany        skoly manzelstvo partnerstvo  \
# index
# jo20231189216           NaN    NaN    NaN          NaN        NaN         NaN
# jk01063501              NaN    NaN    NaN    [Q414309]        NaN         NaN
# xx0081008               NaN    NaN    NaN          NaN        NaN         NaN
# jn19992000718           NaN    NaN    NaN    [Q820887]        NaN   [Q538960]
# xx0128153               NaN    NaN    NaN          NaN        NaN         NaN
# mzk2007411110           NaN    NaN    NaN          NaN        NaN         NaN
# jn20000807028           NaN    NaN    NaN          NaN        NaN         NaN
# kpwa6296                NaN    NaN    NaN          NaN        NaN         NaN
# xx0314039               NaN    NaN    NaN          NaN        NaN         NaN
# xx0079318               NaN    NaN    NaN  [Q15274445]  [Q204426]         NaN
#
#                                        potomstvo sourozenectvo facebook  \
# index
# jo20231189216                                NaN           NaN      NaN
# jk01063501                                   NaN           NaN      NaN
# xx0081008                                    NaN           NaN      NaN
# jn19992000718                                NaN           NaN      NaN
# xx0128153                                    NaN           NaN      NaN
# mzk2007411110                                NaN           NaN      NaN
# jn20000807028                                NaN           NaN      NaN
# kpwa6296                                     NaN           NaN      NaN
# xx0314039                                    NaN           NaN      NaN
# xx0079318      [Q75502103, Q75502100, Q75502101]           NaN      NaN
#
#               twitter instagram                           web udalosti role
# index
# jo20231189216     NaN       NaN                           NaN      NaN  NaN
# jk01063501        NaN       NaN                           NaN      NaN  NaN
# xx0081008         NaN       NaN                           NaN      NaN  NaN
# jn19992000718     NaN       NaN                           NaN      NaN  NaN
# xx0128153         NaN       NaN                           NaN      NaN  NaN
# mzk2007411110     NaN       NaN                           NaN      NaN  NaN
# jn20000807028     NaN       NaN                           NaN      NaN  NaN
# kpwa6296          NaN       NaN                           NaN      NaN  NaN
# xx0314039         NaN       NaN                           NaN      NaN  NaN
# xx0079318         NaN       NaN  http://www.geraldscarfe.com/      NaN  NaN

# %%
df.to_json(os.path.join('data_raw','wikidata_raw.json'))

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 137559 entries, jk01010005 to zmp20211116840
# Data columns (total 33 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   024_a              137559 non-null  object
#  1   label_cs           136525 non-null  object
#  2   label_en           127696 non-null  object
#  3   popis_en           75733 non-null   object
#  4   w_narozeni_presne  118657 non-null  object
#  5   w_umrti_presne     58063 non-null   object
#  6   w_narozeni         118657 non-null  float64
#  7   w_umrti            58063 non-null   float64
#  8   w_gender           129148 non-null  object
#  9   obcanstvi          69338 non-null   object
#  10  w_misto_narozeni   88937 non-null   object
#  11  w_misto_umrti      44183 non-null   object
#  12  profese            117861 non-null  object
#  13  ceny               22828 non-null   object
#  14  jazykove_verze     137209 non-null  object
#  15  popis_cs           94582 non-null   object
#  16  wiki_cs            25450 non-null   object
#  17  wiki_en            34086 non-null   object
#  18  druh_umrti         3420 non-null    object
#  19  pricina_umrti      4109 non-null    object
#  20  vezeni             1021 non-null    object
#  21  strany             5766 non-null    object
#  22  skoly              39282 non-null   object
#  23  manzelstvo         7960 non-null    object
#  24  partnerstvo        773 non-null     object
#  25  potomstvo          6485 non-null    object
#  26  sourozenectvo      4702 non-null    object
#  27  facebook           2927 non-null    object
#  28  twitter            3703 non-null    object
#  29  instagram          1576 non-null    object
#  30  web                9455 non-null    object
#  31  udalosti           1229 non-null    object
#  32  role               1503 non-null    object
# dtypes: float64(2), object(31)
# memory usage: 237.6 MB

# %%
df.columns
# Out:
# Index(['024_a', 'label_cs', 'label_en', 'popis_en', 'w_narozeni_presne',
#        'w_umrti_presne', 'w_narozeni', 'w_umrti', 'w_gender', 'obcanstvi',
#        'w_misto_narozeni', 'w_misto_umrti', 'profese', 'ceny',
#        'jazykove_verze', 'popis_cs', 'wiki_cs', 'wiki_en', 'druh_umrti',
#        'pricina_umrti', 'vezeni', 'strany', 'skoly', 'manzelstvo',
#        'partnerstvo', 'potomstvo', 'sourozenectvo', 'facebook', 'twitter',
#        'instagram', 'web', 'udalosti', 'role'],
#       dtype='object')

# %%
for sloupec in df.columns.to_list():
    print(f"{sloupec}: {int(len(df[df[sloupec].notnull()])/len(df)*100)} %")
# Out:
# 024_a: 100 %
# label_cs: 99 %
# label_en: 92 %
# popis_en: 55 %
# w_narozeni_presne: 86 %
# w_umrti_presne: 42 %
# w_narozeni: 86 %
# w_umrti: 42 %
# w_gender: 93 %
# obcanstvi: 50 %
# w_misto_narozeni: 64 %
# w_misto_umrti: 32 %
# profese: 85 %
# ceny: 16 %
# jazykove_verze: 99 %
# popis_cs: 68 %
# wiki_cs: 18 %
# wiki_en: 24 %
# druh_umrti: 2 %
# pricina_umrti: 2 %
# vezeni: 0 %
# strany: 4 %
# skoly: 28 %
# manzelstvo: 5 %
# partnerstvo: 0 %
# potomstvo: 4 %
# sourozenectvo: 3 %
# facebook: 2 %
# twitter: 2 %
# instagram: 1 %
# web: 6 %
# udalosti: 0 %
# role: 1 %
