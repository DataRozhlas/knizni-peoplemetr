# %%
import os
import re
import json
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
odkud = 'downloads/wikidata/autority'

# %%
def najdi_letopocet(x):
    try:
        return int(re.search(r"\d{4}",x).group())
    except:
        return None

# %%
len([f for f in os.listdir("downloads/wikidata/autority")])
# Out:
# 131212

# %%
medailony = []
pocitadlo = 0

for f in [f for f in os.listdir("downloads/wikidata/autority")]:

    pocitadlo += 1
    if pocitadlo % 1000 == 0:
        print(f"{pocitadlo:006}: {f}")
    
    medailon = {}
    with open(os.path.join('downloads/wikidata/autority', f), 'r', encoding='utf-8') as file:
        
        wd = json.loads(file.read())
        q = f[:-5]
        medailon['024_a'] = q

        try:
            medailon['label_cs'] = wd['entities'][q]['labels']['cs']['value']
        except:
            pass
        try:
            medailon['label_en'] = wd['entities'][q]['labels']['en']['value']
        except:
            pass
        try:
            medailon['popis_cs'] = wd['entities'][q]['descriptions']['cs']['value']
        except:
            pass
        try:
            medailon['popis_en'] = wd['entities'][q]['descriptions']['en']['value']
        except:
            pass

        try:
            medailon['w_narozeni_presne'] = wd['entities'][q]['claims']['P569'][0]['mainsnak']['datavalue']['value']['time']
        except:
            pass
        try:
            medailon['w_umrti_presne'] = wd['entities'][q]['claims']['P570'][0]['mainsnak']['datavalue']['value']['time']
        except:
            pass
        
        try:
            medailon['w_narozeni'] = najdi_letopocet(medailon['w_narozeni_presne'])
        except:
            pass
        try:
            medailon['w_umrti'] = najdi_letopocet(medailon['w_umrti_presne'])
        except:
            pass
        
        try:
            medailon['w_gender'] = wd['entities'][q]['claims']['P21'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['obcanstvi'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P27']]
        except:
            pass
        try:
            medailon['w_misto_narozeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P19']]
        except:
            pass
        try:
            medailon['w_misto_umrti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P20']]
        except:
            pass
        try:
            medailon['druh_umrti'] = wd['entities'][q]['claims']['P1196'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass
        try:
            medailon['pricina_umrti'] = wd['entities'][q]['claims']['P509'][0]['mainsnak']['datavalue']['value']['id']
        except:
            pass      
        try:
            medailon['vezeni'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2632']]
        except:
            pass
        try:
            medailon['profese'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P106']]
        except:
            pass
        try:
            medailon['strany'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P102']]
        except:
            pass
        try:
            medailon['skoly'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P69']]
        except:
            pass
        try:
            medailon['udalosti'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P793']]
        except:
            pass
        try:
            medailon['role'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P2868']]
        except:
            pass
        try:
            medailon['ceny'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P166']]
        except:
            pass
        try:
            medailon['manzelstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P26']]
        except:
            pass
        try:
            medailon['partnerstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P451']]
        except:
            pass
        try:
            medailon['sourozenectvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P3373']]
        except:
            pass
        try:
            medailon['potomstvo'] = [x['mainsnak']['datavalue']['value']['id'] for x in  wd['entities'][q]['claims']['P40']]
        except:
            pass       

        try:
            medailon['facebook'] = wd['entities'][q]['claims']['P2013'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['twitter'] = wd['entities'][q]['claims']['P2002'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['instagram'] = wd['entities'][q]['claims']['P2003'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['web'] = wd['entities'][q]['claims']['P856'][0]['mainsnak']['datavalue']['value']
        except:
            pass
        try:
            medailon['wiki_cs'] = wd['entities'][q]['sitelinks']['cswiki']['url']
        except:
            pass
        try:
            medailon['wiki_en'] = wd['entities'][q]['sitelinks']['enwiki']['url']
        except:
            pass
        
        try:
            medailon['jazykove_verze'] = [z.split(".wikipedia")[0].split("//")[1] for z in set(list([x for x in [hodnoty['url'] for popisky, hodnoty in wd['entities'][q]['sitelinks'].items()]])) if "wikipedia" in z]
        except:
            pass
    
    medailony.append(medailon)
# Out:
# 001000: Q102801061.json
# 002000: Q105353757.json
# 003000: Q106983378.json
# 004000: Q10820050.json
# 005000: Q109491547.json
# 006000: Q110787083.json
# 007000: Q112342826.json
# 008000: Q112349172.json
# 009000: Q112361768.json
# 010000: Q112370966.json
# 011000: Q112378439.json
# 012000: Q112386613.json
# 013000: Q112393668.json
# 014000: Q112404391.json
# 015000: Q112415316.json
# 016000: Q112428290.json
# 017000: Q112456136.json
# 018000: Q112487942.json
# 019000: Q112519385.json
# 020000: Q112560525.json
# 021000: Q113791549.json
# 022000: Q116262492.json
# 023000: Q11769070.json
# 024000: Q11910328.json
# 025000: Q12018531.json
# 026000: Q12025069.json
# 027000: Q12031957.json
# 028000: Q12044019.json
# 029000: Q120572931.json
# 030000: Q120575194.json
# 031000: Q120578274.json
# 032000: Q120583617.json
# 033000: Q120587318.json
# 034000: Q120591722.json
# 035000: Q120597421.json
# 036000: Q120605997.json
# 037000: Q120615644.json
# 038000: Q1222096.json
# 039000: Q12379619.json
# 040000: Q125263.json
# 041000: Q1271.json
# 042000: Q130031.json
# 043000: Q13534569.json
# 044000: Q1436392.json
# 045000: Q1508580.json
# 046000: Q15454791.json
# 047000: Q15830324.json
# 048000: Q16137573.json
# 049000: Q166876.json
# 050000: Q17043452.json
# 051000: Q1748401.json
# 052000: Q18341589.json
# 053000: Q18924925.json
# 054000: Q19630154.json
# 055000: Q201739.json
# 056000: Q2087343.json
# 057000: Q2144912.json
# 058000: Q219912.json
# 059000: Q232391.json
# 060000: Q2420577.json
# 061000: Q2549768.json
# 062000: Q26710231.json
# 063000: Q27985584.json
# 064000: Q28936036.json
# 065000: Q30066743.json
# 066000: Q311931.json
# 067000: Q321691.json
# 068000: Q33592009.json
# 069000: Q3512061.json
# 070000: Q37030.json
# 071000: Q3858116.json
# 072000: Q4136090.json
# 073000: Q4244192.json
# 074000: Q43588359.json
# 075000: Q4496039.json
# 076000: Q467676.json
# 077000: Q4764732.json
# 078000: Q498409.json
# 079000: Q51549893.json
# 080000: Q5298323.json
# 081000: Q54852007.json
# 082000: Q55619874.json
# 083000: Q55949653.json
# 084000: Q56887261.json
# 085000: Q57902533.json
# 086000: Q5919700.json
# 087000: Q59679526.json
# 088000: Q60815978.json
# 089000: Q6160709.json
# 090000: Q62655757.json
# 091000: Q642995.json
# 092000: Q65964592.json
# 093000: Q6810270.json
# 094000: Q70906747.json
# 095000: Q729450.json
# 096000: Q75418937.json
# 097000: Q7822312.json
# 098000: Q81188087.json
# 099000: Q85417790.json
# 100000: Q88013031.json
# 101000: Q90284941.json
# 102000: Q9256667.json
# 103000: Q93435739.json
# 104000: Q94810846.json
# 105000: Q95071772.json
# 106000: Q95080910.json
# 107000: Q95099364.json
# 108000: Q95109782.json
# 109000: Q95134431.json
# 110000: Q95144450.json
# 111000: Q95150839.json
# 112000: Q95154387.json
# 113000: Q95165019.json
# 114000: Q95167965.json
# 115000: Q95174716.json
# 116000: Q95176751.json
# 117000: Q95182640.json
# 118000: Q95214137.json
# 119000: Q95224306.json
# 120000: Q95332557.json
# 121000: Q95365290.json
# 122000: Q95375813.json
# 123000: Q95390061.json
# 124000: Q95395841.json
# 125000: Q95436761.json
# 126000: Q95447792.json
# 127000: Q95459612.json
# 128000: Q95473678.json
# 129000: Q95487882.json
# 130000: Q96954.json
# 131000: Q99460718.json

# %%
medailony[5:100]
# Out:
# [{'024_a': 'Q1000542',
#   'label_cs': 'Christina Kauschke',
#   'label_en': 'Christina Kauschke',
#   'popis_en': 'German linguist',
#   'w_narozeni_presne': '+1964-01-01T00:00:00Z',
#   'w_narozeni': 1964,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q1295'],
#   'profese': ['Q14467526', 'Q1622272', 'Q11762416'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1000592',
#   'label_cs': 'Tyson Fury',
#   'label_en': 'Tyson Fury',
#   'popis_cs': 'britský boxer',
#   'popis_en': 'British boxer (born 1988)',
#   'w_narozeni_presne': '+1988-08-12T00:00:00Z',
#   'w_narozeni': 1988,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q145'],
#   'w_misto_narozeni': ['Q18125'],
#   'profese': ['Q11338576', 'Q2066131'],
#   'ceny': ['Q55042186', 'Q4114674'],
#   'manzelstvo': ['Q124608281'],
#   'sourozenectvo': ['Q64585041'],
#   'facebook': 'TysonFuryGypsyKing',
#   'twitter': 'Tyson_Fury',
#   'instagram': 'gypsyking101',
#   'web': 'https://tyson-fury.com/',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Tyson_Fury',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Tyson_Fury',
#   'jazykove_verze': ['uk',
#    'et',
#    'es',
#    'en',
#    'ko',
#    'vi',
#    'ro',
#    'ja',
#    'tr',
#    'bn',
#    'fa',
#    'nl',
#    'ru',
#    'fr',
#    'sv',
#    'fi',
#    'ar',
#    'pt',
#    'ga',
#    'cs',
#    'sl',
#    'zh',
#    'it',
#    'uz',
#    'simple',
#    'pl',
#    'th',
#    'kcg',
#    'he',
#    'no',
#    'da',
#    'bg',
#    'hr',
#    'hy',
#    'cy',
#    'de',
#    'arz']},
#  {'024_a': 'Q1000649',
#   'label_cs': 'András Ferkai',
#   'label_en': 'András Ferkai',
#   'popis_en': 'Hungarian architect',
#   'w_narozeni_presne': '+1953-06-07T00:00:00Z',
#   'w_narozeni': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q42973'],
#   'ceny': ['Q1466124', 'Q1220788'],
#   'jazykove_verze': ['hu', 'eo', 'arz']},
#  {'024_a': 'Q1000729',
#   'label_cs': 'Ferreira de Castro',
#   'label_en': 'José Maria Ferreira de Castro',
#   'popis_en': 'Portuguese writer and journalist',
#   'w_narozeni_presne': '+1898-05-24T00:00:00Z',
#   'w_umrti_presne': '+1974-06-29T00:00:00Z',
#   'w_narozeni': 1898,
#   'w_umrti': 1974,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q45'],
#   'w_misto_narozeni': ['Q18468715'],
#   'w_misto_umrti': ['Q36433'],
#   'pricina_umrti': 'Q3010352',
#   'profese': ['Q1930187', 'Q36180'],
#   'manzelstvo': ['Q123853170'],
#   'partnerstvo': ['Q122652621'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ferreira_de_Castro',
#   'jazykove_verze': ['gl',
#    'en',
#    'fr',
#    'fi',
#    'ro',
#    'eu',
#    'ru',
#    'it',
#    'uk',
#    'de',
#    'arz',
#    'ar',
#    'hu',
#    'pt',
#    'es']},
#  {'024_a': 'Q100090749',
#   'label_cs': 'Robin R. Means Coleman',
#   'label_en': 'Robin R. Means Coleman',
#   'popis_cs': 'Americká odbornice na komunikační studia, vysokoškolská učitelka, zaměřuje se na mediální studia, kulturní diverzitu a kulturní politiku černých, inkluzi, management vzdělávání; filmová producentka dokumentárního filmu "Horror Noire: A History of Bla',
#   'popis_en': 'American author, scholar and educator',
#   'w_narozeni_presne': '+1969-01-01T00:00:00Z',
#   'w_narozeni': 1969,
#   'w_gender': 'Q6581072',
#   'profese': ['Q28389', 'Q36180', 'Q3282637', 'Q462390', 'Q1622272'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Robin_R._Means_Coleman',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q1000985',
#   'label_cs': 'Milan Pacanda',
#   'label_en': 'Milan Pacanda',
#   'popis_cs': 'český fotbalista',
#   'popis_en': 'Czech football forward',
#   'w_narozeni_presne': '+1978-02-28T00:00:00Z',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q213'],
#   'w_misto_narozeni': ['Q146342'],
#   'profese': ['Q937857'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Milan_Pacanda',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Milan_Pacanda',
#   'jazykove_verze': ['arz', 'en', 'de', 'it', 'cs']},
#  {'024_a': 'Q1001',
#   'label_cs': 'Mahátma Gándhí',
#   'label_en': 'Mahatma Gandhi',
#   'popis_cs': 'indický politik',
#   'popis_en': 'Indian independence activist (1869–1948)',
#   'w_narozeni_presne': '+1869-10-02T00:00:00Z',
#   'w_umrti_presne': '+1948-01-30T00:00:00Z',
#   'w_narozeni': 1869,
#   'w_umrti': 1948,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q129286', 'Q1775277', 'Q668'],
#   'w_misto_narozeni': ['Q6419912'],
#   'w_misto_umrti': ['Q1381516'],
#   'druh_umrti': 'Q149086',
#   'pricina_umrti': 'Q2140674',
#   'vezeni': ['Q142534', 'Q2344976', 'Q142534', 'Q142534'],
#   'profese': ['Q82955',
#    'Q808967',
#    'Q15958642',
#    'Q1930187',
#    'Q4964182',
#    'Q18814623',
#    'Q11774202',
#    'Q17351648',
#    'Q1021386',
#    'Q11774156',
#    'Q22336956',
#    'Q16323111',
#    'Q3242115',
#    'Q36180',
#    'Q185351',
#    'Q30242234'],
#   'strany': ['Q10225'],
#   'skoly': ['Q4722851', 'Q1233784', 'Q193196', 'Q100148173'],
#   'ceny': ['Q207826', 'Q727815', 'Q2469664', 'Q6967959', 'Q2423226'],
#   'manzelstvo': ['Q264908'],
#   'sourozenectvo': ['Q100778818',
#    'Q100778893',
#    'Q100778902',
#    'Q100779061',
#    'Q100779088'],
#   'potomstvo': ['Q1390715', 'Q1280678', 'Q185403', 'Q732728'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Mah%C3%A1tma_G%C3%A1ndh%C3%AD',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Mahatma_Gandhi',
#   'jazykove_verze': ['bg',
#    'mt',
#    'ky',
#    'uk',
#    'ms',
#    'avk',
#    'gd',
#    'sw',
#    'id',
#    'kk',
#    'xmf',
#    'fr',
#    'li',
#    'be',
#    'ce',
#    'lmo',
#    'sr',
#    'ht',
#    'btm',
#    'bh',
#    'bs',
#    'zh-min-nan',
#    'ang',
#    'bcl',
#    'kab',
#    'sat',
#    'tpi',
#    'jv',
#    'nds',
#    'eu',
#    'pcd',
#    'tg',
#    'awa',
#    'rmy',
#    'ca',
#    'mg',
#    'ay',
#    'tt',
#    'gn',
#    'min',
#    'hi',
#    'bxr',
#    'ary',
#    'als',
#    'el',
#    'rue',
#    'gcr',
#    'fo',
#    'tly',
#    'dty',
#    'crh',
#    'scn',
#    'te',
#    'nl',
#    'frp',
#    'tr',
#    'diq',
#    'dtp',
#    'kaa',
#    'skr',
#    'sah',
#    'bpy',
#    'gan',
#    'co',
#    'ug',
#    'ckb',
#    'ia',
#    'ady',
#    'mzn',
#    'hy',
#    'qu',
#    'th',
#    'da',
#    'mr',
#    'pnb',
#    'es',
#    'cy',
#    'mk',
#    'tyv',
#    'ml',
#    'zh-yue',
#    'ur',
#    'hyw',
#    'ar',
#    'ceb',
#    'dsb',
#    'lo',
#    'so',
#    'sco',
#    'ha',
#    'anp',
#    'kw',
#    'tk',
#    'frr',
#    'lad',
#    'sd',
#    'war',
#    'am',
#    'he',
#    'su',
#    'wuu',
#    'mn',
#    'lt',
#    'kbd',
#    'no',
#    'mni',
#    'gom',
#    'pl',
#    'hr',
#    'hu',
#    'lb',
#    'ss',
#    'fi',
#    'pt',
#    'yi',
#    'sh',
#    'sk',
#    'sl',
#    'sa',
#    'tcy',
#    'kn',
#    'lv',
#    'azb',
#    'gu',
#    'oc',
#    'zh',
#    'vo',
#    'ru',
#    'ks',
#    'shi',
#    'et',
#    'pms',
#    'olo',
#    'ga',
#    'mhr',
#    'is',
#    'os',
#    'simple',
#    'br',
#    'eo',
#    'my',
#    'bjn',
#    'ilo',
#    'or',
#    'nn',
#    'cv',
#    'an',
#    'be-tarask',
#    'dv',
#    'de',
#    'sc',
#    'yo',
#    'ne',
#    'cs',
#    'uz',
#    'kbp',
#    'sv',
#    'fy',
#    'jam',
#    'xal',
#    'af',
#    'ba',
#    'vec',
#    'arz',
#    'ban',
#    'bn',
#    'ku',
#    'lfn',
#    'pap',
#    'vep',
#    'en',
#    'ka',
#    'ko',
#    'bat-smg',
#    'gl',
#    'ps',
#    'io',
#    'ja',
#    'pa',
#    'ast',
#    'vi',
#    'ln',
#    'lez',
#    'km',
#    'ts',
#    'az',
#    'si',
#    'it',
#    'zh-classical',
#    'hif',
#    'ta',
#    'as',
#    'sq',
#    'ro',
#    'tl',
#    'fiu-vro',
#    'la',
#    'mnw',
#    'mai',
#    'fa',
#    'new']},
#  {'024_a': 'Q1001077',
#   'label_cs': 'Sergej Vladimirovič Dikovskij',
#   'label_en': 'Sergey Dikovsky',
#   'popis_en': 'Soviet writer',
#   'w_narozeni_presne': '+1907-03-01T00:00:00Z',
#   'w_umrti_presne': '+1940-01-06T00:00:00Z',
#   'w_narozeni': 1907,
#   'w_umrti': 1940,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q34266', 'Q2305208', 'Q15180'],
#   'w_misto_narozeni': ['Q649'],
#   'w_misto_umrti': ['Q214054'],
#   'profese': ['Q36180', 'Q1930187', 'Q12144794'],
#   'ceny': ['Q960966'],
#   'jazykove_verze': ['fr', 'de', 'ru', 'fi']},
#  {'024_a': 'Q100114213',
#   'label_cs': 'Damian Duffy',
#   'label_en': 'Damian Duffy',
#   'popis_en': 'American comics artist',
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'profese': ['Q715301', 'Q109517242', 'Q17098559', 'Q1622272'],
#   'skoly': ['Q457281'],
#   'ceny': ['Q842614', 'Q110165665'],
#   'twitter': 'DamianD2Duffy',
#   'web': 'http://damianduffy.net',
#   'jazykove_verze': ['sv']},
#  {'024_a': 'Q100133408',
#   'label_cs': 'R. Z. Kobiela',
#   'w_narozeni_presne': '+1902-01-01T00:00:00Z',
#   'w_umrti_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q191793'],
#   'profese': ['Q193391', 'Q1930187', 'Q36180', 'Q23656820'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100138089',
#   'label_cs': 'John Jennings',
#   'label_en': 'John Jennings',
#   'popis_en': 'American illustrator (born 1970)',
#   'w_narozeni_presne': '+1970-00-00T00:00:00Z',
#   'w_narozeni': 1970,
#   'w_gender': 'Q6581097',
#   'profese': ['Q644687',
#    'Q109517242',
#    'Q17098559',
#    'Q3658608',
#    'Q5322166',
#    'Q19829999',
#    'Q1622272'],
#   'ceny': ['Q110165665'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100144439',
#   'label_cs': 'Ivan Medeši',
#   'label_en': 'Ivan Medeši',
#   'popis_cs': 'Rusínský básník a prozaik působící v Srbsku. Publikuje básně, povídky, fejetony i reportáže. Pracuje jako pomocný pedagog základní školy a gymnázia.',
#   'popis_en': 'poet and novelist',
#   'w_narozeni_presne': '+1982-01-12T00:00:00Z',
#   'w_narozeni': 1982,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q511216'],
#   'profese': ['Q36180',
#    'Q49757',
#    'Q12144794',
#    'Q1231865',
#    'Q82594',
#    'Q2070313'],
#   'ceny': ['Q9150528'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Ivan_Mede%C5%A1i',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100146632',
#   'label_cs': 'Salmá Samar Damlūjī',
#   'label_en': 'Salma Samar Damluji',
#   'popis_cs': 'Britsko-irácká architektka, vysokoškolská pedagožka, specializace na islámskou architekturu.',
#   'popis_en': 'Iraqi British architect, professor and author',
#   'w_narozeni_presne': '+1954-01-01T00:00:00Z',
#   'w_narozeni': 1954,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q3820'],
#   'profese': ['Q36180', 'Q42973', 'Q1622272'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Salma_Samar_Damluji',
#   'jazykove_verze': ['ar', 'en']},
#  {'024_a': 'Q100151669',
#   'label_cs': 'Stanislav Klika',
#   'label_en': 'Stanislav Klika',
#   'popis_cs': 'pražský novinář, spisovatel a nakladatel (1885-1942)',
#   'popis_en': 'Czech journalist, writer and publisher (1885-1942)',
#   'w_narozeni_presne': '+1885-00-00T00:00:00Z',
#   'w_umrti_presne': '+1942-06-18T00:00:00Z',
#   'w_narozeni': 1885,
#   'w_umrti': 1942,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q378120', 'Q1085'],
#   'w_misto_umrti': ['Q942842'],
#   'profese': ['Q36180',
#    'Q2516866',
#    'Q356139',
#    'Q12144794',
#    'Q6051619',
#    'Q3391743'],
#   'manzelstvo': ['Q106286463'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001547',
#   'label_cs': 'Hambye',
#   'label_en': 'Hambye',
#   'popis_cs': 'obec v departementu Manche ve Francii',
#   'popis_en': 'commune in Manche, France',
#   'facebook': 'hambye',
#   'web': 'http://www.hambye.fr',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Hambye',
#   'jazykove_verze': ['pms',
#    'sk',
#    'es',
#    'oc',
#    'sh',
#    'lld',
#    'ceb',
#    'vec',
#    'it',
#    'pl',
#    'eo',
#    'nl',
#    'eu',
#    'ms',
#    'ca',
#    'zh-min-nan',
#    'uz',
#    'en',
#    'ce',
#    'tt',
#    'kk',
#    'ro',
#    'vi',
#    'pt',
#    'bug',
#    'fi',
#    'hu',
#    'fr',
#    'diq',
#    'de',
#    'sv',
#    'el',
#    'la',
#    'sr',
#    'war',
#    'uk',
#    'fy',
#    'zh']},
#  {'024_a': 'Q100154933',
#   'label_cs': 'Thomas R. Sinclair',
#   'label_en': 'Thomas R. Sinclair',
#   'popis_cs': 'americký rostlinný fyziolog, vysokoškolský pedagog, zaměřený na fyziologii a ekologii rostlin, změny klimatu, vodu a rostlinnou výrobu',
#   'popis_en': '1944-',
#   'w_narozeni_presne': '+1944-01-01T00:00:00Z',
#   'w_narozeni': 1944,
#   'w_gender': 'Q6581097',
#   'profese': ['Q60244908', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1001591',
#   'label_cs': 'La Bernerie-en-Retz',
#   'label_en': 'La Bernerie-en-Retz',
#   'popis_cs': 'obec v departementu Loire-Atlantique ve Francii',
#   'popis_en': 'commune in Loire-Atlantique, France',
#   'web': 'http://www.mairie-labernerie.fr',
#   'wiki_en': 'https://en.wikipedia.org/wiki/La_Bernerie-en-Retz',
#   'jazykove_verze': ['vec',
#    'cy',
#    'la',
#    'bm',
#    'pt',
#    'it',
#    'de',
#    'ro',
#    'war',
#    'zh-min-nan',
#    'nl',
#    'nrm',
#    'ms',
#    'ast',
#    'ce',
#    'es',
#    'zh',
#    'br',
#    'mg',
#    'fr',
#    'ku',
#    'pms',
#    'sk',
#    'uk',
#    'tt',
#    'pl',
#    'sh',
#    'sl',
#    'ceb',
#    'hu',
#    'sr',
#    'vi',
#    'en',
#    'diq',
#    'lld',
#    'simple',
#    'oc',
#    'eo',
#    'ca',
#    'eu',
#    'vo',
#    'ur',
#    'sv']},
#  {'024_a': 'Q100163576',
#   'label_cs': 'Vasyl‘ Mychajlovyč Slobodjan',
#   'label_en': 'Vasyl Slobodian',
#   'popis_cs': 'ukrajinský historik zaměřený na sakrální architekturu, autor prací z oboru',
#   'popis_en': 'Ukrainian historian',
#   'w_narozeni_presne': '+1951-09-21T00:00:00Z',
#   'w_narozeni': 1951,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q212'],
#   'w_misto_narozeni': ['Q36036'],
#   'profese': ['Q201788', 'Q1595570', 'Q36180'],
#   'skoly': ['Q1817355'],
#   'ceny': ['Q12143927'],
#   'jazykove_verze': ['uk']},
#  {'024_a': 'Q1001716',
#   'label_cs': 'Leopold Fischer',
#   'label_en': 'Leopold Fischer',
#   'popis_cs': 'Jezuitský kněz a historik. Roku 1718 vstoupil do jezuitského řádu. Narozen 28. 3. 1703 ve Vídni, zemřel 11. 4. 1787 tamtéž.',
#   'w_narozeni_presne': '+1703-03-28T00:00:00Z',
#   'w_umrti_presne': '+1787-04-11T00:00:00Z',
#   'w_narozeni': 1703,
#   'w_umrti': 1787,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q153136'],
#   'w_misto_narozeni': ['Q1741'],
#   'w_misto_umrti': ['Q1741'],
#   'profese': ['Q250867', 'Q201788', 'Q432386', 'Q37226'],
#   'jazykove_verze': ['hu']},
#  {'024_a': 'Q100200',
#   'label_cs': 'Norbert Buske',
#   'label_en': 'Norbert Buske',
#   'popis_en': 'German politician and theologian',
#   'w_narozeni_presne': '+1936-01-02T00:00:00Z',
#   'w_umrti_presne': '+2023-10-20T00:00:00Z',
#   'w_narozeni': 1936,
#   'w_umrti': 2023,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183', 'Q16957'],
#   'w_misto_narozeni': ['Q50960'],
#   'profese': ['Q82955', 'Q1234713'],
#   'strany': ['Q49762'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Norbert_Buske',
#   'jazykove_verze': ['en', 'de', 'arz', 'pl']},
#  {'024_a': 'Q100207',
#   'label_cs': 'Marie Luise Droop',
#   'label_en': 'Marie Luise Droop',
#   'popis_en': 'German writer, director and producer (1890-1959)',
#   'w_narozeni_presne': '+1890-01-15T00:00:00Z',
#   'w_umrti_presne': '+1959-08-22T00:00:00Z',
#   'w_narozeni': 1890,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q393'],
#   'w_misto_umrti': ['Q505495'],
#   'profese': ['Q28389', 'Q3282637'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Marie_Luise_Droop',
#   'jazykove_verze': ['en', 'arz', 'de']},
#  {'024_a': 'Q100217',
#   'label_cs': 'Kareen Zebroff',
#   'label_en': 'Kareen Zebroff',
#   'popis_en': 'Canadian-based author, actor and television host specialising in yoga',
#   'w_narozeni_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q502441'],
#   'profese': ['Q947873'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Kareen_Zebroff',
#   'jazykove_verze': ['en', 'uz', 'arz', 'de']},
#  {'024_a': 'Q100233',
#   'label_cs': 'Udo Weilacher',
#   'label_en': 'Udo Weilacher',
#   'popis_en': 'German landscape architect, author and Professor for Landscape Architecture',
#   'w_narozeni_presne': '+1963-01-01T00:00:00Z',
#   'w_narozeni': 1963,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q3758'],
#   'profese': ['Q2815948', 'Q1622272'],
#   'skoly': ['Q157808'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Udo_Weilacher',
#   'jazykove_verze': ['arz', 'en', 'de']},
#  {'024_a': 'Q100243280'},
#  {'024_a': 'Q100267570',
#   'label_cs': 'Léon Carez',
#   'label_en': 'Léon Carez',
#   'w_narozeni_presne': '+1854-11-13T00:00:00Z',
#   'w_umrti_presne': '+1932-01-28T00:00:00Z',
#   'w_narozeni': 1854,
#   'w_umrti': 1932,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q2845753', 'Q90'],
#   'w_misto_umrti': ['Q1078086'],
#   'profese': ['Q520549', 'Q1734662', 'Q189010'],
#   'skoly': ['Q3064332'],
#   'ceny': ['Q10855271', 'Q56649459'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100267949',
#   'label_cs': 'Jacqueline Chénieux-Gendron',
#   'label_en': 'Jacqueline Chénieux-Gendron',
#   'popis_en': 'author',
#   'w_narozeni_presne': '+1939-11-19T00:00:00Z',
#   'w_umrti_presne': '+2022-09-01T00:00:00Z',
#   'w_narozeni': 1939,
#   'w_umrti': 2022,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q548924'],
#   'w_misto_umrti': ['Q169293'],
#   'profese': ['Q36180'],
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100269537',
#   'label_cs': 'Alice Travers',
#   'label_en': 'Alice Travers',
#   'popis_en': 'researcher',
#   'w_narozeni_presne': '+1979-05-02T00:00:00Z',
#   'w_narozeni': 1979,
#   'w_gender': 'Q6581072',
#   'profese': ['Q201788', 'Q1864603', 'Q1493121', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q1878600', 'Q999763', 'Q1394262', 'Q1430113', 'Q1394262'],
#   'ceny': ['Q3332320'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100272216',
#   'label_cs': 'Mìkalaj Mìkalajevìč Mjazha',
#   'label_en': 'Nikolaĭ Nikolaevich Mezga',
#   'popis_en': 'Belarusian historian',
#   'w_narozeni_presne': '+1965-05-31T00:00:00Z',
#   'w_narozeni': 1965,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q15180', 'Q184'],
#   'w_misto_narozeni': ['Q21659780'],
#   'profese': ['Q901', 'Q1622272', 'Q201788'],
#   'skoly': ['Q2630637'],
#   'jazykove_verze': ['be']},
#  {'024_a': 'Q100273554',
#   'label_cs': 'Johannes Kaspar',
#   'label_en': 'Johannes Kaspar',
#   'popis_cs': 'německý právník, advokát a vysokoškolský pedagog zaměřený na trestní právo hmotné a obchodní, nápravu a mediaci, právní a filozofické aspekty trestního práva, ústavní právo, teorii zločinu a na empirický výzkum sankcí',
#   'w_narozeni_presne': '+1976-01-01T00:00:00Z',
#   'w_narozeni': 1976,
#   'w_gender': 'Q6581097',
#   'profese': ['Q185351', 'Q1622272', 'Q40348'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100276619',
#   'label_cs': 'Christian Larsen',
#   'label_en': 'Christian Larsen',
#   'popis_cs': 'Narozen v r. 1956 v Basileji. Lékař.',
#   'w_narozeni_presne': '+1956-00-00T00:00:00Z',
#   'w_narozeni': 1956,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q39'],
#   'w_misto_narozeni': ['Q78'],
#   'profese': ['Q39631'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q1002810',
#   'label_cs': 'Imre Forbáth',
#   'label_en': 'Imre Forbáth',
#   'w_narozeni_presne': '+1898-11-17T00:00:00Z',
#   'w_umrti_presne': '+1967-05-16T00:00:00Z',
#   'w_narozeni': 1898,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q190522', 'Q855069'],
#   'w_misto_umrti': ['Q146342'],
#   'profese': ['Q49757', 'Q1930187', 'Q36180'],
#   'jazykove_verze': ['fr', 'hu']},
#  {'024_a': 'Q100282',
#   'label_cs': 'Reinhard Woltman',
#   'label_en': 'Reinhard Woltman',
#   'popis_en': 'hydraulic engineer from Germany',
#   'w_narozeni_presne': '+1757-01-01T00:00:00Z',
#   'w_umrti_presne': '+1837-01-01T00:00:00Z',
#   'w_narozeni': 1757,
#   'w_umrti': 1837,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q164079'],
#   'w_misto_narozeni': ['Q177362'],
#   'w_misto_umrti': ['Q1055'],
#   'profese': ['Q13582652', 'Q901', 'Q36180', 'Q978044'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Reinhard_Woltman',
#   'jazykove_verze': ['arz', 'fr', 'sv', 'de', 'en']},
#  {'024_a': 'Q100296521',
#   'label_cs': 'Paul Joseph Schulte',
#   'label_en': 'Paul J. Schulte',
#   'popis_en': 'forest science researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1650915'],
#   'skoly': ['Q219563', 'Q230492'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100301646',
#   'label_cs': 'Amy Ansehl',
#   'label_en': 'Amy Ansehl',
#   'popis_cs': 'Americká vysokoškolská profesorka a zdravotní sestra.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'profese': ['Q1622272', 'Q186360'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302130',
#   'label_cs': 'Noel Armenakas',
#   'label_en': 'Noel A. Armenakas',
#   'popis_cs': 'americký lékař, urolog, chirurg a vysokoškolský učitel, zaměřený na urologické operace, rekonstrukční chirurgii a úrazy',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581097',
#   'profese': ['Q17345122', 'Q774306', 'Q1622272'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302588',
#   'label_cs': 'Deborah Campbell',
#   'label_en': 'Deborah E. Campbell',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_gender': 'Q6581072',
#   'profese': ['Q28569455', 'Q1622272'],
#   'skoly': ['Q681025'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100302980',
#   'label_cs': 'James E. Cottrell',
#   'label_en': 'James E. Cottrell',
#   'popis_cs': 'americký anesteziolog a vysokoškolský pedagog zaměřený zejména na neuroanestezii',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni_presne': '+1942-01-01T00:00:00Z',
#   'w_narozeni': 1942,
#   'w_gender': 'Q6581097',
#   'profese': ['Q28837', 'Q1622272'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100303696'},
#  {'024_a': 'Q100304023',
#   'label_cs': 'Dennis Alexander',
#   'label_en': 'Dennis Alexander',
#   'popis_cs': 'Americký hudební skladatel a klavírista, učitel hry na klavír. Autor publikací z oboru.',
#   'popis_en': 'American composer',
#   'w_narozeni_presne': '+1947-12-10T00:00:00Z',
#   'w_narozeni': 1947,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q647127'],
#   'profese': ['Q36834', 'Q713200', 'Q16145150', 'Q639669', 'Q486748'],
#   'facebook': 'Dennis-Alexander-Music-136237939764680',
#   'web': 'http://dennisalexander.com/',
#   'jazykove_verze': ['fr']},
#  {'024_a': 'Q100308989',
#   'label_cs': 'Rodrick Wallace',
#   'label_en': 'Rodrick Wallace',
#   'popis_cs': 'Americký odborník v oblasti epidemiologie duševního zdraví, zabývá se dopady veřejné politiky, diskriminace a ekonomického úpadku na veřejné zdraví. Publikace v oboru.',
#   'popis_en': 'member or fellow of the New York Academy of Medicine',
#   'w_narozeni_presne': '+1941-01-01T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q100'],
#   'profese': ['Q12765408', 'Q901'],
#   'skoly': ['Q9008737'],
#   'ceny': ['Q46209064'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100312952',
#   'label_cs': 'Veronika Máková',
#   'label_en': 'Veronika Máková',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q593644', 'Q901'],
#   'skoly': ['Q1291752'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100314247',
#   'label_cs': 'John Collins',
#   'label_en': 'John W Collins',
#   'popis_cs': 'americký odborník na ošetřovatelství, ošetřovatelskou péči na konci života, multikulturní ošetřovatelství a vzdělávání zdravotních sester v této oblasti, vysokoškolský pedagog',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q1622272'],
#   'skoly': ['Q5316093'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100318248',
#   'label_cs': 'M. Iqbal R. Khan',
#   'label_en': 'M Iqbal R Khan',
#   'popis_cs': 'botanik, vysokoškolský pedagog a výzkumný pracovník se zaměřením na fyziologii a genomiku rostlin, rostlinný genom a fytohormony',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581097',
#   'profese': ['Q2374149', 'Q1622272', 'Q901'],
#   'skoly': ['Q196544'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100319915',
#   'label_cs': 'Eric Cervini',
#   'label_en': 'Eric Cervini',
#   'popis_cs': 'americký historik, zaměřený na problematiku LGBT',
#   'popis_en': 'American historian and writer',
#   'w_narozeni_presne': '+1992-01-01T00:00:00Z',
#   'w_narozeni': 1992,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q99'],
#   'profese': ['Q36180', 'Q201788'],
#   'skoly': ['Q14711406', 'Q13371'],
#   'ceny': ['Q121334212'],
#   'facebook': 'ericcervini',
#   'twitter': 'ericcervini',
#   'instagram': 'ericcervini',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Eric_Cervini',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100319998',
#   'label_cs': 'Ann Napolitano',
#   'label_en': 'Ann Napolitano',
#   'popis_cs': 'Americká spisovatelka, autorka románů a redaktorka. Dříve vysokoškolská lektorka tvůrčího psaní.',
#   'popis_en': 'American writer',
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180', 'Q1622272', 'Q876864'],
#   'twitter': 'napolitanoann',
#   'web': 'https://annnapolitano.com',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ann_Napolitano',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100324298',
#   'label_cs': 'Elwin Huaman',
#   'label_en': 'Elwin Huaman',
#   'popis_cs': 'peruánský počítačový vědec a vysokoškolský pedagog, působící v Rakousku, zaměřený na sémantický web, vědomostní grafy a data',
#   'popis_en': 'Peruvian computer scientist',
#   'w_narozeni_presne': '+1990-07-01T00:00:00Z',
#   'w_narozeni': 1990,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q419'],
#   'w_misto_narozeni': ['Q27194667'],
#   'profese': ['Q82594', 'Q1622272', 'Q1650915'],
#   'skoly': ['Q6156603', 'Q308963', 'Q2303432', 'Q875788'],
#   'sourozenectvo': ['Q115660783', 'Q115660896', 'Q115660799'],
#   'twitter': 'ElwinHuaman',
#   'web': 'http://elwin.huamanquispe.com/',
#   'jazykove_verze': []},
#  {'024_a': 'Q100324868',
#   'label_cs': 'Jana Bartošová',
#   'label_en': 'Jana Bartošová',
#   'popis_cs': 'česká historička a archivářka',
#   'w_narozeni_presne': '+1971-01-01T00:00:00Z',
#   'w_narozeni': 1971,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'profese': ['Q201788', 'Q635734'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100327408',
#   'label_cs': 'Bronisława Kokoszyńska',
#   'label_en': 'Bronisława Kokoszyńska',
#   'w_narozeni_presne': '+1897-01-01T00:00:00Z',
#   'w_umrti_presne': '+1959-01-01T00:00:00Z',
#   'w_narozeni': 1897,
#   'w_umrti': 1959,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q36'],
#   'w_misto_narozeni': ['Q1973720'],
#   'w_misto_umrti': ['Q31487'],
#   'profese': ['Q520549', 'Q1622272'],
#   'skoly': ['Q80207'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100333885',
#   'label_cs': 'Jaroslav Boukal',
#   'label_en': 'Jaroslav Boukal',
#   'popis_cs': '* 1902 Jeníkovice u Hradce Králové † ? ? JUDr.; vedoucí knihkupecký a nakladatelský pracovník.',
#   'w_narozeni_presne': '+1902-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q2024848'],
#   'profese': ['Q2516866', 'Q1607826', 'Q333634', 'Q185351'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100334014',
#   'label_cs': 'Bohuslav Kavka',
#   'label_en': 'Bohuslav Kavka',
#   'w_narozeni_presne': '+1869-00-00T00:00:00Z',
#   'w_umrti_presne': '+1914-05-04T00:00:00Z',
#   'w_narozeni': 1869,
#   'w_umrti': 1914,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q1085'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1607826', 'Q2516866'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348318',
#   'label_cs': 'Richard Lederer',
#   'label_en': 'Richard Lederer',
#   'popis_cs': 'Prof. dr. med., lékař, pediatr, vyučoval na vídeňské univerzitě, v roce 1938 emigroval do Bagdádu .',
#   'popis_en': 'pediatrician and university teacher',
#   'w_narozeni_presne': '+1885-06-11T00:00:00Z',
#   'w_umrti_presne': '+1941-00-00T00:00:00Z',
#   'w_narozeni': 1885,
#   'w_umrti': 1941,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q384544'],
#   'w_misto_umrti': ['Q1530'],
#   'profese': ['Q39631', 'Q1919436', 'Q1622272'],
#   'manzelstvo': ['Q113389335'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100348525',
#   'label_cs': 'Roberto Rea',
#   'label_en': 'Roberto Rea',
#   'popis_en': 'Italian philologist',
#   'w_narozeni_presne': '+1973-01-25T00:00:00Z',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q38'],
#   'w_misto_narozeni': ['Q116440'],
#   'profese': ['Q1622272', 'Q13418253'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003501',
#   'label_cs': 'András Frank',
#   'label_en': 'András Frank',
#   'popis_en': 'Hungarian mathematician',
#   'w_narozeni_presne': '+1949-06-03T00:00:00Z',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q1781'],
#   'profese': ['Q170790'],
#   'skoly': ['Q390287', 'Q369839'],
#   'ceny': ['Q1301832'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Andr%C3%A1s_Frank',
#   'jazykove_verze': ['eo', 'ar', 'de', 'arz', 'hu', 'pt', 'en']},
#  {'024_a': 'Q100353158',
#   'label_cs': 'Robert J. Callan',
#   'label_en': 'Robert J. Callan',
#   'popis_cs': 'veterinární lékař a vysokoškolský učitel, zaměřený na infekční nemoci hospodářských zvířat',
#   'popis_en': 'veterinary researcher at Colorado State University',
#   'w_gender': 'Q6581097',
#   'profese': ['Q202883', 'Q12119633', 'Q1622272'],
#   'skoly': ['Q838330'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100356218',
#   'label_cs': 'Caroline Campbell',
#   'label_en': 'Caroline Campbell',
#   'popis_en': 'British museum curator',
#   'w_narozeni_presne': '+1973-06-23T00:00:00Z',
#   'w_narozeni': 1973,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q27'],
#   'w_misto_narozeni': ['Q10686'],
#   'profese': ['Q674426', 'Q1792450'],
#   'skoly': ['Q734266', 'Q734266', 'Q34433'],
#   'twitter': 'campbell_c_m',
#   'instagram': 'carolinecampbelllondon',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Caroline_Campbell_(museum_director)',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100356308',
#   'label_cs': 'Byron Augustin',
#   'label_en': 'Byron Augustin',
#   'popis_en': 'Professor of geography',
#   'w_narozeni_presne': '+1941-00-00T00:00:00Z',
#   'w_narozeni': 1941,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q30'],
#   'w_misto_narozeni': ['Q959512'],
#   'profese': ['Q1622272', 'Q901402'],
#   'skoly': ['Q5680304', 'Q52413', 'Q1783608'],
#   'ceny': ['Q100351031', 'Q100355835'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100358334',
#   'label_cs': 'Ludvík Ratolístka',
#   'label_en': 'Ludvík Ratolístka',
#   'w_narozeni_presne': '+1886-00-00T00:00:00Z',
#   'w_umrti_presne': '+1953-00-00T00:00:00Z',
#   'w_narozeni': 1886,
#   'w_umrti': 1953,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q43453'],
#   'w_misto_umrti': ['Q1085'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003615',
#   'label_cs': 'Franz Josef Beranek',
#   'label_en': 'Franz Josef Beranek',
#   'popis_en': 'German university teacher and writer (1902-1967)',
#   'w_narozeni_presne': '+1902-08-08T00:00:00Z',
#   'w_umrti_presne': '+1967-08-11T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1967,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q581478'],
#   'w_misto_umrti': ['Q3874'],
#   'profese': ['Q1622272', 'Q36180', 'Q13418253', 'Q14467526', 'Q12347522'],
#   'strany': ['Q7320'],
#   'skoly': ['Q102398072', 'Q102398197', 'Q102398119'],
#   'jazykove_verze': ['hu', 'de']},
#  {'024_a': 'Q100366',
#   'label_cs': 'Wilhelm Herchenbach',
#   'label_en': 'Wilhelm Herchenbach',
#   'popis_en': 'German writer; author',
#   'w_narozeni_presne': '+1818-11-13T00:00:00Z',
#   'w_umrti_presne': '+1889-12-14T00:00:00Z',
#   'w_narozeni': 1818,
#   'w_umrti': 1889,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q43287'],
#   'w_misto_narozeni': ['Q254171'],
#   'w_misto_umrti': ['Q1718'],
#   'profese': ['Q36180'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Wilhelm_Herchenbach',
#   'jazykove_verze': ['de', 'en', 'arz']},
#  {'024_a': 'Q100375832',
#   'label_cs': 'Ronald Voullié',
#   'label_en': 'Ronald Voullié',
#   'popis_en': 'German translator (1952-2020)',
#   'w_narozeni_presne': '+1952-05-18T00:00:00Z',
#   'w_umrti_presne': '+2020-09-29T00:00:00Z',
#   'w_narozeni': 1952,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q24879'],
#   'profese': ['Q333634', 'Q2599593'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100378',
#   'label_cs': 'Valentin Triller',
#   'label_en': 'Valentin Triller',
#   'popis_cs': 'německý skladatel, duchovní a spisovatel',
#   'popis_en': 'German composer, parson and writer (1493-1579)',
#   'w_narozeni_presne': '+1493-01-01T00:00:00Z',
#   'w_umrti_presne': '+1579-00-00T00:00:00Z',
#   'w_narozeni': 1493,
#   'w_umrti': 1579,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q746395'],
#   'w_misto_umrti': ['Q389412'],
#   'profese': ['Q36834', 'Q955464', 'Q36180', 'Q96236305'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Valentin_Triller',
#   'jazykove_verze': ['cs', 'pl', 'no', 'de']},
#  {'024_a': 'Q100383505',
#   'label_cs': 'Helga Hipp',
#   'label_en': 'Helga Hipp',
#   'popis_cs': 'Německá germanistka, nederlandistka a vysokoškolská pedagožka.',
#   'w_narozeni_presne': '+1934-09-24T00:00:00Z',
#   'w_umrti_presne': '+1996-04-07T00:00:00Z',
#   'w_narozeni': 1934,
#   'w_umrti': 1996,
#   'w_gender': 'Q6581072',
#   'profese': ['Q2599593', 'Q19513109', 'Q1622272'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100383608',
#   'label_cs': 'Arnulf Rüssel',
#   'label_en': 'Arnulf Rüssel',
#   'w_narozeni_presne': '+1902-05-25T00:00:00Z',
#   'w_umrti_presne': '+1978-01-01T00:00:00Z',
#   'w_narozeni': 1902,
#   'w_umrti': 1978,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q247868'],
#   'profese': ['Q212980'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100383628',
#   'label_cs': 'Robert Schulz',
#   'label_en': 'Robert Wilhelm Schulz',
#   'w_narozeni_presne': '+1914-01-25T00:00:00Z',
#   'w_umrti_presne': '+2000-10-22T00:00:00Z',
#   'w_narozeni': 1914,
#   'w_umrti': 2000,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q16957'],
#   'w_misto_narozeni': ['Q518889'],
#   'profese': ['Q2306091'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100384019',
#   'label_cs': 'Jiří Myszak',
#   'label_en': 'Jiří Myszak',
#   'popis_cs': 'český akademický sochař',
#   'w_narozeni_presne': '+1925-03-02T00:00:00Z',
#   'w_umrti_presne': '+1990-04-07T00:00:00Z',
#   'w_narozeni': 1925,
#   'w_umrti': 1990,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q523489'],
#   'w_misto_umrti': ['Q8385'],
#   'profese': ['Q1281618'],
#   'skoly': ['Q414009'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Ji%C5%99%C3%AD_Myszak',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100384723',
#   'label_cs': 'Jaroslav Škarohlíd',
#   'label_en': 'Jaroslav Škarohlíd',
#   'popis_cs': 'malíř, grafik, ilustrátor',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni_presne': '+1925-01-24T00:00:00Z',
#   'w_umrti_presne': '+2012-10-15T00:00:00Z',
#   'w_narozeni': 1925,
#   'w_umrti': 2012,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100384811',
#   'label_cs': 'Jan Čech',
#   'label_en': 'Jan Cech',
#   'popis_cs': 'letecký mechanik, autor prací o letectví a kosmonautice',
#   'w_narozeni_presne': '+1950-00-00T00:00:00Z',
#   'w_narozeni': 1950,
#   'w_gender': 'Q6581097',
#   'profese': ['Q1430683', 'Q15980158'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100385831',
#   'label_cs': 'Vojtěch V. Sláma',
#   'label_en': 'Vojtech V. Sláma',
#   'popis_cs': 'český fotograf, člen skupiny Česká Paralaxa',
#   'w_narozeni_presne': '+1974-04-06T00:00:00Z',
#   'w_narozeni': 1974,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q14960'],
#   'profese': ['Q33231'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1003886',
#   'label_cs': 'Fričovce',
#   'label_en': 'Fričovce',
#   'popis_cs': 'obec na Slovensku v okrese Prešov',
#   'popis_en': 'municipality of Slovakia',
#   'web': 'https://www.obecfricovce.sk',
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Fri%C4%8Dovce',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Fri%C4%8Dovce',
#   'jazykove_verze': ['war',
#    'cs',
#    'es',
#    'eu',
#    'rue',
#    'nl',
#    'pl',
#    'hu',
#    'fr',
#    'sk',
#    'ce',
#    'ca',
#    'de',
#    'en',
#    'ms',
#    'zh-min-nan',
#    'uk',
#    'sh',
#    'it',
#    'tt',
#    'pt',
#    'sr',
#    'eo',
#    'ro']},
#  {'024_a': 'Q100390701',
#   'label_cs': 'Petr Řehoř',
#   'label_en': 'Petr Řehoř',
#   'popis_cs': 'výtvarník, malíř',
#   'popis_en': 'Czechoslovak painter',
#   'w_narozeni_presne': '+1949-04-26T00:00:00Z',
#   'w_narozeni': 1949,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q158275'],
#   'profese': ['Q1028181',
#    'Q1925963',
#    'Q780596',
#    'Q37226',
#    'Q33231',
#    'Q333634',
#    'Q1229025'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394177',
#   'label_cs': 'Sasan Saatchi',
#   'label_en': 'Sassan S Saatchi',
#   'popis_en': 'researcher',
#   'profese': ['Q1622272'],
#   'skoly': ['Q432637'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100394621',
#   'label_cs': 'Witold Jurasz',
#   'label_en': 'Witold Jurasz',
#   'popis_en': 'Polish journalist, diplomat',
#   'w_narozeni_presne': '+1975-07-20T00:00:00Z',
#   'w_narozeni': 1975,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q36'],
#   'profese': ['Q1930187', 'Q193391'],
#   'skoly': ['Q144488'],
#   'jazykove_verze': ['pl']},
#  {'024_a': 'Q100400535',
#   'label_cs': 'Yasemin Besen-Cassino',
#   'label_en': 'Yasemin Besen–Cassino',
#   'popis_en': 'American sociologist',
#   'w_narozeni_presne': '+1978-12-27T00:00:00Z',
#   'w_narozeni': 1978,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q406'],
#   'profese': ['Q2306091'],
#   'skoly': ['Q896267', 'Q969850'],
#   'manzelstvo': ['Q100752805'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Yasemin_Besen%E2%80%93Cassino',
#   'jazykove_verze': ['en']},
#  {'024_a': 'Q100406682',
#   'label_cs': 'Karolína Kamberská',
#   'label_en': 'Karolína Kamberská',
#   'popis_cs': 'česká písničkářka a autorka kuchařek',
#   'w_narozeni_presne': '+1972-00-00T00:00:00Z',
#   'w_narozeni': 1972,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q146307'],
#   'profese': ['Q488205', 'Q1495660'],
#   'skoly': ['Q31519'],
#   'manzelstvo': ['Q20057968'],
#   'wiki_cs': 'https://cs.wikipedia.org/wiki/Karol%C3%ADna_Kambersk%C3%A1',
#   'jazykove_verze': ['cs']},
#  {'024_a': 'Q100407335',
#   'label_cs': 'Rudolf Brož',
#   'label_en': 'Rudolf Brož',
#   'w_narozeni_presne': '+1880-00-00T00:00:00Z',
#   'w_umrti_presne': '+1939-12-31T00:00:00Z',
#   'w_narozeni': 1880,
#   'w_umrti': 1939,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q12034750'],
#   'w_misto_umrti': ['Q1085', 'Q662985'],
#   'profese': ['Q333634', 'Q2516866', 'Q82955'],
#   'skoly': ['Q12047389'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100411',
#   'label_cs': 'Ulrich Willerding',
#   'label_en': 'Ulrich Willerding',
#   'popis_en': 'American botanist (1932-2021)',
#   'w_narozeni_presne': '+1932-01-01T00:00:00Z',
#   'w_umrti_presne': '+2021-12-20T00:00:00Z',
#   'w_narozeni': 1932,
#   'w_umrti': 2021,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q518204'],
#   'w_misto_umrti': ['Q3033'],
#   'profese': ['Q3621491',
#    'Q4773904',
#    'Q2374149',
#    'Q1622272',
#    'Q32518759',
#    'Q30059961'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Ulrich_Willerding',
#   'jazykove_verze': ['en', 'de', 'arz']},
#  {'024_a': 'Q100415128',
#   'label_cs': 'Peter K. Lommatzsch',
#   'label_en': 'Peter Karl Lommatzsch',
#   'w_narozeni_presne': '+1934-12-20T00:00:00Z',
#   'w_umrti_presne': '+2020-11-23T00:00:00Z',
#   'w_narozeni': 1934,
#   'w_umrti': 2020,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q57782'],
#   'w_misto_umrti': ['Q2079'],
#   'profese': ['Q12013238', 'Q39631', 'Q1622272'],
#   'manzelstvo': ['Q106169513'],
#   'potomstvo': ['Q106166221'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004158',
#   'label_cs': 'Frédéric Eichhoff',
#   'label_en': 'Frédéric Eichhoff',
#   'popis_en': 'writer',
#   'w_narozeni_presne': '+1799-08-17T00:00:00Z',
#   'w_umrti_presne': '+1875-05-10T00:00:00Z',
#   'w_narozeni': 1799,
#   'w_umrti': 1875,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q142'],
#   'w_misto_narozeni': ['Q42810'],
#   'w_misto_umrti': ['Q245546', 'Q90'],
#   'profese': ['Q2251335', 'Q36180', 'Q13418253', 'Q14467526', 'Q1622272'],
#   'udalosti': ['Q201676'],
#   'ceny': ['Q10855271'],
#   'wiki_en': 'https://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ric_Eichhoff',
#   'jazykove_verze': ['hu', 'ru', 'fr', 'sv', 'en', 'da']},
#  {'024_a': 'Q100416047',
#   'label_cs': 'Marie Hovorková',
#   'label_en': 'Marie Hovorková',
#   'popis_cs': 'autorka knihy o alternativní léčbě, tzv. léčení vírou',
#   'w_narozeni_presne': '+1952-00-00T00:00:00Z',
#   'w_narozeni': 1952,
#   'w_gender': 'Q6581072',
#   'profese': ['Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100416283',
#   'label_cs': 'Thecla z Coudenhove',
#   'label_en': 'Thecla Coudenhove-Honrichs',
#   'popis_cs': 'česká šlechtična, manželka Františka Coudenhove-Honrichse (1865-1912), posledního majitele zámku Kunštát.',
#   'popis_en': 'writer',
#   'w_narozeni_presne': '+1865-05-31T00:00:00Z',
#   'w_umrti_presne': '+1933-03-27T00:00:00Z',
#   'w_narozeni': 1865,
#   'w_umrti': 1933,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1756960'],
#   'w_misto_umrti': ['Q1381784'],
#   'profese': ['Q36180'],
#   'manzelstvo': ['Q94933498'],
#   'potomstvo': ['Q94919745'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417561',
#   'label_cs': 'Václav Vaculovič',
#   'label_en': 'Václav Vaculovič',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni_presne': '+1957-01-01T00:00:00Z',
#   'w_narozeni': 1957,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946', 'Q213'],
#   'w_misto_narozeni': ['Q81137'],
#   'profese': ['Q1028181', 'Q1925963'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100417809',
#   'label_cs': 'Jan Mácha',
#   'label_en': 'Jan Mácha',
#   'popis_cs': 'český malíř',
#   'popis_en': 'Czech painter',
#   'w_narozeni_presne': '+1926-09-16T00:00:00Z',
#   'w_umrti_presne': '+1984-11-07T00:00:00Z',
#   'w_narozeni': 1926,
#   'w_umrti': 1984,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q33946'],
#   'w_misto_narozeni': ['Q1008696'],
#   'w_misto_umrti': ['Q1085'],
#   'profese': ['Q1028181', 'Q1925963', 'Q644687', 'Q6051619'],
#   'skoly': ['Q414009'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421384',
#   'label_cs': 'Anna Boog',
#   'label_en': 'Anna Boog',
#   'popis_en': "Austrian children's writer",
#   'w_narozeni_presne': '+1894-06-16T00:00:00Z',
#   'w_narozeni': 1894,
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q40'],
#   'w_misto_narozeni': ['Q39193'],
#   'profese': ['Q4853732'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100421794',
#   'label_cs': 'Miloslav Urban',
#   'label_en': 'Miloslav Urban',
#   'popis_cs': 'autor cestopisných vzpomínek',
#   'w_narozeni_presne': '+1932-00-00T00:00:00Z',
#   'w_umrti_presne': '+2010-00-00T00:00:00Z',
#   'w_narozeni': 1932,
#   'w_umrti': 2010,
#   'w_gender': 'Q6581097',
#   'profese': ['Q3579035'],
#   'jazykove_verze': []},
#  {'024_a': 'Q1004275',
#   'label_cs': 'Fridrich Jakub Fuker',
#   'label_en': 'Frigyes Jakab Fuker',
#   'popis_cs': 'německý lékař',
#   'popis_en': 'German physician',
#   'w_narozeni_presne': '+1748-01-01T00:00:00Z',
#   'w_umrti_presne': '+1805-01-01T00:00:00Z',
#   'w_narozeni': 1748,
#   'w_umrti': 1805,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'w_misto_narozeni': ['Q25409'],
#   'w_misto_umrti': ['Q304304'],
#   'profese': ['Q39631', 'Q897317', 'Q21771805', 'Q36180', 'Q901402', 'Q18805'],
#   'skoly': ['Q368998'],
#   'jazykove_verze': ['sk', 'hu']},
#  {'024_a': 'Q100429039',
#   'label_cs': 'Martina Mináriková',
#   'label_en': 'Martina Mináriková',
#   'popis_cs': 'slovenská šperkařka',
#   'popis_en': 'jewelry designer',
#   'w_narozeni_presne': '+1968-05-07T00:00:00Z',
#   'w_narozeni': 1968,
#   'w_gender': 'Q6581072',
#   'w_misto_narozeni': ['Q1780'],
#   'profese': ['Q336221', 'Q1281618', 'Q2519376'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100430173',
#   'label_cs': 'Otakar Mlejnek',
#   'label_en': 'Otakar Mlejnek',
#   'popis_cs': 'chirurg, lodní lékař, autor vzpomínek',
#   'w_narozeni_presne': '+1930-00-00T00:00:00Z',
#   'w_narozeni': 1930,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q63855'],
#   'profese': ['Q774306', 'Q325855', 'Q36180'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100433950',
#   'label_cs': 'Kurt Ziemke',
#   'label_en': 'Kurt Ziemke',
#   'popis_en': 'German diplomat',
#   'w_narozeni_presne': '+1888-01-02T00:00:00Z',
#   'w_umrti_presne': '+1965-07-18T00:00:00Z',
#   'w_narozeni': 1888,
#   'w_umrti': 1965,
#   'w_gender': 'Q6581097',
#   'w_misto_narozeni': ['Q41252'],
#   'profese': ['Q1136290'],
#   'strany': ['Q7320'],
#   'jazykove_verze': ['de']},
#  {'024_a': 'Q100443143',
#   'label_cs': 'Dana Ďuricová',
#   'label_en': 'Dana Duricova',
#   'popis_en': 'researcher',
#   'w_gender': 'Q6581072',
#   'profese': ['Q1650915'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100450',
#   'label_cs': 'Stephan Fridolin',
#   'label_en': 'Stephan Fridolin',
#   'popis_en': 'German Franciscan',
#   'w_narozeni_presne': '+1430-01-01T00:00:00Z',
#   'w_umrti_presne': '+1498-01-01T00:00:00Z',
#   'w_narozeni': 1430,
#   'w_umrti': 1498,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q183'],
#   'w_misto_narozeni': ['Q82741'],
#   'profese': ['Q36180', 'Q432386'],
#   'jazykove_verze': ['fr', 'de']},
#  {'024_a': 'Q1004517',
#   'label_cs': 'Samuel Fabry',
#   'label_en': 'Sámuel Fábri',
#   'w_narozeni_presne': '+1769-00-00T00:00:00Z',
#   'w_umrti_presne': '+1826-00-00T00:00:00Z',
#   'w_narozeni': 1769,
#   'w_umrti': 1826,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28'],
#   'profese': ['Q96236305',
#    'Q28319434',
#    'Q21591523',
#    'Q37226',
#    'Q333634',
#    'Q49757'],
#   'jazykove_verze': ['hu']},
#  {'024_a': 'Q1004532',
#   'label_cs': 'Zoltán Fábry',
#   'label_en': 'Zoltán Fábry',
#   'w_narozeni_presne': '+1897-08-10T00:00:00Z',
#   'w_umrti_presne': '+1970-05-31T00:00:00Z',
#   'w_narozeni': 1897,
#   'w_umrti': 1970,
#   'w_gender': 'Q6581097',
#   'obcanstvi': ['Q28', 'Q33946'],
#   'w_misto_narozeni': ['Q392547'],
#   'w_misto_umrti': ['Q392547'],
#   'profese': ['Q201788'],
#   'jazykove_verze': ['hu', 'sk', 'eo']},
#  {'024_a': 'Q100454750',
#   'label_cs': 'Koji Miura',
#   'label_en': 'Kōji Miura',
#   'popis_en': 'Japanese mangaka',
#   'w_gender': 'Q6581072',
#   'obcanstvi': ['Q17'],
#   'profese': ['Q191633', 'Q11892507', 'Q17098559'],
#   'twitter': 'Amzk0303',
#   'wiki_en': 'https://en.wikipedia.org/wiki/Kouji_Miura',
#   'jazykove_verze': ['zh', 'ja', 'en']},
#  {'024_a': 'Q100457406',
#   'label_cs': 'Chelsey A. Juarez',
#   'label_en': 'Chelsey Juarez',
#   'popis_en': 'researcher',
#   'profese': ['Q1650915'],
#   'skoly': ['Q108122', 'Q1047293', 'Q168756'],
#   'jazykove_verze': []},
#  {'024_a': 'Q100457421',
#   'label_cs': 'Amanda C. Cote',
#   'label_en': 'Amanda C Cote',
#   'popis_en': 'researcher',
#   'profese': ['Q1930187', 'Q1622272'],
#   'jazykove_verze': []}]

# %%
import sys
sys.getsizeof(medailony)
# Out:
# 1140568

# %%
text = "text"
sys.getsizeof(text)
# Out:
# 45

# %%
df = pd.read_json(os.path.join("data_raw","autority_wikidataids.json")).reset_index(drop=False)

# %%
df
# Out:
#                  index       024_a
# 0           jk01010005    Q1063371
# 1           jk01010022   Q12028104
# 2           jk01010023     Q640512
# 3           jk01010026   Q12055885
# 4           jk01010030     Q634048
# ...                ...         ...
# 131824   zmp2016925673   Q13582412
# 131825   zmp2016925675  Q112503439
# 131826  zmp20191037071   Q26208443
# 131827  zmp20191054500     Q825192
# 131828  zmp20211116840  Q107140306
#
# [131829 rows x 2 columns]

# %%
df = df.merge(pd.DataFrame(medailony), on='024_a').set_index('index')

# %%
df.sample(20)
# Out:
#                      024_a                        label_cs  \
# index
# jn19981000883    Q95176379                   Václav Dvořák
# jk01011594       Q95069178                  Jaroslav Beneš
# ola20201087977  Q120610822                    Míša Landová
# jk01130360       Q95437690                 Vilém Škovránek
# jn20000401952    Q95106644                Miroslav Pařízek
# xx0254251        Q55287077                   Vavrinecz Mór
# ola2006357415      Q112087               Herbert Friedrich
# jo20231172670     Q6923845                    Boris Lekar‘
# ola2012699792      Q888518                     Bobby Doerr
# jcu2012676901    Q59531270                    Josef Grisar
# mub20231209627  Q110597895                  Pierre Sanchez
# xx0073631       Q120580684                       Karel Hon
# jk01033340       Q11904669                Vladimír Hanačík
# xx0021432        Q89139546             Christiane Northrup
# jo20201094824     Q1966404             Nathela Iankhošvili
# xx0313786        Q95388779                      Aimé Patri
# jk01062117       Q95388713                   Eva Kotarbová
# xx0266692        Q19602383  Marie Karolína Josefa Šporková
# jk01032309      Q109877721                   Vilém Gampert
# jk01103431       Q12036881                     Miki Ryvola
#
#                                  label_en  \
# index
# jn19981000883               Václav Dvořák
# jk01011594                 Jaroslav Beneš
# ola20201087977               Míša Landová
# jk01130360                Vilém Škovránek
# jn20000401952            Miroslav Pařízek
# xx0254251                   Mór Vavrinecz
# ola2006357415           Herbert Friedrich
# jo20231172670                 Boris Lekar
# ola2012699792                 Bobby Doerr
# jcu2012676901                Josef Grisar
# mub20231209627             Pierre Sanchez
# xx0073631                       Karel Hon
# jk01033340               Vladimír Hanačík
# xx0021432             Christiane Northrup
# jo20201094824          Natela Iankoshvili
# xx0313786                      Aimé Patri
# jk01062117                  Eva Kotarbová
# xx0266692       Maria Carolina von Sporck
# jk01032309                  Vilém Gampert
# jk01103431                    Miki Ryvola
#
#                                                          popis_en  \
# index
# jn19981000883                                                 NaN
# jk01011594                                                    NaN
# ola20201087977                                                NaN
# jk01130360                                                    NaN
# jn20000401952                                                 NaN
# xx0254251                           Hungarian composer, chorister
# ola2006357415                                       German writer
# jo20231172670                       an Israeli artist (1932-2010)
# ola2012699792                        Major League Baseball player
# jcu2012676901   born:1886-11-21|died:1967-08-08|; Grisar, Jose...
# mub20231209627                       French art historian (1963-)
# xx0073631                                                     NaN
# jk01033340                         Czech politician and economist
# xx0021432                           American physician and author
# jo20201094824                        Georgian painter (1918-2007)
# xx0313786                                                     NaN
# jk01062117                              Czech poet and journalist
# xx0266692                                             (1752-1799)
# jk01032309                                                    NaN
# jk01103431                   Czech composer, guitarist and singer
#
#                     w_narozeni_presne         w_umrti_presne  w_narozeni  \
# index
# jn19981000883   +1941-10-08T00:00:00Z                    NaN      1941.0
# jk01011594      +1929-11-12T00:00:00Z                    NaN      1929.0
# ola20201087977                    NaN                    NaN         NaN
# jk01130360      +1914-01-10T00:00:00Z  +1982-06-02T00:00:00Z      1914.0
# jn20000401952   +1898-01-11T00:00:00Z  +1979-11-09T00:00:00Z      1898.0
# xx0254251       +1858-07-18T00:00:00Z  +1913-08-16T00:00:00Z      1858.0
# ola2006357415   +1926-08-07T00:00:00Z                    NaN      1926.0
# jo20231172670   +1932-10-28T00:00:00Z  +2010-10-30T00:00:00Z      1932.0
# ola2012699792   +1918-04-07T00:00:00Z  +2017-11-13T00:00:00Z      1918.0
# jcu2012676901   +1886-11-21T00:00:00Z  +1967-08-08T00:00:00Z      1886.0
# mub20231209627  +1963-08-20T00:00:00Z                    NaN      1963.0
# xx0073631                         NaN                    NaN         NaN
# jk01033340      +1861-11-23T00:00:00Z  +1954-01-11T00:00:00Z      1861.0
# xx0021432       +1949-10-04T00:00:00Z                    NaN      1949.0
# jo20201094824   +1918-08-28T00:00:00Z  +2008-10-12T00:00:00Z      1918.0
# xx0313786       +1904-08-18T00:00:00Z  +1983-07-18T00:00:00Z      1904.0
# jk01062117      +1948-12-24T00:00:00Z                    NaN      1948.0
# xx0266692       +1752-08-15T00:00:00Z  +1799-09-18T00:00:00Z      1752.0
# jk01032309      +1902-06-29T00:00:00Z  +1987-03-14T00:00:00Z      1902.0
# jk01103431      +1942-04-12T00:00:00Z                    NaN      1942.0
#
#                 w_umrti  w_gender obcanstvi  w_misto_narozeni w_misto_umrti  \
# index
# jn19981000883       NaN  Q6581097       NaN          [Q14960]           NaN
# jk01011594          NaN  Q6581097       NaN        [Q1632616]           NaN
# ola20201087977      NaN  Q6581072       NaN               NaN           NaN
# jk01130360       1982.0  Q6581097       NaN         [Q765513]           NaN
# jn20000401952    1979.0  Q6581097  [Q33946]         [Q161513]      [Q14960]
# xx0254251        1913.0  Q6581097     [Q28]         [Q214948]       [Q1781]
# ola2006357415       NaN  Q6581097    [Q183]         [Q227206]           NaN
# jo20231172670    2010.0  Q6581097    [Q801]          [Q42308]       [Q1218]
# ola2012699792    2017.0  Q6581097     [Q30]             [Q65]    [Q2793345]
# jcu2012676901    1967.0  Q6581097       NaN           [Q3104]     [Q131605]
# mub20231209627      NaN  Q6581097    [Q142]               NaN           NaN
# xx0073631           NaN       NaN       NaN               NaN           NaN
# jk01033340       1954.0  Q6581097  [Q33946]          [Q14960]       [Q1085]
# xx0021432           NaN  Q6581072       NaN               NaN           NaN
# jo20201094824    2008.0  Q6581072    [Q230]        [Q1011047]           NaN
# xx0313786        1983.0  Q6581097       NaN               NaN         [Q90]
# jk01062117          NaN  Q6581072    [Q213]  [Q8385, Q733581]           NaN
# xx0266692        1799.0  Q6581072       NaN           [Q1085]       [Q1085]
# jk01032309       1987.0  Q6581097       NaN           [Q1085]       [Q1085]
# jk01103431          NaN  Q6581097    [Q213]         [Q155993]           NaN
#
#                                                           profese  \
# index
# jn19981000883                                    [Q901, Q1231865]
# jk01011594                                                    NaN
# ola20201087977                             [Q25936100, Q60118864]
# jk01130360                                              [Q651566]
# jn20000401952                                                 NaN
# xx0254251                 [Q36834, Q84206977, Q158852, Q16145150]
# ola2006357415                                            [Q36180]
# jo20231172670                        [Q1028181, Q1281618, Q42973]
# ola2012699792                                         [Q10871364]
# jcu2012676901                                          [Q3400985]
# mub20231209627                                         [Q1792450]
# xx0073631                                                     NaN
# jk01033340                                              [Q188094]
# xx0021432                 [Q39631, Q482980, Q29887242, Q29881694]
# jo20201094824                                [Q1028181, Q3391743]
# xx0313786                                                     NaN
# jk01062117      [Q37226, Q182436, Q49757, Q1930187, Q876864, Q...
# xx0266692                                                     NaN
# jk01032309                        [Q18524037, Q182436, Q10429346]
# jk01103431      [Q36834, Q855091, Q177220, Q7541856, Q639669, ...
#
#                                 ceny  \
# index
# jn19981000883                    NaN
# jk01011594                       NaN
# ola20201087977                   NaN
# jk01130360                       NaN
# jn20000401952                    NaN
# xx0254251                        NaN
# ola2006357415              [Q531586]
# jo20231172670            [Q97384614]
# ola2012699792             [Q4948047]
# jcu2012676901                    NaN
# mub20231209627                   NaN
# xx0073631                        NaN
# jk01033340                       NaN
# xx0021432                        NaN
# jo20201094824   [Q240219, Q59717867]
# xx0313786                        NaN
# jk01062117                       NaN
# xx0266692                        NaN
# jk01032309                       NaN
# jk01103431               [Q65924278]
#
#                                                    jazykove_verze  \
# index
# jn19981000883                                                  []
# jk01011594                                                     []
# ola20201087977                                                 []
# jk01130360                                                     []
# jn20000401952                                                  []
# xx0254251                                            [hu, eo, en]
# ola2006357415                                        [de, cs, ja]
# jo20231172670                                            [en, he]
# ola2012699792   [ar, zh, ko, pt, simple, arz, fi, fr, pl, it, ...
# jcu2012676901                                                [de]
# mub20231209627                                                 []
# xx0073631                                                      []
# jk01033340                                               [de, cs]
# xx0021432                                            [en, no, ml]
# jo20201094824                [hy, de, ka, pl, mk, cy, ru, bs, en]
# xx0313786                                                      []
# jk01062117                                                   [cs]
# xx0266692                                                    [cs]
# jk01032309                                                     []
# jk01103431                                                   [cs]
#
#                                                          popis_cs  \
# index
# jn19981000883   Narozen 8.10.1941 v Brně. Prof., Ing., DrSc., ...
# jk01011594      Narozen 12.11.1929 v Počátkách. RNDr. CSc., do...
# ola20201087977  foodblogerka, lektorka cukrářských kruzů, auto...
# jk01130360      Narozen 10.1.1914 v Závadě u Opavy, zemřel 2.6...
# jn20000401952   Narozen 11.1.1898 v Tišnově, zemřel 9.11.1979 ...
# xx0254251                                                     NaN
# ola2006357415                                  německý spisovatel
# jo20231172670                                                 NaN
# ola2012699792                                                 NaN
# jcu2012676901                                                 NaN
# mub20231209627                          francouzský kunsthistorik
# xx0073631       spoluautor učebních textů pro výuku češtiny, u...
# jk01033340                                 český politik a ekonom
# xx0021432                                                     NaN
# jo20201094824                                   gruzínská malířka
# xx0313786       Francouzský historik, specialista na soudobé d...
# jk01062117      česká učitelka, knihovnice, básnířka, novinářk...
# xx0266692       Narozena 15. 8. 1752 v Praze, zemřela 18. 9. 1...
# jk01032309                                                    NaN
# jk01103431            český hudební skladatel, kytarista a zpěvák
#
#                                                           wiki_cs  \
# index
# jn19981000883                                                 NaN
# jk01011594                                                    NaN
# ola20201087977                                                NaN
# jk01130360                                                    NaN
# jn20000401952                                                 NaN
# xx0254251                                                     NaN
# ola2006357415     https://cs.wikipedia.org/wiki/Herbert_Friedrich
# jo20231172670                                                 NaN
# ola2012699792                                                 NaN
# jcu2012676901                                                 NaN
# mub20231209627                                                NaN
# xx0073631                                                     NaN
# jk01033340      https://cs.wikipedia.org/wiki/Vladim%C3%ADr_Ha...
# xx0021432                                                     NaN
# jo20201094824                                                 NaN
# xx0313786                                                     NaN
# jk01062117       https://cs.wikipedia.org/wiki/Eva_Kotarbov%C3%A1
# xx0266692       https://cs.wikipedia.org/wiki/Marie_Karol%C3%A...
# jk01032309                                                    NaN
# jk01103431              https://cs.wikipedia.org/wiki/Miki_Ryvola
#
#                                                           wiki_en druh_umrti  \
# index
# jn19981000883                                                 NaN        NaN
# jk01011594                                                    NaN        NaN
# ola20201087977                                                NaN        NaN
# jk01130360                                                    NaN        NaN
# jn20000401952                                                 NaN        NaN
# xx0254251        https://en.wikipedia.org/wiki/M%C3%B3r_Vavrinecz        NaN
# ola2006357415                                                 NaN        NaN
# jo20231172670           https://en.wikipedia.org/wiki/Boris_Lekar        NaN
# ola2012699792           https://en.wikipedia.org/wiki/Bobby_Doerr        NaN
# jcu2012676901                                                 NaN        NaN
# mub20231209627                                                NaN        NaN
# xx0073631                                                     NaN        NaN
# jk01033340                                                    NaN        NaN
# xx0021432       https://en.wikipedia.org/wiki/Christiane_Northrup        NaN
# jo20201094824    https://en.wikipedia.org/wiki/Natela_Iankoshvili        NaN
# xx0313786                                                     NaN        NaN
# jk01062117                                                    NaN        NaN
# xx0266692                                                     NaN        NaN
# jk01032309                                                    NaN        NaN
# jk01103431                                                    NaN        NaN
#
#                pricina_umrti vezeni strany                     skoly  \
# index
# jn19981000883            NaN    NaN    NaN                       NaN
# jk01011594               NaN    NaN    NaN                       NaN
# ola20201087977           NaN    NaN    NaN                       NaN
# jk01130360               NaN    NaN    NaN                 [Q163164]
# jn20000401952            NaN    NaN    NaN                       NaN
# xx0254251                NaN    NaN    NaN                       NaN
# ola2006357415            NaN    NaN    NaN                       NaN
# jo20231172670            NaN    NaN    NaN                       NaN
# ola2012699792            NaN    NaN    NaN                [Q6224415]
# jcu2012676901            NaN    NaN    NaN                       NaN
# mub20231209627           NaN    NaN    NaN                       NaN
# xx0073631                NaN    NaN    NaN                       NaN
# jk01033340               NaN    NaN    NaN                       NaN
# xx0021432                NaN    NaN    NaN                       NaN
# jo20201094824            NaN    NaN    NaN                       NaN
# xx0313786                NaN    NaN    NaN                       NaN
# jk01062117               NaN    NaN    NaN               [Q12044520]
# xx0266692                NaN    NaN    NaN                       NaN
# jk01032309               NaN    NaN    NaN  [Q102398072, Q102398197]
# jk01103431               NaN    NaN    NaN                       NaN
#
#                  manzelstvo partnerstvo  \
# index
# jn19981000883           NaN         NaN
# jk01011594              NaN         NaN
# ola20201087977          NaN         NaN
# jk01130360              NaN         NaN
# jn20000401952           NaN         NaN
# xx0254251               NaN         NaN
# ola2006357415           NaN         NaN
# jo20231172670           NaN         NaN
# ola2012699792           NaN         NaN
# jcu2012676901           NaN         NaN
# mub20231209627          NaN         NaN
# xx0073631               NaN         NaN
# jk01033340              NaN         NaN
# xx0021432               NaN         NaN
# jo20201094824           NaN         NaN
# xx0313786               NaN         NaN
# jk01062117              NaN         NaN
# xx0266692       [Q12031491]         NaN
# jk01032309              NaN         NaN
# jk01103431              NaN         NaN
#
#                                                     potomstvo sourozenectvo  \
# index
# jn19981000883                                             NaN           NaN
# jk01011594                                                NaN           NaN
# ola20201087977                                            NaN           NaN
# jk01130360                                                NaN           NaN
# jn20000401952                                             NaN           NaN
# xx0254251                                                 NaN           NaN
# ola2006357415                                             NaN           NaN
# jo20231172670                                             NaN           NaN
# ola2012699792                                             NaN           NaN
# jcu2012676901                                             NaN           NaN
# mub20231209627                                            NaN           NaN
# xx0073631                                                 NaN           NaN
# jk01033340                                                NaN           NaN
# xx0021432                                                 NaN           NaN
# jo20201094824                                             NaN           NaN
# xx0313786                                                 NaN           NaN
# jk01062117                                                NaN           NaN
# xx0266692       [Q1079174, Q55882336, Q100154040, Q110456146]           NaN
# jk01032309                                                NaN           NaN
# jk01103431                                                NaN   [Q10838340]
#
#                             facebook          twitter instagram  \
# index
# jn19981000883                    NaN              NaN       NaN
# jk01011594                       NaN              NaN       NaN
# ola20201087977                   NaN              NaN       NaN
# jk01130360                       NaN              NaN       NaN
# jn20000401952                    NaN              NaN       NaN
# xx0254251                        NaN              NaN       NaN
# ola2006357415                    NaN              NaN       NaN
# jo20231172670                    NaN              NaN       NaN
# ola2012699792                    NaN              NaN       NaN
# jcu2012676901                    NaN              NaN       NaN
# mub20231209627                   NaN              NaN       NaN
# xx0073631                        NaN              NaN       NaN
# jk01033340                       NaN              NaN       NaN
# xx0021432       DrChristianeNorthrup  DrChrisNorthrup       NaN
# jo20201094824                    NaN              NaN       NaN
# xx0313786                        NaN              NaN       NaN
# jk01062117                       NaN              NaN       NaN
# xx0266692                        NaN              NaN       NaN
# jk01032309                       NaN              NaN       NaN
# jk01103431                       NaN              NaN       NaN
#
#                                         web udalosti role
# index
# jn19981000883                           NaN      NaN  NaN
# jk01011594                              NaN      NaN  NaN
# ola20201087977  https://vikendovepeceni.cz/      NaN  NaN
# jk01130360                              NaN      NaN  NaN
# jn20000401952                           NaN      NaN  NaN
# xx0254251                               NaN      NaN  NaN
# ola2006357415                           NaN      NaN  NaN
# jo20231172670                           NaN      NaN  NaN
# ola2012699792                           NaN      NaN  NaN
# jcu2012676901                           NaN      NaN  NaN
# mub20231209627                          NaN      NaN  NaN
# xx0073631                               NaN      NaN  NaN
# jk01033340                              NaN      NaN  NaN
# xx0021432       https://www.drnorthrup.com/      NaN  NaN
# jo20201094824                           NaN      NaN  NaN
# xx0313786                               NaN      NaN  NaN
# jk01062117                              NaN      NaN  NaN
# xx0266692                               NaN      NaN  NaN
# jk01032309                              NaN      NaN  NaN
# jk01103431                              NaN      NaN  NaN

# %%
df[df.index == 'Q93240837']
# Out:
# Empty DataFrame
# Columns: [024_a, label_cs, label_en, popis_en, w_narozeni_presne, w_umrti_presne, w_narozeni, w_umrti, w_gender, obcanstvi, w_misto_narozeni, w_misto_umrti, profese, ceny, jazykove_verze, popis_cs, wiki_cs, wiki_en, druh_umrti, pricina_umrti, vezeni, strany, skoly, manzelstvo, partnerstvo, potomstvo, sourozenectvo, facebook, twitter, instagram, web, udalosti, role]
# Index: []

# %%
df[df['024_a'] == 'Q571203']
# Out:
#               024_a       label_cs       label_en  \
# index
# jk01100136  Q571203  Karel Poláček  Karel Poláček
#
#                                                      popis_en  \
# index
# jk01100136  Czech humorist, publicist, bookwriter, scriptw...
#
#                 w_narozeni_presne         w_umrti_presne  w_narozeni  w_umrti  \
# index
# jk01100136  +1892-03-22T00:00:00Z  +1945-01-21T00:00:00Z      1892.0   1945.0
#
#             w_gender          obcanstvi w_misto_narozeni  \
# index
# jk01100136  Q6581097  [Q533534, Q33946]       [Q1000091]
#
#                       w_misto_umrti  \
# index
# jk01100136  [Q105084, Q7342, Q7341]
#
#                                                    profese         ceny  \
# index
# jk01100136  [Q36180, Q28389, Q1930187, Q69423232, Q876864]  [Q42794387]
#
#                                            jazykove_verze  \
# index
# jk01100136  [it, de, fa, eo, cs, arz, en, fr, ru, uk, sk]
#
#                                                      popis_cs  \
# index
# jk01100136  český humorista, novinář, romanopisec, scenári...
#
#                                                       wiki_cs  \
# index
# jk01100136  https://cs.wikipedia.org/wiki/Karel_Pol%C3%A1%...
#
#                                                       wiki_en druh_umrti  \
# index
# jk01100136  https://en.wikipedia.org/wiki/Karel_Pol%C3%A1%...        NaN
#
#            pricina_umrti              vezeni strany        skoly  \
# index
# jk01100136           NaN  [Q7341, Q15111616]    NaN  [Q12047389]
#
#               manzelstvo  partnerstvo potomstvo             sourozenectvo  \
# index
# jk01100136  [Q105573892]  [Q95459535]       NaN  [Q105573905, Q105574064]
#
#            facebook twitter instagram  web                           udalosti  \
# index
# jk01100136      NaN     NaN       NaN  NaN  [Q5883980, Q104055388, Q76358503]
#
#                   role
# index
# jk01100136  [Q5883980]

# %%
df[df['024_a'] == 'Q16861736']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                    w_narozeni_presne w_umrti_presne  w_narozeni  w_umrti  \
# index
# jx20100301005  +1984-01-16T00:00:00Z            NaN      1984.0      NaN
#
#                w_gender obcanstvi w_misto_narozeni w_misto_umrti  \
# index
# jx20100301005  Q6581097    [Q213]         [Q14960]           NaN
#
#                                                       profese ceny  \
# index
# jx20100301005  [Q36180, Q1930187, Q6051619, Q822146, Q333634]  NaN
#
#               jazykove_verze          popis_cs  \
# index
# jx20100301005           [cs]  český publicista
#
#                                                          wiki_cs wiki_en  \
# index
# jx20100301005  https://cs.wikipedia.org/wiki/Michal_Ka%C5%A1p...     NaN
#
#               druh_umrti pricina_umrti vezeni strany      skoly manzelstvo  \
# index
# jx20100301005        NaN           NaN    NaN    NaN  [Q763586]        NaN
#
#               partnerstvo potomstvo sourozenectvo  facebook   twitter  \
# index
# jx20100301005         NaN       NaN           NaN  kasparek  kasparek
#
#                             instagram                            web udalosti  \
# index
# jx20100301005  jakovzdynaprostopresny  http://www.michalkasparek.cz/      NaN
#
#               role
# index
# jx20100301005  NaN

# %%
df[df.index == 'jx20100301005']
# Out:
#                    024_a         label_cs         label_en         popis_en  \
# index
# jx20100301005  Q16861736  Michal Kašpárek  Michal Kašpárek  Czech publicist
#
#                    w_narozeni_presne w_umrti_presne  w_narozeni  w_umrti  \
# index
# jx20100301005  +1984-01-16T00:00:00Z            NaN      1984.0      NaN
#
#                w_gender obcanstvi w_misto_narozeni w_misto_umrti  \
# index
# jx20100301005  Q6581097    [Q213]         [Q14960]           NaN
#
#                                                       profese ceny  \
# index
# jx20100301005  [Q36180, Q1930187, Q6051619, Q822146, Q333634]  NaN
#
#               jazykove_verze          popis_cs  \
# index
# jx20100301005           [cs]  český publicista
#
#                                                          wiki_cs wiki_en  \
# index
# jx20100301005  https://cs.wikipedia.org/wiki/Michal_Ka%C5%A1p...     NaN
#
#               druh_umrti pricina_umrti vezeni strany      skoly manzelstvo  \
# index
# jx20100301005        NaN           NaN    NaN    NaN  [Q763586]        NaN
#
#               partnerstvo potomstvo sourozenectvo  facebook   twitter  \
# index
# jx20100301005         NaN       NaN           NaN  kasparek  kasparek
#
#                             instagram                            web udalosti  \
# index
# jx20100301005  jakovzdynaprostopresny  http://www.michalkasparek.cz/      NaN
#
#               role
# index
# jx20100301005  NaN

# %%
df.sample(10)
# Out:
#                      024_a                           label_cs  \
# index
# xx0194560       Q120594118                       Elena Brower
# mzk2004221744      Q123507                   Jean Starobinski
# xx0173748       Q112467652  Aleksej Aleksandrovič Jefremenkov
# mub20231208469   Q62090796                     Edmund Russell
# jk01102397        Q3184053                        Josef Režný
# js20221152286    Q85998228       Mychajlo Vasyl‘ovyč Romanjuk
# xx0322810        Q93241001       Anders Klostergaard Petersen
# mzk2002173688   Q112374726                       Alois Kubový
# jn20000720077      Q691855     Maxmilián Josef Sommerau-Beckh
# mub20231178654   Q95209577                                NaN
#
#                                                        label_en  \
# index
# xx0194560                                          Elena Brower
# mzk2004221744                                  Jean Starobinski
# xx0173748                                   Aleksey Yefremenkov
# mub20231208469                                   Edmund Russell
# jk01102397                                          Josef Režný
# js20221152286                                               NaN
# xx0322810                          Anders Klostergaard Petersen
# mzk2002173688                                      Alois Kubový
# jn20000720077   Maximilian Joseph Gottfried von Sommerau Beeckh
# mub20231178654                                              NaN
#
#                                          popis_en      w_narozeni_presne  \
# index
# xx0194560                                     NaN                    NaN
# mzk2004221744            Swiss writer (1920-2019)  +1920-11-17T00:00:00Z
# xx0173748                                     NaN  +1888-00-00T00:00:00Z
# mub20231208469                 American historian  +1957-09-11T00:00:00Z
# jk01102397      Czech collector of regional songs  +1924-02-02T00:00:00Z
# js20221152286                                 NaN  +1976-01-01T00:00:00Z
# xx0322810                                     NaN  +1969-00-00T00:00:00Z
# mzk2002173688                                 NaN  +1934-00-00T00:00:00Z
# jn20000720077                      Czech cardinal  +1769-12-21T00:00:00Z
# mub20231178654                                NaN                    NaN
#
#                        w_umrti_presne  w_narozeni  w_umrti  w_gender  \
# index
# xx0194560                         NaN         NaN      NaN  Q6581072
# mzk2004221744   +2019-03-04T00:00:00Z      1920.0   2019.0  Q6581097
# xx0173748       +1961-00-00T00:00:00Z      1888.0   1961.0       NaN
# mub20231208469                    NaN      1957.0      NaN  Q6581097
# jk01102397      +2012-12-10T00:00:00Z      1924.0   2012.0  Q6581097
# js20221152286                     NaN      1976.0      NaN  Q6581097
# xx0322810                         NaN      1969.0      NaN  Q6581097
# mzk2002173688                     NaN      1934.0      NaN  Q6581097
# jn20000720077   +1853-03-31T00:00:00Z      1769.0   1853.0  Q6581097
# mub20231178654                    NaN         NaN      NaN       NaN
#
#                obcanstvi w_misto_narozeni      w_misto_umrti  \
# index
# xx0194560            NaN              NaN                NaN
# mzk2004221744      [Q39]       [Q71, Q39]           [Q69401]
# xx0173748            NaN              NaN                NaN
# mub20231208469     [Q30]              NaN                NaN
# jk01102397        [Q213]        [Q750224]          [Q750224]
# js20221152286        NaN              NaN                NaN
# xx0322810            NaN              NaN                NaN
# mzk2002173688        NaN              NaN                NaN
# jn20000720077      [Q40]  [Q1741, Q94528]  [Q81137, Q158239]
# mub20231178654       NaN              NaN                NaN
#
#                                                           profese  \
# index
# xx0194560                                                [Q37226]
# mzk2004221744   [Q15985128, Q13570226, Q551835, Q4263842, Q162...
# xx0173748       [Q36834, Q639669, Q486748, Q49757, Q16145150, ...
# mub20231208469                                [Q201788, Q1622272]
# jk01102397      [Q14915627, Q17484288, Q21550382, Q37226, Q639...
# js20221152286                                  [Q201788, Q876864]
# xx0322810                                                     NaN
# mzk2002173688                                 [Q169470, Q1622272]
# jn20000720077               [Q250867, Q25393460, Q49476, Q611644]
# mub20231178654                                                NaN
#
#                                                              ceny  \
# index
# xx0194560                                                     NaN
# mzk2004221744   [Q2966818, Q628457, Q1730045, Q692949, Q621552...
# xx0173748                                                     NaN
# mub20231208469                                         [Q1316544]
# jk01102397                                                    NaN
# js20221152286                                                 NaN
# xx0322810                                                     NaN
# mzk2002173688                                                 NaN
# jn20000720077                                                 NaN
# mub20231178654                                                NaN
#
#                                                    jazykove_verze  \
# index
# xx0194560                                                      []
# mzk2004221744   [es, zh, ru, eu, ja, ro, sv, nl, fr, simple, p...
# xx0173748                                                      []
# mub20231208469                                                 []
# jk01102397                                       [fr, eo, ca, cs]
# js20221152286                                                [uk]
# xx0322810                                                      []
# mzk2002173688                                                  []
# jn20000720077                [no, pl, de, sl, it, fr, pt, cs, ru]
# mub20231178654                                                NaN
#
#                                                          popis_cs  \
# index
# xx0194560       učitelka jógy a meditace, textilní a oděvní na...
# mzk2004221744                        švýcarský literární teoretik
# xx0173748                      ruský hudební skladatel a hudebník
# mub20231208469                                                NaN
# jk01102397                          český sběratel lidových písní
# js20221152286   ukrajinský historik, pedagog a redaktor, zaměř...
# xx0322810                                                     NaN
# mzk2002173688         Narozen 1934. Fyzik, vysokoškolský pedagog.
# jn20000720077                                      český kardinál
# mub20231178654                                                NaN
#
#                                                           wiki_cs  \
# index
# xx0194560                                                     NaN
# mzk2004221744      https://cs.wikipedia.org/wiki/Jean_Starobinski
# xx0173748                                                     NaN
# mub20231208469                                                NaN
# jk01102397      https://cs.wikipedia.org/wiki/Josef_Re%C5%BEn%...
# js20221152286                                                 NaN
# xx0322810                                                     NaN
# mzk2002173688                                                 NaN
# jn20000720077   https://cs.wikipedia.org/wiki/Maxmili%C3%A1n_J...
# mub20231178654                                                NaN
#
#                                                        wiki_en druh_umrti  \
# index
# xx0194560                                                  NaN        NaN
# mzk2004221744   https://en.wikipedia.org/wiki/Jean_Starobinski        NaN
# xx0173748                                                  NaN        NaN
# mub20231208469                                             NaN        NaN
# jk01102397                                                 NaN        NaN
# js20221152286                                              NaN        NaN
# xx0322810                                                  NaN        NaN
# mzk2002173688                                              NaN        NaN
# jn20000720077                                              NaN        NaN
# mub20231178654                                             NaN        NaN
#
#                pricina_umrti vezeni strany               skoly manzelstvo  \
# index
# xx0194560                NaN    NaN    NaN                 NaN        NaN
# mzk2004221744            NaN    NaN    NaN  [Q503473, Q672022]        NaN
# xx0173748                NaN    NaN    NaN                 NaN        NaN
# mub20231208469           NaN    NaN    NaN                 NaN        NaN
# jk01102397               NaN    NaN    NaN                 NaN        NaN
# js20221152286            NaN    NaN    NaN            [Q80207]        NaN
# xx0322810                NaN    NaN    NaN                 NaN        NaN
# mzk2002173688            NaN    NaN    NaN                 NaN        NaN
# jn20000720077            NaN    NaN    NaN                 NaN        NaN
# mub20231178654           NaN    NaN    NaN                 NaN        NaN
#
#                partnerstvo    potomstvo sourozenectvo facebook twitter  \
# index
# xx0194560              NaN          NaN           NaN      NaN     NaN
# mzk2004221744          NaN  [Q24929766]           NaN      NaN     NaN
# xx0173748              NaN          NaN           NaN      NaN     NaN
# mub20231208469         NaN          NaN           NaN      NaN     NaN
# jk01102397             NaN          NaN           NaN      NaN     NaN
# js20221152286          NaN          NaN           NaN      NaN     NaN
# xx0322810              NaN          NaN           NaN      NaN     NaN
# mzk2002173688          NaN          NaN           NaN      NaN     NaN
# jn20000720077          NaN          NaN           NaN      NaN     NaN
# mub20231178654         NaN          NaN           NaN      NaN     NaN
#
#                instagram  web udalosti role
# index
# xx0194560            NaN  NaN      NaN  NaN
# mzk2004221744        NaN  NaN      NaN  NaN
# xx0173748            NaN  NaN      NaN  NaN
# mub20231208469       NaN  NaN      NaN  NaN
# jk01102397           NaN  NaN      NaN  NaN
# js20221152286        NaN  NaN      NaN  NaN
# xx0322810            NaN  NaN      NaN  NaN
# mzk2002173688        NaN  NaN      NaN  NaN
# jn20000720077        NaN  NaN      NaN  NaN
# mub20231178654       NaN  NaN      NaN  NaN

# %%
df.to_json(os.path.join('data_raw','wikidata_raw.json'))

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131714 entries, jk01010005 to zmp20211116840
# Data columns (total 33 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   024_a              131714 non-null  object
#  1   label_cs           130825 non-null  object
#  2   label_en           122117 non-null  object
#  3   popis_en           72022 non-null   object
#  4   w_narozeni_presne  114494 non-null  object
#  5   w_umrti_presne     56114 non-null   object
#  6   w_narozeni         114494 non-null  float64
#  7   w_umrti            56114 non-null   float64
#  8   w_gender           124138 non-null  object
#  9   obcanstvi          66677 non-null   object
#  10  w_misto_narozeni   85966 non-null   object
#  11  w_misto_umrti      42774 non-null   object
#  12  profese            112734 non-null  object
#  13  ceny               21956 non-null   object
#  14  jazykove_verze     131371 non-null  object
#  15  popis_cs           91938 non-null   object
#  16  wiki_cs            24687 non-null   object
#  17  wiki_en            32583 non-null   object
#  18  druh_umrti         3291 non-null    object
#  19  pricina_umrti      3967 non-null    object
#  20  vezeni             1004 non-null    object
#  21  strany             5624 non-null    object
#  22  skoly              37724 non-null   object
#  23  manzelstvo         7686 non-null    object
#  24  partnerstvo        748 non-null     object
#  25  potomstvo          6269 non-null    object
#  26  sourozenectvo      4543 non-null    object
#  27  facebook           2788 non-null    object
#  28  twitter            3511 non-null    object
#  29  instagram          1463 non-null    object
#  30  web                8997 non-null    object
#  31  udalosti           1189 non-null    object
#  32  role               1488 non-null    object
# dtypes: float64(2), object(31)
# memory usage: 228.3 MB

# %%
df.columns
# Out:
# Index(['024_a', 'label_cs', 'label_en', 'popis_en', 'w_narozeni_presne',
#        'w_umrti_presne', 'w_narozeni', 'w_umrti', 'w_gender', 'obcanstvi',
#        'w_misto_narozeni', 'w_misto_umrti', 'profese', 'ceny',
#        'jazykove_verze', 'popis_cs', 'wiki_cs', 'wiki_en', 'druh_umrti',
#        'pricina_umrti', 'vezeni', 'strany', 'skoly', 'manzelstvo',
#        'partnerstvo', 'potomstvo', 'sourozenectvo', 'facebook', 'twitter',
#        'instagram', 'web', 'udalosti', 'role'],
#       dtype='object')

# %%
for sloupec in df.columns.to_list():
    print(f"{sloupec}: {int(len(df[df[sloupec].notnull()])/len(df)*100)} %")
# Out:
# 024_a: 100 %
# label_cs: 99 %
# label_en: 92 %
# popis_en: 54 %
# w_narozeni_presne: 86 %
# w_umrti_presne: 42 %
# w_narozeni: 86 %
# w_umrti: 42 %
# w_gender: 94 %
# obcanstvi: 50 %
# w_misto_narozeni: 65 %
# w_misto_umrti: 32 %
# profese: 85 %
# ceny: 16 %
# jazykove_verze: 99 %
# popis_cs: 69 %
# wiki_cs: 18 %
# wiki_en: 24 %
# druh_umrti: 2 %
# pricina_umrti: 3 %
# vezeni: 0 %
# strany: 4 %
# skoly: 28 %
# manzelstvo: 5 %
# partnerstvo: 0 %
# potomstvo: 4 %
# sourozenectvo: 3 %
# facebook: 2 %
# twitter: 2 %
# instagram: 1 %
# web: 6 %
# udalosti: 0 %
# role: 1 %
