# %%
# %%time
import pandas as pd
# Out:
# CPU times: total: 438 ms
# Wall time: 599 ms

# %%
# %%time
import polars as pl
# Out:
# CPU times: total: 78.1 ms
# Wall time: 111 ms

# %%
# %%time
import duckdb
# Out:
# CPU times: total: 78.1 ms
# Wall time: 113 ms

# %%
# %%time
df = pd.read_parquet("data/cnb_vyber.parquet")
df[df['245_a'].str.contains('Jeseník',na=False)]
# Out:
# CPU times: total: 27.7 s
# Wall time: 25.5 s
#                                                 008            020_a  \
# 001
# bk192805549  991006s1928    xr                  cze             None
# bk192904680  991116s1928    xr abf        000 | cze             None
# bk193100657  990721s1931    xr            ||| | cze             None
# bk193601339  990125s1936    xr                  cze             None
# bk193801483  990313s1938    xr                  cze             None
# ...                                             ...              ...
# np9318043    940418s1992    xr a     s   u0|0 0 cze             None
# np9329324    950206s1984    xr a         |0|0 0 cze             None
# np9433388    950103s1994    xr a         u0|0 0 cze  [80-901205-0-4]
# np9539658    950330s1995    xr a   e      000 0 cze  [80-85083-10-8]
# vsI/161133   930504s1971    xr a         |0|0 0 cze             None
#
#                    020_c                     020_q  041_a 041_h 041_ind1  \
# 001
# ...

# %%
# %%time
df = pl.read_parquet("data/cnb_vyber.parquet")
df.filter(pl.col('245_a').str.contains('Jeseník'))
# Out:
# CPU times: total: 9.47 s
# Wall time: 1.51 s
# shape: (203, 62)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ 008          ┆ 020_a        ┆ 020_c        ┆ 020_q       ┆ … ┆ 928_a       ┆ 964_a       ┆ leader      ┆ 001         │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ ---         │
# │ str          ┆ list[str]    ┆ list[str]    ┆ list[str]   ┆   ┆ list[str]   ┆ list[str]   ┆ str         ┆ str         │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 991006s1928  ┆ null         ┆ null         ┆ null        ┆ … ┆ null        ┆ null        ┆ nam a22     ┆ bk192805549 │
# │ xr           ┆              ┆              ┆             ┆   ┆             ┆             ┆ 1  4500     ┆             │
# ...

# %%
# %%time
query = """
SELECT *
FROM read_parquet('data/cnb_vyber.parquet')
WHERE "245_a" LIKE '%Jeseník%'
"""

df = duckdb.sql(query)
print(df)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ...

# %%
# %%time
import lancedb
# Out:
# CPU times: total: 1.12 s
# Wall time: 1.64 s

# %%
pip uninstall lancedb
